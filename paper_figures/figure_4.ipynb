# %% [markdown]
# # Figure 4 (Robustness Analysis)

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Replace with the path to where you store data
DATA_PATH = "../../cnt-data/"

RNS_SYNCHRONY_PATH = os.path.join(DATA_PATH, "synchrony/all/robustness/rns_full")
FULL_SYNCHRONY_PATH = os.path.join(DATA_PATH, "synchrony/all/broadband")

# %% [markdown]
# ## Figure 4 (B)

# %%
rns_hup_id = 143

# %%
rns_synchrony = np.load(os.path.join(RNS_SYNCHRONY_PATH, f"HUP_{rns_hup_id}_rns.npy"))

# %%
full_synchrony = np.load(os.path.join(FULL_SYNCHRONY_PATH, f"HUP_{rns_hup_id}.npy"))

# %%
# Plot rns_synchrony and full_synchrony in a single plot
plt.figure(figsize=(6, 3))

plt.plot(rns_synchrony[1000:1300], label="RNS Co-Located Synchrony")
plt.plot(full_synchrony[1000:1300], label="Full Synchrony")

plt.xlabel("Time (s)")
plt.ylabel("Synchrony")
plt.title(f"RNS Co-Located Synchrony vs Full Synchrony for HUP {rns_hup_id}")

# Add a legend outside
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()
