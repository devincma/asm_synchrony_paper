# %% [markdown]
# # Causality & Correlation Analysis

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import grangercausalitytests
import numpy as np
import pandas as pd
import os

TABLES_DIRECTORY = "../../Data/giant_tables"

# %%
patient_hup_ids = []
# Iterate through all files in TABLES_DIRECTORY
for filename in os.listdir(TABLES_DIRECTORY):
    # Only look at filename that are .csv files and does not begin with .
    if filename.endswith(".csv") and not filename.startswith("."):
        # Get the patient_hup_id from the filename which is after _ and before .
        patient_hup_id = filename.split("_")[1].split(".")[0]
        patient_hup_ids.append(patient_hup_id)

patient_hup_ids = sorted(patient_hup_ids)
len(patient_hup_ids)
# Out:
# 62

# %% [markdown]
# ## Do interictal spikes drive phase synchronization?

# %%
for patient_hup_id in patient_hup_ids:
    # Read in the giant table for this patient
    hourly_patient_features_df = pd.read_csv(
        os.path.join(TABLES_DIRECTORY, f"HUP_{patient_hup_id}.csv")
    )

    # Assuming you already have the dataframe hourly_patient_features_df
    df = hourly_patient_features_df[["spikes_avg_all", "kuramoto"]]

    # It's recommended to handle missing values and make the series stationary
    # (via differencing or some other method) before the Granger test
    df = df.dropna()
    df = df.diff().dropna()

    # Perform the Granger Causality test
    # maxlag is the maximum lag that you would like the test to check
    granger_test_result = grangercausalitytests(df, maxlag=10)

    # Print the test results
    for lag, test_result in granger_test_result.items():
        print(f"Lag: {lag}")
        for test_name, result in test_result[0].items():
            t_statistic, p_value = result[0], result[1]
            print(f"{test_name} Test statistic value: {t_statistic}")
            print(f"{test_name} p-value: {p_value}\n")
            if p_value < 0.05:
                print(f"Null hypothesis rejected for {test_name} test")
                break
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.8674  , p=0.0098  , df_denom=127, df_num=1
# ssr based chi2 test:   chi2=7.0296  , p=0.0080  , df=1
# likelihood ratio test: chi2=6.8462  , p=0.0089  , df=1
# parameter F test:         F=6.8674  , p=0.0098  , df_denom=127, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3811  , p=0.2551  , df_denom=124, df_num=2
# ssr based chi2 test:   chi2=2.8736  , p=0.2377  , df=2
# likelihood ratio test: chi2=2.8421  , p=0.2415  , df=2
# parameter F test:         F=1.3811  , p=0.2551  , df_denom=124, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8200  , p=0.4852  , df_denom=121, df_num=3
# ssr based chi2 test:   chi2=2.6025  , p=0.4571  , df=3
# likelihood ratio test: chi2=2.5764  , p=0.4616  , df=3
# parameter F test:         F=0.8200  , p=0.4852  , df_denom=121, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1038  , p=0.3581  , df_denom=118, df_num=4
# ssr based chi2 test:   chi2=4.7518  , p=0.3137  , df=4
# likelihood ratio test: chi2=4.6651  , p=0.3234  , df=4
# parameter F test:         F=1.1038  , p=0.3581  , df_denom=118, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9332  , p=0.4623  , df_denom=115, df_num=5
# ssr based chi2 test:   chi2=5.1125  , p=0.4023  , df=5
# likelihood ratio test: chi2=5.0115  , p=0.4145  , df=5
# parameter F test:         F=0.9332  , p=0.4623  , df_denom=115, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7979  , p=0.5735  , df_denom=112, df_num=6
# ssr based chi2 test:   chi2=5.3428  , p=0.5007  , df=6
# likelihood ratio test: chi2=5.2318  , p=0.5144  , df=6
# parameter F test:         F=0.7979  , p=0.5735  , df_denom=112, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6261  , p=0.7334  , df_denom=109, df_num=7
# ssr based chi2 test:   chi2=4.9855  , p=0.6617  , df=7
# likelihood ratio test: chi2=4.8879  , p=0.6736  , df=7
# parameter F test:         F=0.6261  , p=0.7334  , df_denom=109, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5826  , p=0.7902  , df_denom=106, df_num=8
# ssr based chi2 test:   chi2=5.4083  , p=0.7132  , df=8
# likelihood ratio test: chi2=5.2928  , p=0.7259  , df=8
# parameter F test:         F=0.5826  , p=0.7902  , df_denom=106, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5530  , p=0.8323  , df_denom=103, df_num=9
# ssr based chi2 test:   chi2=5.8948  , p=0.7504  , df=9
# likelihood ratio test: chi2=5.7568  , p=0.7640  , df=9
# parameter F test:         F=0.5530  , p=0.8323  , df_denom=103, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4966  , p=0.8887  , df_denom=100, df_num=10
# ssr based chi2 test:   chi2=6.0083  , p=0.8146  , df=10
# likelihood ratio test: chi2=5.8639  , p=0.8266  , df=10
# parameter F test:         F=0.4966  , p=0.8887  , df_denom=100, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 6.867414991517525
# ssr_ftest p-value: 0.009848978146702127
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 2
# ssr_ftest Test statistic value: 1.3811311162888344
# ssr_ftest p-value: 0.25513242124051827
#
# ssr_chi2test Test statistic value: 2.873643774213865
# ssr_chi2test p-value: 0.23768193964804663
#
# lrtest Test statistic value: 2.842104217456665
# lrtest p-value: 0.24145984120377778
#
# params_ftest Test statistic value: 1.381131116288857
# params_ftest p-value: 0.25513242124051266
#
# Lag: 3
# ssr_ftest Test statistic value: 0.8200495736921039
# ssr_ftest p-value: 0.48522366994139343
#
# ssr_chi2test Test statistic value: 2.602471374361718
# ssr_chi2test p-value: 0.4570564477551561
#
# lrtest Test statistic value: 2.576368125143233
# lrtest p-value: 0.46164759002913436
#
# params_ftest Test statistic value: 0.8200495736921055
# params_ftest p-value: 0.4852236699413911
#
# Lag: 4
# ssr_ftest Test statistic value: 1.1037641748961953
# ssr_ftest p-value: 0.3581272534482976
#
# ssr_chi2test Test statistic value: 4.7517983122649765
# ssr_chi2test p-value: 0.3137253207297048
#
# lrtest Test statistic value: 4.66505928793282
# lrtest p-value: 0.32342178376675984
#
# params_ftest Test statistic value: 1.103764174896197
# params_ftest p-value: 0.3581272534482962
#
# Lag: 5
# ssr_ftest Test statistic value: 0.9332336232922206
# ssr_ftest p-value: 0.4622681807805281
#
# ssr_chi2test Test statistic value: 5.112497240644339
# ssr_chi2test p-value: 0.4023058412970178
#
# lrtest Test statistic value: 5.01149946660729
# lrtest p-value: 0.4144783890594467
#
# params_ftest Test statistic value: 0.933233623292223
# params_ftest p-value: 0.4622681807805281
#
# Lag: 6
# ssr_ftest Test statistic value: 0.797864564470607
# ssr_ftest p-value: 0.5735499800004066
#
# ssr_chi2test Test statistic value: 5.342843065651387
# ssr_chi2test p-value: 0.5006509241741439
#
# lrtest Test statistic value: 5.231812006406642
# lrtest p-value: 0.5144438273926748
#
# params_ftest Test statistic value: 0.7978645644706038
# params_ftest p-value: 0.5735499800004102
#
# Lag: 7
# ssr_ftest Test statistic value: 0.6260653816306202
# ssr_ftest p-value: 0.7334158834666208
#
# ssr_chi2test Test statistic value: 4.985548176654848
# ssr_chi2test p-value: 0.6617269460533518
#
# lrtest Test statistic value: 4.887931552471457
# lrtest p-value: 0.6736373386551294
#
# params_ftest Test statistic value: 0.6260653816306228
# params_ftest p-value: 0.7334158834666193
#
# Lag: 8
# ssr_ftest Test statistic value: 0.5826066943950096
# ssr_ftest p-value: 0.7902466715884864
#
# ssr_chi2test Test statistic value: 5.408348936648013
# ssr_chi2test p-value: 0.7131716278776532
#
# lrtest Test statistic value: 5.292819966798504
# lrtest p-value: 0.7258695970046711
#
# params_ftest Test statistic value: 0.5826066943950082
# params_ftest p-value: 0.7902466715884892
#
# Lag: 9
# ssr_ftest Test statistic value: 0.5529699796343238
# ssr_ftest p-value: 0.8322708856250673
#
# ssr_chi2test Test statistic value: 5.894767355713471
# ssr_chi2test p-value: 0.7504025062350459
#
# lrtest Test statistic value: 5.7567836242736234
# lrtest p-value: 0.7639920116908316
#
# params_ftest Test statistic value: 0.5529699796343257
# params_ftest p-value: 0.8322708856250652
#
# Lag: 10
# ssr_ftest Test statistic value: 0.49655090569482385
# ssr_ftest p-value: 0.8886682942103352
#
# ssr_chi2test Test statistic value: 6.008265958907368
# ssr_chi2test p-value: 0.8145682966703736
#
# lrtest Test statistic value: 5.86385662916706
# lrtest p-value: 0.8265687257780527
#
# params_ftest Test statistic value: 0.49655090569482097
# params_ftest p-value: 0.8886682942103369
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.4133  , p=0.0668  , df_denom=137, df_num=1
# ssr based chi2 test:   chi2=3.4880  , p=0.0618  , df=1
# likelihood ratio test: chi2=3.4453  , p=0.0634  , df=1
# parameter F test:         F=3.4133  , p=0.0668  , df_denom=137, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4641  , p=0.2350  , df_denom=134, df_num=2
# ssr based chi2 test:   chi2=3.0375  , p=0.2190  , df=2
# likelihood ratio test: chi2=3.0048  , p=0.2226  , df=2
# parameter F test:         F=1.4641  , p=0.2350  , df_denom=134, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0466  , p=0.3743  , df_denom=131, df_num=3
# ssr based chi2 test:   chi2=3.3075  , p=0.3466  , df=3
# likelihood ratio test: chi2=3.2685  , p=0.3521  , df=3
# parameter F test:         F=1.0466  , p=0.3743  , df_denom=131, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7717  , p=0.5455  , df_denom=128, df_num=4
# ssr based chi2 test:   chi2=3.3039  , p=0.5083  , df=4
# likelihood ratio test: chi2=3.2647  , p=0.5145  , df=4
# parameter F test:         F=0.7717  , p=0.5455  , df_denom=128, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2203  , p=0.3035  , df_denom=125, df_num=5
# ssr based chi2 test:   chi2=6.6386  , p=0.2489  , df=5
# likelihood ratio test: chi2=6.4816  , p=0.2621  , df=5
# parameter F test:         F=1.2203  , p=0.3035  , df_denom=125, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.5433  , p=0.0235  , df_denom=122, df_num=6
# ssr based chi2 test:   chi2=16.8857 , p=0.0097  , df=6
# likelihood ratio test: chi2=15.9103 , p=0.0142  , df=6
# parameter F test:         F=2.5433  , p=0.0235  , df_denom=122, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2999  , p=0.0311  , df_denom=119, df_num=7
# ssr based chi2 test:   chi2=18.1287 , p=0.0114  , df=7
# likelihood ratio test: chi2=17.0028 , p=0.0174  , df=7
# parameter F test:         F=2.2999  , p=0.0311  , df_denom=119, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0920  , p=0.0419  , df_denom=116, df_num=8
# ssr based chi2 test:   chi2=19.1886 , p=0.0139  , df=8
# likelihood ratio test: chi2=17.9246 , p=0.0218  , df=8
# parameter F test:         F=2.0920  , p=0.0419  , df_denom=116, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7420  , p=0.0875  , df_denom=113, df_num=9
# ssr based chi2 test:   chi2=18.3139 , p=0.0317  , df=9
# likelihood ratio test: chi2=17.1500 , p=0.0464  , df=9
# parameter F test:         F=1.7420  , p=0.0875  , df_denom=113, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4721  , p=0.1594  , df_denom=110, df_num=10
# ssr based chi2 test:   chi2=17.5316 , p=0.0634  , df=10
# likelihood ratio test: chi2=16.4536 , p=0.0874  , df=10
# parameter F test:         F=1.4721  , p=0.1594  , df_denom=110, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 3.413276254559518
# ssr_ftest p-value: 0.06683081698020771
#
# ssr_chi2test Test statistic value: 3.4880195302068064
# ssr_chi2test p-value: 0.061814494066451287
#
# lrtest Test statistic value: 3.4452770114993427
# lrtest p-value: 0.06343278751182008
#
# params_ftest Test statistic value: 3.4132762545595106
# params_ftest p-value: 0.06683081698020771
#
# Lag: 2
# ssr_ftest Test statistic value: 1.4641232013935574
# ssr_ftest p-value: 0.2349564583077038
#
# ssr_chi2test Test statistic value: 3.0375093282642456
# ssr_chi2test p-value: 0.21898442637610485
#
# lrtest Test statistic value: 3.0047963305448775
# lrtest p-value: 0.22259569826723918
#
# params_ftest Test statistic value: 1.4641232013935763
# params_ftest p-value: 0.23495645830770007
#
# Lag: 3
# ssr_ftest Test statistic value: 1.046565366697413
# ssr_ftest p-value: 0.3743146409819791
#
# ssr_chi2test Test statistic value: 3.307466120707855
# ssr_chi2test p-value: 0.3466048508527797
#
# lrtest Test statistic value: 3.268452985663771
# lrtest p-value: 0.35205759179461155
#
# params_ftest Test statistic value: 1.0465653666974242
# params_ftest p-value: 0.37431464098197664
#
# Lag: 4
# ssr_ftest Test statistic value: 0.7717180324116534
# ssr_ftest p-value: 0.5455307828984435
#
# ssr_chi2test Test statistic value: 3.3039178262623907
# ssr_chi2test p-value: 0.5083117524464124
#
# lrtest Test statistic value: 3.26470801695325
# lrtest p-value: 0.5145433337097631
#
# params_ftest Test statistic value: 0.7717180324116554
# params_ftest p-value: 0.5455307828984435
#
# Lag: 5
# ssr_ftest Test statistic value: 1.2203226813197419
# ssr_ftest p-value: 0.30348026511697174
#
# ssr_chi2test Test statistic value: 6.638555386379396
# ssr_chi2test p-value: 0.2489385746327431
#
# lrtest Test statistic value: 6.481618570623596
# lrtest p-value: 0.26213300157650926
#
# params_ftest Test statistic value: 1.2203226813197419
# params_ftest p-value: 0.30348026511697174
#
# Lag: 6
# ssr_ftest Test statistic value: 2.543284879052735
# ssr_ftest p-value: 0.02351430005357363
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 7
# ssr_ftest Test statistic value: 2.2999038357431627
# ssr_ftest p-value: 0.031072601688963943
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 8
# ssr_ftest Test statistic value: 2.0919942789717583
# ssr_ftest p-value: 0.04194626694843929
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 9
# ssr_ftest Test statistic value: 1.7419799521131232
# ssr_ftest p-value: 0.0874891279319007
#
# ssr_chi2test Test statistic value: 18.313913124870712
# ssr_chi2test p-value: 0.03170139906858258
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 10
# ssr_ftest Test statistic value: 1.4721163446928407
# ssr_ftest p-value: 0.15936839798520286
#
# ssr_chi2test Test statistic value: 17.53156737770565
# ssr_chi2test p-value: 0.0633985820217482
#
# lrtest Test statistic value: 16.453624547408594
# lrtest p-value: 0.08736243609393282
#
# params_ftest Test statistic value: 1.4721163446928385
# params_ftest p-value: 0.15936839798520336
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0139  , p=0.9063  , df_denom=127, df_num=1
# ssr based chi2 test:   chi2=0.0143  , p=0.9050  , df=1
# likelihood ratio test: chi2=0.0143  , p=0.9050  , df=1
# parameter F test:         F=0.0139  , p=0.9063  , df_denom=127, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1080  , p=0.8978  , df_denom=124, df_num=2
# ssr based chi2 test:   chi2=0.2246  , p=0.8938  , df=2
# likelihood ratio test: chi2=0.2244  , p=0.8939  , df=2
# parameter F test:         F=0.1080  , p=0.8978  , df_denom=124, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2407  , p=0.8678  , df_denom=121, df_num=3
# ssr based chi2 test:   chi2=0.7640  , p=0.8581  , df=3
# likelihood ratio test: chi2=0.7617  , p=0.8586  , df=3
# parameter F test:         F=0.2407  , p=0.8678  , df_denom=121, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8814  , p=0.1182  , df_denom=118, df_num=4
# ssr based chi2 test:   chi2=8.0996  , p=0.0880  , df=4
# likelihood ratio test: chi2=7.8518  , p=0.0972  , df=4
# parameter F test:         F=1.8814  , p=0.1182  , df_denom=118, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2414  , p=0.2944  , df_denom=115, df_num=5
# ssr based chi2 test:   chi2=6.8006  , p=0.2359  , df=5
# likelihood ratio test: chi2=6.6234  , p=0.2502  , df=5
# parameter F test:         F=1.2414  , p=0.2944  , df_denom=115, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1474  , p=0.3398  , df_denom=112, df_num=6
# ssr based chi2 test:   chi2=7.6833  , p=0.2622  , df=6
# likelihood ratio test: chi2=7.4564  , p=0.2807  , df=6
# parameter F test:         F=1.1474  , p=0.3398  , df_denom=112, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1698  , p=0.3261  , df_denom=109, df_num=7
# ssr based chi2 test:   chi2=9.3152  , p=0.2308  , df=7
# likelihood ratio test: chi2=8.9819  , p=0.2540  , df=7
# parameter F test:         F=1.1698  , p=0.3261  , df_denom=109, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1021  , p=0.3677  , df_denom=106, df_num=8
# ssr based chi2 test:   chi2=10.2311 , p=0.2492  , df=8
# likelihood ratio test: chi2=9.8278  , p=0.2773  , df=8
# parameter F test:         F=1.1021  , p=0.3677  , df_denom=106, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1178  , p=0.3570  , df_denom=103, df_num=9
# ssr based chi2 test:   chi2=11.9163 , p=0.2181  , df=9
# likelihood ratio test: chi2=11.3697 , p=0.2512  , df=9
# parameter F test:         F=1.1178  , p=0.3570  , df_denom=103, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0525  , p=0.4061  , df_denom=100, df_num=10
# ssr based chi2 test:   chi2=12.7354 , p=0.2388  , df=10
# likelihood ratio test: chi2=12.1088 , p=0.2778  , df=10
# parameter F test:         F=1.0525  , p=0.4061  , df_denom=100, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.013923081376486098
# ssr_ftest p-value: 0.9062571609506023
#
# ssr_chi2test Test statistic value: 0.014251973062544825
# ssr_chi2test p-value: 0.9049730160653989
#
# lrtest Test statistic value: 0.014251191893663417
# lrtest p-value: 0.9049756080281929
#
# params_ftest Test statistic value: 0.01392308137645394
# params_ftest p-value: 0.9062571609507439
#
# Lag: 2
# ssr_ftest Test statistic value: 0.10795541813435443
# ssr_ftest p-value: 0.8977518903549373
#
# ssr_chi2test Test statistic value: 0.2246169183763181
# ssr_chi2test p-value: 0.8937685238629837
#
# lrtest Test statistic value: 0.22442159174732978
# lrtest p-value: 0.8938558165219905
#
# params_ftest Test statistic value: 0.10795541813434584
# params_ftest p-value: 0.8977518903549435
#
# Lag: 3
# ssr_ftest Test statistic value: 0.24073071913773098
# ssr_ftest p-value: 0.8677790699660964
#
# ssr_chi2test Test statistic value: 0.7639718689990801
# ssr_chi2test p-value: 0.8580636276646183
#
# lrtest Test statistic value: 0.7617010057336131
# lrtest p-value: 0.8586039698312399
#
# params_ftest Test statistic value: 0.24073071913772529
# params_ftest p-value: 0.8677790699660997
#
# Lag: 4
# ssr_ftest Test statistic value: 1.8814135201708129
# ssr_ftest p-value: 0.11819864649906393
#
# ssr_chi2test Test statistic value: 8.099644646159094
# ssr_chi2test p-value: 0.08799552976142391
#
# lrtest Test statistic value: 7.851842081628774
# lrtest p-value: 0.09715867907372998
#
# params_ftest Test statistic value: 1.8814135201708213
# params_ftest p-value: 0.11819864649906264
#
# Lag: 5
# ssr_ftest Test statistic value: 1.2413822631487554
# ssr_ftest p-value: 0.29440445944126276
#
# ssr_chi2test Test statistic value: 6.800615876380138
# ssr_chi2test p-value: 0.2358960750485116
#
# lrtest Test statistic value: 6.623437930634225
# lrtest p-value: 0.2501851922796244
#
# params_ftest Test statistic value: 1.2413822631487554
# params_ftest p-value: 0.29440445944126276
#
# Lag: 6
# ssr_ftest Test statistic value: 1.147373321470414
# ssr_ftest p-value: 0.33983963035406506
#
# ssr_chi2test Test statistic value: 7.6833034919893795
# ssr_chi2test p-value: 0.26223540915431315
#
# lrtest Test statistic value: 7.45642183220653
# lrtest p-value: 0.2806898072470783
#
# params_ftest Test statistic value: 1.1473733214704083
# params_ftest p-value: 0.3398396303540658
#
# Lag: 7
# ssr_ftest Test statistic value: 1.1697683620735655
# ssr_ftest p-value: 0.32609894696375946
#
# ssr_chi2test Test statistic value: 9.315219617246376
# ssr_chi2test p-value: 0.23080980642342663
#
# lrtest Test statistic value: 8.981919011182953
# lrtest p-value: 0.25395679743164673
#
# params_ftest Test statistic value: 1.1697683620735673
# params_ftest p-value: 0.32609894696375846
#
# Lag: 8
# ssr_ftest Test statistic value: 1.1021318973284193
# ssr_ftest p-value: 0.3677212182142189
#
# ssr_chi2test Test statistic value: 10.231111197841175
# ssr_chi2test p-value: 0.24917823706058945
#
# lrtest Test statistic value: 9.82781599054698
# lrtest p-value: 0.27731962615678557
#
# params_ftest Test statistic value: 1.1021318973284193
# params_ftest p-value: 0.3677212182142189
#
# Lag: 9
# ssr_ftest Test statistic value: 1.1178327358022726
# ssr_ftest p-value: 0.35701488846131085
#
# ssr_chi2test Test statistic value: 11.91631401855238
# ssr_chi2test p-value: 0.21806835109431308
#
# lrtest Test statistic value: 11.369672620480827
# lrtest p-value: 0.251218149273627
#
# params_ftest Test statistic value: 1.1178327358022733
# params_ftest p-value: 0.35701488846131085
#
# Lag: 10
# ssr_ftest Test statistic value: 1.052513654624956
# ssr_ftest p-value: 0.4060959291032633
#
# ssr_chi2test Test statistic value: 12.73541522096197
# ssr_chi2test p-value: 0.2388435738040298
#
# lrtest Test statistic value: 12.108807487949576
# lrtest p-value: 0.27784044017019693
#
# params_ftest Test statistic value: 1.0525136546249556
# params_ftest p-value: 0.4060959291032633
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0039  , p=0.9500  , df_denom=301, df_num=1
# ssr based chi2 test:   chi2=0.0040  , p=0.9497  , df=1
# likelihood ratio test: chi2=0.0040  , p=0.9497  , df=1
# parameter F test:         F=0.0039  , p=0.9500  , df_denom=301, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2405  , p=0.7864  , df_denom=298, df_num=2
# ssr based chi2 test:   chi2=0.4890  , p=0.7831  , df=2
# likelihood ratio test: chi2=0.4886  , p=0.7832  , df=2
# parameter F test:         F=0.2405  , p=0.7864  , df_denom=298, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2186  , p=0.8835  , df_denom=295, df_num=3
# ssr based chi2 test:   chi2=0.6714  , p=0.8799  , df=3
# likelihood ratio test: chi2=0.6706  , p=0.8801  , df=3
# parameter F test:         F=0.2186  , p=0.8835  , df_denom=295, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1295  , p=0.9716  , df_denom=292, df_num=4
# ssr based chi2 test:   chi2=0.5339  , p=0.9701  , df=4
# likelihood ratio test: chi2=0.5334  , p=0.9702  , df=4
# parameter F test:         F=0.1295  , p=0.9716  , df_denom=292, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2080  , p=0.9590  , df_denom=289, df_num=5
# ssr based chi2 test:   chi2=1.0798  , p=0.9559  , df=5
# likelihood ratio test: chi2=1.0778  , p=0.9560  , df=5
# parameter F test:         F=0.2080  , p=0.9590  , df_denom=289, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2312  , p=0.9663  , df_denom=286, df_num=6
# ssr based chi2 test:   chi2=1.4501  , p=0.9627  , df=6
# likelihood ratio test: chi2=1.4466  , p=0.9630  , df=6
# parameter F test:         F=0.2312  , p=0.9663  , df_denom=286, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1586  , p=0.9927  , df_denom=283, df_num=7
# ssr based chi2 test:   chi2=1.1691  , p=0.9916  , df=7
# likelihood ratio test: chi2=1.1668  , p=0.9917  , df=7
# parameter F test:         F=0.1586  , p=0.9927  , df_denom=283, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2395  , p=0.9831  , df_denom=280, df_num=8
# ssr based chi2 test:   chi2=2.0319  , p=0.9800  , df=8
# likelihood ratio test: chi2=2.0250  , p=0.9802  , df=8
# parameter F test:         F=0.2395  , p=0.9831  , df_denom=280, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.2878  , p=0.9777  , df_denom=277, df_num=9
# ssr based chi2 test:   chi2=2.7683  , p=0.9728  , df=9
# likelihood ratio test: chi2=2.7554  , p=0.9732  , df=9
# parameter F test:         F=0.2878  , p=0.9777  , df_denom=277, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4584  , p=0.9156  , df_denom=274, df_num=10
# ssr based chi2 test:   chi2=4.9349  , p=0.8955  , df=10
# likelihood ratio test: chi2=4.8941  , p=0.8981  , df=10
# parameter F test:         F=0.4584  , p=0.9156  , df_denom=274, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.003937876227540508
# ssr_ftest p-value: 0.9500052409381079
#
# ssr_chi2test Test statistic value: 0.0039771241633631705
# ssr_chi2test p-value: 0.9497151870750034
#
# lrtest Test statistic value: 0.00397709814785685
# lrtest p-value: 0.9497153513210274
#
# params_ftest Test statistic value: 0.00393787622748356
# params_ftest p-value: 0.9500052409385316
#
# Lag: 2
# ssr_ftest Test statistic value: 0.24048660764308355
# ssr_ftest p-value: 0.7863976149452266
#
# ssr_chi2test Test statistic value: 0.4890432356768746
# ssr_chi2test p-value: 0.7830790597057886
#
# lrtest Test statistic value: 0.48864900092917196
# lrtest p-value: 0.7832334334079252
#
# params_ftest Test statistic value: 0.24048660764309712
# params_ftest p-value: 0.7863976149452137
#
# Lag: 3
# ssr_ftest Test statistic value: 0.21860946077984475
# ssr_ftest p-value: 0.8834524101493966
#
# ssr_chi2test Test statistic value: 0.6713904117509808
# ssr_chi2test p-value: 0.8799116769078148
#
# lrtest Test statistic value: 0.6706452161898824
# lrtest p-value: 0.8800857925033115
#
# params_ftest Test statistic value: 0.21860946077983925
# params_ftest p-value: 0.8834524101493966
#
# Lag: 4
# ssr_ftest Test statistic value: 0.1294856927356035
# ssr_ftest p-value: 0.9715998475994881
#
# ssr_chi2test Test statistic value: 0.5339067604577624
# ssr_chi2test p-value: 0.9701173116361005
#
# lrtest Test statistic value: 0.5334338039921249
# lrtest p-value: 0.9701656341098919
#
# params_ftest Test statistic value: 0.1294856927356058
# params_ftest p-value: 0.9715998475994881
#
# Lag: 5
# ssr_ftest Test statistic value: 0.2080355224486255
# ssr_ftest p-value: 0.9589657214627063
#
# ssr_chi2test Test statistic value: 1.0797691476572258
# ssr_chi2test p-value: 0.9558787017726031
#
# lrtest Test statistic value: 1.0778306286954376
# lrtest p-value: 0.956047128787183
#
# params_ftest Test statistic value: 0.20803552244863627
# params_ftest p-value: 0.9589657214627063
#
# Lag: 6
# ssr_ftest Test statistic value: 0.23117048074386612
# ssr_ftest p-value: 0.966263505260485
#
# ssr_chi2test Test statistic value: 1.4500693792115238
# ssr_chi2test p-value: 0.9627420165716305
#
# lrtest Test statistic value: 1.446564483758948
# lrtest p-value: 0.962964749401938
#
# params_ftest Test statistic value: 0.23117048074387728
# params_ftest p-value: 0.966263505260483
#
# Lag: 7
# ssr_ftest Test statistic value: 0.15860265416848365
# ssr_ftest p-value: 0.9926979528333281
#
# ssr_chi2test Test statistic value: 1.1690640869097417
# ssr_chi2test p-value: 0.9916218340738999
#
# lrtest Test statistic value: 1.166776927701335
# lrtest p-value: 0.9916718418774124
#
# params_ftest Test statistic value: 0.15860265416847888
# params_ftest p-value: 0.9926979528333294
#
# Lag: 8
# ssr_ftest Test statistic value: 0.23945096057703852
# ssr_ftest p-value: 0.9830983460030619
#
# ssr_chi2test Test statistic value: 2.031912436896584
# ssr_chi2test p-value: 0.9800178644109562
#
# lrtest Test statistic value: 2.024993356907885
# lrtest p-value: 0.9802360364792969
#
# params_ftest Test statistic value: 0.23945096057703805
# params_ftest p-value: 0.9830983460030619
#
# Lag: 9
# ssr_ftest Test statistic value: 0.287844785048502
# ssr_ftest p-value: 0.9777473666151087
#
# ssr_chi2test Test statistic value: 2.768297860538662
# ssr_chi2test p-value: 0.9727772716692881
#
# lrtest Test statistic value: 2.755432953987338
# lrtest p-value: 0.9732074070087156
#
# params_ftest Test statistic value: 0.2878447850485111
# params_ftest p-value: 0.9777473666151069
#
# Lag: 10
# ssr_ftest Test statistic value: 0.458359974662857
# ssr_ftest p-value: 0.9155631267087141
#
# ssr_chi2test Test statistic value: 4.9348975374285695
# ssr_chi2test p-value: 0.8954842437588035
#
# lrtest Test statistic value: 4.894075534645822
# lrtest p-value: 0.8981405397803549
#
# params_ftest Test statistic value: 0.45835997466285916
# params_ftest p-value: 0.9155631267087141
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9338  , p=0.3349  , df_denom=225, df_num=1
# ssr based chi2 test:   chi2=0.9463  , p=0.3307  , df=1
# likelihood ratio test: chi2=0.9443  , p=0.3312  , df=1
# parameter F test:         F=0.9338  , p=0.3349  , df_denom=225, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8418  , p=0.0229  , df_denom=222, df_num=2
# ssr based chi2 test:   chi2=7.8567  , p=0.0197  , df=2
# likelihood ratio test: chi2=7.7238  , p=0.0210  , df=2
# parameter F test:         F=3.8418  , p=0.0229  , df_denom=222, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4928  , p=0.0610  , df_denom=219, df_num=3
# ssr based chi2 test:   chi2=7.7174  , p=0.0522  , df=3
# likelihood ratio test: chi2=7.5886  , p=0.0553  , df=3
# parameter F test:         F=2.4928  , p=0.0610  , df_denom=219, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.0575  , p=0.0875  , df_denom=216, df_num=4
# ssr based chi2 test:   chi2=8.5731  , p=0.0727  , df=4
# likelihood ratio test: chi2=8.4138  , p=0.0775  , df=4
# parameter F test:         F=2.0575  , p=0.0875  , df_denom=216, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6409  , p=0.0243  , df_denom=213, df_num=5
# ssr based chi2 test:   chi2=13.8865 , p=0.0163  , df=5
# likelihood ratio test: chi2=13.4730 , p=0.0193  , df=5
# parameter F test:         F=2.6409  , p=0.0243  , df_denom=213, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3408  , p=0.0329  , df_denom=210, df_num=6
# ssr based chi2 test:   chi2=14.9145 , p=0.0209  , df=6
# likelihood ratio test: chi2=14.4370 , p=0.0251  , df=6
# parameter F test:         F=2.3408  , p=0.0329  , df_denom=210, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1220  , p=0.0427  , df_denom=207, df_num=7
# ssr based chi2 test:   chi2=15.9307 , p=0.0258  , df=7
# likelihood ratio test: chi2=15.3851 , p=0.0314  , df=7
# parameter F test:         F=2.1220  , p=0.0427  , df_denom=207, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1321  , p=0.0343  , df_denom=204, df_num=8
# ssr based chi2 test:   chi2=18.4783 , p=0.0179  , df=8
# likelihood ratio test: chi2=17.7463 , p=0.0232  , df=8
# parameter F test:         F=2.1321  , p=0.0343  , df_denom=204, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9121  , p=0.0520  , df_denom=201, df_num=9
# ssr based chi2 test:   chi2=18.8355 , p=0.0266  , df=9
# likelihood ratio test: chi2=18.0725 , p=0.0343  , df=9
# parameter F test:         F=1.9121  , p=0.0520  , df_denom=201, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9305  , p=0.0430  , df_denom=198, df_num=10
# ssr based chi2 test:   chi2=21.3527 , p=0.0188  , df=10
# likelihood ratio test: chi2=20.3748 , p=0.0259  , df=10
# parameter F test:         F=1.9305  , p=0.0430  , df_denom=198, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.9338177796199838
# ssr_ftest p-value: 0.33491035814825176
#
# ssr_chi2test Test statistic value: 0.9462686833482503
# ssr_chi2test p-value: 0.33067089391607685
#
# lrtest Test statistic value: 0.9443104496056094
# lrtest p-value: 0.3311717641862516
#
# params_ftest Test statistic value: 0.9338177796200291
# params_ftest p-value: 0.33491035814823855
#
# Lag: 2
# ssr_ftest Test statistic value: 3.8418110680263937
# ssr_ftest p-value: 0.02289533540114347
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 3
# ssr_ftest Test statistic value: 2.492804569343702
# ssr_ftest p-value: 0.06098711073355813
#
# ssr_chi2test Test statistic value: 7.717449762625707
# ssr_chi2test p-value: 0.05222675694343121
#
# lrtest Test statistic value: 7.588606947557082
# lrtest p-value: 0.055324940385566415
#
# params_ftest Test statistic value: 2.4928045693437006
# params_ftest p-value: 0.06098711073355813
#
# Lag: 4
# ssr_ftest Test statistic value: 2.0575429077553853
# ssr_ftest p-value: 0.08747491370004269
#
# ssr_chi2test Test statistic value: 8.573095448980771
# ssr_chi2test p-value: 0.07270229726306977
#
# lrtest Test statistic value: 8.413800418118967
# lrtest p-value: 0.07754355505091239
#
# params_ftest Test statistic value: 2.0575429077553853
# params_ftest p-value: 0.08747491370004269
#
# Lag: 5
# ssr_ftest Test statistic value: 2.640908357513749
# ssr_ftest p-value: 0.024325001918656105
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 6
# ssr_ftest Test statistic value: 2.3408466935859558
# ssr_ftest p-value: 0.03287930207764864
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 7
# ssr_ftest Test statistic value: 2.1220417708420483
# ssr_ftest p-value: 0.04271162040528098
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 8
# ssr_ftest Test statistic value: 2.1321101451005853
# ssr_ftest p-value: 0.03432394122687539
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 9
# ssr_ftest Test statistic value: 1.9120929104090845
# ssr_ftest p-value: 0.052009101434580964
#
# ssr_chi2test Test statistic value: 18.83554210253725
# ssr_chi2test p-value: 0.026628127915043827
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 10
# ssr_ftest Test statistic value: 1.9305167192983246
# ssr_ftest p-value: 0.043033150728170176
#
# Null hypothesis rejected for ssr_ftest test
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2278  , p=0.6338  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.2323  , p=0.6298  , df=1
# likelihood ratio test: chi2=0.2321  , p=0.6300  , df=1
# parameter F test:         F=0.2278  , p=0.6338  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1460  , p=0.8643  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=0.3018  , p=0.8599  , df=2
# likelihood ratio test: chi2=0.3015  , p=0.8601  , df=2
# parameter F test:         F=0.1460  , p=0.8643  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1136  , p=0.3456  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=3.4999  , p=0.3208  , df=3
# likelihood ratio test: chi2=3.4607  , p=0.3259  , df=3
# parameter F test:         F=1.1136  , p=0.3456  , df_denom=147, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0731  , p=0.3721  , df_denom=144, df_num=4
# ssr based chi2 test:   chi2=4.5608  , p=0.3354  , df=4
# likelihood ratio test: chi2=4.4941  , p=0.3432  , df=4
# parameter F test:         F=1.0731  , p=0.3721  , df_denom=144, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1074  , p=0.3592  , df_denom=141, df_num=5
# ssr based chi2 test:   chi2=5.9691  , p=0.3092  , df=5
# likelihood ratio test: chi2=5.8549  , p=0.3206  , df=5
# parameter F test:         F=1.1074  , p=0.3592  , df_denom=141, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0463  , p=0.3982  , df_denom=138, df_num=6
# ssr based chi2 test:   chi2=6.8694  , p=0.3331  , df=6
# likelihood ratio test: chi2=6.7177  , p=0.3477  , df=6
# parameter F test:         F=1.0463  , p=0.3982  , df_denom=138, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8868  , p=0.5189  , df_denom=135, df_num=7
# ssr based chi2 test:   chi2=6.8972  , p=0.4397  , df=7
# likelihood ratio test: chi2=6.7433  , p=0.4561  , df=7
# parameter F test:         F=0.8868  , p=0.5189  , df_denom=135, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1097  , p=0.3608  , df_denom=132, df_num=8
# ssr based chi2 test:   chi2=10.0209 , p=0.2636  , df=8
# likelihood ratio test: chi2=9.6984  , p=0.2868  , df=8
# parameter F test:         F=1.1097  , p=0.3608  , df_denom=132, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9476  , p=0.4867  , df_denom=129, df_num=9
# ssr based chi2 test:   chi2=9.7840  , p=0.3682  , df=9
# likelihood ratio test: chi2=9.4742  , p=0.3947  , df=9
# parameter F test:         F=0.9476  , p=0.4867  , df_denom=129, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8788  , p=0.5549  , df_denom=126, df_num=10
# ssr based chi2 test:   chi2=10.2522 , p=0.4187  , df=10
# likelihood ratio test: chi2=9.9105  , p=0.4484  , df=10
# parameter F test:         F=0.8788  , p=0.5549  , df_denom=126, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.22780768334414134
# ssr_ftest p-value: 0.633835271231193
#
# ssr_chi2test Test statistic value: 0.23227450066461472
# ssr_chi2test p-value: 0.6298424252249089
#
# lrtest Test statistic value: 0.2321017508255636
# lrtest p-value: 0.629969772223086
#
# params_ftest Test statistic value: 0.22780768334412704
# params_ftest p-value: 0.633835271231193
#
# Lag: 2
# ssr_ftest Test statistic value: 0.14602157606011174
# ssr_ftest p-value: 0.8642617439891515
#
# ssr_chi2test Test statistic value: 0.30177792385756425
# ssr_chi2test p-value: 0.8599431797901279
#
# lrtest Test statistic value: 0.3014845306908569
# lrtest p-value: 0.8600693397698742
#
# params_ftest Test statistic value: 0.14602157606012617
# params_ftest p-value: 0.864261743989137
#
# Lag: 3
# ssr_ftest Test statistic value: 1.113605588697928
# ssr_ftest p-value: 0.34561536218409683
#
# ssr_chi2test Test statistic value: 3.4999032787649167
# ssr_chi2test p-value: 0.32077466544207445
#
# lrtest Test statistic value: 3.4607252293137094
# lrtest p-value: 0.32589176478327503
#
# params_ftest Test statistic value: 1.1136055886979428
# params_ftest p-value: 0.3456153621840892
#
# Lag: 4
# ssr_ftest Test statistic value: 1.073130631227098
# ssr_ftest p-value: 0.37208879814507917
#
# ssr_chi2test Test statistic value: 4.560805182715167
# ssr_chi2test p-value: 0.33539832111488044
#
# lrtest Test statistic value: 4.494149634309281
# lrtest p-value: 0.34324174561196047
#
# params_ftest Test statistic value: 1.0731306312270994
# params_ftest p-value: 0.37208879814507917
#
# Lag: 5
# ssr_ftest Test statistic value: 1.1074229488376954
# ssr_ftest p-value: 0.35920700709587916
#
# ssr_chi2test Test statistic value: 5.969088234869848
# ssr_chi2test p-value: 0.3092383996336797
#
# lrtest Test statistic value: 5.854865041431765
# lrtest p-value: 0.3205983633330556
#
# params_ftest Test statistic value: 1.1074229488377
# params_ftest p-value: 0.3592070070958764
#
# Lag: 6
# ssr_ftest Test statistic value: 1.04632858048512
# ssr_ftest p-value: 0.39818524059712335
#
# ssr_chi2test Test statistic value: 6.869374593619701
# ssr_chi2test p-value: 0.3330965816113375
#
# lrtest Test statistic value: 6.717704790165612
# lrtest p-value: 0.34774438596581747
#
# params_ftest Test statistic value: 1.0463285804851157
# params_ftest p-value: 0.398185240597125
#
# Lag: 7
# ssr_ftest Test statistic value: 0.8867780162510109
# ssr_ftest p-value: 0.5188597295750537
#
# ssr_chi2test Test statistic value: 6.8971623486189735
# ssr_chi2test p-value: 0.43966534846952865
#
# lrtest Test statistic value: 6.743291962048488
# lrtest p-value: 0.4560887095797874
#
# params_ftest Test statistic value: 0.8867780162510116
# params_ftest p-value: 0.5188597295750537
#
# Lag: 8
# ssr_ftest Test statistic value: 1.1097022646451176
# ssr_ftest p-value: 0.36077095151788413
#
# ssr_chi2test Test statistic value: 10.020947723158942
# ssr_chi2test p-value: 0.2635587373121251
#
# lrtest Test statistic value: 9.698355508237626
# lrtest p-value: 0.2868388575422506
#
# params_ftest Test statistic value: 1.1097022646451173
# params_ftest p-value: 0.36077095151788413
#
# Lag: 9
# ssr_ftest Test statistic value: 0.9475541858912565
# ssr_ftest p-value: 0.486661514273643
#
# ssr_chi2test Test statistic value: 9.784047872923672
# ssr_chi2test p-value: 0.3682491175429777
#
# lrtest Test statistic value: 9.47422573426212
# lrtest p-value: 0.39469848345279157
#
# params_ftest Test statistic value: 0.9475541858912572
# params_ftest p-value: 0.486661514273643
#
# Lag: 10
# ssr_ftest Test statistic value: 0.8787590025057427
# ssr_ftest p-value: 0.5549471236580125
#
# ssr_chi2test Test statistic value: 10.252188362566997
# ssr_chi2test p-value: 0.41865361654389033
#
# lrtest Test statistic value: 9.91047909853421
# lrtest p-value: 0.4483821192934717
#
# params_ftest Test statistic value: 0.878759002505741
# params_ftest p-value: 0.5549471236580148
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0365  , p=0.8486  , df_denom=244, df_num=1
# ssr based chi2 test:   chi2=0.0370  , p=0.8475  , df=1
# likelihood ratio test: chi2=0.0370  , p=0.8475  , df=1
# parameter F test:         F=0.0365  , p=0.8486  , df_denom=244, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0927  , p=0.9115  , df_denom=241, df_num=2
# ssr based chi2 test:   chi2=0.1893  , p=0.9097  , df=2
# likelihood ratio test: chi2=0.1892  , p=0.9097  , df=2
# parameter F test:         F=0.0927  , p=0.9115  , df_denom=241, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0607  , p=0.9804  , df_denom=238, df_num=3
# ssr based chi2 test:   chi2=0.1876  , p=0.9796  , df=3
# likelihood ratio test: chi2=0.1875  , p=0.9796  , df=3
# parameter F test:         F=0.0607  , p=0.9804  , df_denom=238, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0884  , p=0.9860  , df_denom=235, df_num=4
# ssr based chi2 test:   chi2=0.3670  , p=0.9851  , df=4
# likelihood ratio test: chi2=0.3667  , p=0.9851  , df=4
# parameter F test:         F=0.0884  , p=0.9860  , df_denom=235, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.0658  , p=0.9970  , df_denom=232, df_num=5
# ssr based chi2 test:   chi2=0.3444  , p=0.9967  , df=5
# likelihood ratio test: chi2=0.3442  , p=0.9967  , df=5
# parameter F test:         F=0.0658  , p=0.9970  , df_denom=232, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.0584  , p=0.9992  , df_denom=229, df_num=6
# ssr based chi2 test:   chi2=0.3703  , p=0.9991  , df=6
# likelihood ratio test: chi2=0.3700  , p=0.9991  , df=6
# parameter F test:         F=0.0584  , p=0.9992  , df_denom=229, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.0828  , p=0.9991  , df_denom=226, df_num=7
# ssr based chi2 test:   chi2=0.6182  , p=0.9989  , df=7
# likelihood ratio test: chi2=0.6175  , p=0.9989  , df=7
# parameter F test:         F=0.0828  , p=0.9991  , df_denom=226, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.0814  , p=0.9996  , df_denom=223, df_num=8
# ssr based chi2 test:   chi2=0.7007  , p=0.9995  , df=8
# likelihood ratio test: chi2=0.6996  , p=0.9995  , df=8
# parameter F test:         F=0.0814  , p=0.9996  , df_denom=223, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.0741  , p=0.9999  , df_denom=220, df_num=9
# ssr based chi2 test:   chi2=0.7244  , p=0.9999  , df=9
# likelihood ratio test: chi2=0.7233  , p=0.9999  , df=9
# parameter F test:         F=0.0741  , p=0.9999  , df_denom=220, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.0666  , p=1.0000  , df_denom=217, df_num=10
# ssr based chi2 test:   chi2=0.7305  , p=1.0000  , df=10
# likelihood ratio test: chi2=0.7293  , p=1.0000  , df=10
# parameter F test:         F=0.0666  , p=1.0000  , df_denom=217, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.03653228869446372
# ssr_ftest p-value: 0.8485793867469168
#
# ssr_chi2test Test statistic value: 0.03698145617841204
# ssr_chi2test p-value: 0.8475028068762089
#
# lrtest Test statistic value: 0.0369786879766707
# lrtest p-value: 0.8475084444703369
#
# params_ftest Test statistic value: 0.03653228869440866
# params_ftest p-value: 0.8485793867470277
#
# Lag: 2
# ssr_ftest Test statistic value: 0.09271312772228855
# ssr_ftest p-value: 0.911487426638443
#
# ssr_chi2test Test statistic value: 0.1892732731923899
# ssr_chi2test p-value: 0.9097034273539015
#
# lrtest Test statistic value: 0.18920049675557493
# lrtest p-value: 0.9097365304431797
#
# params_ftest Test statistic value: 0.09271312772226814
# params_ftest p-value: 0.9114874266384674
#
# Lag: 3
# ssr_ftest Test statistic value: 0.06074852880138907
# ssr_ftest p-value: 0.9803546896679614
#
# ssr_chi2test Test statistic value: 0.18760575071017216
# ssr_chi2test p-value: 0.979564909768736
#
# lrtest Test statistic value: 0.18753395895350877
# lrtest p-value: 0.9795762034594419
#
# params_ftest Test statistic value: 0.06074852880137952
# params_ftest p-value: 0.9803546896679655
#
# Lag: 4
# ssr_ftest Test statistic value: 0.08836452766520447
# ssr_ftest p-value: 0.9860154476097089
#
# ssr_chi2test Test statistic value: 0.3669948042605939
# ssr_chi2test p-value: 0.9850888417232108
#
# lrtest Test statistic value: 0.3667190864588292
# lrtest p-value: 0.9851098911165991
#
# params_ftest Test statistic value: 0.08836452766521004
# params_ftest p-value: 0.986015447609707
#
# Lag: 5
# ssr_ftest Test statistic value: 0.06577151111290226
# ssr_ftest p-value: 0.9970245692193122
#
# ssr_chi2test Test statistic value: 0.34444993966455284
# ssr_chi2test p-value: 0.9967225745115665
#
# lrtest Test statistic value: 0.3442060430377296
# lrtest p-value: 0.9967280912606021
#
# params_ftest Test statistic value: 0.0657715111129031
# params_ftest p-value: 0.9970245692193122
#
# Lag: 6
# ssr_ftest Test statistic value: 0.058403603196797035
# ssr_ftest p-value: 0.9991954288823219
#
# ssr_chi2test Test statistic value: 0.3703145495272895
# ssr_chi2test p-value: 0.9990786098916766
#
# lrtest Test statistic value: 0.37003150587077016
# lrtest p-value: 0.9990806243623426
#
# params_ftest Test statistic value: 0.05840360319679411
# params_ftest p-value: 0.999195428882322
#
# Lag: 7
# ssr_ftest Test statistic value: 0.08282422638444727
# ssr_ftest p-value: 0.9990697827536441
#
# ssr_chi2test Test statistic value: 0.6182498668608962
# ssr_chi2test p-value: 0.9988880868589924
#
# lrtest Test statistic value: 0.617458206186484
# lrtest p-value: 0.9988927256773651
#
# params_ftest Test statistic value: 0.0828242263844505
# params_ftest p-value: 0.999069782753644
#
# Lag: 8
# ssr_ftest Test statistic value: 0.08137787553812528
# ssr_ftest p-value: 0.9996225646761105
#
# ssr_chi2test Test statistic value: 0.700652560686998
# ssr_chi2test p-value: 0.9995250052142767
#
# lrtest Test statistic value: 0.6996318093264335
# lrtest p-value: 0.9995275766382121
#
# params_ftest Test statistic value: 0.08137787553812495
# params_ftest p-value: 0.9996225646761105
#
# Lag: 9
# ssr_ftest Test statistic value: 0.07408917309617194
# ssr_ftest p-value: 0.9998896764532168
#
# ssr_chi2test Test statistic value: 0.7243900514993902
# ssr_chi2test p-value: 0.9998526499010272
#
# lrtest Test statistic value: 0.7232944802601651
# lrtest p-value: 0.9998535851668968
#
# params_ftest Test statistic value: 0.07408917309617112
# params_ftest p-value: 0.9998896764532168
#
# Lag: 10
# ssr_ftest Test statistic value: 0.06660065307894036
# ssr_ftest p-value: 0.9999719991982849
#
# ssr_chi2test Test statistic value: 0.7304587757045073
# ssr_chi2test p-value: 0.9999600006495515
#
# lrtest Test statistic value: 0.7293401185812627
# lrtest p-value: 0.9999602876566589
#
# params_ftest Test statistic value: 0.06660065307893674
# params_ftest p-value: 0.9999719991982849
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6819  , p=0.4095  , df_denom=330, df_num=1
# ssr based chi2 test:   chi2=0.6881  , p=0.4068  , df=1
# likelihood ratio test: chi2=0.6874  , p=0.4070  , df=1
# parameter F test:         F=0.6819  , p=0.4095  , df_denom=330, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1747  , p=0.3102  , df_denom=327, df_num=2
# ssr based chi2 test:   chi2=2.3854  , p=0.3034  , df=2
# likelihood ratio test: chi2=2.3769  , p=0.3047  , df=2
# parameter F test:         F=1.1747  , p=0.3102  , df_denom=327, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0741  , p=0.3602  , df_denom=324, df_num=3
# ssr based chi2 test:   chi2=3.2919  , p=0.3488  , df=3
# likelihood ratio test: chi2=3.2757  , p=0.3510  , df=3
# parameter F test:         F=1.0741  , p=0.3602  , df_denom=324, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2472  , p=0.2908  , df_denom=321, df_num=4
# ssr based chi2 test:   chi2=5.1286  , p=0.2744  , df=4
# likelihood ratio test: chi2=5.0891  , p=0.2783  , df=4
# parameter F test:         F=1.2472  , p=0.2908  , df_denom=321, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6717  , p=0.1410  , df_denom=318, df_num=5
# ssr based chi2 test:   chi2=8.6475  , p=0.1240  , df=5
# likelihood ratio test: chi2=8.5358  , p=0.1291  , df=5
# parameter F test:         F=1.6717  , p=0.1410  , df_denom=318, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5958  , p=0.1478  , df_denom=315, df_num=6
# ssr based chi2 test:   chi2=9.9698  , p=0.1259  , df=6
# likelihood ratio test: chi2=9.8212  , p=0.1324  , df=6
# parameter F test:         F=1.5958  , p=0.1478  , df_denom=315, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4014  , p=0.2041  , df_denom=312, df_num=7
# ssr based chi2 test:   chi2=10.2812 , p=0.1732  , df=7
# likelihood ratio test: chi2=10.1229 , p=0.1817  , df=7
# parameter F test:         F=1.4014  , p=0.2041  , df_denom=312, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5384  , p=0.1431  , df_denom=309, df_num=8
# ssr based chi2 test:   chi2=12.9842 , p=0.1124  , df=8
# likelihood ratio test: chi2=12.7323 , p=0.1214  , df=8
# parameter F test:         F=1.5384  , p=0.1431  , df_denom=309, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4015  , p=0.1865  , df_denom=306, df_num=9
# ssr based chi2 test:   chi2=13.3969 , p=0.1455  , df=9
# likelihood ratio test: chi2=13.1282 , p=0.1569  , df=9
# parameter F test:         F=1.4015  , p=0.1865  , df_denom=306, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3775  , p=0.1897  , df_denom=303, df_num=10
# ssr based chi2 test:   chi2=14.7295 , p=0.1422  , df=10
# likelihood ratio test: chi2=14.4045 , p=0.1553  , df=10
# parameter F test:         F=1.3775  , p=0.1897  , df_denom=303, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.6819441688986378
# ssr_ftest p-value: 0.4095146623408742
#
# ssr_chi2test Test statistic value: 0.688143661343171
# ssr_chi2test p-value: 0.40679650887493635
#
# ...
# number of lags (no zero) 6
# ssr based F test:         F=1.5050  , p=0.1772  , df_denom=236, df_num=6
# ssr based chi2 test:   chi2=9.5276  , p=0.1460  , df=6
# likelihood ratio test: chi2=9.3499  , p=0.1548  , df=6
# parameter F test:         F=1.5050  , p=0.1772  , df_denom=236, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.7224  , p=0.0099  , df_denom=233, df_num=7
# ssr based chi2 test:   chi2=20.2838 , p=0.0050  , df=7
# likelihood ratio test: chi2=19.4969 , p=0.0068  , df=7
# parameter F test:         F=2.7224  , p=0.0099  , df_denom=233, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.2948  , p=0.0014  , df_denom=230, df_num=8
# ssr based chi2 test:   chi2=28.3068 , p=0.0004  , df=8
# likelihood ratio test: chi2=26.7990 , p=0.0008  , df=8
# parameter F test:         F=3.2948  , p=0.0014  , df_denom=230, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.5115  , p=0.0004  , df_denom=227, df_num=9
# ssr based chi2 test:   chi2=34.2490 , p=0.0001  , df=9
# likelihood ratio test: chi2=32.0653 , p=0.0002  , df=9
# parameter F test:         F=3.5115  , p=0.0004  , df_denom=227, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.6864  , p=0.0001  , df_denom=224, df_num=10
# ssr based chi2 test:   chi2=40.3197 , p=0.0000  , df=10
# likelihood ratio test: chi2=37.3263 , p=0.0000  , df=10
# parameter F test:         F=3.6864  , p=0.0001  , df_denom=224, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.5350013854133513
# ssr_ftest p-value: 0.46519403464397935
#
# ssr_chi2test Test statistic value: 0.5413958242828336
# ssr_chi2test p-value: 0.4618548266547474
#
# lrtest Test statistic value: 0.5408196557814335
# lrtest p-value: 0.46209323292556437
#
# params_ftest Test statistic value: 0.5350013854133281
# params_ftest p-value: 0.4651940346439909
#
# Lag: 2
# ssr_ftest Test statistic value: 2.1685195622407987
# ssr_ftest p-value: 0.11651023342559196
#
# ssr_chi2test Test statistic value: 4.424479429410662
# ssr_chi2test p-value: 0.10945522530143116
#
# lrtest Test statistic value: 4.386236861496684
# lrtest p-value: 0.11156828759535617
#
# params_ftest Test statistic value: 2.168519562240823
# params_ftest p-value: 0.11651023342559086
#
# Lag: 3
# ssr_ftest Test statistic value: 1.4875525577444255
# ssr_ftest p-value: 0.21848253078291574
#
# ssr_chi2test Test statistic value: 4.590162178182799
# ssr_chi2test p-value: 0.20438764600954212
#
# lrtest Test statistic value: 4.548858249857403
# lrtest p-value: 0.20797342637784283
#
# params_ftest Test statistic value: 1.4875525577444246
# params_ftest p-value: 0.21848253078291574
#
# Lag: 4
# ssr_ftest Test statistic value: 2.1328152127837314
# ssr_ftest p-value: 0.0773870294358245
#
# ssr_chi2test Test statistic value: 8.848539147251513
# ssr_chi2test p-value: 0.06499880953694609
#
# lrtest Test statistic value: 8.696141080158782
# lrtest p-value: 0.06915985664756714
#
# params_ftest Test statistic value: 2.1328152127837394
# params_ftest p-value: 0.07738702943582336
#
# Lag: 5
# ssr_ftest Test statistic value: 1.451376282064629
# ssr_ftest p-value: 0.20664006930627726
#
# ssr_chi2test Test statistic value: 7.590880136321282
# ssr_chi2test p-value: 0.18027115593257456
#
# lrtest Test statistic value: 7.477918135933351
# lrtest p-value: 0.1874529829761697
#
# params_ftest Test statistic value: 1.4513762820646274
# params_ftest p-value: 0.20664006930627726
#
# Lag: 6
# ssr_ftest Test statistic value: 1.5050326120881021
# ssr_ftest p-value: 0.17718831230278365
#
# ssr_chi2test Test statistic value: 9.527621705337394
# ssr_chi2test p-value: 0.1460065964027592
#
# lrtest Test statistic value: 9.349861746363274
# lrtest p-value: 0.15483699001253617
#
# params_ftest Test statistic value: 1.5050326120880992
# params_ftest p-value: 0.17718831230278365
#
# Lag: 7
# ssr_ftest Test statistic value: 2.722417271392729
# ssr_ftest p-value: 0.009860599151701158
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 8
# ssr_ftest Test statistic value: 3.2948251019924926
# ssr_ftest p-value: 0.0013956862052664737
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 9
# ssr_ftest Test statistic value: 3.5115252875822387
# ssr_ftest p-value: 0.00043220663345415586
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 10
# ssr_ftest Test statistic value: 3.686374912356204
# ssr_ftest p-value: 0.00013905010217694395
#
# Null hypothesis rejected for ssr_ftest test
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2737  , p=0.6017  , df_denom=128, df_num=1
# ssr based chi2 test:   chi2=0.2802  , p=0.5966  , df=1
# likelihood ratio test: chi2=0.2799  , p=0.5968  , df=1
# parameter F test:         F=0.2737  , p=0.6017  , df_denom=128, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3333  , p=0.7172  , df_denom=125, df_num=2
# ssr based chi2 test:   chi2=0.6933  , p=0.7070  , df=2
# likelihood ratio test: chi2=0.6915  , p=0.7077  , df=2
# parameter F test:         F=0.3333  , p=0.7172  , df_denom=125, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.5832  , p=0.0013  , df_denom=122, df_num=3
# ssr based chi2 test:   chi2=17.7106 , p=0.0005  , df=3
# likelihood ratio test: chi2=16.5958 , p=0.0009  , df=3
# parameter F test:         F=5.5832  , p=0.0013  , df_denom=122, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.5899  , p=0.0084  , df_denom=119, df_num=4
# ssr based chi2 test:   chi2=15.4455 , p=0.0039  , df=4
# likelihood ratio test: chi2=14.5824 , p=0.0057  , df=4
# parameter F test:         F=3.5899  , p=0.0084  , df_denom=119, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2308  , p=0.0091  , df_denom=116, df_num=5
# ssr based chi2 test:   chi2=17.6858 , p=0.0034  , df=5
# likelihood ratio test: chi2=16.5579 , p=0.0054  , df=5
# parameter F test:         F=3.2308  , p=0.0091  , df_denom=116, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.6175  , p=0.0206  , df_denom=113, df_num=6
# ssr based chi2 test:   chi2=17.5116 , p=0.0076  , df=6
# likelihood ratio test: chi2=16.3968 , p=0.0118  , df=6
# parameter F test:         F=2.6175  , p=0.0206  , df_denom=113, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.5260  , p=0.0190  , df_denom=110, df_num=7
# ssr based chi2 test:   chi2=20.0935 , p=0.0054  , df=7
# likelihood ratio test: chi2=18.6331 , p=0.0094  , df=7
# parameter F test:         F=2.5260  , p=0.0190  , df_denom=110, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=6.4723  , p=0.0000  , df_denom=107, df_num=8
# ssr based chi2 test:   chi2=60.0048 , p=0.0000  , df=8
# likelihood ratio test: chi2=48.9403 , p=0.0000  , df=8
# parameter F test:         F=6.4723  , p=0.0000  , df_denom=107, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=6.9449  , p=0.0000  , df_denom=104, df_num=9
# ssr based chi2 test:   chi2=73.9228 , p=0.0000  , df=9
# likelihood ratio test: chi2=57.8872 , p=0.0000  , df=9
# parameter F test:         F=6.9449  , p=0.0000  , df_denom=104, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=6.4610  , p=0.0000  , df_denom=101, df_num=10
# ssr based chi2 test:   chi2=78.0435 , p=0.0000  , df=10
# likelihood ratio test: chi2=60.3307 , p=0.0000  , df=10
# parameter F test:         F=6.4610  , p=0.0000  , df_denom=101, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.27374368787199654
# ssr_ftest p-value: 0.6017360276652697
#
# ssr_chi2test Test statistic value: 0.2801595555564964
# ssr_chi2test p-value: 0.5965966574511379
#
# lrtest Test statistic value: 0.2798604042220063
# lrtest p-value: 0.5967927273294846
#
# params_ftest Test statistic value: 0.2737436878720106
# params_ftest p-value: 0.6017360276652508
#
# Lag: 2
# ssr_ftest Test statistic value: 0.333328997973132
# ssr_ftest p-value: 0.7171693455636197
#
# ssr_chi2test Test statistic value: 0.6933243157841145
# ssr_chi2test p-value: 0.7070441572007184
#
# lrtest Test statistic value: 0.6914820223768743
# lrtest p-value: 0.7076957486550244
#
# params_ftest Test statistic value: 0.3333289979731109
# params_ftest p-value: 0.7171693455636348
#
# Lag: 3
# ssr_ftest Test statistic value: 5.583190375957637
# ssr_ftest p-value: 0.0012707613561214381
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 4
# ssr_ftest Test statistic value: 3.5898745983127385
# ssr_ftest p-value: 0.008428337414640198
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 5
# ssr_ftest Test statistic value: 3.230783155335926
# ssr_ftest p-value: 0.009093305881129887
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 6
# ssr_ftest Test statistic value: 2.617467867196695
# ssr_ftest p-value: 0.02056192015866756
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 7
# ssr_ftest Test statistic value: 2.526043238465818
# ssr_ftest p-value: 0.018992266408082544
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 8
# ssr_ftest Test statistic value: 6.472290456337821
# ssr_ftest p-value: 7.491321512377427e-07
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 9
# ssr_ftest Test statistic value: 6.944868435971008
# ssr_ftest p-value: 8.6219097935821e-08
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 10
# ssr_ftest Test statistic value: 6.46097584947325
# ssr_ftest p-value: 1.23010290180605e-07
#
# Null hypothesis rejected for ssr_ftest test
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0426  , p=0.8368  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.0436  , p=0.8347  , df=1
# likelihood ratio test: chi2=0.0436  , p=0.8347  , df=1
# parameter F test:         F=0.0426  , p=0.8368  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1653  , p=0.1188  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=4.4959  , p=0.1056  , df=2
# likelihood ratio test: chi2=4.4231  , p=0.1095  , df=2
# parameter F test:         F=2.1653  , p=0.1188  , df_denom=131, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8959  , p=0.1336  , df_denom=128, df_num=3
# ssr based chi2 test:   chi2=5.9986  , p=0.1117  , df=3
# likelihood ratio test: chi2=5.8692  , p=0.1182  , df=3
# parameter F test:         F=1.8959  , p=0.1336  , df_denom=128, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5548  , p=0.1905  , df_denom=125, df_num=4
# ssr based chi2 test:   chi2=6.6671  , p=0.1546  , df=4
# likelihood ratio test: chi2=6.5065  , p=0.1644  , df=4
# parameter F test:         F=1.5548  , p=0.1905  , df_denom=125, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1872  , p=0.3194  , df_denom=122, df_num=5
# ssr based chi2 test:   chi2=6.4713  , p=0.2630  , df=5
# likelihood ratio test: chi2=6.3188  , p=0.2764  , df=5
# parameter F test:         F=1.1872  , p=0.3194  , df_denom=122, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2680  , p=0.2773  , df_denom=119, df_num=6
# ssr based chi2 test:   chi2=8.4394  , p=0.2076  , df=6
# likelihood ratio test: chi2=8.1806  , p=0.2252  , df=6
# parameter F test:         F=1.2680  , p=0.2773  , df_denom=119, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4368  , p=0.1972  , df_denom=116, df_num=7
# ssr based chi2 test:   chi2=11.3584 , p=0.1237  , df=7
# likelihood ratio test: chi2=10.8927 , p=0.1434  , df=7
# parameter F test:         F=1.4368  , p=0.1972  , df_denom=116, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4027  , p=0.2029  , df_denom=113, df_num=8
# ssr based chi2 test:   chi2=12.9099 , p=0.1150  , df=8
# likelihood ratio test: chi2=12.3084 , p=0.1380  , df=8
# parameter F test:         F=1.4027  , p=0.2029  , df_denom=113, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3783  , p=0.2065  , df_denom=110, df_num=9
# ssr based chi2 test:   chi2=14.5477 , p=0.1041  , df=9
# likelihood ratio test: chi2=13.7843 , p=0.1302  , df=9
# parameter F test:         F=1.3783  , p=0.2065  , df_denom=110, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1879  , p=0.3072  , df_denom=107, df_num=10
# ssr based chi2 test:   chi2=14.2098 , p=0.1636  , df=10
# likelihood ratio test: chi2=13.4750 , p=0.1983  , df=10
# parameter F test:         F=1.1879  , p=0.3072  , df_denom=107, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.04260526452559348
# ssr_ftest p-value: 0.8367836214278297
#
# ssr_chi2test Test statistic value: 0.043559113731390355
# ssr_chi2test p-value: 0.8346760365964053
#
# lrtest Test statistic value: 0.043552190394507306
# lrtest p-value: 0.8346889858662502
#
# params_ftest Test statistic value: 0.04260526452558373
# params_ftest p-value: 0.8367836214278859
#
# Lag: 2
# ssr_ftest Test statistic value: 2.1652827344297485
# ssr_ftest p-value: 0.11880607421059318
#
# ssr_chi2test Test statistic value: 4.495854227212914
# ssr_chi2test p-value: 0.10561793177964375
#
# lrtest Test statistic value: 4.42314096389768
# lrtest p-value: 0.10952850084003247
#
# params_ftest Test statistic value: 2.1652827344297636
# params_ftest p-value: 0.11880607421059135
#
# Lag: 3
# ssr_ftest Test statistic value: 1.8958653303308408
# ssr_ftest p-value: 0.1335587102150678
#
# ssr_chi2test Test statistic value: 5.9986363967499265
# ssr_chi2test p-value: 0.11167658620644778
#
# lrtest Test statistic value: 5.869184527971754
# lrtest p-value: 0.11815106336763485
#
# params_ftest Test statistic value: 1.895865330330837
# params_ftest p-value: 0.1335587102150678
#
# Lag: 4
# ssr_ftest Test statistic value: 1.5548235487693685
# ssr_ftest p-value: 0.19052978519432617
#
# ssr_chi2test Test statistic value: 6.667083377123053
# ssr_chi2test p-value: 0.15456253010139576
#
# lrtest Test statistic value: 6.506529166434518
# lrtest p-value: 0.16437945760311753
#
# params_ftest Test statistic value: 1.5548235487693738
# params_ftest p-value: 0.19052978519432323
#
# Lag: 5
# ssr_ftest Test statistic value: 1.1872087404935172
# ssr_ftest p-value: 0.31939676210929624
#
# ssr_chi2test Test statistic value: 6.471260757608106
# ssr_chi2test p-value: 0.26302367897050966
#
# lrtest Test statistic value: 6.3187549535458345
# lrtest p-value: 0.2764263917100594
#
# params_ftest Test statistic value: 1.1872087404935177
# params_ftest p-value: 0.31939676210929624
#
# Lag: 6
# ssr_ftest Test statistic value: 1.2680435600995426
# ssr_ftest p-value: 0.2772699391639917
#
# ssr_chi2test Test statistic value: 8.439415963015444
# ssr_chi2test p-value: 0.20764481693588754
#
# lrtest Test statistic value: 8.180603650880016
# lrtest p-value: 0.2251682306057761
#
# params_ftest Test statistic value: 1.2680435600995452
# params_ftest p-value: 0.2772699391639899
#
# Lag: 7
# ssr_ftest Test statistic value: 1.4368256547668063
# ssr_ftest p-value: 0.19720263556083098
#
# ssr_chi2test Test statistic value: 11.358354529492768
# ssr_chi2test p-value: 0.1237336460998922
#
# lrtest Test statistic value: 10.8926734302473
# lrtest p-value: 0.143369553178713
#
# params_ftest Test statistic value: 1.4368256547668046
# params_ftest p-value: 0.19720263556083215
#
# Lag: 8
# ssr_ftest Test statistic value: 1.4027150917017766
# ssr_ftest p-value: 0.20291334410535045
#
# ssr_chi2test Test statistic value: 12.909944206812812
# ssr_chi2test p-value: 0.11498593887556276
#
# lrtest Test statistic value: 12.308428681924113
# lrtest p-value: 0.13796396023778504
#
# params_ftest Test statistic value: 1.4027150917017743
# params_ftest p-value: 0.2029133441053521
#
# Lag: 9
# ssr_ftest Test statistic value: 1.3783385990859438
# ssr_ftest p-value: 0.20653406130989133
#
# ssr_chi2test Test statistic value: 14.547737395807099
# ssr_chi2test p-value: 0.10413170018603893
#
# lrtest Test statistic value: 13.784325998246999
# lrtest p-value: 0.13020665342410115
#
# params_ftest Test statistic value: 1.378338599085943
# params_ftest p-value: 0.20653406130989152
#
# Lag: 10
# ssr_ftest Test statistic value: 1.1878506683398844
# ssr_ftest p-value: 0.30719625612094753
#
# ssr_chi2test Test statistic value: 14.209802387617309
# ssr_chi2test p-value: 0.16363517498369295
#
# lrtest Test statistic value: 13.47496766496505
# lrtest p-value: 0.1983142248453492
#
# params_ftest Test statistic value: 1.1878506683398868
# params_ftest p-value: 0.30719625612094587

# %% [markdown]
# ## Do interictal spikes drive teager energy?

# %%
for patient_hup_id in patient_hup_ids:
    # Read in the giant table for this patient
    hourly_patient_features_df = pd.read_csv(
        os.path.join(TABLES_DIRECTORY, f"HUP_{patient_hup_id}.csv")
    )

    # Assuming you already have the dataframe hourly_patient_features_df
    df = hourly_patient_features_df[["spikes_avg_all", "teager_energy"]]

    # It's recommended to handle missing values and make the series stationary
    # (via differencing or some other method) before the Granger test
    df = df.dropna()
    df = df.diff().dropna()

    # Perform the Granger Causality test
    # maxlag is the maximum lag that you would like the test to check
    granger_test_result = grangercausalitytests(df, maxlag=10)

    # Print the test results
    for lag, test_result in granger_test_result.items():
        print(f"Lag: {lag}")
        for test_name, result in test_result[0].items():
            t_statistic, p_value = result[0], result[1]
            print(f"{test_name} Test statistic value: {t_statistic}")
            print(f"{test_name} p-value: {p_value}\n")
            if p_value < 0.05:
                print(f"Null hypothesis rejected for {test_name} test")
                break
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.2253  , p=0.0749  , df_denom=127, df_num=1
# ssr based chi2 test:   chi2=3.3015  , p=0.0692  , df=1
# likelihood ratio test: chi2=3.2603  , p=0.0710  , df=1
# parameter F test:         F=3.2253  , p=0.0749  , df_denom=127, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6880  , p=0.5045  , df_denom=124, df_num=2
# ssr based chi2 test:   chi2=1.4315  , p=0.4888  , df=2
# likelihood ratio test: chi2=1.4237  , p=0.4907  , df=2
# parameter F test:         F=0.6880  , p=0.5045  , df_denom=124, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6097  , p=0.6100  , df_denom=121, df_num=3
# ssr based chi2 test:   chi2=1.9350  , p=0.5860  , df=3
# likelihood ratio test: chi2=1.9205  , p=0.5891  , df=3
# parameter F test:         F=0.6097  , p=0.6100  , df_denom=121, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5244  , p=0.7180  , df_denom=118, df_num=4
# ssr based chi2 test:   chi2=2.2577  , p=0.6885  , df=4
# likelihood ratio test: chi2=2.2379  , p=0.6921  , df=4
# parameter F test:         F=0.5244  , p=0.7180  , df_denom=118, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4264  , p=0.8295  , df_denom=115, df_num=5
# ssr based chi2 test:   chi2=2.3358  , p=0.8010  , df=5
# likelihood ratio test: chi2=2.3144  , p=0.8042  , df=5
# parameter F test:         F=0.4264  , p=0.8295  , df_denom=115, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7024  , p=0.6483  , df_denom=112, df_num=6
# ssr based chi2 test:   chi2=4.7034  , p=0.5824  , df=6
# likelihood ratio test: chi2=4.6171  , p=0.5938  , df=6
# parameter F test:         F=0.7024  , p=0.6483  , df_denom=112, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6151  , p=0.7424  , df_denom=109, df_num=7
# ssr based chi2 test:   chi2=4.8985  , p=0.6724  , df=7
# likelihood ratio test: chi2=4.8042  , p=0.6838  , df=7
# parameter F test:         F=0.6151  , p=0.7424  , df_denom=109, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6187  , p=0.7605  , df_denom=106, df_num=8
# ssr based chi2 test:   chi2=5.7433  , p=0.6760  , df=8
# likelihood ratio test: chi2=5.6132  , p=0.6905  , df=8
# parameter F test:         F=0.6187  , p=0.7605  , df_denom=106, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6034  , p=0.7916  , df_denom=103, df_num=9
# ssr based chi2 test:   chi2=6.4322  , p=0.6960  , df=9
# likelihood ratio test: chi2=6.2684  , p=0.7128  , df=9
# parameter F test:         F=0.6034  , p=0.7916  , df_denom=103, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7564  , p=0.6699  , df_denom=100, df_num=10
# ssr based chi2 test:   chi2=9.1524  , p=0.5177  , df=10
# likelihood ratio test: chi2=8.8228  , p=0.5490  , df=10
# parameter F test:         F=0.7564  , p=0.6699  , df_denom=100, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 3.225333621866307
# ssr_ftest p-value: 0.07488454093786212
#
# ssr_chi2test Test statistic value: 3.3015226050599997
# ssr_chi2test p-value: 0.06921569740253287
#
# lrtest Test statistic value: 3.2602958774612603
# lrtest p-value: 0.07097631869857694
#
# params_ftest Test statistic value: 3.2253336218663002
# params_ftest p-value: 0.07488454093786212
#
# Lag: 2
# ssr_ftest Test statistic value: 0.6880273502927479
# ssr_ftest p-value: 0.5044746104728344
#
# ssr_chi2test Test statistic value: 1.4315407772220077
# ssr_chi2test p-value: 0.4888153888949591
#
# lrtest Test statistic value: 1.423655998194647
# lrtest p-value: 0.4907462932458846
#
# params_ftest Test statistic value: 0.6880273502927617
# params_ftest p-value: 0.5044746104728275
#
# Lag: 3
# ssr_ftest Test statistic value: 0.6097219594464085
# ssr_ftest p-value: 0.6099546850101611
#
# ssr_chi2test Test statistic value: 1.934985391962156
# ssr_chi2test p-value: 0.5860097675275115
#
# lrtest Test statistic value: 1.920505480773329
# lrtest p-value: 0.589068883293375
#
# params_ftest Test statistic value: 0.6097219594464042
# params_ftest p-value: 0.609954685010164
#
# Lag: 4
# ssr_ftest Test statistic value: 0.5244342226361381
# ssr_ftest p-value: 0.7179547670789062
#
# ssr_chi2test Test statistic value: 2.2577337720267643
# ssr_chi2test p-value: 0.6884744809265853
#
# lrtest Test statistic value: 2.237900134328072
# lrtest p-value: 0.6920968666205698
#
# params_ftest Test statistic value: 0.5244342226361371
# params_ftest p-value: 0.7179547670789062
#
# Lag: 5
# ssr_ftest Test statistic value: 0.4263692927761787
# ssr_ftest p-value: 0.8294967967072502
#
# ssr_chi2test Test statistic value: 2.3357622125999353
# ssr_chi2test p-value: 0.8010003651692439
#
# lrtest Test statistic value: 2.314376167451428
# lrtest p-value: 0.80415310860855
#
# params_ftest Test statistic value: 0.4263692927761788
# params_ftest p-value: 0.8294967967072502
#
# Lag: 6
# ssr_ftest Test statistic value: 0.70238046798347
# ssr_ftest p-value: 0.6482618569609715
#
# ssr_chi2test Test statistic value: 4.7034406338178805
# ssr_chi2test p-value: 0.5823718257173791
#
# lrtest Test statistic value: 4.61711016248006
# lrtest p-value: 0.5937714255283459
#
# params_ftest Test statistic value: 0.7023804679834669
# params_ftest p-value: 0.648261856960973
#
# Lag: 7
# ssr_ftest Test statistic value: 0.6151317055364203
# ssr_ftest p-value: 0.7423955776967199
#
# ssr_chi2test Test statistic value: 4.898480003721218
# ssr_chi2test p-value: 0.6723507347581725
#
# lrtest Test statistic value: 4.804200474357174
# lrtest p-value: 0.6838433363692236
#
# params_ftest Test statistic value: 0.6151317055364236
# params_ftest p-value: 0.7423955776967186
#
# Lag: 8
# ssr_ftest Test statistic value: 0.6186852241487037
# ssr_ftest p-value: 0.7604853029654113
#
# ssr_chi2test Test statistic value: 5.743266609078533
# ssr_chi2test p-value: 0.6759645121279065
#
# lrtest Test statistic value: 5.61321380849563
# lrtest p-value: 0.6904671609527867
#
# params_ftest Test statistic value: 0.6186852241487024
# params_ftest p-value: 0.7604853029654125
#
# Lag: 9
# ssr_ftest Test statistic value: 0.6033876032008142
# ssr_ftest p-value: 0.791594969393822
#
# ssr_chi2test Test statistic value: 6.432229012762077
# ssr_chi2test p-value: 0.6959999096849908
#
# lrtest Test statistic value: 6.268399015412967
# lrtest p-value: 0.7127842139883114
#
# params_ftest Test statistic value: 0.6033876032008155
# params_ftest p-value: 0.791594969393821
#
# Lag: 10
# ssr_ftest Test statistic value: 0.7563941656275655
# ssr_ftest p-value: 0.669921431714568
#
# ssr_chi2test Test statistic value: 9.152369404093541
# ssr_chi2test p-value: 0.5177068927686233
#
# lrtest Test statistic value: 8.822750193755041
# lrtest p-value: 0.5490039295658687
#
# params_ftest Test statistic value: 0.7563941656275647
# params_ftest p-value: 0.6699214317145696
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.7670  , p=0.0103  , df_denom=137, df_num=1
# ssr based chi2 test:   chi2=6.9152  , p=0.0085  , df=1
# likelihood ratio test: chi2=6.7499  , p=0.0094  , df=1
# parameter F test:         F=6.7670  , p=0.0103  , df_denom=137, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8585  , p=0.0609  , df_denom=134, df_num=2
# ssr based chi2 test:   chi2=5.9303  , p=0.0516  , df=2
# likelihood ratio test: chi2=5.8073  , p=0.0548  , df=2
# parameter F test:         F=2.8585  , p=0.0609  , df_denom=134, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6585  , p=0.1791  , df_denom=131, df_num=3
# ssr based chi2 test:   chi2=5.2413  , p=0.1550  , df=3
# likelihood ratio test: chi2=5.1443  , p=0.1615  , df=3
# parameter F test:         F=1.6585  , p=0.1791  , df_denom=131, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2646  , p=0.2874  , df_denom=128, df_num=4
# ssr based chi2 test:   chi2=5.4139  , p=0.2474  , df=4
# likelihood ratio test: chi2=5.3096  , p=0.2570  , df=4
# parameter F test:         F=1.2646  , p=0.2874  , df_denom=128, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3250  , p=0.2578  , df_denom=125, df_num=5
# ssr based chi2 test:   chi2=7.2077  , p=0.2056  , df=5
# likelihood ratio test: chi2=7.0232  , p=0.2189  , df=5
# parameter F test:         F=1.3250  , p=0.2578  , df_denom=125, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.9302  , p=0.0812  , df_denom=122, df_num=6
# ssr based chi2 test:   chi2=12.8150 , p=0.0461  , df=6
# likelihood ratio test: chi2=12.2427 , p=0.0568  , df=6
# parameter F test:         F=1.9302  , p=0.0812  , df_denom=122, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6658  , p=0.1239  , df_denom=119, df_num=7
# ssr based chi2 test:   chi2=13.1302 , p=0.0690  , df=7
# likelihood ratio test: chi2=12.5260 , p=0.0845  , df=7
# parameter F test:         F=1.6658  , p=0.1239  , df_denom=119, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6704  , p=0.1129  , df_denom=116, df_num=8
# ssr based chi2 test:   chi2=15.3220 , p=0.0532  , df=8
# likelihood ratio test: chi2=14.5019 , p=0.0696  , df=8
# parameter F test:         F=1.6704  , p=0.1129  , df_denom=116, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4105  , p=0.1918  , df_denom=113, df_num=9
# ssr based chi2 test:   chi2=14.8293 , p=0.0957  , df=9
# likelihood ratio test: chi2=14.0539 , p=0.1204  , df=9
# parameter F test:         F=1.4105  , p=0.1918  , df_denom=113, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2170  , p=0.2881  , df_denom=110, df_num=10
# ssr based chi2 test:   chi2=14.4934 , p=0.1517  , df=10
# likelihood ratio test: chi2=13.7463 , p=0.1849  , df=10
# parameter F test:         F=1.2170  , p=0.2881  , df_denom=110, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 6.767034673618842
# ssr_ftest p-value: 0.010305852574944433
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 2
# ssr_ftest Test statistic value: 2.858484257621701
# ssr_ftest p-value: 0.060859470549269545
#
# ssr_chi2test Test statistic value: 5.93028823596144
# ssr_chi2test p-value: 0.051553038989831164
#
# lrtest Test statistic value: 5.807270282555237
# lrtest p-value: 0.05482356598319065
#
# params_ftest Test statistic value: 2.8584842576217016
# params_ftest p-value: 0.060859470549269545
#
# Lag: 3
# ssr_ftest Test statistic value: 1.6584943491644406
# ssr_ftest p-value: 0.17912728251065343
#
# ssr_chi2test Test statistic value: 5.241348553847927
# ssr_chi2test p-value: 0.15495379086008942
#
# lrtest Test statistic value: 5.144263891266519
# lrtest p-value: 0.16153313859613672
#
# params_ftest Test statistic value: 1.6584943491644433
# params_ftest p-value: 0.17912728251065343
#
# Lag: 4
# ssr_ftest Test statistic value: 1.2645555875592196
# ssr_ftest p-value: 0.2873675769898539
#
# ssr_chi2test Test statistic value: 5.4138786092379085
# ssr_chi2test p-value: 0.24740397457690305
#
# lrtest Test statistic value: 5.309644684548516
# lrtest p-value: 0.25697541580243016
#
# params_ftest Test statistic value: 1.2645555875592214
# params_ftest p-value: 0.2873675769898539
#
# Lag: 5
# ssr_ftest Test statistic value: 1.3249514392654897
# ssr_ftest p-value: 0.25784053345199504
#
# ssr_chi2test Test statistic value: 7.207735829604264
# ssr_chi2test p-value: 0.20564348891494622
#
# lrtest Test statistic value: 7.023228834348515
# lrtest p-value: 0.2189184748781083
#
# params_ftest Test statistic value: 1.324951439265489
# params_ftest p-value: 0.25784053345199504
#
# Lag: 6
# ssr_ftest Test statistic value: 1.9301600045825824
# ssr_ftest p-value: 0.08115596446323967
#
# ssr_chi2test Test statistic value: 12.814996751736821
# ssr_chi2test p-value: 0.04606971352527103
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 7
# ssr_ftest Test statistic value: 1.6657678432315384
# ssr_ftest p-value: 0.1238938159904187
#
# ssr_chi2test Test statistic value: 13.1301700584133
# ssr_chi2test p-value: 0.06899962484974922
#
# lrtest Test statistic value: 12.526039349872121
# lrtest p-value: 0.08453359765820188
#
# params_ftest Test statistic value: 1.6657678432315346
# params_ftest p-value: 0.12389381599041883
#
# Lag: 8
# ssr_ftest Test statistic value: 1.6704452983203015
# ssr_ftest p-value: 0.11288293894663803
#
# ssr_chi2test Test statistic value: 15.32201549493794
# ssr_chi2test p-value: 0.053178329786300334
#
# lrtest Test statistic value: 14.501862790056975
# lrtest p-value: 0.06958653071408875
#
# params_ftest Test statistic value: 1.6704452983203044
# params_ftest p-value: 0.11288293894663803
#
# Lag: 9
# ssr_ftest Test statistic value: 1.410531606615316
# ssr_ftest p-value: 0.1918225643123775
#
# ssr_chi2test Test statistic value: 14.829305740345092
# ssr_chi2test p-value: 0.09573263517094656
#
# lrtest Test statistic value: 14.053882135177219
# lrtest p-value: 0.12042140412824374
#
# params_ftest Test statistic value: 1.4105316066153135
# params_ftest p-value: 0.1918225643123783
#
# Lag: 10
# ssr_ftest Test statistic value: 1.2170012935141907
# ssr_ftest p-value: 0.2880768915002406
#
# ssr_chi2test Test statistic value: 14.493379040941726
# ssr_chi2test p-value: 0.1516527678016292
#
# lrtest Test statistic value: 13.74625673273124
# lrtest p-value: 0.18488340142821336
#
# params_ftest Test statistic value: 1.217001293514192
# params_ftest p-value: 0.28807689150024035
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0515  , p=0.8208  , df_denom=127, df_num=1
# ssr based chi2 test:   chi2=0.0528  , p=0.8183  , df=1
# likelihood ratio test: chi2=0.0528  , p=0.8183  , df=1
# parameter F test:         F=0.0515  , p=0.8208  , df_denom=127, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8502  , p=0.1615  , df_denom=124, df_num=2
# ssr based chi2 test:   chi2=3.8496  , p=0.1459  , df=2
# likelihood ratio test: chi2=3.7932  , p=0.1501  , df=2
# parameter F test:         F=1.8502  , p=0.1615  , df_denom=124, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3449  , p=0.2631  , df_denom=121, df_num=3
# ssr based chi2 test:   chi2=4.2681  , p=0.2339  , df=3
# likelihood ratio test: chi2=4.1985  , p=0.2408  , df=3
# parameter F test:         F=1.3449  , p=0.2631  , df_denom=121, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8788  , p=0.4790  , df_denom=118, df_num=4
# ssr based chi2 test:   chi2=3.7832  , p=0.4361  , df=4
# likelihood ratio test: chi2=3.7280  , p=0.4441  , df=4
# parameter F test:         F=0.8788  , p=0.4790  , df_denom=118, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7204  , p=0.6094  , df_denom=115, df_num=5
# ssr based chi2 test:   chi2=3.9463  , p=0.5572  , df=5
# likelihood ratio test: chi2=3.8858  , p=0.5660  , df=5
# parameter F test:         F=0.7204  , p=0.6094  , df_denom=115, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6419  , p=0.1421  , df_denom=112, df_num=6
# ssr based chi2 test:   chi2=10.9950 , p=0.0885  , df=6
# likelihood ratio test: chi2=10.5380 , p=0.1037  , df=6
# parameter F test:         F=1.6419  , p=0.1421  , df_denom=112, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2372  , p=0.2888  , df_denom=109, df_num=7
# ssr based chi2 test:   chi2=9.8521  , p=0.1971  , df=7
# likelihood ratio test: chi2=9.4803  , p=0.2200  , df=7
# parameter F test:         F=1.2372  , p=0.2888  , df_denom=109, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1625  , p=0.3287  , df_denom=106, df_num=8
# ssr based chi2 test:   chi2=10.7919 , p=0.2138  , df=8
# likelihood ratio test: chi2=10.3444 , p=0.2417  , df=8
# parameter F test:         F=1.1625  , p=0.3287  , df_denom=106, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0201  , p=0.4291  , df_denom=103, df_num=9
# ssr based chi2 test:   chi2=10.8743 , p=0.2844  , df=9
# likelihood ratio test: chi2=10.4167 , p=0.3178  , df=9
# parameter F test:         F=1.0201  , p=0.4291  , df_denom=103, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9165  , p=0.5213  , df_denom=100, df_num=10
# ssr based chi2 test:   chi2=11.0897 , p=0.3506  , df=10
# likelihood ratio test: chi2=10.6106 , p=0.3887  , df=10
# parameter F test:         F=0.9165  , p=0.5213  , df_denom=100, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.051546878771063974
# ssr_ftest p-value: 0.820758183467783
#
# ssr_chi2test Test statistic value: 0.05276452157667966
# ssr_chi2test p-value: 0.8183207817556262
#
# lrtest Test statistic value: 0.052753816416554855
# lrtest p-value: 0.8183388908925704
#
# params_ftest Test statistic value: 0.05154687877106642
# params_ftest p-value: 0.820758183467783
#
# Lag: 2
# ssr_ftest Test statistic value: 1.8501764176607818
# ssr_ftest p-value: 0.16152302985810146
#
# ssr_chi2test Test statistic value: 3.8495606109393683
# ssr_chi2test p-value: 0.14590780848276896
#
# lrtest Test statistic value: 3.793239895647332
# lrtest p-value: 0.15007502431523814
#
# params_ftest Test statistic value: 1.8501764176607716
# params_ftest p-value: 0.16152302985810396
#
# Lag: 3
# ssr_ftest Test statistic value: 1.3448911425225911
# ssr_ftest p-value: 0.26307054514183165
#
# ssr_chi2test Test statistic value: 4.268084287013843
# ssr_chi2test p-value: 0.23393314326162348
#
# lrtest Test statistic value: 4.198469204649541
# lrtest p-value: 0.24081519153228967
#
# params_ftest Test statistic value: 1.3448911425225865
# params_ftest p-value: 0.263070545141833
#
# Lag: 4
# ssr_ftest Test statistic value: 0.8787768750969781
# ssr_ftest p-value: 0.47895454116502445
#
# ssr_chi2test Test statistic value: 3.7832089199090246
# ssr_chi2test p-value: 0.43613958602866176
#
# lrtest Test statistic value: 3.7279544633224475
# lrtest p-value: 0.44407317017621495
#
# params_ftest Test statistic value: 0.8787768750969834
# params_ftest p-value: 0.47895454116502223
#
# Lag: 5
# ssr_ftest Test statistic value: 0.7203644269038059
# ssr_ftest p-value: 0.6094431802810678
#
# ssr_chi2test Test statistic value: 3.946344251733893
# ssr_chi2test p-value: 0.5571666991039426
#
# lrtest Test statistic value: 3.885804944256961
# lrtest p-value: 0.5659717591080964
#
# params_ftest Test statistic value: 0.7203644269038052
# params_ftest p-value: 0.6094431802810678
#
# Lag: 6
# ssr_ftest Test statistic value: 1.641914109595917
# ssr_ftest p-value: 0.14213697326131153
#
# ssr_chi2test Test statistic value: 10.9949605553298
# ssr_chi2test p-value: 0.08853230741240542
#
# lrtest Test statistic value: 10.538011625873082
# lrtest p-value: 0.10374796253475506
#
# params_ftest Test statistic value: 1.6419141095959076
# params_ftest p-value: 0.14213697326131366
#
# Lag: 7
# ssr_ftest Test statistic value: 1.2371845136223378
# ssr_ftest p-value: 0.2888119053677085
#
# ssr_chi2test Test statistic value: 9.852074842423756
# ssr_chi2test p-value: 0.19711239469482186
#
# lrtest Test statistic value: 9.480259481009597
# lrtest p-value: 0.2199883431410231
#
# params_ftest Test statistic value: 1.2371845136223332
# params_ftest p-value: 0.28881190536771106
#
# Lag: 8
# ssr_ftest Test statistic value: 1.1625410368198157
# ssr_ftest p-value: 0.3287055553793179
#
# ssr_chi2test Test statistic value: 10.791890379534893
# ssr_chi2test p-value: 0.21377208106929657
#
# lrtest Test statistic value: 10.344445197370305
# lrtest p-value: 0.24167766110549554
#
# params_ftest Test statistic value: 1.162541036819817
# params_ftest p-value: 0.3287055553793162
#
# Lag: 9
# ssr_ftest Test statistic value: 1.0200842148654277
# ssr_ftest p-value: 0.42914200476217496
#
# ssr_chi2test Test statistic value: 10.874295805070286
# ssr_chi2test p-value: 0.2844238735580646
#
# lrtest Test statistic value: 10.41666405269325
# lrtest p-value: 0.3178181984683381
#
# params_ftest Test statistic value: 1.0200842148654299
# params_ftest p-value: 0.4291420047621766
#
# Lag: 10
# ssr_ftest Test statistic value: 0.9165048477168977
# ssr_ftest p-value: 0.5213291540392733
#
# ssr_chi2test Test statistic value: 11.08970865737446
# ssr_chi2test p-value: 0.350571735732959
#
# lrtest Test statistic value: 10.610581621120048
# lrtest p-value: 0.3886505153217496
#
# params_ftest Test statistic value: 0.9165048477168952
# params_ftest p-value: 0.521329154039275
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5834  , p=0.4456  , df_denom=301, df_num=1
# ssr based chi2 test:   chi2=0.5892  , p=0.4427  , df=1
# likelihood ratio test: chi2=0.5886  , p=0.4430  , df=1
# parameter F test:         F=0.5834  , p=0.4456  , df_denom=301, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5026  , p=0.0314  , df_denom=298, df_num=2
# ssr based chi2 test:   chi2=7.1228  , p=0.0284  , df=2
# likelihood ratio test: chi2=7.0404  , p=0.0296  , df=2
# parameter F test:         F=3.5026  , p=0.0314  , df_denom=298, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.1277  , p=0.0968  , df_denom=295, df_num=3
# ssr based chi2 test:   chi2=6.5347  , p=0.0883  , df=3
# likelihood ratio test: chi2=6.4650  , p=0.0911  , df=3
# parameter F test:         F=2.1277  , p=0.0968  , df_denom=295, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2580  , p=0.0630  , df_denom=292, df_num=4
# ssr based chi2 test:   chi2=9.3105  , p=0.0538  , df=4
# likelihood ratio test: chi2=9.1695  , p=0.0570  , df=4
# parameter F test:         F=2.2580  , p=0.0630  , df_denom=292, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.7125  , p=0.1316  , df_denom=289, df_num=5
# ssr based chi2 test:   chi2=8.8882  , p=0.1136  , df=5
# likelihood ratio test: chi2=8.7591  , p=0.1191  , df=5
# parameter F test:         F=1.7125  , p=0.1316  , df_denom=289, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.6263  , p=0.0171  , df_denom=286, df_num=6
# ssr based chi2 test:   chi2=16.4740 , p=0.0114  , df=6
# likelihood ratio test: chi2=16.0362 , p=0.0136  , df=6
# parameter F test:         F=2.6263  , p=0.0171  , df_denom=286, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2543  , p=0.0302  , df_denom=283, df_num=7
# ssr based chi2 test:   chi2=16.6162 , p=0.0200  , df=7
# likelihood ratio test: chi2=16.1694 , p=0.0236  , df=7
# parameter F test:         F=2.2543  , p=0.0302  , df_denom=283, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4815  , p=0.0129  , df_denom=280, df_num=8
# ssr based chi2 test:   chi2=21.0570 , p=0.0070  , df=8
# likelihood ratio test: chi2=20.3440 , p=0.0091  , df=8
# parameter F test:         F=2.4815  , p=0.0129  , df_denom=280, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.2454  , p=0.0195  , df_denom=277, df_num=9
# ssr based chi2 test:   chi2=21.5950 , p=0.0103  , df=9
# likelihood ratio test: chi2=20.8436 , p=0.0134  , df=9
# parameter F test:         F=2.2454  , p=0.0195  , df_denom=277, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.1836  , p=0.0190  , df_denom=274, df_num=10
# ssr based chi2 test:   chi2=23.5099 , p=0.0090  , df=10
# likelihood ratio test: chi2=22.6201 , p=0.0122  , df=10
# parameter F test:         F=2.1836  , p=0.0190  , df_denom=274, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.583360446216001
# ssr_ftest p-value: 0.445596404814286
#
# ssr_chi2test Test statistic value: 0.5891746699324396
# ssr_chi2test p-value: 0.4427384463031243
#
# lrtest Test statistic value: 0.5886044743115235
# lrtest p-value: 0.4429592677671075
#
# params_ftest Test statistic value: 0.5833604462160077
# params_ftest p-value: 0.4455964048142729
#
# Lag: 2
# ssr_ftest Test statistic value: 3.5026404383265537
# ssr_ftest p-value: 0.03136367066861335
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 3
# ssr_ftest Test statistic value: 2.127734574058723
# ssr_ftest p-value: 0.09679184640890329
#
# ssr_chi2test Test statistic value: 6.5346695732108575
# ssr_chi2test p-value: 0.08830520367195373
#
# lrtest Test statistic value: 6.464974632178723
# lrtest p-value: 0.09105409969007243
#
# params_ftest Test statistic value: 2.127734574058704
# params_ftest p-value: 0.09679184640890436
#
# Lag: 4
# ssr_ftest Test statistic value: 2.2580394098256464
# ssr_ftest p-value: 0.06298587151782374
#
# ssr_chi2test Test statistic value: 9.310546059692049
# ssr_chi2test p-value: 0.0537890889338582
#
# lrtest Test statistic value: 9.16945112828671
# lrtest p-value: 0.05700078320221895
#
# params_ftest Test statistic value: 2.2580394098256495
# params_ftest p-value: 0.06298587151782158
#
# Lag: 5
# ssr_ftest Test statistic value: 1.712461563368412
# ssr_ftest p-value: 0.13161906970627457
#
# ssr_chi2test Test statistic value: 8.888208806410443
# ssr_chi2test p-value: 0.11360707523732769
#
# lrtest Test statistic value: 8.759085895192015
# lrtest p-value: 0.11906793091300849
#
# params_ftest Test statistic value: 1.7124615633684208
# params_ftest p-value: 0.13161906970627277
#
# Lag: 6
# ssr_ftest Test statistic value: 2.626295492841074
# ssr_ftest p-value: 0.017060679565646716
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 7
# ssr_ftest Test statistic value: 2.254253507562779
# ssr_ftest p-value: 0.030204477445506472
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 8
# ssr_ftest Test statistic value: 2.4814645950396033
# ssr_ftest p-value: 0.012938893332407197
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 9
# ssr_ftest Test statistic value: 2.2454245027387274
# ssr_ftest p-value: 0.019520489185569742
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 10
# ssr_ftest Test statistic value: 2.1836305538786016
# ssr_ftest p-value: 0.01901071794423936
#
# Null hypothesis rejected for ssr_ftest test
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.1196  , p=0.0787  , df_denom=225, df_num=1
# ssr based chi2 test:   chi2=3.1612  , p=0.0754  , df=1
# likelihood ratio test: chi2=3.1395  , p=0.0764  , df=1
# parameter F test:         F=3.1196  , p=0.0787  , df_denom=225, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7708  , p=0.4639  , df_denom=222, df_num=2
# ssr based chi2 test:   chi2=1.5763  , p=0.4547  , df=2
# likelihood ratio test: chi2=1.5709  , p=0.4559  , df=2
# parameter F test:         F=0.7708  , p=0.4639  , df_denom=222, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4033  , p=0.7507  , df_denom=219, df_num=3
# ssr based chi2 test:   chi2=1.2487  , p=0.7414  , df=3
# likelihood ratio test: chi2=1.2452  , p=0.7422  , df=3
# parameter F test:         F=0.4033  , p=0.7507  , df_denom=219, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5836  , p=0.1797  , df_denom=216, df_num=4
# ssr based chi2 test:   chi2=6.5983  , p=0.1587  , df=4
# likelihood ratio test: chi2=6.5034  , p=0.1646  , df=4
# parameter F test:         F=1.5836  , p=0.1797  , df_denom=216, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2791  , p=0.2740  , df_denom=213, df_num=5
# ssr based chi2 test:   chi2=6.7260  , p=0.2418  , df=5
# likelihood ratio test: chi2=6.6270  , p=0.2499  , df=5
# parameter F test:         F=1.2791  , p=0.2740  , df_denom=213, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1368  , p=0.3421  , df_denom=210, df_num=6
# ssr based chi2 test:   chi2=7.2431  , p=0.2989  , df=6
# likelihood ratio test: chi2=7.1280  , p=0.3092  , df=6
# parameter F test:         F=1.1368  , p=0.3421  , df_denom=210, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3688  , p=0.2201  , df_denom=207, df_num=7
# ssr based chi2 test:   chi2=10.2758 , p=0.1735  , df=7
# likelihood ratio test: chi2=10.0451 , p=0.1860  , df=7
# parameter F test:         F=1.3688  , p=0.2201  , df_denom=207, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2241  , p=0.2864  , df_denom=204, df_num=8
# ssr based chi2 test:   chi2=10.6089 , p=0.2249  , df=8
# likelihood ratio test: chi2=10.3621 , p=0.2405  , df=8
# parameter F test:         F=1.2241  , p=0.2864  , df_denom=204, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2891  , p=0.2446  , df_denom=201, df_num=9
# ssr based chi2 test:   chi2=12.6981 , p=0.1767  , df=9
# likelihood ratio test: chi2=12.3452 , p=0.1945  , df=9
# parameter F test:         F=1.2891  , p=0.2446  , df_denom=201, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1057  , p=0.3595  , df_denom=198, df_num=10
# ssr based chi2 test:   chi2=12.2292 , p=0.2700  , df=10
# likelihood ratio test: chi2=11.9000 , p=0.2918  , df=10
# parameter F test:         F=1.1057  , p=0.3595  , df_denom=198, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 3.119646391336314
# ssr_ftest p-value: 0.07870958927489817
#
# ssr_chi2test Test statistic value: 3.1612416765541314
# ssr_chi2test p-value: 0.07540580968322909
#
# lrtest Test statistic value: 3.1395267082076543
# lrtest p-value: 0.07641597953638024
#
# params_ftest Test statistic value: 3.1196463913363686
# params_ftest p-value: 0.07870958927489534
#
# Lag: 2
# ssr_ftest Test statistic value: 0.7708016194113645
# ssr_ftest p-value: 0.46387615925449577
#
# ssr_chi2test Test statistic value: 1.5763240324899077
# ssr_chi2test p-value: 0.45467972169894755
#
# lrtest Test statistic value: 1.5708761165956275
# lrtest p-value: 0.45591993852264756
#
# params_ftest Test statistic value: 0.7708016194113538
# params_ftest p-value: 0.46387615925449577
#
# Lag: 3
# ssr_ftest Test statistic value: 0.4033351380244687
# ssr_ftest p-value: 0.750745084217013
#
# ssr_chi2test Test statistic value: 1.2486813862127386
# ssr_chi2test p-value: 0.7413537196266149
#
# lrtest Test statistic value: 1.2452444709874726
# lrtest p-value: 0.7421745076879601
#
# params_ftest Test statistic value: 0.40333513802447146
# params_ftest p-value: 0.750745084217013
#
# Lag: 4
# ssr_ftest Test statistic value: 1.5835930311379711
# ssr_ftest p-value: 0.17973266919813496
#
# ssr_chi2test Test statistic value: 6.598304296408213
# ssr_chi2test p-value: 0.15870084613787455
#
# lrtest Test statistic value: 6.503404899781344
# lrtest p-value: 0.16457597344909172
#
# params_ftest Test statistic value: 1.5835930311379751
# params_ftest p-value: 0.17973266919813496
#
# Lag: 5
# ssr_ftest Test statistic value: 1.2791442747585544
# ssr_ftest p-value: 0.2740164481941371
#
# ssr_chi2test Test statistic value: 6.726016843800848
# ssr_chi2test p-value: 0.2418271111180977
#
# lrtest Test statistic value: 6.6270132218602384
# lrtest p-value: 0.24988990020319707
#
# params_ftest Test statistic value: 1.279144274758553
# params_ftest p-value: 0.2740164481941374
#
# Lag: 6
# ssr_ftest Test statistic value: 1.1368170498101156
# ssr_ftest p-value: 0.3420576775366854
#
# ssr_chi2test Test statistic value: 7.2431486316473075
# ssr_chi2test p-value: 0.29894524610007916
#
# lrtest Test statistic value: 7.128004785064832
# lrtest p-value: 0.3091715418478305
#
# params_ftest Test statistic value: 1.1368170498101136
# params_ftest p-value: 0.3420576775366854
#
# Lag: 7
# ssr_ftest Test statistic value: 1.3687865879755505
# ssr_ftest p-value: 0.22009141557337453
#
# ssr_chi2test Test statistic value: 10.275818153207757
# ssr_chi2test p-value: 0.17347445510648857
#
# lrtest Test statistic value: 10.045090409144109
# lrtest p-value: 0.18603260364358817
#
# params_ftest Test statistic value: 1.3687865879755472
# params_ftest p-value: 0.2200914155733767
#
# Lag: 8
# ssr_ftest Test statistic value: 1.2241051292908747
# ssr_ftest p-value: 0.2863741940206516
#
# ssr_chi2test Test statistic value: 10.608911120520913
# ssr_chi2test p-value: 0.2248582530419571
#
# lrtest Test statistic value: 10.362141871745962
# lrtest p-value: 0.24052243505294207
#
# params_ftest Test statistic value: 1.2241051292908662
# params_ftest p-value: 0.28637419402065745
#
# Lag: 9
# ssr_ftest Test statistic value: 1.289052547844077
# ssr_ftest p-value: 0.24463579387601236
#
# ssr_chi2test Test statistic value: 12.698129575777475
# ssr_chi2test p-value: 0.17674801146476835
#
# lrtest Test statistic value: 12.3451869205619
# lrtest p-value: 0.19454133489377895
#
# params_ftest Test statistic value: 1.2890525478440706
# params_ftest p-value: 0.2446357938760146
#
# Lag: 10
# ssr_ftest Test statistic value: 1.1056562564602443
# ssr_ftest p-value: 0.3595332283191741
#
# ssr_chi2test Test statistic value: 12.229228291151188
# ssr_chi2test p-value: 0.27000804899590647
#
# lrtest Test statistic value: 11.899982346944512
# lrtest p-value: 0.2918061003559408
#
# params_ftest Test statistic value: 1.1056562564602435
# params_ftest p-value: 0.3595332283191741
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2101  , p=0.6473  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.2143  , p=0.6434  , df=1
# likelihood ratio test: chi2=0.2141  , p=0.6436  , df=1
# parameter F test:         F=0.2101  , p=0.6473  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0505  , p=0.9508  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=0.1043  , p=0.9492  , df=2
# likelihood ratio test: chi2=0.1043  , p=0.9492  , df=2
# parameter F test:         F=0.0505  , p=0.9508  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1284  , p=0.9431  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=0.4036  , p=0.9395  , df=3
# likelihood ratio test: chi2=0.4031  , p=0.9396  , df=3
# parameter F test:         F=0.1284  , p=0.9431  , df_denom=147, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1715  , p=0.9526  , df_denom=144, df_num=4
# ssr based chi2 test:   chi2=0.7291  , p=0.9477  , df=4
# likelihood ratio test: chi2=0.7274  , p=0.9479  , df=4
# parameter F test:         F=0.1715  , p=0.9526  , df_denom=144, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2712  , p=0.9282  , df_denom=141, df_num=5
# ssr based chi2 test:   chi2=1.4621  , p=0.9174  , df=5
# likelihood ratio test: chi2=1.4551  , p=0.9182  , df=5
# parameter F test:         F=0.2712  , p=0.9282  , df_denom=141, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3488  , p=0.9096  , df_denom=138, df_num=6
# ssr based chi2 test:   chi2=2.2898  , p=0.8912  , df=6
# likelihood ratio test: chi2=2.2726  , p=0.8930  , df=6
# parameter F test:         F=0.3488  , p=0.9096  , df_denom=138, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3382  , p=0.9352  , df_denom=135, df_num=7
# ssr based chi2 test:   chi2=2.6303  , p=0.9170  , df=7
# likelihood ratio test: chi2=2.6075  , p=0.9188  , df=7
# parameter F test:         F=0.3382  , p=0.9352  , df_denom=135, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6498  , p=0.7345  , df_denom=132, df_num=8
# ssr based chi2 test:   chi2=5.8682  , p=0.6620  , df=8
# likelihood ratio test: chi2=5.7556  , p=0.6746  , df=8
# parameter F test:         F=0.6498  , p=0.7345  , df_denom=132, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6243  , p=0.7746  , df_denom=129, df_num=9
# ssr based chi2 test:   chi2=6.4464  , p=0.6945  , df=9
# likelihood ratio test: chi2=6.3100  , p=0.7085  , df=9
# parameter F test:         F=0.6243  , p=0.7746  , df_denom=129, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6471  , p=0.7709  , df_denom=126, df_num=10
# ssr based chi2 test:   chi2=7.5497  , p=0.6727  , df=10
# likelihood ratio test: chi2=7.3622  , p=0.6909  , df=10
# parameter F test:         F=0.6471  , p=0.7709  , df_denom=126, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.210140346667453
# ssr_ftest p-value: 0.6473078856096977
#
# ssr_chi2test Test statistic value: 0.21426074562171676
# ssr_chi2test p-value: 0.6434481762663189
#
# lrtest Test statistic value: 0.21411374025228724
# lrtest p-value: 0.6435620271227553
#
# params_ftest Test statistic value: 0.2101403466674683
# params_ftest p-value: 0.6473078856096977
#
# Lag: 2
# ssr_ftest Test statistic value: 0.05048604607234195
# ssr_ftest p-value: 0.9507833441022241
#
# ssr_chi2test Test statistic value: 0.10433782854950671
# ssr_chi2test p-value: 0.9491685251882228
#
# lrtest Test statistic value: 0.10430272693815823
# lrtest p-value: 0.9491851840067479
#
# params_ftest Test statistic value: 0.05048604607233535
# params_ftest p-value: 0.9507833441022241
#
# Lag: 3
# ssr_ftest Test statistic value: 0.12842836571689914
# ssr_ftest p-value: 0.9431015923775825
#
# ssr_chi2test Test statistic value: 0.4036320065388259
# ssr_chi2test p-value: 0.9394911895284042
#
# lrtest Test statistic value: 0.4031039718535112
# lrtest p-value: 0.9396005431003362
#
# params_ftest Test statistic value: 0.12842836571689428
# params_ftest p-value: 0.9431015923775892
#
# Lag: 4
# ssr_ftest Test statistic value: 0.1715486628384323
# ssr_ftest p-value: 0.9526417996545722
#
# ssr_chi2test Test statistic value: 0.7290818170633373
# ssr_chi2test p-value: 0.9476947073882788
#
# lrtest Test statistic value: 0.7273501908113076
# lrtest p-value: 0.9479137477923999
#
# params_ftest Test statistic value: 0.17154866283842785
# params_ftest p-value: 0.9526417996545742
#
# Lag: 5
# ssr_ftest Test statistic value: 0.271249820777859
# ssr_ftest p-value: 0.9282043147361175
#
# ssr_chi2test Test statistic value: 1.4620557715686016
# ssr_chi2test p-value: 0.9174065936956817
#
# lrtest Test statistic value: 1.4550689368592202
# lrtest p-value: 0.9181958782666264
#
# params_ftest Test statistic value: 0.27124982077785675
# params_ftest p-value: 0.9282043147361175
#
# Lag: 6
# ssr_ftest Test statistic value: 0.3487725700334149
# ssr_ftest p-value: 0.9096141507584714
#
# ssr_chi2test Test statistic value: 2.289767742393289
# ssr_chi2test p-value: 0.8912142829606959
#
# lrtest Test statistic value: 2.2725802317441435
# lrtest p-value: 0.8930010086656126
#
# params_ftest Test statistic value: 0.34877257003340983
# params_ftest p-value: 0.9096141507584744
#
# Lag: 7
# ssr_ftest Test statistic value: 0.338185291843284
# ssr_ftest p-value: 0.9351542576770606
#
# ssr_chi2test Test statistic value: 2.6303300476699865
# ssr_chi2test p-value: 0.916967621456439
#
# lrtest Test statistic value: 2.607534034814023
# lrtest p-value: 0.918784362054502
#
# params_ftest Test statistic value: 0.33818529184328877
# params_ftest p-value: 0.9351542576770573
#
# Lag: 8
# ssr_ftest Test statistic value: 0.6498339064043153
# ssr_ftest p-value: 0.7345098313805327
#
# ssr_chi2test Test statistic value: 5.868197094196544
# ssr_chi2test p-value: 0.6619929681684265
#
# lrtest Test statistic value: 5.755588077211826
# lrtest p-value: 0.674587960632087
#
# params_ftest Test statistic value: 0.6498339064043182
# params_ftest p-value: 0.7345098313805294
#
# Lag: 9
# ssr_ftest Test statistic value: 0.6243153577438499
# ssr_ftest p-value: 0.7746067584785272
#
# ssr_chi2test Test statistic value: 6.446419042750451
# ssr_chi2test p-value: 0.6945398745362608
#
# lrtest Test statistic value: 6.309974096511098
# lrtest p-value: 0.7085384840480486
#
# params_ftest Test statistic value: 0.6243153577438572
# params_ftest p-value: 0.7746067584785212
#
# Lag: 10
# ssr_ftest Test statistic value: 0.6471129816909102
# ssr_ftest p-value: 0.7708969465790679
#
# ssr_chi2test Test statistic value: 7.549651453060621
# ssr_chi2test p-value: 0.6727330575675491
#
# lrtest Test statistic value: 7.362175504239303
# lrtest p-value: 0.6908678179486103
#
# params_ftest Test statistic value: 0.6471129816909089
# params_ftest p-value: 0.7708969465790679
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0072  , p=0.9326  , df_denom=244, df_num=1
# ssr based chi2 test:   chi2=0.0073  , p=0.9321  , df=1
# likelihood ratio test: chi2=0.0073  , p=0.9321  , df=1
# parameter F test:         F=0.0072  , p=0.9326  , df_denom=244, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5871  , p=0.5567  , df_denom=241, df_num=2
# ssr based chi2 test:   chi2=1.1985  , p=0.5492  , df=2
# likelihood ratio test: chi2=1.1956  , p=0.5500  , df=2
# parameter F test:         F=0.5871  , p=0.5567  , df_denom=241, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2399  , p=0.2959  , df_denom=238, df_num=3
# ssr based chi2 test:   chi2=3.8292  , p=0.2805  , df=3
# likelihood ratio test: chi2=3.7996  , p=0.2839  , df=3
# parameter F test:         F=1.2399  , p=0.2959  , df_denom=238, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2145  , p=0.3053  , df_denom=235, df_num=4
# ssr based chi2 test:   chi2=5.0441  , p=0.2828  , df=4
# likelihood ratio test: chi2=4.9927  , p=0.2880  , df=4
# parameter F test:         F=1.2145  , p=0.3053  , df_denom=235, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8734  , p=0.4996  , df_denom=232, df_num=5
# ssr based chi2 test:   chi2=4.5743  , p=0.4700  , df=5
# likelihood ratio test: chi2=4.5318  , p=0.4756  , df=5
# parameter F test:         F=0.8734  , p=0.4996  , df_denom=232, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8560  , p=0.5281  , df_denom=229, df_num=6
# ssr based chi2 test:   chi2=5.4277  , p=0.4902  , df=6
# likelihood ratio test: chi2=5.3678  , p=0.4976  , df=6
# parameter F test:         F=0.8560  , p=0.5281  , df_denom=229, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7174  , p=0.6573  , df_denom=226, df_num=7
# ssr based chi2 test:   chi2=5.3553  , p=0.6167  , df=7
# likelihood ratio test: chi2=5.2966  , p=0.6238  , df=7
# parameter F test:         F=0.7174  , p=0.6573  , df_denom=226, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6488  , p=0.7361  , df_denom=223, df_num=8
# ssr based chi2 test:   chi2=5.5861  , p=0.6935  , df=8
# likelihood ratio test: chi2=5.5220  , p=0.7006  , df=8
# parameter F test:         F=0.6488  , p=0.7361  , df_denom=223, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6664  , p=0.7388  , df_denom=220, df_num=9
# ssr based chi2 test:   chi2=6.5156  , p=0.6874  , df=9
# likelihood ratio test: chi2=6.4284  , p=0.6964  , df=9
# parameter F test:         F=0.6664  , p=0.7388  , df_denom=220, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5799  , p=0.8295  , df_denom=217, df_num=10
# ssr based chi2 test:   chi2=6.3603  , p=0.7841  , df=10
# likelihood ratio test: chi2=6.2768  , p=0.7915  , df=10
# parameter F test:         F=0.5799  , p=0.8295  , df_denom=217, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.007174766949618788
# ssr_ftest p-value: 0.9325661760210668
#
# ssr_chi2test Test statistic value: 0.007262981297360002
# ssr_chi2test p-value: 0.9320840051427786
#
# lrtest Test statistic value: 0.00726287451607277
# lrtest p-value: 0.932084503191955
#
# params_ftest Test statistic value: 0.007174766949562214
# params_ftest p-value: 0.9325661760213209
#
# Lag: 2
# ssr_ftest Test statistic value: 0.587083402525241
# ssr_ftest p-value: 0.5567394748701532
#
# ssr_chi2test Test statistic value: 1.1985271122092058
# ssr_chi2test p-value: 0.5492159539335797
#
# lrtest Test statistic value: 1.1956169119719107
# lrtest p-value: 0.5500156998473889
#
# params_ftest Test statistic value: 0.5870834025252262
# params_ftest p-value: 0.5567394748701682
#
# Lag: 3
# ssr_ftest Test statistic value: 1.239937804994886
# ssr_ftest p-value: 0.2958819747445843
#
# ssr_chi2test Test statistic value: 3.8292196918959704
# ssr_chi2test p-value: 0.28050563551523
#
# lrtest Test statistic value: 3.799603549422841
# lrtest p-value: 0.2839322479798265
#
# params_ftest Test statistic value: 1.2399378049948944
# params_ftest p-value: 0.2958819747445767
#
# Lag: 4
# ssr_ftest Test statistic value: 1.2145159797486043
# ssr_ftest p-value: 0.30530661178980023
#
# ssr_chi2test Test statistic value: 5.044117430785692
# ssr_chi2test p-value: 0.2828006534212063
#
# lrtest Test statistic value: 4.992687475052662
# lrtest p-value: 0.28804862926789554
#
# params_ftest Test statistic value: 1.214515979748601
# params_ftest p-value: 0.3053066117898025
#
# Lag: 5
# ssr_ftest Test statistic value: 0.87344385131352
# ssr_ftest p-value: 0.49958577239694235
#
# ssr_chi2test Test statistic value: 4.574285686835892
# ssr_chi2test p-value: 0.47000620800750004
#
# lrtest Test statistic value: 4.531764791031833
# lrtest p-value: 0.47564470065865483
#
# params_ftest Test statistic value: 0.8734438513135137
# params_ftest p-value: 0.4995857723969459
#
# Lag: 6
# ssr_ftest Test statistic value: 0.8560270924976535
# ssr_ftest p-value: 0.5280659141382948
#
# ssr_chi2test Test statistic value: 5.427735101775514
# ssr_chi2test p-value: 0.49023356813280894
#
# lrtest Test statistic value: 5.36776178710511
# lrtest p-value: 0.4975813083447138
#
# params_ftest Test statistic value: 0.8560270924976544
# params_ftest p-value: 0.5280659141382948
#
# Lag: 7
# ssr_ftest Test statistic value: 0.7174198967001973
# ssr_ftest p-value: 0.6573247915864133
#
# ssr_chi2test Test statistic value: 5.355253830678022
# ssr_chi2test p-value: 0.6166954395868441
#
# lrtest Test statistic value: 5.296621353402998
# lrtest p-value: 0.6238146061747412
#
# params_ftest Test statistic value: 0.7174198967001991
# params_ftest p-value: 0.6573247915864102
#
# Lag: 8
# ssr_ftest Test statistic value: 0.6487964745790372
# ssr_ftest p-value: 0.7360529852855977
#
# ssr_chi2test Test statistic value: 5.586050364088572
# ssr_chi2test p-value: 0.6934888249349265
#
# lrtest Test statistic value: 5.522033550263018
# lrtest p-value: 0.7005976579202846
#
# params_ftest Test statistic value: 0.64879647457903
# params_ftest p-value: 0.7360529852856033
#
# Lag: 9
# ssr_ftest Test statistic value: 0.6664013704202767
# ssr_ftest p-value: 0.7388311526801391
#
# ssr_chi2test Test statistic value: 6.515587944427341
# ssr_chi2test p-value: 0.6874106804466147
#
# lrtest Test statistic value: 6.428356224674189
# lrtest p-value: 0.6963982293565932
#
# params_ftest Test statistic value: 0.6664013704202725
# params_ftest p-value: 0.7388311526801417
#
# Lag: 10
# ssr_ftest Test statistic value: 0.5799067150150496
# ssr_ftest p-value: 0.8295240196783055
#
# ssr_chi2test Test statistic value: 6.360267196939255
# ssr_chi2test p-value: 0.7841417114800483
#
# lrtest Test statistic value: 6.276766280617721
# lrtest p-value: 0.7914992356729273
#
# params_ftest Test statistic value: 0.5799067150150469
# params_ftest p-value: 0.8295240196783076
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3634  , p=0.2438  , df_denom=330, df_num=1
# ssr based chi2 test:   chi2=1.3757  , p=0.2408  , df=1
# likelihood ratio test: chi2=1.3729  , p=0.2413  , df=1
# parameter F test:         F=1.3634  , p=0.2438  , df_denom=330, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5432  , p=0.2152  , df_denom=327, df_num=2
# ssr based chi2 test:   chi2=3.1337  , p=0.2087  , df=2
# likelihood ratio test: chi2=3.1190  , p=0.2102  , df=2
# parameter F test:         F=1.5432  , p=0.2152  , df_denom=327, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1600  , p=0.3251  , df_denom=324, df_num=3
# ssr based chi2 test:   chi2=3.5553  , p=0.3137  , df=3
# likelihood ratio test: chi2=3.5364  , p=0.3161  , df=3
# parameter F test:         F=1.1600  , p=0.3251  , df_denom=324, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7793  , p=0.5393  , df_denom=321, df_num=4
# ssr based chi2 test:   chi2=3.2048  , p=0.5242  , df=4
# likelihood ratio test: chi2=3.1893  , p=0.5267  , df=4
# parameter F test:         F=0.7793  , p=0.5393  , df_denom=321, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7119  , p=0.6149  , df_denom=318, df_num=5
# ssr based chi2 test:   chi2=3.6828  , p=0.5959  , df=5
# likelihood ratio test: chi2=3.6623  , p=0.5990  , df=5
# parameter F test:         F=0.7119  , p=0.6149  , df_denom=318, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8602  , p=0.5245  , df_denom=315, df_num=6
# ssr based chi2 test:   chi2=5.3741  , p=0.4968  , df=6
# likelihood ratio test: chi2=5.3306  , p=0.5022  , df=6
# parameter F test:         F=0.8602  , p=0.5245  , df_denom=315, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0161  , p=0.4197  , df_denom=312, df_num=7
# ssr based chi2 test:   chi2=7.4544  , p=0.3832  , df=7
# likelihood ratio test: chi2=7.3707  , p=0.3913  , df=7
# parameter F test:         F=1.0161  , p=0.4197  , df_denom=312, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0824  , p=0.3751  , df_denom=309, df_num=8
# ssr based chi2 test:   chi2=9.1359  , p=0.3310  , df=8
# likelihood ratio test: chi2=9.0103  , p=0.3414  , df=8
# parameter F test:         F=1.0824  , p=0.3751  , df_denom=309, df_num=8
#
# Granger Causality
# ...
# ssr based chi2 test:   chi2=24.1720 , p=0.0011  , df=7
# likelihood ratio test: chi2=23.0654 , p=0.0017  , df=7
# parameter F test:         F=3.2443  , p=0.0026  , df_denom=233, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.8767  , p=0.0045  , df_denom=230, df_num=8
# ssr based chi2 test:   chi2=24.7145 , p=0.0017  , df=8
# likelihood ratio test: chi2=23.5548 , p=0.0027  , df=8
# parameter F test:         F=2.8767  , p=0.0045  , df_denom=230, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6679  , p=0.0058  , df_denom=227, df_num=9
# ssr based chi2 test:   chi2=26.0209 , p=0.0020  , df=9
# likelihood ratio test: chi2=24.7346 , p=0.0033  , df=9
# parameter F test:         F=2.6679  , p=0.0058  , df_denom=227, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5722  , p=0.0058  , df_denom=224, df_num=10
# ssr based chi2 test:   chi2=28.1338 , p=0.0017  , df=10
# likelihood ratio test: chi2=26.6324 , p=0.0030  , df=10
# parameter F test:         F=2.5722  , p=0.0058  , df_denom=224, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.010809482528097799
# ssr_ftest p-value: 0.9172772440011852
#
# ssr_chi2test Test statistic value: 0.010938679530425661
# ssr_chi2test p-value: 0.9167026240936964
#
# lrtest Test statistic value: 0.010938443996394653
# lrtest p-value: 0.9167035176220547
#
# params_ftest Test statistic value: 0.010809482528105192
# params_ftest p-value: 0.9172772440010789
#
# Lag: 2
# ssr_ftest Test statistic value: 2.0082427794230115
# ssr_ftest p-value: 0.13640129993709652
#
# ssr_chi2test Test statistic value: 4.09746309027437
# ssr_chi2test p-value: 0.12889830161187465
#
# lrtest Test statistic value: 4.064636797030289
# lrtest p-value: 0.13103138576101864
#
# params_ftest Test statistic value: 2.0082427794230213
# params_ftest p-value: 0.13640129993709427
#
# Lag: 3
# ssr_ftest Test statistic value: 1.1586644668558794
# ssr_ftest p-value: 0.32617274076944924
#
# ssr_chi2test Test statistic value: 3.5753074977267136
# ssr_chi2test p-value: 0.31112553273332105
#
# lrtest Test statistic value: 3.550182121422665
# lrtest p-value: 0.3143117531842709
#
# params_ftest Test statistic value: 1.1586644668558916
# params_ftest p-value: 0.3261727407694422
#
# Lag: 4
# ssr_ftest Test statistic value: 4.033517557470289
# ssr_ftest p-value: 0.003475293111433766
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 5
# ssr_ftest Test statistic value: 3.8615265434607546
# ssr_ftest p-value: 0.002201821319531575
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 6
# ssr_ftest Test statistic value: 3.679459842905471
# ssr_ftest p-value: 0.0016327827977613927
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 7
# ssr_ftest Test statistic value: 3.244284382127791
# ssr_ftest p-value: 0.002642962295808684
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 8
# ssr_ftest Test statistic value: 2.876691152730536
# ssr_ftest p-value: 0.0045303127775245585
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 9
# ssr_ftest Test statistic value: 2.667902586901578
# ssr_ftest p-value: 0.005821814377549241
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 10
# ssr_ftest Test statistic value: 2.5722373555930296
# ssr_ftest p-value: 0.00578132286358199
#
# Null hypothesis rejected for ssr_ftest test
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3262  , p=0.2516  , df_denom=128, df_num=1
# ssr based chi2 test:   chi2=1.3573  , p=0.2440  , df=1
# likelihood ratio test: chi2=1.3503  , p=0.2452  , df=1
# parameter F test:         F=1.3262  , p=0.2516  , df_denom=128, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6897  , p=0.0277  , df_denom=125, df_num=2
# ssr based chi2 test:   chi2=7.6745  , p=0.0216  , df=2
# likelihood ratio test: chi2=7.4565  , p=0.0240  , df=2
# parameter F test:         F=3.6897  , p=0.0277  , df_denom=125, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3323  , p=0.0775  , df_denom=122, df_num=3
# ssr based chi2 test:   chi2=7.3982  , p=0.0602  , df=3
# likelihood ratio test: chi2=7.1939  , p=0.0660  , df=3
# parameter F test:         F=2.3323  , p=0.0775  , df_denom=122, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8530  , p=0.1232  , df_denom=119, df_num=4
# ssr based chi2 test:   chi2=7.9725  , p=0.0926  , df=4
# likelihood ratio test: chi2=7.7341  , p=0.1018  , df=4
# parameter F test:         F=1.8530  , p=0.1232  , df_denom=119, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9486  , p=0.0915  , df_denom=116, df_num=5
# ssr based chi2 test:   chi2=10.6672 , p=0.0584  , df=5
# likelihood ratio test: chi2=10.2428 , p=0.0686  , df=5
# parameter F test:         F=1.9486  , p=0.0915  , df_denom=116, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0278  , p=0.0676  , df_denom=113, df_num=6
# ssr based chi2 test:   chi2=13.5663 , p=0.0349  , df=6
# likelihood ratio test: chi2=12.8845 , p=0.0449  , df=6
# parameter F test:         F=2.0278  , p=0.0676  , df_denom=113, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8180  , p=0.0908  , df_denom=110, df_num=7
# ssr based chi2 test:   chi2=14.4610 , p=0.0436  , df=7
# likelihood ratio test: chi2=13.6839 , p=0.0571  , df=7
# parameter F test:         F=1.8180  , p=0.0908  , df_denom=110, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8303  , p=0.0792  , df_denom=107, df_num=8
# ssr based chi2 test:   chi2=16.9688 , p=0.0304  , df=8
# likelihood ratio test: chi2=15.9039 , p=0.0438  , df=8
# parameter F test:         F=1.8303  , p=0.0792  , df_denom=107, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6017  , p=0.1243  , df_denom=104, df_num=9
# ssr based chi2 test:   chi2=17.0490 , p=0.0480  , df=9
# likelihood ratio test: chi2=15.9664 , p=0.0676  , df=9
# parameter F test:         F=1.6017  , p=0.1243  , df_denom=104, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2222  , p=0.2860  , df_denom=101, df_num=10
# ssr based chi2 test:   chi2=14.7630 , p=0.1409  , df=10
# likelihood ratio test: chi2=13.9358 , p=0.1759  , df=10
# parameter F test:         F=1.2222  , p=0.2860  , df_denom=101, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 1.3261872719310621
# ssr_ftest p-value: 0.25163113296841966
#
# ssr_chi2test Test statistic value: 1.3572697861169463
# ssr_chi2test p-value: 0.24401121244697133
#
# lrtest Test statistic value: 1.3502867518619155
# lrtest p-value: 0.24522799272152782
#
# params_ftest Test statistic value: 1.3261872719310839
# params_ftest p-value: 0.25163113296841966
#
# Lag: 2
# ssr_ftest Test statistic value: 3.689659045452442
# ssr_ftest p-value: 0.027740678943502996
#
# Null hypothesis rejected for ssr_ftest test
# Lag: 3
# ssr_ftest Test statistic value: 2.332256041129098
# ssr_ftest p-value: 0.07747889229621101
#
# ssr_chi2test Test statistic value: 7.3982220321062355
# ssr_chi2test p-value: 0.06023204681487977
#
# lrtest Test statistic value: 7.193853474967625
# lrtest p-value: 0.06596907261863748
#
# params_ftest Test statistic value: 2.332256041129099
# params_ftest p-value: 0.07747889229621101
#
# Lag: 4
# ssr_ftest Test statistic value: 1.8529817783083637
# ssr_ftest p-value: 0.12324602161637276
#
# ssr_chi2test Test statistic value: 7.972493029360355
# ssr_chi2test p-value: 0.09259102267081439
#
# lrtest Test statistic value: 7.734060060498564
# lrtest p-value: 0.1018202648614013
#
# params_ftest Test statistic value: 1.852981778308362
# params_ftest p-value: 0.123246021616373
#
# Lag: 5
# ssr_ftest Test statistic value: 1.9486463362697353
# ssr_ftest p-value: 0.09154735716960015
#
# ssr_chi2test Test statistic value: 10.667158823545535
# ssr_chi2test p-value: 0.05839353997400108
#
# lrtest Test statistic value: 10.242777687806779
# lrtest p-value: 0.06864134466660228
#
# params_ftest Test statistic value: 1.948646336269738
# params_ftest p-value: 0.09154735716959957
#
# Lag: 6
# ssr_ftest Test statistic value: 2.0277643145569484
# ssr_ftest p-value: 0.06762166797123143
#
# ssr_chi2test Test statistic value: 13.566281608894272
# ssr_chi2test p-value: 0.03487465257231696
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 7
# ssr_ftest Test statistic value: 1.817950804264204
# ssr_ftest p-value: 0.09077905930627243
#
# ssr_chi2test Test statistic value: 14.460972306647076
# ssr_chi2test p-value: 0.04356426440225095
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 8
# ssr_ftest Test statistic value: 1.8303028497536495
# ssr_ftest p-value: 0.07916457630731914
#
# ssr_chi2test Test statistic value: 16.968789036968413
# ssr_chi2test p-value: 0.030435722718671992
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 9
# ssr_ftest Test statistic value: 1.6017164536594555
# ssr_ftest p-value: 0.12427346435298287
#
# ssr_chi2test Test statistic value: 17.049039559625164
# ssr_chi2test p-value: 0.047953537113575244
#
# Null hypothesis rejected for ssr_chi2test test
# Lag: 10
# ssr_ftest Test statistic value: 1.222180594319572
# ssr_ftest p-value: 0.2860438352307926
#
# ssr_chi2test Test statistic value: 14.762973515543344
# ssr_chi2test p-value: 0.14094533637769063
#
# lrtest Test statistic value: 13.93584801081019
# lrtest p-value: 0.17593794253457404
#
# params_ftest Test statistic value: 1.2221805943195552
# params_ftest p-value: 0.28604383523080323
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2356  , p=0.6282  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.2409  , p=0.6236  , df=1
# likelihood ratio test: chi2=0.2407  , p=0.6237  , df=1
# parameter F test:         F=0.2356  , p=0.6282  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9230  , p=0.1503  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=3.9928  , p=0.1358  , df=2
# likelihood ratio test: chi2=3.9353  , p=0.1398  , df=2
# parameter F test:         F=1.9230  , p=0.1503  , df_denom=131, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0199  , p=0.3862  , df_denom=128, df_num=3
# ssr based chi2 test:   chi2=3.2269  , p=0.3579  , df=3
# likelihood ratio test: chi2=3.1890  , p=0.3634  , df=3
# parameter F test:         F=1.0199  , p=0.3862  , df_denom=128, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0042  , p=0.4080  , df_denom=125, df_num=4
# ssr based chi2 test:   chi2=4.3062  , p=0.3662  , df=4
# likelihood ratio test: chi2=4.2384  , p=0.3747  , df=4
# parameter F test:         F=1.0042  , p=0.4080  , df_denom=125, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5518  , p=0.1789  , df_denom=122, df_num=5
# ssr based chi2 test:   chi2=8.4584  , p=0.1327  , df=5
# likelihood ratio test: chi2=8.2003  , p=0.1455  , df=5
# parameter F test:         F=1.5518  , p=0.1789  , df_denom=122, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9367  , p=0.4715  , df_denom=119, df_num=6
# ssr based chi2 test:   chi2=6.2340  , p=0.3975  , df=6
# likelihood ratio test: chi2=6.0913  , p=0.4130  , df=6
# parameter F test:         F=0.9367  , p=0.4715  , df_denom=119, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2567  , p=0.2780  , df_denom=116, df_num=7
# ssr based chi2 test:   chi2=9.9345  , p=0.1923  , df=7
# likelihood ratio test: chi2=9.5759  , p=0.2139  , df=7
# parameter F test:         F=1.2567  , p=0.2780  , df_denom=116, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1019  , p=0.3673  , df_denom=113, df_num=8
# ssr based chi2 test:   chi2=10.1414 , p=0.2552  , df=8
# likelihood ratio test: chi2=9.7653  , p=0.2819  , df=8
# parameter F test:         F=1.1019  , p=0.3673  , df_denom=113, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0421  , p=0.4116  , df_denom=110, df_num=9
# ssr based chi2 test:   chi2=10.9987 , p=0.2758  , df=9
# likelihood ratio test: chi2=10.5548 , p=0.3075  , df=9
# parameter F test:         F=1.0421  , p=0.4116  , df_denom=110, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1579  , p=0.3274  , df_denom=107, df_num=10
# ssr based chi2 test:   chi2=13.8512 , p=0.1799  , df=10
# likelihood ratio test: chi2=13.1518 , p=0.2153  , df=10
# parameter F test:         F=1.1579  , p=0.3274  , df_denom=107, df_num=10
# Lag: 1
# ssr_ftest Test statistic value: 0.23562546357762174
# ssr_ftest p-value: 0.6281763455717391
#
# ssr_chi2test Test statistic value: 0.24090066052338938
# ssr_chi2test p-value: 0.623556365790919
#
# lrtest Test statistic value: 0.2406891087438794
# lrtest p-value: 0.6237088466000451
#
# params_ftest Test statistic value: 0.235625463577596
# params_ftest p-value: 0.6281763455717608
#
# Lag: 2
# ssr_ftest Test statistic value: 1.9229815513304982
# ssr_ftest p-value: 0.1502741137844024
#
# ssr_chi2test Test statistic value: 3.9927555874953855
# ssr_chi2test p-value: 0.13582638444368883
#
# lrtest Test statistic value: 3.9352674033871438
# lrtest p-value: 0.139787243480983
#
# params_ftest Test statistic value: 1.922981551330508
# params_ftest p-value: 0.15027411378440006
#
# Lag: 3
# ssr_ftest Test statistic value: 1.0198676240610531
# ssr_ftest p-value: 0.3862057778057737
#
# ssr_chi2test Test statistic value: 3.226924904255676
# ssr_chi2test p-value: 0.35794351660907914
#
# lrtest Test statistic value: 3.1889618412659217
# lrtest p-value: 0.3633984622476634
#
# params_ftest Test statistic value: 1.019867624061049
# params_ftest p-value: 0.3862057778057737
#
# Lag: 4
# ssr_ftest Test statistic value: 1.0042388663908661
# ssr_ftest p-value: 0.40801479571826343
#
# ssr_chi2test Test statistic value: 4.306176259084034
# ssr_chi2test p-value: 0.3661523415798394
#
# lrtest Test statistic value: 4.238432882724851
# lrtest p-value: 0.3746981120830836
#
# params_ftest Test statistic value: 1.0042388663908666
# params_ftest p-value: 0.40801479571826343
#
# Lag: 5
# ssr_ftest Test statistic value: 1.5517592225193186
# ssr_ftest p-value: 0.17885370630859268
#
# ssr_chi2test Test statistic value: 8.458359696519237
# ssr_chi2test p-value: 0.13271842149251192
#
# lrtest Test statistic value: 8.200283616100052
# lrtest p-value: 0.14553756674918833
#
# params_ftest Test statistic value: 1.5517592225193173
# params_ftest p-value: 0.17885370630859268
#
# Lag: 6
# ssr_ftest Test statistic value: 0.9366716126755809
# ssr_ftest p-value: 0.47150805678628527
#
# ssr_chi2test Test statistic value: 6.233982497807227
# ssr_chi2test p-value: 0.39749629926778673
#
# lrtest Test statistic value: 6.091252482066636
# lrtest p-value: 0.41304600963898846
#
# params_ftest Test statistic value: 0.9366716126755804
# params_ftest p-value: 0.47150805678628704
#
# Lag: 7
# ssr_ftest Test statistic value: 1.2567128772300153
# ssr_ftest p-value: 0.2780076414216257
#
# ssr_chi2test Test statistic value: 9.934531969137277
# ssr_chi2test p-value: 0.19231394254871267
#
# lrtest Test statistic value: 9.575857266834419
# lrtest p-value: 0.21390992099059156
#
# params_ftest Test statistic value: 1.2567128772300202
# params_ftest p-value: 0.27800764142162215
#
# Lag: 8
# ssr_ftest Test statistic value: 1.1019009278378944
# ssr_ftest p-value: 0.36729565555659616
#
# ssr_chi2test Test statistic value: 10.141389070366463
# ssr_chi2test p-value: 0.2552422087652416
#
# lrtest Test statistic value: 9.76525997939072
# lrtest p-value: 0.2818897181949531
#
# params_ftest Test statistic value: 1.1019009278378933
# params_ftest p-value: 0.3672956555565973
#
# Lag: 9
# ssr_ftest Test statistic value: 1.0420784348439285
# ssr_ftest p-value: 0.41162896560492457
#
# ssr_chi2test Test statistic value: 10.998664207761829
# ssr_chi2test p-value: 0.27580050971399916
#
# lrtest Test statistic value: 10.554841510938843
# lrtest p-value: 0.3074595551993408
#
# params_ftest Test statistic value: 1.0420784348439278
# params_ftest p-value: 0.41162896560492457
#
# Lag: 10
# ssr_ftest Test statistic value: 1.157871992607256
# ssr_ftest p-value: 0.3273746115386828
#
# ssr_chi2test Test statistic value: 13.851178976983999
# ssr_chi2test p-value: 0.17988866714562965
#
# lrtest Test statistic value: 13.151770718106206
# lrtest p-value: 0.2153095367598661
#
# params_ftest Test statistic value: 1.157871992607259
# params_ftest p-value: 0.32737461153868197
