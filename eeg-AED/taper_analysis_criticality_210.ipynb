# %% [markdown]
# # AED Taper Analysis (Using AD Ratios)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, pickle
from numpy import hanning
from scipy.fftpack import fft
from scipy.signal import iirnotch, filtfilt
from ieeg_utils import *

TABLES_DIRECTORY = "../../Data/giant_tables"
IEEG_DIRECTORY = "../../Data/ieeg/all/2_min"
OUTPUT_DIRECTORY = "../../Data/aed_taper_criticality/gamma_normalization_960_lags"

# %%
patient_hup_ids = []
# Iterate through all files in TABLES_DIRECTORY
for filename in os.listdir(TABLES_DIRECTORY):
    # Only look at filename that are .csv files and does not begin with .
    if filename.endswith(".csv") and not filename.startswith("."):
        # Get the patient_hup_id from the filename which is after _ and before .
        patient_hup_id = str(filename.split("_")[1].split(".")[0])
        patient_hup_ids.append(patient_hup_id)

patient_hup_ids = [153]
patient_hup_ids = sorted(patient_hup_ids)
len(patient_hup_ids)
# Out:
# 1

# %%
# Create an empty dictionary to store all the data
data_dict = {"dataset_name": [], "max_hour": [], "sample_rate": [], "hup_id": []}

# Iterate through the directory
for filename in os.listdir(IEEG_DIRECTORY):
    if filename.endswith(".pkl"):  # Only process .pkl files
        # Split the filename to get the dataset_name, hour, and sample_rate
        parts = filename.split("_")
        dataset_name = "_".join(parts[:-4])  # Exclude the '_hr' from the dataset_name
        hour = int(parts[-3])
        sample_rate = int(parts[-1].split(".")[0])

        # Extract hup_id from dataset_name
        hup_id = dataset_name.split("_")[0].split("HUP")[1]

        # If the dataset_name is already in the dictionary, update the max_hour
        if dataset_name in data_dict["dataset_name"]:
            index = data_dict["dataset_name"].index(dataset_name)
            data_dict["max_hour"][index] = max(data_dict["max_hour"][index], hour)
        else:
            # Else, add the dataset_name, hour, sample_rate and hup_id to the dictionary
            data_dict["dataset_name"].append(dataset_name)
            data_dict["max_hour"].append(hour)
            data_dict["sample_rate"].append(sample_rate)
            data_dict["hup_id"].append(hup_id)

# Create a DataFrame from the dictionary
datasets_df = pd.DataFrame(data_dict)
# Make max_hour and sample_rate and hup_id integers
datasets_df["max_hour"] = datasets_df["max_hour"].astype(int)
datasets_df["sample_rate"] = datasets_df["sample_rate"].astype(int)
datasets_df["hup_id"] = datasets_df["hup_id"].astype(int)
# Sort by hup_id
datasets_df = datasets_df.sort_values(by=["hup_id"])
# Reset the index
datasets_df = datasets_df.reset_index(drop=True)
# Create a column called max_hour_count that is the max_hour + 1
datasets_df["max_hour_count"] = datasets_df["max_hour"] + 1
datasets_df
# Out:
#           dataset_name  max_hour  sample_rate  hup_id  max_hour_count
# 0       HUP138_phaseII       172         1024     138             173
# 1   HUP140_phaseII_D02       128         1024     140             129
# 2   HUP140_phaseII_D01        19         1024     140              20
# 3       HUP141_phaseII       146          512     141             147
# 4       HUP142_phaseII       311          512     142             312
# ..                 ...       ...          ...     ...             ...
# 81  HUP215_phaseII_D01        14         2048     215              15
# 82  HUP216_phaseII_D01       143          512     216             144
# 83  HUP216_phaseII_D02       144          512     216             145
# 84      HUP223_phaseII       135         1024     223             136
# 85      HUP224_phaseII       145         1024     224             146
#
# [86 rows x 5 columns]

# %%
# Only keep the datasets that are in the patient_hup_ids
datasets_df = datasets_df[datasets_df["hup_id"].isin(patient_hup_ids)]
# Sort by hup_id then by dataset_name
datasets_df = datasets_df.sort_values(by=["hup_id", "dataset_name"])
# Reset the index
datasets_df = datasets_df.reset_index(drop=True)
# Drop the row with dataset_name = HUP153_phaseII_D02
datasets_df = datasets_df.drop(
    datasets_df[datasets_df["dataset_name"] == "HUP153_phaseII_D02"].index
)
datasets_df
# Out:
#          dataset_name  max_hour  sample_rate  hup_id  max_hour_count
# 0  HUP153_phaseII_D01       166          512     153             167

# %%
# Load ./data/ieeg_starts.xlsx into a dataframe
ieeg_starts_df = pd.read_excel("../../Data/ieeg_starts.xlsx")
ieeg_starts_df
# Out:
#     hup_id  ieeg_start
# 0      225   38.024167
# 1      224   37.582778
# 2      223   32.985556
# 3      221   37.690000
# 4      219   33.396667
# ..     ...         ...
# 75     141   37.249444
# 76     140   35.197500
# 77     139   37.151667
# 78     138   37.529444
# 79     137   13.654444
#
# [80 rows x 2 columns]

# %%
# Frequency range of interest
freq_range = (60, 100)

for patient_hup_id in patient_hup_ids:
    print(f"Processing patient {patient_hup_id}")

    # Find the ieeg_start value for patient_hup_id in ieeg_starts_df and convert it into float
    ieeg_start_hrs = float(
        ieeg_starts_df.loc[
            ieeg_starts_df["hup_id"] == patient_hup_id, "ieeg_start"
        ].values[0]
    )
    aligned_emu_start_time_hrs = round(ieeg_start_hrs)

    # Initialize a DataFrame to store the results for this patient
    results_df = pd.DataFrame()

    # Read in the giant table for this patient
    hourly_patient_features_df = pd.read_csv(
        os.path.join(TABLES_DIRECTORY, f"HUP_{str(patient_hup_id)}.csv")
    )

    # Get the row in datasets_df correspinding the patient_hup_id
    patient_datasets_df = datasets_df[datasets_df["hup_id"] == patient_hup_id]

    # Find the dataset_name and sample_rate for the first row in patient_datasets_df
    dataset_name = patient_datasets_df.iloc[0]["dataset_name"]
    sample_rate = patient_datasets_df.iloc[0]["sample_rate"]

    # Window size for FFT
    window_size = int(sample_rate * 0.125)  # 125 ms

    # Iterate hour from taper_start to taper_end
    for hour in range(10, 96):
        print(f"Processing hour {hour}")
        # Get the filename
        filename = f"{dataset_name}_hr_{hour}_fs_{sample_rate}.pkl"
        # Get the full path to the file
        full_path = os.path.join(IEEG_DIRECTORY, filename)

        # Load the data
        try:
            with open(full_path, "rb") as f:
                # print(f"Loading {filename}")
                eeg_segment_df = pickle.load(f)
        except FileNotFoundError:
            print(f"Skipping {hour} for {dataset_name}")
            continue

        channel_labels = eeg_segment_df.columns.values.tolist()
        channel_indices = np.arange(len(channel_labels))
        channel_types_df = check_channel_types(channel_labels)
        # Get a list of "name" in channel_types_df whose type is seeg
        seeg_channel_labels = channel_types_df[channel_types_df["type"] == "seeg"][
            "name"
        ].tolist()

        eeg_segment_df = eeg_segment_df[seeg_channel_labels]

        # Initialize a list to store the autocorrelations for each electrode
        autocorrelations = []

        # For each electrode
        for electrode in seeg_channel_labels:
            print(f"Processing electrode {electrode}")

            # Get the EEG signal for this electrode
            signal = eeg_segment_df[electrode]

            # Apply a notch filter at 60 Hz to remove line noise
            notch_b, notch_a = iirnotch(60, 30, sample_rate)
            signal = filtfilt(notch_b, notch_a, signal)

            # Calculate the power modulation
            power_modulation = []
            for i in range(0, len(signal), window_size):
                # Get the signal for this window
                window = signal[i : i + window_size]

                # Apply Hanning window
                window *= hanning(window_size)

                # Calculate FFT
                fft_result = fft(window)

                # Calculate power in the frequency range of interest
                power = np.abs(fft_result[freq_range[0] : freq_range[1]]) ** 2

                # # Normalize the power estimates by taking the logarithm
                # power = np.log(power)

                # Add the mean power to the power modulation
                power_modulation.append(np.nanmean(power))

            print(len(power_modulation))

            # Calculate the autocorrelation of the power modulation for lags from 0 to min(max_lag * sample_rate, len(power_modulation))
            autocorrelation = [
                np.correlate(
                    power_modulation[: -lag or None],
                    power_modulation[lag:],
                    mode="valid",
                )[0]
                for lag in range(len(power_modulation))
            ]

            # # Normalize the autocorrelation
            # autocorrelation /= max(autocorrelation)

            # Add the autocorrelation to the list
            autocorrelations.append(autocorrelation)

        # # Calculate ACW for each autocorrelation
        # acws = [calculate_acw(autocorrelation) for autocorrelation in autocorrelations]

        # # Calculate the average ACW
        # avg_acw = np.mean(acws)

        # Calculate the average autocorrelation for each lag across all electrodes
        avg_autocorrelation = np.nanmean(autocorrelations, axis=0)

        # Add the results to the DataFrame
        results_df = pd.concat(
            [
                results_df,
                pd.DataFrame(
                    [
                        {
                            "emu_hour": hour,
                            **{
                                f"lag_{i}": avg_autocorrelation[i]
                                for i in range(len(power_modulation))
                            },
                        }
                    ]
                ),
            ],
            ignore_index=True,
        )

    # Save the results to a CSV file
    results_df.to_csv(
        os.path.join(OUTPUT_DIRECTORY, f"HUP_{patient_hup_id}.csv"), index=False
    )
# Out:
# Processing patient 153
# Processing hour 10
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 11
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 12
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 13
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 14
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 15
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 16
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 17
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# ...
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 94
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960
# Processing hour 95
# Processing electrode LA01
# 960
# Processing electrode LA02
# 960
# Processing electrode LA03
# 960
# Processing electrode LA04
# 960
# Processing electrode LA05
# 960
# Processing electrode LA06
# 960
# Processing electrode LA07
# 960
# Processing electrode LA08
# 960
# Processing electrode LB01
# 960
# Processing electrode LB02
# 960
# Processing electrode LB03
# 960
# Processing electrode LB04
# 960
# Processing electrode LB05
# 960
# Processing electrode LB06
# 960
# Processing electrode LB07
# 960
# Processing electrode LB08
# 960
# Processing electrode LC01
# 960
# Processing electrode LC10
# 960
# Processing electrode LC11
# 960
# Processing electrode LC12
# 960
# Processing electrode LC02
# 960
# Processing electrode LC03
# 960
# Processing electrode LC04
# 960
# Processing electrode LC05
# 960
# Processing electrode LC06
# 960
# Processing electrode LC07
# 960
# Processing electrode LC08
# 960
# Processing electrode LC09
# 960
# Processing electrode LD01
# 960
# Processing electrode LD10
# 960
# Processing electrode LD11
# 960
# Processing electrode LD12
# 960
# Processing electrode LD02
# 960
# Processing electrode LD03
# 960
# Processing electrode LD04
# 960
# Processing electrode LD05
# 960
# Processing electrode LD06
# 960
# Processing electrode LD07
# 960
# Processing electrode LD08
# 960
# Processing electrode LD09
# 960
# Processing electrode LE01
# 960
# Processing electrode LE10
# 960
# Processing electrode LE11
# 960
# Processing electrode LE02
# 960
# Processing electrode LE03
# 960
# Processing electrode LE04
# 960
# Processing electrode LE05
# 960
# Processing electrode LE06
# 960
# Processing electrode LE07
# 960
# Processing electrode LE08
# 960
# Processing electrode LE09
# 960
# Processing electrode LF01
# 960
# Processing electrode LF10
# 960
# Processing electrode LF11
# 960
# Processing electrode LF12
# 960
# Processing electrode LF02
# 960
# Processing electrode LF03
# 960
# Processing electrode LF04
# 960
# Processing electrode LF05
# 960
# Processing electrode LF06
# 960
# Processing electrode LF07
# 960
# Processing electrode LF08
# 960
# Processing electrode LF09
# 960
# Processing electrode LG01
# 960
# Processing electrode LG10
# 960
# Processing electrode LG11
# 960
# Processing electrode LG12
# 960
# Processing electrode LG02
# 960
# Processing electrode LG03
# 960
# Processing electrode LG04
# 960
# Processing electrode LG05
# 960
# Processing electrode LG06
# 960
# Processing electrode LG07
# 960
# Processing electrode LG08
# 960
# Processing electrode LG09
# 960
# Processing electrode LH01
# 960
# Processing electrode LH10
# 960
# Processing electrode LH11
# 960
# Processing electrode LH12
# 960
# Processing electrode LH02
# 960
# Processing electrode LH03
# 960
# Processing electrode LH04
# 960
# Processing electrode LH05
# 960
# Processing electrode LH06
# 960
# Processing electrode LH07
# 960
# Processing electrode LH08
# 960
# Processing electrode LH09
# 960
# Processing electrode LI01
# 960
# Processing electrode LI10
# 960
# Processing electrode LI11
# 960
# Processing electrode LI12
# 960
# Processing electrode LI02
# 960
# Processing electrode LI03
# 960
# Processing electrode LI04
# 960
# Processing electrode LI05
# 960
# Processing electrode LI06
# 960
# Processing electrode LI07
# 960
# Processing electrode LI08
# 960
# Processing electrode LI09
# 960
# Processing electrode LJ01
# 960
# Processing electrode LJ10
# 960
# Processing electrode LJ11
# 960
# Processing electrode LJ12
# 960
# Processing electrode LJ02
# 960
# Processing electrode LJ03
# 960
# Processing electrode LJ04
# 960
# Processing electrode LJ05
# 960
# Processing electrode LJ06
# 960
# Processing electrode LJ07
# 960
# Processing electrode LJ08
# 960
# Processing electrode LJ09
# 960
# Processing electrode RA01
# 960
# Processing electrode RA02
# 960
# Processing electrode RA03
# 960
# Processing electrode RA04
# 960
# Processing electrode RA05
# 960
# Processing electrode RA06
# 960
# Processing electrode RA07
# 960
# Processing electrode RA08
# 960
# Processing electrode RB01
# 960
# Processing electrode RB02
# 960
# Processing electrode RB03
# 960
# Processing electrode RB04
# 960
# Processing electrode RB05
# 960
# Processing electrode RB06
# 960
# Processing electrode RB07
# 960
# Processing electrode RB08
# 960
# Processing electrode RC01
# 960
# Processing electrode RC10
# 960
# Processing electrode RC11
# 960
# Processing electrode RC12
# 960
# Processing electrode RC02
# 960
# Processing electrode RC03
# 960
# Processing electrode RC04
# 960
# Processing electrode RC05
# 960
# Processing electrode RC06
# 960
# Processing electrode RC07
# 960
# Processing electrode RC08
# 960
# Processing electrode RC09
# 960
# Processing electrode RD01
# 960
# Processing electrode RD10
# 960
# Processing electrode RD11
# 960
# Processing electrode RD12
# 960
# Processing electrode RD02
# 960
# Processing electrode RD03
# 960
# Processing electrode RD04
# 960
# Processing electrode RD05
# 960
# Processing electrode RD06
# 960
# Processing electrode RD07
# 960
# Processing electrode RD08
# 960
# Processing electrode RD09
# 960
# Processing electrode RE01
# 960
# Processing electrode RE10
# 960
# Processing electrode RE11
# 960
# Processing electrode RE02
# 960
# Processing electrode RE03
# 960
# Processing electrode RE04
# 960
# Processing electrode RE05
# 960
# Processing electrode RE06
# 960
# Processing electrode RE07
# 960
# Processing electrode RE08
# 960
# Processing electrode RE09
# 960
# Processing electrode RF01
# 960
# Processing electrode RF10
# 960
# Processing electrode RF11
# 960
# Processing electrode RF12
# 960
# Processing electrode RF02
# 960
# Processing electrode RF03
# 960
# Processing electrode RF04
# 960
# Processing electrode RF05
# 960
# Processing electrode RF06
# 960
# Processing electrode RF07
# 960
# Processing electrode RF08
# 960
# Processing electrode RF09
# 960
# Processing electrode RG01
# 960
# Processing electrode RG10
# 960
# Processing electrode RG11
# 960
# Processing electrode RG12
# 960
# Processing electrode RG02
# 960
# Processing electrode RG03
# 960
# Processing electrode RG04
# 960
# Processing electrode RG05
# 960
# Processing electrode RG06
# 960
# Processing electrode RG07
# 960
# Processing electrode RG08
# 960
# Processing electrode RG09
# 960
# Processing electrode RH01
# 960
# Processing electrode RH10
# 960
# Processing electrode RH11
# 960
# Processing electrode RH12
# 960
# Processing electrode RH02
# 960
# Processing electrode RH03
# 960
# Processing electrode RH04
# 960
# Processing electrode RH05
# 960
# Processing electrode RH06
# 960
# Processing electrode RH07
# 960
# Processing electrode RH08
# 960
# Processing electrode RH09
# 960
# Processing electrode RI01
# 960
# Processing electrode RI10
# 960
# Processing electrode RI11
# 960
# Processing electrode RI12
# 960
# Processing electrode RI02
# 960
# Processing electrode RI03
# 960
# Processing electrode RI04
# 960
# Processing electrode RI05
# 960
# Processing electrode RI06
# 960
# Processing electrode RI07
# 960
# Processing electrode RI08
# 960
# Processing electrode RI09
# 960
# Processing electrode RJ01
# 960
# Processing electrode RJ10
# 960
# Processing electrode RJ11
# 960
# Processing electrode RJ12
# 960
# Processing electrode RJ02
# 960
# Processing electrode RJ03
# 960
# Processing electrode RJ04
# 960
# Processing electrode RJ05
# 960
# Processing electrode RJ06
# 960
# Processing electrode RJ07
# 960
# Processing electrode RJ08
# 960
# Processing electrode RJ09
# 960

# %%
# Load HUP_153.csv from output directory
hup_153_df = pd.read_csv(os.path.join(OUTPUT_DIRECTORY, "HUP_153.csv"))

# For each row, calculate the first lag drops below of the first lag. Add that number as a column named acw
hup_153_df["acw_after"] = hup_153_df.apply(
    lambda row: np.argmax(row[1:] < row[1] * 0.4), axis=1
)

hup_153_df

# for each row, plot lag_0 to lag_19, all in the same plot
for index, row in hup_153_df.iterrows():
    # plt.plot(range(20), row[1:21]) but make it redder as index increases
    plt.loglog(range(1, 949), row[2:950], color=(index / len(hup_153_df), 0, 0))
    plt.title(f"hour {row.emu_hour}")
    plt.show()
# Make the curve with higher emu_hour redder

# %%
# Plot the awc column over time
plt.plot(hup_153_df["emu_hour"], hup_153_df["acw_after"])
plt.title("HUP 153")
plt.xlabel("Time (hours)")
plt.ylabel("ACW")
plt.show()

# %%
180 - aligned_emu_start_time_hrs
# Out:
# 144
