# %% [markdown]
# # Mix Effect Models

# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

TABLES_DIRECTORY = "../../Data/giant_tables"

# %%
patient_hup_ids = []
# Iterate through all files in TABLES_DIRECTORY
for filename in os.listdir(TABLES_DIRECTORY):
    # Only look at filename that are .csv files and does not begin with .
    if filename.endswith(".csv") and not filename.startswith("."):
        # Get the patient_hup_id from the filename which is after _ and before .
        patient_hup_id = int(filename.split("_")[1].split(".")[0])
        patient_hup_ids.append(patient_hup_id)

patient_hup_ids = sorted(patient_hup_ids)
len(patient_hup_ids)
# Out:
# 62

# %%
for patient_hup_id in patient_hup_ids:
    # Read in the giant table for this patient
    hourly_patient_features_df = pd.read_csv(
        os.path.join(TABLES_DIRECTORY, f"HUP_{patient_hup_id}.csv")
    )

    # Only keep the emu_hour, teager_energy_delta, kuramoto_delta, spikes_avg_all, and med_sum_no_lorazepam_raw columns
    data = hourly_patient_features_df[
        [
            "emu_hour",
            "teager_energy_delta",
            "kuramoto_delta",
            "spikes_avg_all",
            "med_sum_no_lorazepam_raw",
        ]
    ]

    # Fill missing values using linear interpolation
    data_interpolated = data.interpolate(method="linear")

    # Drop remaining rows with missing values
    data_clean = data_interpolated.dropna(
        subset=[
            "teager_energy_delta",
            "kuramoto_delta",
            "spikes_avg_all",
            "med_sum_no_lorazepam_raw",
        ]
    )

    # Define the model formula
    predict_teager_energy_delta_formula = "teager_energy_delta ~ kuramoto_delta + spikes_avg_all + med_sum_no_lorazepam_raw"
    predict_aed_sum_formula = "med_sum_no_lorazepam_raw ~ kuramoto_delta + spikes_avg_all + teager_energy_delta"
    predict_kuramoto_delta_formula = "kuramoto_delta ~ med_sum_no_lorazepam_raw + spikes_avg_all + teager_energy_delta"
    predict_spikes_formula = "spikes_avg_all ~ med_sum_no_lorazepam_raw + kuramoto_delta + teager_energy_delta"

    all_formulae = [
        predict_teager_energy_delta_formula,
        predict_aed_sum_formula,
        predict_kuramoto_delta_formula,
        predict_spikes_formula,
    ]

    for formula in all_formulae:
        # Fit the model
        model = smf.ols(formula, data=data_clean)
        result = model.fit()

        # Print the summary statistics of the fitted model
        print(result.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.442
# Model:                             OLS   Adj. R-squared:                  0.430
# Method:                  Least Squares   F-statistic:                     38.78
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           1.60e-18
# Time:                         01:36:14   Log-Likelihood:                 104.79
# No. Observations:                  151   AIC:                            -201.6
# Df Residuals:                      147   BIC:                            -189.5
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    1.4955      0.155      9.638      0.000       1.189       1.802
# kuramoto_delta              -8.8131      1.004     -8.782      0.000     -10.796      -6.830
# spikes_avg_all               0.1613      0.045      3.588      0.000       0.072       0.250
# med_sum_no_lorazepam_raw     0.0060      0.002      3.559      0.001       0.003       0.009
# ==============================================================================
# Omnibus:                        4.309   Durbin-Watson:                   1.620
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                4.339
# Skew:                           0.409   Prob(JB):                        0.114
# Kurtosis:                       2.852   Cond. No.                     2.11e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.082
# Model:                                  OLS   Adj. R-squared:                  0.063
# Method:                       Least Squares   F-statistic:                     4.360
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):            0.00566
# Time:                              01:36:14   Log-Likelihood:                -475.85
# No. Observations:                       151   AIC:                             959.7
# Df Residuals:                           147   BIC:                             971.8
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -5.6191      9.260     -0.607      0.545     -23.919      12.681
# kuramoto_delta        143.6276     56.735      2.532      0.012      31.505     255.750
# spikes_avg_all         -2.0679      2.186     -0.946      0.346      -6.387       2.251
# teager_energy_delta    13.1720      3.702      3.559      0.001       5.857      20.487
# ==============================================================================
# Omnibus:                        5.413   Durbin-Watson:                   0.723
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                4.422
# Skew:                           0.318   Prob(JB):                        0.110
# Kurtosis:                       2.454   Cond. No.                         132.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.372
# Model:                            OLS   Adj. R-squared:                  0.359
# Method:                 Least Squares   F-statistic:                     29.02
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           8.50e-15
# Time:                        01:36:14   Log-Likelihood:                 513.95
# No. Observations:                 151   AIC:                            -1020.
# Df Residuals:                     147   BIC:                            -1008.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1571      0.002     63.224      0.000       0.152       0.162
# med_sum_no_lorazepam_raw     0.0003      0.000      2.532      0.012    6.38e-05       0.001
# spikes_avg_all               0.0004      0.003      0.135      0.893      -0.006       0.007
# teager_energy_delta         -0.0390      0.004     -8.782      0.000      -0.048      -0.030
# ==============================================================================
# Omnibus:                        2.769   Durbin-Watson:                   1.605
# Prob(Omnibus):                  0.250   Jarque-Bera (JB):                2.552
# Skew:                           0.318   Prob(JB):                        0.279
# Kurtosis:                       3.018   Cond. No.                         147.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     6.517
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           0.000361
# Time:                        01:36:14   Log-Likelihood:                 19.452
# No. Observations:                 151   AIC:                            -30.90
# Df Residuals:                     147   BIC:                            -18.83
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0066      0.349      0.019      0.985      -0.683       0.696
# med_sum_no_lorazepam_raw    -0.0029      0.003     -0.946      0.346      -0.009       0.003
# kuramoto_delta               0.2941      2.181      0.135      0.893      -4.015       4.603
# teager_energy_delta          0.4994      0.139      3.588      0.000       0.224       0.774
# ==============================================================================
# Omnibus:                      143.824   Durbin-Watson:                   0.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2153.054
# Skew:                           3.508   Prob(JB):                         0.00
# Kurtosis:                      20.117   Cond. No.                     2.61e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.61e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.636
# Model:                             OLS   Adj. R-squared:                  0.630
# Method:                  Least Squares   F-statistic:                     101.3
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           5.63e-38
# Time:                         01:36:14   Log-Likelihood:                 235.01
# No. Observations:                  178   AIC:                            -462.0
# Df Residuals:                      174   BIC:                            -449.3
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.9493      0.054     17.733      0.000       0.844       1.055
# kuramoto_delta              -6.2504      0.410    -15.235      0.000      -7.060      -5.441
# spikes_avg_all               0.2407      0.046      5.188      0.000       0.149       0.332
# med_sum_no_lorazepam_raw     0.0017      0.004      0.445      0.657      -0.006       0.009
# ==============================================================================
# Omnibus:                       14.268   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.969
# Skew:                           0.570   Prob(JB):                     0.000207
# Kurtosis:                       3.995   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.025
# Model:                                  OLS   Adj. R-squared:                  0.008
# Method:                       Least Squares   F-statistic:                     1.469
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):              0.225
# Time:                              01:36:14   Log-Likelihood:                -300.54
# No. Observations:                       178   AIC:                             609.1
# Df Residuals:                           174   BIC:                             621.8
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -1.4141      1.814     -0.780      0.437      -4.994       2.166
# kuramoto_delta         18.0002     12.626      1.426      0.156      -6.919      42.919
# spikes_avg_all         -0.9563      1.008     -0.949      0.344      -2.945       1.032
# teager_energy_delta     0.6832      1.535      0.445      0.657      -2.347       3.713
# ==============================================================================
# Omnibus:                       77.561   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.381
# Skew:                           2.007   Prob(JB):                     2.05e-41
# Kurtosis:                       6.026   Cond. No.                         133.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.595
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     85.07
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           6.28e-34
# Time:                        01:36:14   Log-Likelihood:                 611.01
# No. Observations:                 178   AIC:                            -1214.
# Df Residuals:                     174   BIC:                            -1201.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1421      0.001    110.476      0.000       0.140       0.145
# med_sum_no_lorazepam_raw     0.0006      0.000      1.426      0.156      -0.000       0.002
# spikes_avg_all               0.0129      0.006      2.176      0.031       0.001       0.025
# teager_energy_delta         -0.0914      0.006    -15.235      0.000      -0.103      -0.080
# ==============================================================================
# Omnibus:                        2.143   Durbin-Watson:                   1.397
# Prob(Omnibus):                  0.342   Jarque-Bera (JB):                1.753
# Skew:                           0.222   Prob(JB):                        0.416
# Kurtosis:                       3.199   Cond. No.                         20.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     11.96
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           3.71e-07
# Time:                        01:36:14   Log-Likelihood:                 160.41
# No. Observations:                 178   AIC:                            -312.8
# Df Residuals:                     174   BIC:                            -300.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.2469      0.135     -1.828      0.069      -0.514       0.020
# med_sum_no_lorazepam_raw    -0.0054      0.006     -0.949      0.344      -0.017       0.006
# kuramoto_delta               2.0465      0.940      2.176      0.031       0.191       3.902
# teager_energy_delta          0.5565      0.107      5.188      0.000       0.345       0.768
# ==============================================================================
# Omnibus:                       62.887   Durbin-Watson:                   1.281
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              156.478
# Skew:                           1.537   Prob(JB):                     1.05e-34
# Kurtosis:                       6.414   Cond. No.                         222.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.288
# Model:                             OLS   Adj. R-squared:                  0.274
# Method:                  Least Squares   F-statistic:                     20.47
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           3.40e-11
# Time:                         01:36:14   Log-Likelihood:                -189.17
# No. Observations:                  156   AIC:                             386.3
# Df Residuals:                      152   BIC:                             398.5
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    1.2914      0.675      1.913      0.058      -0.042       2.625
# kuramoto_delta              -5.9154      3.765     -1.571      0.118     -13.355       1.524
# spikes_avg_all               0.3331      0.058      5.740      0.000       0.218       0.448
# med_sum_no_lorazepam_raw     0.0454      0.012      3.779      0.000       0.022       0.069
# ==============================================================================
# Omnibus:                       30.881   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.662
# Skew:                           1.127   Prob(JB):                     5.45e-10
# Kurtosis:                       4.219   Cond. No.                     1.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.121
# Model:                                  OLS   Adj. R-squared:                  0.103
# Method:                       Least Squares   F-statistic:                     6.952
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):           0.000205
# Time:                              01:36:14   Log-Likelihood:                -479.98
# No. Observations:                       156   AIC:                             968.0
# Df Residuals:                           152   BIC:                             980.2
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              19.4997      4.112      4.742      0.000      11.376      27.624
# kuramoto_delta          5.5597     24.480      0.227      0.821     -42.806      53.925
# spikes_avg_all          0.2230      0.413      0.541      0.590      -0.592       1.038
# teager_energy_delta     1.8904      0.500      3.779      0.000       0.902       2.879
# ==============================================================================
# Omnibus:                       63.843   Durbin-Watson:                   0.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.237
# Skew:                           1.586   Prob(JB):                     8.19e-47
# Kurtosis:                       7.753   Cond. No.                         185.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9224
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):              0.432
# Time:                        01:36:14   Log-Likelihood:                 410.78
# No. Observations:                 156   AIC:                            -813.6
# Df Residuals:                     152   BIC:                            -801.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1612      0.006     24.843      0.000       0.148       0.174
# med_sum_no_lorazepam_raw  6.101e-05      0.000      0.227      0.821      -0.000       0.001
# spikes_avg_all               0.0004      0.001      0.272      0.786      -0.002       0.003
# teager_energy_delta         -0.0027      0.002     -1.571      0.118      -0.006       0.001
# ==============================================================================
# Omnibus:                      181.750   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6594.821
# Skew:                           4.373   Prob(JB):                         0.00
# Kurtosis:                      33.628   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     13.47
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           7.64e-08
# Time:                        01:36:14   Log-Likelihood:                -226.08
# No. Observations:                 156   AIC:                             460.2
# Df Residuals:                     152   BIC:                             472.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.2665      0.865      0.308      0.758      -1.443       1.976
# med_sum_no_lorazepam_raw     0.0086      0.016      0.541      0.590      -0.023       0.040
# kuramoto_delta               1.3084      4.808      0.272      0.786      -8.191      10.807
# teager_energy_delta          0.5348      0.093      5.740      0.000       0.351       0.719
# ==============================================================================
# Omnibus:                       16.341   Durbin-Watson:                   0.593
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.193
# Skew:                           0.810   Prob(JB):                     0.000112
# Kurtosis:                       3.417   Cond. No.                     1.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.412
# Model:                             OLS   Adj. R-squared:                  0.406
# Method:                  Least Squares   F-statistic:                     74.37
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           1.71e-36
# Time:                         01:36:14   Log-Likelihood:                -422.11
# No. Observations:                  323   AIC:                             852.2
# Df Residuals:                      319   BIC:                             867.3
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -3.0788      0.498     -6.184      0.000      -4.058      -2.099
# kuramoto_delta              30.6179      3.984      7.686      0.000      22.780      38.455
# spikes_avg_all               1.3757      0.141      9.770      0.000       1.099       1.653
# med_sum_no_lorazepam_raw     0.0244      0.003      7.753      0.000       0.018       0.031
# ==============================================================================
# Omnibus:                       19.271   Durbin-Watson:                   1.610
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.620
# Skew:                           0.424   Prob(JB):                     6.10e-07
# Kurtosis:                       4.187   Cond. No.                     1.72e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.72e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.238
# Model:                                  OLS   Adj. R-squared:                  0.231
# Method:                       Least Squares   F-statistic:                     33.23
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):           1.03e-18
# Time:                              01:36:14   Log-Likelihood:                -1323.5
# No. Observations:                       323   AIC:                             2655.
# Df Residuals:                           319   BIC:                             2670.
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              16.6554      8.534      1.952      0.052      -0.135      33.446
# kuramoto_delta        -26.7982     70.650     -0.379      0.705    -165.797     112.201
# spikes_avg_all        -19.5744      2.374     -8.244      0.000     -24.246     -14.903
# teager_energy_delta     6.4884      0.837      7.753      0.000       4.842       8.135
# ==============================================================================
# Omnibus:                       34.943   Durbin-Watson:                   0.556
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.461
# Skew:                           0.890   Prob(JB):                     3.65e-10
# Kurtosis:                       3.251   Cond. No.                         226.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     24.80
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           1.90e-14
# Time:                        01:36:14   Log-Likelihood:                 982.86
# No. Observations:                 323   AIC:                            -1958.
# Df Residuals:                     319   BIC:                            -1943.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1180      0.002     72.615      0.000       0.115       0.121
# med_sum_no_lorazepam_raw -1.682e-05   4.44e-05     -0.379      0.705      -0.000    7.04e-05
# spikes_avg_all              -0.0024      0.002     -1.168      0.244      -0.006       0.002
# teager_energy_delta          0.0051      0.001      7.686      0.000       0.004       0.006
# ==============================================================================
# Omnibus:                      559.707   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           266127.927
# Skew:                           9.659   Prob(JB):                         0.00
# Kurtosis:                     142.287   Cond. No.                         79.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     45.88
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           1.12e-24
# Time:                        01:36:14   Log-Likelihood:                -81.971
# No. Observations:                 323   AIC:                             171.9
# Df Residuals:                     319   BIC:                             187.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.6647      0.180      3.693      0.000       0.311       1.019
# med_sum_no_lorazepam_raw    -0.0090      0.001     -8.244      0.000      -0.011      -0.007
# kuramoto_delta              -1.7639      1.510     -1.168      0.244      -4.734       1.206
# teager_energy_delta          0.1674      0.017      9.770      0.000       0.134       0.201
# ==============================================================================
# Omnibus:                       24.074   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.260
# Skew:                           0.691   Prob(JB):                     1.20e-06
# Kurtosis:                       3.338   Cond. No.                     1.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.259
# Model:                             OLS   Adj. R-squared:                  0.250
# Method:                  Least Squares   F-statistic:                     28.95
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           4.37e-16
# Time:                         01:36:14   Log-Likelihood:                -1.0654
# No. Observations:                  252   AIC:                             10.13
# Df Residuals:                      248   BIC:                             24.25
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    2.1327      0.269      7.940      0.000       1.604       2.662
# kuramoto_delta             -17.0925      2.282     -7.489      0.000     -21.588     -12.597
# spikes_avg_all               0.5750      0.103      5.586      0.000       0.372       0.778
# med_sum_no_lorazepam_raw     0.0008      0.001      0.705      0.481      -0.001       0.003
# ==============================================================================
# Omnibus:                       92.620   Durbin-Watson:                   1.459
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              369.605
# Skew:                           1.485   Prob(JB):                     5.51e-81
# Kurtosis:                       8.136   Cond. No.                     2.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.070
# Model:                                  OLS   Adj. R-squared:                  0.058
# Method:                       Least Squares   F-statistic:                     6.180
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):           0.000458
# Time:                              01:36:14   Log-Likelihood:                -1017.2
# No. Observations:                       252   AIC:                             2042.
# Df Residuals:                           248   BIC:                             2057.
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              30.6817     16.852      1.821      0.070      -2.510      63.873
# kuramoto_delta       -185.9159    142.040     -1.309      0.192    -465.674      93.842
# spikes_avg_all         20.9382      6.014      3.482      0.001       9.093      32.783
# teager_energy_delta     2.5221      3.578      0.705      0.481      -4.524       9.568
# ==============================================================================
# Omnibus:                       26.295   Durbin-Watson:                   0.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.317
# Skew:                           0.877   Prob(JB):                     9.61e-08
# Kurtosis:                       3.018   Cond. No.                         174.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     20.73
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           5.13e-12
# Time:                        01:36:14   Log-Likelihood:                 927.27
# No. Observations:                 252   AIC:                            -1847.
# Df Residuals:                     248   BIC:                            -1832.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1185      0.001    172.369      0.000       0.117       0.120
# med_sum_no_lorazepam_raw  -3.69e-05   2.82e-05     -1.309      0.192   -9.24e-05    1.86e-05
# spikes_avg_all               0.0102      0.003      3.817      0.000       0.005       0.015
# teager_energy_delta         -0.0108      0.001     -7.489      0.000      -0.014      -0.008
# ==============================================================================
# Omnibus:                      145.413   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2696.147
# Skew:                          -1.852   Prob(JB):                         0.00
# Kurtosis:                      18.590   Cond. No.                         137.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     17.05
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           4.25e-10
# Time:                        01:36:14   Log-Likelihood:                 135.59
# No. Observations:                 252   AIC:                            -263.2
# Df Residuals:                     248   BIC:                            -249.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.5303      0.172     -3.090      0.002      -0.868      -0.192
# med_sum_no_lorazepam_raw     0.0022      0.001      3.482      0.001       0.001       0.003
# kuramoto_delta               5.4514      1.428      3.817      0.000       2.639       8.264
# teager_energy_delta          0.1944      0.035      5.586      0.000       0.126       0.263
# ==============================================================================
# Omnibus:                       50.044   Durbin-Watson:                   0.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.213
# Skew:                           1.142   Prob(JB):                     1.04e-17
# Kurtosis:                       4.494   Cond. No.                     3.13e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.087
# Model:                             OLS   Adj. R-squared:                  0.070
# Method:                  Least Squares   F-statistic:                     5.167
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):            0.00195
# Time:                         01:36:14   Log-Likelihood:                -13.986
# No. Observations:                  166   AIC:                             35.97
# Df Residuals:                      162   BIC:                             48.42
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.3103      0.113      2.757      0.007       0.088       0.533
# kuramoto_delta               0.0197      0.758      0.026      0.979      -1.477       1.516
# spikes_avg_all               0.2302      0.060      3.820      0.000       0.111       0.349
# med_sum_no_lorazepam_raw     0.0012      0.002      0.627      0.532      -0.003       0.005
# ==============================================================================
# Omnibus:                       42.249   Durbin-Watson:                   1.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.155
# Skew:                           1.210   Prob(JB):                     1.07e-17
# Kurtosis:                       5.332   Cond. No.                     1.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.064
# Model:                                  OLS   Adj. R-squared:                  0.047
# Method:                       Least Squares   F-statistic:                     3.720
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):             0.0127
# Time:                              01:36:14   Log-Likelihood:                -628.91
# No. Observations:                       166   AIC:                             1266.
# Df Residuals:                           162   BIC:                             1278.
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              21.3512      4.367      4.889      0.000      12.728      29.975
# kuramoto_delta         95.4213     29.865      3.195      0.002      36.446     154.396
# spikes_avg_all          0.3921      2.556      0.153      0.878      -4.655       5.439
# teager_energy_delta     1.9976      3.188      0.627      0.532      -4.298       8.293
# ==============================================================================
# Omnibus:                       12.173   Durbin-Watson:                   0.496
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                6.937
# Skew:                           0.327   Prob(JB):                       0.0312
# Kurtosis:                       2.242   Cond. No.                         40.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     4.122
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):            0.00755
# ...
# Intercept                    0.3548      0.060      5.911      0.000       0.236       0.473
# kuramoto_delta               0.4266      0.331      1.288      0.199      -0.227       1.080
# spikes_avg_all               0.0265      0.047      0.560      0.576      -0.067       0.120
# med_sum_no_lorazepam_raw    -0.0039      0.017     -0.229      0.819      -0.037       0.030
# ==============================================================================
# Omnibus:                      163.677   Durbin-Watson:                   1.489
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3762.917
# Skew:                           3.005   Prob(JB):                         0.00
# Kurtosis:                      23.897   Cond. No.                         29.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.029
# Model:                                  OLS   Adj. R-squared:                  0.014
# Method:                       Least Squares   F-statistic:                     1.890
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):              0.133
# Time:                              01:36:18   Log-Likelihood:                -345.81
# No. Observations:                       191   AIC:                             699.6
# Df Residuals:                           187   BIC:                             712.6
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               1.6088      0.256      6.282      0.000       1.104       2.114
# kuramoto_delta         -0.3354      1.434     -0.234      0.815      -3.164       2.493
# spikes_avg_all         -0.4709      0.201     -2.338      0.020      -0.868      -0.074
# teager_energy_delta    -0.0722      0.315     -0.229      0.819      -0.694       0.549
# ==============================================================================
# Omnibus:                       33.295   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.545
# Skew:                           1.106   Prob(JB):                     2.12e-10
# Kurtosis:                       3.837   Cond. No.                         15.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.5997
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):              0.616
# Time:                        01:36:18   Log-Likelihood:                 222.60
# No. Observations:                 191   AIC:                            -437.2
# Df Residuals:                     187   BIC:                            -424.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.1288      0.011     11.867      0.000       0.107       0.150
# med_sum_no_lorazepam_raw    -0.0009      0.004     -0.234      0.815      -0.008       0.006
# spikes_avg_all               0.0018      0.010      0.171      0.864      -0.019       0.022
# teager_energy_delta          0.0206      0.016      1.288      0.199      -0.011       0.052
# ==============================================================================
# Omnibus:                      335.369   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            71533.024
# Skew:                           8.812   Prob(JB):                         0.00
# Kurtosis:                      96.155   Cond. No.                         7.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.974
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):              0.119
# Time:                        01:36:18   Log-Likelihood:                -149.57
# No. Observations:                 191   AIC:                             307.1
# Df Residuals:                     187   BIC:                             320.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.3674      0.097      3.779      0.000       0.176       0.559
# med_sum_no_lorazepam_raw    -0.0603      0.026     -2.338      0.020      -0.111      -0.009
# kuramoto_delta               0.0878      0.513      0.171      0.864      -0.925       1.100
# teager_energy_delta          0.0631      0.113      0.560      0.576      -0.159       0.285
# ==============================================================================
# Omnibus:                      338.356   Durbin-Watson:                   1.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            74453.992
# Skew:                           8.959   Prob(JB):                         0.00
# Kurtosis:                      98.049   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.465
# Model:                             OLS   Adj. R-squared:                  0.453
# Method:                  Least Squares   F-statistic:                     39.96
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           1.19e-18
# Time:                         01:36:18   Log-Likelihood:                 62.134
# No. Observations:                  142   AIC:                            -116.3
# Df Residuals:                      138   BIC:                            -104.4
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.5536      0.178     -3.108      0.002      -0.906      -0.201
# kuramoto_delta               6.2626      1.843      3.398      0.001       2.618       9.907
# spikes_avg_all               0.1882      0.030      6.367      0.000       0.130       0.247
# med_sum_no_lorazepam_raw     0.0163      0.004      3.770      0.000       0.008       0.025
# ==============================================================================
# Omnibus:                       29.476   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.369
# Skew:                           0.937   Prob(JB):                     9.48e-13
# Kurtosis:                       5.418   Cond. No.                     1.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.096
# Model:                                  OLS   Adj. R-squared:                  0.076
# Method:                       Least Squares   F-statistic:                     4.866
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):            0.00301
# Time:                              01:36:18   Log-Likelihood:                -354.41
# No. Observations:                       142   AIC:                             716.8
# Df Residuals:                           138   BIC:                             728.6
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              13.5670      3.265      4.155      0.000       7.111      20.023
# kuramoto_delta        -36.0521     35.924     -1.004      0.317    -107.084      34.980
# spikes_avg_all         -0.8133      0.628     -1.295      0.197      -2.055       0.429
# teager_energy_delta     5.7424      1.523      3.770      0.000       2.731       8.754
# ==============================================================================
# Omnibus:                        6.419   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                3.121
# Skew:                          -0.031   Prob(JB):                        0.210
# Kurtosis:                       2.276   Cond. No.                         185.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                     22.16
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           8.94e-12
# Time:                        01:36:18   Log-Likelihood:                 504.50
# No. Observations:                 142   AIC:                            -1001.
# Df Residuals:                     138   BIC:                            -989.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0919      0.002     38.662      0.000       0.087       0.097
# med_sum_no_lorazepam_raw    -0.0002      0.000     -1.004      0.317      -0.001       0.000
# spikes_avg_all               0.0053      0.001      3.762      0.000       0.003       0.008
# teager_energy_delta          0.0123      0.004      3.398      0.001       0.005       0.020
# ==============================================================================
# Omnibus:                        5.134   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                6.191
# Skew:                           0.198   Prob(JB):                       0.0453
# Kurtosis:                       3.943   Cond. No.                         76.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     35.53
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           4.44e-17
# Time:                        01:36:18   Log-Likelihood:                -69.768
# No. Observations:                 142   AIC:                             147.5
# Df Residuals:                     138   BIC:                             159.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -1.3343      0.453     -2.949      0.004      -2.229      -0.440
# med_sum_no_lorazepam_raw    -0.0148      0.011     -1.295      0.197      -0.037       0.008
# kuramoto_delta              17.4029      4.626      3.762      0.000       8.256      26.550
# teager_energy_delta          1.2064      0.189      6.367      0.000       0.832       1.581
# ==============================================================================
# Omnibus:                       34.255   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.243
# Skew:                           1.185   Prob(JB):                     1.01e-12
# Kurtosis:                       4.929   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
