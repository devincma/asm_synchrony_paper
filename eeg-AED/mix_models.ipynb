# %% [markdown]
# # Mix Effect Models

# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

TABLES_DIRECTORY = "../../Data/giant_tables"

# %%
patient_hup_ids = [210]
# # Iterate through all files in TABLES_DIRECTORY
# for filename in os.listdir(TABLES_DIRECTORY):
#     # Only look at filename that are .csv files and does not begin with .
#     if filename.endswith(".csv") and not filename.startswith("."):
#         # Get the patient_hup_id from the filename which is after _ and before .
#         patient_hup_id = int(filename.split("_")[1].split(".")[0])
#         patient_hup_ids.append(patient_hup_id)

# patient_hup_ids = sorted(patient_hup_ids)
# len(patient_hup_ids)

# %%
for patient_hup_id in patient_hup_ids:
    # Read in the giant table for this patient
    hourly_patient_features_df = pd.read_csv(
        os.path.join(TABLES_DIRECTORY, f"HUP_{patient_hup_id}.csv")
    )

    # Only keep the emu_hour, teager_energy_delta, kuramoto_delta, spikes_avg_all, and med_sum_no_lorazepam_raw columns
    data = hourly_patient_features_df[
        [
            "emu_hour",
            "teager_energy_delta",
            "kuramoto_delta",
            "spikes_avg_all",
            "med_sum_no_lorazepam_raw",
        ]
    ]

    # Fill missing values using linear interpolation
    data_interpolated = data.interpolate(method="linear")

    # Drop remaining rows with missing values
    data_clean = data_interpolated.dropna(
        subset=[
            "teager_energy_delta",
            "kuramoto_delta",
            "spikes_avg_all",
            "med_sum_no_lorazepam_raw",
        ]
    )

    # Define the model formula
    predict_teager_energy_delta_formula = "teager_energy_delta ~ kuramoto_delta + spikes_avg_all + med_sum_no_lorazepam_raw"
    predict_aed_sum_formula = "med_sum_no_lorazepam_raw ~ kuramoto_delta + spikes_avg_all + teager_energy_delta"
    predict_kuramoto_delta_formula = "kuramoto_delta ~ med_sum_no_lorazepam_raw + spikes_avg_all + teager_energy_delta"
    predict_spikes_formula = "spikes_avg_all ~ med_sum_no_lorazepam_raw + kuramoto_delta + teager_energy_delta"

    all_formulae = [
        predict_teager_energy_delta_formula,
        predict_aed_sum_formula,
        predict_kuramoto_delta_formula,
        predict_spikes_formula,
    ]

    for formula in all_formulae:
        # Fit the model
        model = smf.ols(formula, data=data_clean)
        result = model.fit()

        # Print the summary statistics of the fitted model
        print(result.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teager_energy_delta   R-squared:                       0.501
# Model:                             OLS   Adj. R-squared:                  0.495
# Method:                  Least Squares   F-statistic:                     75.43
# Date:                 Fri, 28 Jul 2023   Prob (F-statistic):           8.44e-34
# Time:                         07:48:12   Log-Likelihood:                 45.833
# No. Observations:                  229   AIC:                            -83.67
# Df Residuals:                      225   BIC:                            -69.93
# Df Model:                            3
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.2104      0.212     -0.993      0.322      -0.628       0.207
# kuramoto_delta               3.8311      2.584      1.483      0.140      -1.260       8.922
# spikes_avg_all               0.3746      0.078      4.776      0.000       0.220       0.529
# med_sum_no_lorazepam_raw     0.0629      0.006     10.013      0.000       0.051       0.075
# ==============================================================================
# Omnibus:                       49.327   Durbin-Watson:                   1.398
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              297.166
# Skew:                           0.640   Prob(JB):                     2.96e-65
# Kurtosis:                       8.432   Cond. No.                         693.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     med_sum_no_lorazepam_raw   R-squared:                       0.631
# Model:                                  OLS   Adj. R-squared:                  0.626
# Method:                       Least Squares   F-statistic:                     128.4
# Date:                      Fri, 28 Jul 2023   Prob (F-statistic):           1.72e-48
# Time:                              07:48:12   Log-Likelihood:                -452.86
# No. Observations:                       229   AIC:                             913.7
# Df Residuals:                           225   BIC:                             927.5
# Df Model:                                 3
# Covariance Type:                  nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              16.3701      1.524     10.742      0.000      13.367      19.373
# kuramoto_delta       -202.8486     18.498    -10.966      0.000    -239.300    -166.397
# spikes_avg_all          1.3826      0.721      1.919      0.056      -0.037       2.803
# teager_energy_delta     4.9001      0.489     10.013      0.000       3.936       5.865
# ==============================================================================
# Omnibus:                       47.470   Durbin-Watson:                   0.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              249.869
# Skew:                           0.655   Prob(JB):                     5.52e-55
# Kurtosis:                       7.947   Cond. No.                         173.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kuramoto_delta   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     55.28
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           8.23e-27
# Time:                        07:48:12   Log-Likelihood:                 884.45
# No. Observations:                 229   AIC:                            -1761.
# Df Residuals:                     225   BIC:                            -1747.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0813      0.001    133.544      0.000       0.080       0.082
# med_sum_no_lorazepam_raw    -0.0017      0.000    -10.966      0.000      -0.002      -0.001
# spikes_avg_all               0.0065      0.002      3.127      0.002       0.002       0.011
# teager_energy_delta          0.0025      0.002      1.483      0.140      -0.001       0.006
# ==============================================================================
# Omnibus:                       21.485   Durbin-Watson:                   1.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.610
# Skew:                          -0.144   Prob(JB):                     1.90e-18
# Kurtosis:                       5.910   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         spikes_avg_all   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     20.93
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           5.37e-12
# Time:                        07:48:12   Log-Likelihood:                 94.096
# No. Observations:                 229   AIC:                            -180.2
# Df Residuals:                     225   BIC:                            -166.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.3685      0.170     -2.165      0.031      -0.704      -0.033
# med_sum_no_lorazepam_raw     0.0116      0.006      1.919      0.056      -0.000       0.024
# kuramoto_delta               6.4377      2.059      3.127      0.002       2.381      10.494
# teager_energy_delta          0.2458      0.051      4.776      0.000       0.144       0.347
# ==============================================================================
# Omnibus:                       28.093   Durbin-Watson:                   1.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.406
# Skew:                           0.910   Prob(JB):                     3.38e-08
# Kurtosis:                       3.544   Cond. No.                         684.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
