# %% [markdown]
# # Select Patients for Analysis Temporal Neocortical

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## 1. What Nina has

# %%
# Load HUP_implant_dates.xlsx
nina_patients_df = pd.read_excel("../../Data/HUP_implant_dates.xlsx")
nina_patients_df
# Out:
#     ptID      IEEG_Portal_Number Implant_Date implant_time  \
# 0    225          HUP225_phaseII   2021-10-18     07:15:00
# 1    224          HUP224_phaseII   2021-10-13     07:15:00
# 2    223          HUP223_phaseII   2021-09-29     07:15:00
# 3    221          HUP221_phaseII   2021-08-16     07:15:00
# 4    219          HUP219_phaseII   2021-07-12     07:15:00
# ..   ...                     ...          ...          ...
# 75   141          HUP141_phaseII   2017-05-24     07:15:00
# 76   140  HUP140_phaseII_D01-D02   2017-05-10     07:15:00
# 77   139          HUP139_phaseII   2017-04-26     07:15:00
# 78   138          HUP138_phaseII   2017-04-12     07:15:00
# 79   137  HUP137_phaseII_D01-D03   2017-03-22     07:15:00
#
#           Explant_Date  weight_kg
# 0  2021-10-26 17:30:00       58.5
# 1  2021-10-20 00:00:00       85.5
# 2  2021-10-08 08:21:00      101.4
# 3  2021-08-23 00:00:00      124.3
# 4  2021-07-16 08:18:00      101.6
# ..                 ...        ...
# 75 2017-06-01 00:00:00       85.7
# 76 2017-05-19 00:00:00       56.7
# 77 2017-05-09 00:00:00       69.8
# 78 2017-04-20 00:00:00       84.4
# 79 2017-03-29 13:30:00      141.3
#
# [80 rows x 6 columns]

# %%
hup_patient_ids = nina_patients_df["ptID"].to_numpy()
hup_patient_ids
# Out:
# array([225, 224, 223, 221, 219, 217, 216, 215, 214, 213, 211, 210, 209,
#        208, 207, 206, 205, 204, 202, 201, 199, 197, 196, 195, 194, 193,
#        192, 191, 190, 189, 188, 187, 186, 185, 184, 182, 181, 180, 179,
#        178, 177, 175, 174, 173, 172, 171, 170, 169, 168, 167, 166, 165,
#        164, 163, 162, 161, 160, 159, 158, 157, 156, 155, 154, 153, 152,
#        151, 150, 149, 148, 147, 146, 145, 144, 143, 142, 141, 140, 139,
#        138, 137])

# %% [markdown]
# ## 4. Focal epilepsy - temporal neocortical

# %%
# Load the csv file from /data/soz_locations.csv
soz_locations_df = pd.read_csv("../../Data/soz_locations.csv").dropna()

# Drop the rows where name does not contain HUP
soz_locations_df = soz_locations_df[soz_locations_df["name"].str.contains("HUP")]

# Drop the rows where lateralization is bilateral
# soz_locations_df = soz_locations_df[soz_locations_df["lateralization"] != "bilateral"]

# # Drop the rows where region is not "mesial temporal"
# soz_locations_df = soz_locations_df[
#     soz_locations_df["region"] == "temporal neocortical"
# ]

# Delete the first three characters in the name column
soz_locations_df["name"] = soz_locations_df["name"].str[3:]

# Rename the name column to hup_id
soz_locations_df = soz_locations_df.rename(columns={"name": "hup_id"})

# Drop the columns where region is "temporal neocortical" or "mesial temporal"
soz_locations_df = soz_locations_df[
    (soz_locations_df["region"] != "temporal neocortical")
    & (soz_locations_df["region"] != "mesial temporal")
]


# Convert the hup_id column to int
soz_locations_df["hup_id"] = soz_locations_df["hup_id"].astype(int)

# Find the rows where hup_id is in common_hup_ids
soz_locations_df = soz_locations_df[soz_locations_df["hup_id"].isin(hup_patient_ids)]

# Reset index
soz_locations_df = soz_locations_df.reset_index(drop=True)
soz_locations_df
# Out:
#     hup_id               region lateralization
# 0      137           multifocal      bilateral
# 1      139         other cortex           left
# 2      143           multifocal      bilateral
# 3      144  temporal multifocal          right
# 4      145         other cortex          right
# 5      146         other cortex          right
# 6      147           multifocal           left
# 7      148  temporal multifocal      bilateral
# 8      149           multifocal      bilateral
# 9      150         other cortex          right
# 10     151              frontal          right
# 11     152              diffuse           left
# 12     153             temporal      bilateral
# 13     154              diffuse      bilateral
# 14     155         other cortex      bilateral
# 15     156             temporal      bilateral
# 16     157             temporal           left
# 17     158         other cortex          right
# 18     160           multifocal          right
# 19     161         other cortex          right
# 20     166         other cortex           left
# 21     167              diffuse      bilateral
# 22     168           multifocal      bilateral
# 23     169             temporal      bilateral
# 24     170         other cortex          right
# 25     171         other cortex           left
# 26     172         other cortex           left
# 27     174             temporal           left
# 28     175              diffuse        diffuse
# 29     177             temporal          right
# 30     178             temporal          right
# 31     179         other cortex           left
# 32     180         other cortex           left
# 33     184             temporal           left
# 34     186             temporal           left
# 35     188         other cortex           left
# 36     194         other cortex          right
# 37     196         other cortex          right
# 38     197             temporal           left
# 39     201           multifocal           left
# 40     206           multifocal          right
# 41     208             temporal           left
# 42     210              diffuse           left
# 43     211             temporal      bilateral
# 44     213           multifocal           left
# 45     216         other cortex           left

# %% [markdown]
# ## 5. Get other information and write to file

# %%
# Find weight_kg from nina_patients_df and add it to soz_locations_df as a new column
soz_locations_df["weight_kg"] = soz_locations_df["hup_id"].apply(
    lambda x: nina_patients_df[nina_patients_df["ptID"] == x]["weight_kg"].values[0]
)
soz_locations_df
# Out:
#     hup_id               region lateralization  weight_kg
# 0      137           multifocal      bilateral      141.3
# 1      139         other cortex           left       69.8
# 2      143           multifocal      bilateral       61.5
# 3      144  temporal multifocal          right       62.8
# 4      145         other cortex          right      122.9
# 5      146         other cortex          right      102.1
# 6      147           multifocal           left       96.6
# 7      148  temporal multifocal      bilateral       81.6
# 8      149           multifocal      bilateral       81.8
# 9      150         other cortex          right      108.0
# 10     151              frontal          right       81.6
# 11     152              diffuse           left      102.8
# 12     153             temporal      bilateral      101.6
# 13     154              diffuse      bilateral       62.6
# 14     155         other cortex      bilateral       68.9
# 15     156             temporal      bilateral       57.6
# 16     157             temporal           left       74.8
# 17     158         other cortex          right       79.4
# 18     160           multifocal          right       80.6
# 19     161         other cortex          right       96.2
# 20     166         other cortex           left       60.3
# 21     167              diffuse      bilateral       47.9
# 22     168           multifocal      bilateral      131.1
# 23     169             temporal      bilateral       62.2
# 24     170         other cortex          right       63.5
# 25     171         other cortex           left      107.2
# 26     172         other cortex           left      109.4
# 27     174             temporal           left       70.6
# 28     175              diffuse        diffuse       61.7
# 29     177             temporal          right       88.4
# 30     178             temporal          right       79.4
# 31     179         other cortex           left      103.0
# 32     180         other cortex           left       51.3
# 33     184             temporal           left       90.7
# 34     186             temporal           left       64.9
# 35     188         other cortex           left       70.7
# 36     194         other cortex          right       72.6
# 37     196         other cortex          right       60.8
# 38     197             temporal           left       88.8
# 39     201           multifocal           left       97.1
# 40     206           multifocal          right       97.3
# 41     208             temporal           left       85.4
# 42     210              diffuse           left       66.6
# 43     211             temporal      bilateral       69.9
# 44     213           multifocal           left       87.5
# 45     216         other cortex           left       77.1

# %%
# Load rid_hup_table.csv from ./data/
rid_hup_table_df = pd.read_csv("../../Data/rid_hup_table.csv")

# Drop the t3_subject_id and ieegportalsubjno columns
rid_hup_table_df = rid_hup_table_df.drop(columns=["t3_subject_id", "ieegportalsubjno"])

# Rename hupsubjno to hup_id
rid_hup_table_df = rid_hup_table_df.rename(columns={"hupsubjno": "hup_id"})
rid_hup_table_df
# Out:
#      record_id  hup_id
# 0          623      35
# 1          624      36
# 2          625      37
# 3          626      38
# 4          627      39
# ..         ...     ...
# 212        534     250
# 213        923     251
# 214        918     252
# 215        864     253
# 216        675     254
#
# [217 rows x 2 columns]

# %%
# Find record_id from rid_hup_table_df and add it to soz_locations_df as a new column of type int, skip if not found
soz_locations_df["record_id"] = soz_locations_df["hup_id"].apply(
    lambda x: rid_hup_table_df[rid_hup_table_df["hup_id"] == x]["record_id"].values[0]
    if len(rid_hup_table_df[rid_hup_table_df["hup_id"] == x]["record_id"].values) > 0
    else np.nan
)
# Drop the rows where record_id is nan
soz_locations_df = soz_locations_df.dropna(subset=["record_id"])
# Convert record_id to int
soz_locations_df["record_id"] = soz_locations_df["record_id"].astype(int)
soz_locations_df
# Out:
# /tmp/ipykernel_20451/2827785430.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   soz_locations_df["record_id"] = soz_locations_df["record_id"].astype(int)
#     hup_id               region lateralization  weight_kg  record_id
# 0      137           multifocal      bilateral      141.3        280
# 2      143           multifocal      bilateral       61.5        206
# 3      144  temporal multifocal          right       62.8        112
# 4      145         other cortex          right      122.9        167
# 5      146         other cortex          right      102.1        301
# 6      147           multifocal           left       96.6        334
# 7      148  temporal multifocal      bilateral       81.6        267
# 8      149           multifocal      bilateral       81.8        240
# 9      150         other cortex          right      108.0        322
# 10     151              frontal          right       81.6        309
# 11     152              diffuse           left      102.8        317
# 12     153             temporal      bilateral      101.6        328
# 13     154              diffuse      bilateral       62.6        146
# 14     155         other cortex      bilateral       68.9        394
# 15     156             temporal      bilateral       57.6        337
# 16     157             temporal           left       74.8        365
# 17     158         other cortex          right       79.4        382
# 18     160           multifocal          right       80.6        381
# 19     161         other cortex          right       96.2        338
# 20     166         other cortex           left       60.3        230
# 21     167              diffuse      bilateral       47.9        330
# 22     168           multifocal      bilateral      131.1        385
# 23     169             temporal      bilateral       62.2        296
# 24     170         other cortex          right       63.5        442
# 25     171         other cortex           left      107.2        371
# 26     172         other cortex           left      109.4        440
# 27     174             temporal           left       70.6        392
# 28     175              diffuse        diffuse       61.7        452
# 29     177             temporal          right       88.4        424
# 30     178             temporal          right       79.4        356
# 31     179         other cortex           left      103.0        139
# 32     180         other cortex           left       51.3        476
# 33     184             temporal           left       90.7        508
# 34     186             temporal           left       64.9        420
# 35     188         other cortex           left       70.7        472
# 36     194         other cortex          right       72.6        562
# 37     196         other cortex          right       60.8        529
# 38     197             temporal           left       88.8        583
# 39     201           multifocal           left       97.1        595
# 40     206           multifocal          right       97.3        572
# 41     208             temporal           left       85.4        648
# 42     210              diffuse           left       66.6        459
# 43     211             temporal      bilateral       69.9        650
# 44     213           multifocal           left       87.5        649
# 45     216         other cortex           left       77.1        658

# %%
soz_locations_df["r_id"] = soz_locations_df["hup_id"].apply(
    lambda x: rid_hup_table_df[rid_hup_table_df["hup_id"] == x]["record_id"].values[0]
)
soz_locations_df
# Out:
# /tmp/ipykernel_20451/2082741109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   soz_locations_df["r_id"] = soz_locations_df["hup_id"].apply(
#     hup_id               region lateralization  weight_kg  record_id  r_id
# 0      137           multifocal      bilateral      141.3        280   280
# 2      143           multifocal      bilateral       61.5        206   206
# 3      144  temporal multifocal          right       62.8        112   112
# 4      145         other cortex          right      122.9        167   167
# 5      146         other cortex          right      102.1        301   301
# 6      147           multifocal           left       96.6        334   334
# 7      148  temporal multifocal      bilateral       81.6        267   267
# 8      149           multifocal      bilateral       81.8        240   240
# 9      150         other cortex          right      108.0        322   322
# 10     151              frontal          right       81.6        309   309
# 11     152              diffuse           left      102.8        317   317
# 12     153             temporal      bilateral      101.6        328   328
# 13     154              diffuse      bilateral       62.6        146   146
# 14     155         other cortex      bilateral       68.9        394   394
# 15     156             temporal      bilateral       57.6        337   337
# 16     157             temporal           left       74.8        365   365
# 17     158         other cortex          right       79.4        382   382
# 18     160           multifocal          right       80.6        381   381
# 19     161         other cortex          right       96.2        338   338
# 20     166         other cortex           left       60.3        230   230
# 21     167              diffuse      bilateral       47.9        330   330
# 22     168           multifocal      bilateral      131.1        385   385
# 23     169             temporal      bilateral       62.2        296   296
# 24     170         other cortex          right       63.5        442   442
# 25     171         other cortex           left      107.2        371   371
# 26     172         other cortex           left      109.4        440   440
# 27     174             temporal           left       70.6        392   392
# 28     175              diffuse        diffuse       61.7        452   452
# 29     177             temporal          right       88.4        424   424
# 30     178             temporal          right       79.4        356   356
# 31     179         other cortex           left      103.0        139   139
# 32     180         other cortex           left       51.3        476   476
# 33     184             temporal           left       90.7        508   508
# 34     186             temporal           left       64.9        420   420
# 35     188         other cortex           left       70.7        472   472
# 36     194         other cortex          right       72.6        562   562
# 37     196         other cortex          right       60.8        529   529
# 38     197             temporal           left       88.8        583   583
# 39     201           multifocal           left       97.1        595   595
# 40     206           multifocal          right       97.3        572   572
# 41     208             temporal           left       85.4        648   648
# 42     210              diffuse           left       66.6        459   459
# 43     211             temporal      bilateral       69.9        650   650
# 44     213           multifocal           left       87.5        649   649
# 45     216         other cortex           left       77.1        658   658

# %%
# Save soz_locations_df as selected_patients.xlsx
soz_locations_df.to_excel("../../Data/selected_patients_rest.xlsx", index=False)
