# %% [markdown]
# # Compute Phase Locking Value Vectors

# %%
# !rm -r __pycache__

# %%
import scipy.io
import numpy as np
import os, pickle, re
import pandas as pd
from scipy.fft import fft
from numpy import NaN

from ieeg_utils import *
from signal_processing import *

IEEG_DIRECTORY = "../../../Data/ieeg/all/2_min"
OUTPUT_DIRECTORY = "../../../Data/plv/kuramoto"

# %%
nina_patient_hup_ids = pd.read_excel("../../../Data/HUP_implant_dates.xlsx")
nina_patient_hup_ids = nina_patient_hup_ids["hup_id"].to_numpy()
nina_patient_hup_ids
# Out:
# array([225, 224, 223, 221, 219, 217, 216, 215, 214, 213, 211, 210, 209,
#        208, 207, 206, 205, 204, 202, 201, 199, 197, 196, 195, 194, 193,
#        192, 191, 190, 189, 188, 187, 186, 185, 184, 182, 181, 180, 179,
#        178, 177, 175, 174, 173, 172, 171, 170, 169, 168, 167, 166, 165,
#        164, 163, 162, 161, 160, 159, 158, 157, 156, 155, 154, 153, 152,
#        151, 150, 149, 148, 147, 146, 145, 144, 143, 142, 141, 140, 139,
#        138, 137])

# %%
# Create a mapping between patient ids and the index of the patient in the patients_df dataframe
patient_hup_id_to_index = {}
for i, patient_id in enumerate(nina_patient_hup_ids):
    patient_hup_id_to_index[patient_id] = i
# patient_hup_id_to_index

# %%
ieeg_offset_row1_df = pd.read_excel("../../../Data/ieeg_offset/row_1.xlsx", header=None)
ieeg_offset_row2_df = pd.read_excel("../../../Data/ieeg_offset/row_2.xlsx", header=None)
ieeg_offset_row3_df = pd.read_excel("../../../Data/ieeg_offset/row_3.xlsx", header=None)

# %%
# Load master_elecs.csv from ./data/
master_elecs_df = pd.read_csv("../../../Data/master_elecs.csv")

# only take the numbers in rid column
master_elecs_df["rid"] = master_elecs_df["rid"].str.extract("(\d+)", expand=False)
master_elecs_df["rid"] = master_elecs_df["rid"].astype(int)

# Drop mni_x, mni_y, mni_z, mm_x, mm_y, mm_z columns
master_elecs_df = master_elecs_df.drop(
    columns=["mni_x", "mni_y", "mni_z", "mm_x", "mm_y", "mm_z"]
)

master_elecs_df
# Out:
#        rid   name     vox_x     vox_y     vox_z                   label  \
# 0       13  LST01   80.6116  106.5480   64.5941  left inferior temporal
# 1       13  LST02   72.0779  109.4150   63.1223  left inferior temporal
# 2       13  LST03   64.9060  112.3760   68.7455              EmptyLabel
# 3       13  LST04   65.0210  114.6600   78.2339    left middle temporal
# 4       13  MST01  131.7410   64.3756   70.4205           right lingual
# ...    ...    ...       ...       ...       ...                     ...
# 14212  785   RB08  154.2550  114.2730  136.7560              EmptyLabel
# 14213  785   RB09  159.1350  111.9920  136.6960              EmptyLabel
# 14214  785   RB10  164.7520  109.9030  137.7640   right middle temporal
# 14215  785   RB11  169.6320  107.6220  137.7040   right middle temporal
# 14216  785   RB12  175.1210  105.8310  137.7080              EmptyLabel
#
#          soz resected  spike_rate  engel
# 0      False    False    1.091902    1.0
# 1      False    False    1.091902    1.0
# 2      False    False    1.419472    1.0
# 3      False    False    0.655141    1.0
# 4       True    False    3.439490    1.0
# ...      ...      ...         ...    ...
# 14212  False      NaN    0.369914    1.0
# 14213  False      NaN    0.665845    1.0
# 14214  False      NaN    4.586930    1.0
# 14215  False      NaN    2.071517    1.0
# 14216  False      NaN    5.104809    1.0
#
# [14217 rows x 10 columns]

# %%
# Load rid_hup_table.csv from ./data/
rid_hup_table_df = pd.read_csv("../../../Data/rid_hup_table.csv")
# Drop the t3_subject_id and ieegportalsubjno columns
rid_hup_table_df = rid_hup_table_df.drop(columns=["t3_subject_id", "ieegportalsubjno"])
rid_hup_table_df
# Out:
#      record_id  hupsubjno
# 0          623         35
# 1          624         36
# 2          625         37
# 3          626         38
# 4          627         39
# ..         ...        ...
# 212        534        250
# 213        923        251
# 214        918        252
# 215        864        253
# 216        675        254
#
# [217 rows x 2 columns]

# %%
def bipolar_montage(data: np.ndarray, ch_types: pd.DataFrame) -> np.ndarray:
    """_summary_

    Args:
        data (np.ndarray): _description_
        ch_types (pd.DataFrame): _description_

    Returns:
        np.ndarray: _description_
    """

    n_ch = len(ch_types)
    new_ch_types = []
    for ind, row in ch_types.iterrows():
        # do only if type is ecog or seeg
        if row["type"] not in ["ecog", "seeg"]:
            continue

        ch1 = row["name"]

        ch2 = ch_types.loc[
            (ch_types["lead"] == row["lead"])
            & (ch_types["contact"] == row["contact"] + 1),
            "name",
        ]
        if len(ch2) > 0:
            ch2 = ch2.iloc[0]
            entry = {
                "name": ch1 + "-" + ch2,
                "type": row["type"],
                "idx1": ind,
                "idx2": ch_types.loc[ch_types["name"] == ch2].index[0],
            }
            new_ch_types.append(entry)

    new_ch_types = pd.DataFrame(new_ch_types)
    # apply montage to data
    new_data = np.empty((len(new_ch_types), data.shape[1]))
    for ind, row in new_ch_types.iterrows():
        new_data[ind, :] = data[row["idx1"], :] - data[row["idx2"], :]

    return new_data, new_ch_types

# %%
def identify_bad_channels(values, channel_indices, channel_labels, fs):
    """
    Identifies 'bad' channels in an EEG dataset based on various criteria such as high variance, missing data,
    crossing absolute threshold, high variance above baseline, and 60 Hz noise.

    Parameters:
    values (numpy.ndarray): A 2D array of EEG data where each column is a different channel and each row is a reading.
    channel_indices (list): A list containing indices of channels to be analyzed.
    channel_labels (list): A list of channel labels.
    fs (float): The sampling frequency.

    Returns:
    bad (list): A list of 'bad' channel indices.
    details (dict): A dictionary containing the reasons why each channel was marked as 'bad'. Keys are 'noisy', 'nans',
                    'zeros', 'var', 'higher_std', and 'high_voltage'. Each key maps to a list of channel indices.
    """

    # set parameters
    tile = 99
    mult = 10
    num_above = 1
    abs_thresh = 5e3
    percent_60_hz = 0.99
    mult_std = 10

    bad = []
    high_ch = []
    nan_ch = []
    zero_ch = []
    high_var_ch = []
    noisy_ch = []
    all_std = np.full(len(channel_indices), NaN)

    for i in range(len(channel_indices)):
        bad_ch = 0
        ich = channel_indices[i]
        eeg = values[:, ich]
        bl = np.nanmedian(eeg)

        all_std[i] = np.nanstd(eeg)

        if np.sum(np.isnan(eeg)) > 0.5 * len(eeg):
            bad.append(ich)
            nan_ch.append(ich)
            continue

        if np.sum(eeg == 0) > 0.5 * len(eeg):
            bad.append(ich)
            zero_ch.append(ich)
            continue

        if np.sum(np.abs(eeg - bl) > abs_thresh) > 10:
            bad.append(ich)
            bad_ch = 1
            high_ch.append(ich)

        if bad_ch == 1:
            continue

        pct = np.percentile(eeg, [100 - tile, tile])
        thresh = [bl - mult * (bl - pct[0]), bl + mult * (pct[1] - bl)]
        sum_outside = np.sum((eeg > thresh[1]) | (eeg < thresh[0]))

        if sum_outside >= num_above:
            bad_ch = 1

        if bad_ch == 1:
            bad.append(ich)
            high_var_ch.append(ich)
            continue

        Y = fft(eeg - np.nanmean(eeg))

        P = np.abs(Y) ** 2
        freqs = np.linspace(0, fs, len(P) + 1)
        freqs = freqs[:-1]
        P = P[: int(np.ceil(len(P) / 2))]
        freqs = freqs[: int(np.ceil(len(freqs) / 2))]

        P_60Hz = np.sum(P[(freqs > 58) & (freqs < 62)]) / np.sum(P)

        if P_60Hz > percent_60_hz:
            bad_ch = 1

        if bad_ch == 1:
            bad.append(ich)
            noisy_ch.append(ich)
            continue

    median_std = np.nanmedian(all_std)
    higher_std = [
        channel_indices[i]
        for i in range(len(all_std))
        if all_std[i] > mult_std * median_std
    ]
    bad_std = [ch for ch in higher_std if ch not in bad]
    bad.extend(bad_std)

    details = {
        "noisy": noisy_ch,
        "nans": nan_ch,
        "zeros": zero_ch,
        "var": high_var_ch,
        "higher_std": bad_std,
        "high_voltage": high_ch,
    }

    return bad, details

# %%
# Create an empty dictionary to store all the data
data_dict = {"dataset_name": [], "max_hour": [], "sample_rate": [], "hup_id": []}

# Iterate through the directory
for filename in os.listdir(IEEG_DIRECTORY):
    if filename.endswith(".pkl"):  # Only process .pkl files
        # Split the filename to get the dataset_name, hour, and sample_rate
        parts = filename.split("_")
        dataset_name = "_".join(parts[:-4])  # Exclude the '_hr' from the dataset_name
        hour = int(parts[-3])
        sample_rate = int(parts[-1].split(".")[0])

        # Extract hup_id from dataset_name
        hup_id = dataset_name.split("_")[0].split("HUP")[1]

        # If the dataset_name is already in the dictionary, update the max_hour
        if dataset_name in data_dict["dataset_name"]:
            index = data_dict["dataset_name"].index(dataset_name)
            data_dict["max_hour"][index] = max(data_dict["max_hour"][index], hour)
        else:
            # Else, add the dataset_name, hour, sample_rate and hup_id to the dictionary
            data_dict["dataset_name"].append(dataset_name)
            data_dict["max_hour"].append(hour)
            data_dict["sample_rate"].append(sample_rate)
            data_dict["hup_id"].append(hup_id)

# Create a DataFrame from the dictionary
datasets_df = pd.DataFrame(data_dict)
# Make max_hour and sample_rate and hup_id integers
datasets_df["max_hour"] = datasets_df["max_hour"].astype(int)
datasets_df["sample_rate"] = datasets_df["sample_rate"].astype(int)
datasets_df["hup_id"] = datasets_df["hup_id"].astype(int)
# Sort by hup_id
datasets_df = datasets_df.sort_values(by=["hup_id"])
# Reset the index
datasets_df = datasets_df.reset_index(drop=True)
# Create a column called max_hour_count that is the max_hour + 1
datasets_df["max_hour_count"] = datasets_df["max_hour"] + 1
datasets_df
# Out:
#           dataset_name  max_hour  sample_rate  hup_id  max_hour_count
# 0       HUP138_phaseII       172         1024     138             173
# 1   HUP140_phaseII_D02       128         1024     140             129
# 2   HUP140_phaseII_D01        19         1024     140              20
# 3       HUP141_phaseII       146          512     141             147
# 4       HUP142_phaseII       311          512     142             312
# ..                 ...       ...          ...     ...             ...
# 81  HUP215_phaseII_D01        14         2048     215              15
# 82  HUP216_phaseII_D01       143          512     216             144
# 83  HUP216_phaseII_D02       144          512     216             145
# 84      HUP223_phaseII       135         1024     223             136
# 85      HUP224_phaseII       145         1024     224             146
#
# [86 rows x 5 columns]

# %%
frequency_bands = {
    "delta": (0.5, 4),
    "theta": (4, 8),
    "alpha": (8, 12),
    "beta": (12, 30),
    "gamma": (30, 100),
}

# %%
for patient_hup_id in datasets_df["hup_id"].unique():
    # Find the value of record_id in rid_hup_table_df where hupsubjno == patient_hup_id
    patient_rid = rid_hup_table_df[rid_hup_table_df["hupsubjno"] == patient_hup_id][
        "record_id"
    ].values[0]
    # Get the row in datasets_df corresponding to the patient_hup_id
    rows_df = datasets_df[datasets_df["hup_id"] == patient_hup_id]
    patient_electrodes_df = master_elecs_df.loc[master_elecs_df["rid"] == patient_rid]
    print(f"HUP {patient_hup_id}, rid {patient_rid}")

    # Add up all the max_hours for rows_df
    total_max_hour_count = rows_df["max_hour_count"].sum()
    # Initialize an empty vector numpy array of length total_max_hour
    plv_vector_to_save = np.zeros(total_max_hour_count)
    current_hour = 0

    for dataset_idx, dataset_row in rows_df.iterrows():
        # Get the dataset_name, max_hour, and sample_rate
        dataset_name = dataset_row["dataset_name"]
        max_hour_count = dataset_row["max_hour_count"]
        sample_rate = dataset_row["sample_rate"]
        print(dataset_name)

        for hour in range(max_hour_count):
            # Get the filename
            filename = f"{dataset_name}_hr_{hour}_fs_{sample_rate}.pkl"
            # Get the full path to the file
            full_path = os.path.join(IEEG_DIRECTORY, filename)
            channel_labels = None

            # Load the data
            try:
                with open(full_path, "rb") as f:
                    eeg_segment_df = pickle.load(f)
                    channel_labels = eeg_segment_df.columns.values.tolist()
                    eeg_segment_df = eeg_segment_df.T
            except FileNotFoundError:
                print(f"Skipping {hour} for {dataset_name}")
                plv_vector_to_save[current_hour] = np.nan
                current_hour += 1
                continue

            print(
                f"Processing hour {hour} in {dataset_name}, that's hour {current_hour} out of {total_max_hour_count} for HUP {patient_hup_id}"
            )
            channel_types_df = check_channel_types(channel_labels)
            bipolar_eeg_data, bipolar_channel_types_df = bipolar_montage(
                eeg_segment_df.to_numpy(), channel_types_df
            )
            # print(bipolar_channel_types_df)

            bipolar_eeg_data_filtered = process_eeg_data(
                data=bipolar_eeg_data,
                sample_rate=sample_rate,
                band_pass_freq=frequency_bands["delta"],
                notch_freq=60,
            )

            R = calculate_kuramoto_order_parameter(bipolar_eeg_data_filtered).mean()
            plv_vector_to_save[current_hour] = R
            current_hour += 1
    # Save plv_vector_to_save as a .npy file
    print(plv_vector_to_save)
    np.save(
        f"{OUTPUT_DIRECTORY}/delta/HUP_{patient_hup_id}.npy",
        plv_vector_to_save,
    )
# Out:
# HUP 138, rid 278
# HUP138_phaseII
# Processing hour 0 in HUP138_phaseII, that's hour 0 out of 173 for HUP 138
# Processing hour 1 in HUP138_phaseII, that's hour 1 out of 173 for HUP 138
# Processing hour 2 in HUP138_phaseII, that's hour 2 out of 173 for HUP 138
# Processing hour 3 in HUP138_phaseII, that's hour 3 out of 173 for HUP 138
# Processing hour 4 in HUP138_phaseII, that's hour 4 out of 173 for HUP 138
# Processing hour 5 in HUP138_phaseII, that's hour 5 out of 173 for HUP 138
# Processing hour 6 in HUP138_phaseII, that's hour 6 out of 173 for HUP 138
# Processing hour 7 in HUP138_phaseII, that's hour 7 out of 173 for HUP 138
# Processing hour 8 in HUP138_phaseII, that's hour 8 out of 173 for HUP 138
# Processing hour 9 in HUP138_phaseII, that's hour 9 out of 173 for HUP 138
# Skipping 10 for HUP138_phaseII
# Processing hour 11 in HUP138_phaseII, that's hour 11 out of 173 for HUP 138
# Processing hour 12 in HUP138_phaseII, that's hour 12 out of 173 for HUP 138
# Processing hour 13 in HUP138_phaseII, that's hour 13 out of 173 for HUP 138
# Processing hour 14 in HUP138_phaseII, that's hour 14 out of 173 for HUP 138
# Processing hour 15 in HUP138_phaseII, that's hour 15 out of 173 for HUP 138
# Processing hour 16 in HUP138_phaseII, that's hour 16 out of 173 for HUP 138
# Processing hour 17 in HUP138_phaseII, that's hour 17 out of 173 for HUP 138
# Processing hour 18 in HUP138_phaseII, that's hour 18 out of 173 for HUP 138
# Processing hour 19 in HUP138_phaseII, that's hour 19 out of 173 for HUP 138
# Processing hour 20 in HUP138_phaseII, that's hour 20 out of 173 for HUP 138
# Processing hour 21 in HUP138_phaseII, that's hour 21 out of 173 for HUP 138
# Processing hour 22 in HUP138_phaseII, that's hour 22 out of 173 for HUP 138
# Processing hour 23 in HUP138_phaseII, that's hour 23 out of 173 for HUP 138
# Processing hour 24 in HUP138_phaseII, that's hour 24 out of 173 for HUP 138
# Processing hour 25 in HUP138_phaseII, that's hour 25 out of 173 for HUP 138
# Processing hour 26 in HUP138_phaseII, that's hour 26 out of 173 for HUP 138
# Processing hour 27 in HUP138_phaseII, that's hour 27 out of 173 for HUP 138
# Processing hour 28 in HUP138_phaseII, that's hour 28 out of 173 for HUP 138
# Processing hour 29 in HUP138_phaseII, that's hour 29 out of 173 for HUP 138
# Processing hour 30 in HUP138_phaseII, that's hour 30 out of 173 for HUP 138
# Processing hour 31 in HUP138_phaseII, that's hour 31 out of 173 for HUP 138
# Processing hour 32 in HUP138_phaseII, that's hour 32 out of 173 for HUP 138
# Processing hour 33 in HUP138_phaseII, that's hour 33 out of 173 for HUP 138
# Processing hour 34 in HUP138_phaseII, that's hour 34 out of 173 for HUP 138
# Processing hour 35 in HUP138_phaseII, that's hour 35 out of 173 for HUP 138
# Processing hour 36 in HUP138_phaseII, that's hour 36 out of 173 for HUP 138
# Processing hour 37 in HUP138_phaseII, that's hour 37 out of 173 for HUP 138
# Processing hour 38 in HUP138_phaseII, that's hour 38 out of 173 for HUP 138
# Processing hour 39 in HUP138_phaseII, that's hour 39 out of 173 for HUP 138
# Processing hour 40 in HUP138_phaseII, that's hour 40 out of 173 for HUP 138
# Processing hour 41 in HUP138_phaseII, that's hour 41 out of 173 for HUP 138
# Processing hour 42 in HUP138_phaseII, that's hour 42 out of 173 for HUP 138
# Processing hour 43 in HUP138_phaseII, that's hour 43 out of 173 for HUP 138
# Processing hour 44 in HUP138_phaseII, that's hour 44 out of 173 for HUP 138
# Processing hour 45 in HUP138_phaseII, that's hour 45 out of 173 for HUP 138
# Processing hour 46 in HUP138_phaseII, that's hour 46 out of 173 for HUP 138
# Processing hour 47 in HUP138_phaseII, that's hour 47 out of 173 for HUP 138
# Processing hour 48 in HUP138_phaseII, that's hour 48 out of 173 for HUP 138
# Processing hour 49 in HUP138_phaseII, that's hour 49 out of 173 for HUP 138
# Processing hour 50 in HUP138_phaseII, that's hour 50 out of 173 for HUP 138
# Processing hour 51 in HUP138_phaseII, that's hour 51 out of 173 for HUP 138
# Processing hour 52 in HUP138_phaseII, that's hour 52 out of 173 for HUP 138
# Processing hour 53 in HUP138_phaseII, that's hour 53 out of 173 for HUP 138
# Processing hour 54 in HUP138_phaseII, that's hour 54 out of 173 for HUP 138
# Processing hour 55 in HUP138_phaseII, that's hour 55 out of 173 for HUP 138
# Processing hour 56 in HUP138_phaseII, that's hour 56 out of 173 for HUP 138
# Processing hour 57 in HUP138_phaseII, that's hour 57 out of 173 for HUP 138
# Processing hour 58 in HUP138_phaseII, that's hour 58 out of 173 for HUP 138
# Processing hour 59 in HUP138_phaseII, that's hour 59 out of 173 for HUP 138
# Processing hour 60 in HUP138_phaseII, that's hour 60 out of 173 for HUP 138
# Processing hour 61 in HUP138_phaseII, that's hour 61 out of 173 for HUP 138
# Processing hour 62 in HUP138_phaseII, that's hour 62 out of 173 for HUP 138
# Processing hour 63 in HUP138_phaseII, that's hour 63 out of 173 for HUP 138
# Processing hour 64 in HUP138_phaseII, that's hour 64 out of 173 for HUP 138
# Processing hour 65 in HUP138_phaseII, that's hour 65 out of 173 for HUP 138
# Processing hour 66 in HUP138_phaseII, that's hour 66 out of 173 for HUP 138
# Processing hour 67 in HUP138_phaseII, that's hour 67 out of 173 for HUP 138
# Processing hour 68 in HUP138_phaseII, that's hour 68 out of 173 for HUP 138
# Processing hour 69 in HUP138_phaseII, that's hour 69 out of 173 for HUP 138
# Processing hour 70 in HUP138_phaseII, that's hour 70 out of 173 for HUP 138
# Processing hour 71 in HUP138_phaseII, that's hour 71 out of 173 for HUP 138
# Processing hour 72 in HUP138_phaseII, that's hour 72 out of 173 for HUP 138
# Processing hour 73 in HUP138_phaseII, that's hour 73 out of 173 for HUP 138
# Processing hour 74 in HUP138_phaseII, that's hour 74 out of 173 for HUP 138
# Processing hour 75 in HUP138_phaseII, that's hour 75 out of 173 for HUP 138
# Processing hour 76 in HUP138_phaseII, that's hour 76 out of 173 for HUP 138
# Processing hour 77 in HUP138_phaseII, that's hour 77 out of 173 for HUP 138
# Processing hour 78 in HUP138_phaseII, that's hour 78 out of 173 for HUP 138
# Processing hour 79 in HUP138_phaseII, that's hour 79 out of 173 for HUP 138
# Processing hour 80 in HUP138_phaseII, that's hour 80 out of 173 for HUP 138
# Processing hour 81 in HUP138_phaseII, that's hour 81 out of 173 for HUP 138
# Processing hour 82 in HUP138_phaseII, that's hour 82 out of 173 for HUP 138
# Processing hour 83 in HUP138_phaseII, that's hour 83 out of 173 for HUP 138
# Processing hour 84 in HUP138_phaseII, that's hour 84 out of 173 for HUP 138
# Processing hour 85 in HUP138_phaseII, that's hour 85 out of 173 for HUP 138
# Processing hour 86 in HUP138_phaseII, that's hour 86 out of 173 for HUP 138
# Processing hour 87 in HUP138_phaseII, that's hour 87 out of 173 for HUP 138
# Processing hour 88 in HUP138_phaseII, that's hour 88 out of 173 for HUP 138
# Processing hour 89 in HUP138_phaseII, that's hour 89 out of 173 for HUP 138
# Processing hour 90 in HUP138_phaseII, that's hour 90 out of 173 for HUP 138
# Processing hour 91 in HUP138_phaseII, that's hour 91 out of 173 for HUP 138
# Processing hour 92 in HUP138_phaseII, that's hour 92 out of 173 for HUP 138
# Processing hour 93 in HUP138_phaseII, that's hour 93 out of 173 for HUP 138
# Processing hour 94 in HUP138_phaseII, that's hour 94 out of 173 for HUP 138
# Processing hour 95 in HUP138_phaseII, that's hour 95 out of 173 for HUP 138
# Processing hour 96 in HUP138_phaseII, that's hour 96 out of 173 for HUP 138
# Processing hour 97 in HUP138_phaseII, that's hour 97 out of 173 for HUP 138
# Processing hour 98 in HUP138_phaseII, that's hour 98 out of 173 for HUP 138
# Skipping 99 for HUP138_phaseII
# Processing hour 100 in HUP138_phaseII, that's hour 100 out of 173 for HUP 138
# Processing hour 101 in HUP138_phaseII, that's hour 101 out of 173 for HUP 138
# Processing hour 102 in HUP138_phaseII, that's hour 102 out of 173 for HUP 138
# Processing hour 103 in HUP138_phaseII, that's hour 103 out of 173 for HUP 138
# Processing hour 104 in HUP138_phaseII, that's hour 104 out of 173 for HUP 138
# Processing hour 105 in HUP138_phaseII, that's hour 105 out of 173 for HUP 138
# Processing hour 106 in HUP138_phaseII, that's hour 106 out of 173 for HUP 138
# Processing hour 107 in HUP138_phaseII, that's hour 107 out of 173 for HUP 138
# Processing hour 108 in HUP138_phaseII, that's hour 108 out of 173 for HUP 138
# Processing hour 109 in HUP138_phaseII, that's hour 109 out of 173 for HUP 138
# Processing hour 110 in HUP138_phaseII, that's hour 110 out of 173 for HUP 138
# Processing hour 111 in HUP138_phaseII, that's hour 111 out of 173 for HUP 138
# Processing hour 112 in HUP138_phaseII, that's hour 112 out of 173 for HUP 138
# Processing hour 113 in HUP138_phaseII, that's hour 113 out of 173 for HUP 138
# Processing hour 114 in HUP138_phaseII, that's hour 114 out of 173 for HUP 138
# Processing hour 115 in HUP138_phaseII, that's hour 115 out of 173 for HUP 138
# Processing hour 116 in HUP138_phaseII, that's hour 116 out of 173 for HUP 138
# Processing hour 117 in HUP138_phaseII, that's hour 117 out of 173 for HUP 138
# Processing hour 118 in HUP138_phaseII, that's hour 118 out of 173 for HUP 138
# Processing hour 119 in HUP138_phaseII, that's hour 119 out of 173 for HUP 138
# Processing hour 120 in HUP138_phaseII, that's hour 120 out of 173 for HUP 138
# Processing hour 121 in HUP138_phaseII, that's hour 121 out of 173 for HUP 138
# Processing hour 122 in HUP138_phaseII, that's hour 122 out of 173 for HUP 138
# Processing hour 123 in HUP138_phaseII, that's hour 123 out of 173 for HUP 138
# Processing hour 124 in HUP138_phaseII, that's hour 124 out of 173 for HUP 138
# Processing hour 125 in HUP138_phaseII, that's hour 125 out of 173 for HUP 138
# Processing hour 126 in HUP138_phaseII, that's hour 126 out of 173 for HUP 138
# Processing hour 127 in HUP138_phaseII, that's hour 127 out of 173 for HUP 138
# Processing hour 128 in HUP138_phaseII, that's hour 128 out of 173 for HUP 138
# Processing hour 129 in HUP138_phaseII, that's hour 129 out of 173 for HUP 138
# Processing hour 130 in HUP138_phaseII, that's hour 130 out of 173 for HUP 138
# Processing hour 131 in HUP138_phaseII, that's hour 131 out of 173 for HUP 138
# Processing hour 132 in HUP138_phaseII, that's hour 132 out of 173 for HUP 138
# Processing hour 133 in HUP138_phaseII, that's hour 133 out of 173 for HUP 138
# Processing hour 134 in HUP138_phaseII, that's hour 134 out of 173 for HUP 138
# Processing hour 135 in HUP138_phaseII, that's hour 135 out of 173 for HUP 138
# Processing hour 136 in HUP138_phaseII, that's hour 136 out of 173 for HUP 138
# Processing hour 137 in HUP138_phaseII, that's hour 137 out of 173 for HUP 138
# Processing hour 138 in HUP138_phaseII, that's hour 138 out of 173 for HUP 138
# Processing hour 139 in HUP138_phaseII, that's hour 139 out of 173 for HUP 138
# Processing hour 140 in HUP138_phaseII, that's hour 140 out of 173 for HUP 138
# Processing hour 141 in HUP138_phaseII, that's hour 141 out of 173 for HUP 138
# Processing hour 142 in HUP138_phaseII, that's hour 142 out of 173 for HUP 138
# Processing hour 143 in HUP138_phaseII, that's hour 143 out of 173 for HUP 138
# Processing hour 144 in HUP138_phaseII, that's hour 144 out of 173 for HUP 138
# Processing hour 145 in HUP138_phaseII, that's hour 145 out of 173 for HUP 138
# Processing hour 146 in HUP138_phaseII, that's hour 146 out of 173 for HUP 138
# Processing hour 147 in HUP138_phaseII, that's hour 147 out of 173 for HUP 138
# Processing hour 148 in HUP138_phaseII, that's hour 148 out of 173 for HUP 138
# Processing hour 149 in HUP138_phaseII, that's hour 149 out of 173 for HUP 138
# Processing hour 150 in HUP138_phaseII, that's hour 150 out of 173 for HUP 138
# Processing hour 151 in HUP138_phaseII, that's hour 151 out of 173 for HUP 138
# Processing hour 152 in HUP138_phaseII, that's hour 152 out of 173 for HUP 138
# Processing hour 153 in HUP138_phaseII, that's hour 153 out of 173 for HUP 138
# Processing hour 154 in HUP138_phaseII, that's hour 154 out of 173 for HUP 138
# Processing hour 155 in HUP138_phaseII, that's hour 155 out of 173 for HUP 138
# Processing hour 156 in HUP138_phaseII, that's hour 156 out of 173 for HUP 138
# Processing hour 157 in HUP138_phaseII, that's hour 157 out of 173 for HUP 138
# Processing hour 158 in HUP138_phaseII, that's hour 158 out of 173 for HUP 138
# Processing hour 159 in HUP138_phaseII, that's hour 159 out of 173 for HUP 138
# Processing hour 160 in HUP138_phaseII, that's hour 160 out of 173 for HUP 138
# Processing hour 161 in HUP138_phaseII, that's hour 161 out of 173 for HUP 138
# Processing hour 162 in HUP138_phaseII, that's hour 162 out of 173 for HUP 138
# Processing hour 163 in HUP138_phaseII, that's hour 163 out of 173 for HUP 138
# Processing hour 164 in HUP138_phaseII, that's hour 164 out of 173 for HUP 138
# Processing hour 165 in HUP138_phaseII, that's hour 165 out of 173 for HUP 138
# Processing hour 166 in HUP138_phaseII, that's hour 166 out of 173 for HUP 138
# Processing hour 167 in HUP138_phaseII, that's hour 167 out of 173 for HUP 138
# Processing hour 168 in HUP138_phaseII, that's hour 168 out of 173 for HUP 138
# Processing hour 169 in HUP138_phaseII, that's hour 169 out of 173 for HUP 138
# Processing hour 170 in HUP138_phaseII, that's hour 170 out of 173 for HUP 138
# Processing hour 171 in HUP138_phaseII, that's hour 171 out of 173 for HUP 138
# Processing hour 172 in HUP138_phaseII, that's hour 172 out of 173 for HUP 138
# [0.13866025 0.06980414 0.14739993 0.1573159  0.14318397 0.13788095
#  0.14501299 0.13669234 0.06856329 0.13939455        nan 0.14138356
#  0.14784226 0.13480206 0.12986821 0.13250186 0.13870599 0.145917
#  0.07879759 0.1582174  0.18074466 0.13776564 0.1395783  0.15516436
#  0.16073411 0.15703891 0.14772642 0.13853799 0.13628581 0.15544102
#  0.15997515 0.14320592 0.16179815 0.15299792 0.14605787 0.14559061
#  0.1445444  0.14736263 0.1577605  0.13601984 0.1427769  0.14147551
#  0.16344541 0.16143412 0.15865726 0.17280258 0.16800561 0.14443162
#  0.16287826 0.16934465 0.17166672 0.16492573 0.15661247 0.15767192
#  0.15645686 0.15797024 0.13562761 0.15859396 0.14394592 0.14761035
#  0.15361777 0.13684507 0.14152606 0.15237339 0.1489739  0.15006304
#  0.14100209 0.15818631 0.15787339 0.16318298 0.13556139 0.16896386
#  0.18118771 0.15118193 0.16507638 0.16138969 0.15057414 0.14858222
#  0.15733344 0.15471542 0.14328302 0.15786083 0.13233888 0.14781458
#  0.14990859 0.14005453 0.1399774  0.15784684 0.1444285  0.15445228
#  0.15895431 0.15585105 0.15390144 0.16602707 0.15064545 0.14104643
#  0.1514401  0.13794681 0.14917651        nan 0.16357586 0.14769021
#  0.15227789 0.16026576 0.15221798 0.13478296 0.13451627 0.14090617
#  0.14586854 0.13317734 0.14248754 0.1495231  0.14778487 0.14808005
#  0.14612088 0.15141094 0.15897222 0.15287928 0.15764498 0.14527394
#  0.1470754  0.16020787 0.15161455 0.14735054 0.15475265 0.15558737
#  0.15349116 0.16026635 0.13708252 0.13299259 0.13854754 0.15197469
#  0.13666616 0.13272709 0.1368892  0.14076688 0.14924338 0.16000045
#  0.16158491 0.15839357 0.15342644 0.16269031 0.14633143 0.14972002
#  0.14869104 0.15295614 0.16762879 0.15334259 0.1458696  0.14523919
#  0.15173877 0.14901843 0.15520308 0.15165222 0.15261066 0.13143559
#  0.14754161 0.13393934 0.16047858 0.14732677 0.14361877 0.15673928
#  0.15655677 0.16238233 0.16061565 0.15115252 0.15171611 0.14310361
#  0.15789191 0.16305197 0.15351013 0.15122145 0.05812374]
# HUP 140, rid 320
# HUP140_phaseII_D02
# Processing hour 0 in HUP140_phaseII_D02, that's hour 0 out of 149 for HUP 140
# Processing hour 1 in HUP140_phaseII_D02, that's hour 1 out of 149 for HUP 140
# Processing hour 2 in HUP140_phaseII_D02, that's hour 2 out of 149 for HUP 140
# Processing hour 3 in HUP140_phaseII_D02, that's hour 3 out of 149 for HUP 140
# Processing hour 4 in HUP140_phaseII_D02, that's hour 4 out of 149 for HUP 140
# Processing hour 5 in HUP140_phaseII_D02, that's hour 5 out of 149 for HUP 140
# Processing hour 6 in HUP140_phaseII_D02, that's hour 6 out of 149 for HUP 140
# Processing hour 7 in HUP140_phaseII_D02, that's hour 7 out of 149 for HUP 140
# Processing hour 8 in HUP140_phaseII_D02, that's hour 8 out of 149 for HUP 140
# Processing hour 9 in HUP140_phaseII_D02, that's hour 9 out of 149 for HUP 140
# Processing hour 10 in HUP140_phaseII_D02, that's hour 10 out of 149 for HUP 140
# Processing hour 11 in HUP140_phaseII_D02, that's hour 11 out of 149 for HUP 140
# Processing hour 12 in HUP140_phaseII_D02, that's hour 12 out of 149 for HUP 140
# Processing hour 13 in HUP140_phaseII_D02, that's hour 13 out of 149 for HUP 140
# Processing hour 14 in HUP140_phaseII_D02, that's hour 14 out of 149 for HUP 140
# Processing hour 15 in HUP140_phaseII_D02, that's hour 15 out of 149 for HUP 140
# Processing hour 16 in HUP140_phaseII_D02, that's hour 16 out of 149 for HUP 140
# Processing hour 17 in HUP140_phaseII_D02, that's hour 17 out of 149 for HUP 140
# Processing hour 18 in HUP140_phaseII_D02, that's hour 18 out of 149 for HUP 140
# Processing hour 19 in HUP140_phaseII_D02, that's hour 19 out of 149 for HUP 140
# Processing hour 20 in HUP140_phaseII_D02, that's hour 20 out of 149 for HUP 140
# Processing hour 21 in HUP140_phaseII_D02, that's hour 21 out of 149 for HUP 140
# Processing hour 22 in HUP140_phaseII_D02, that's hour 22 out of 149 for HUP 140
# Processing hour 23 in HUP140_phaseII_D02, that's hour 23 out of 149 for HUP 140
# Processing hour 24 in HUP140_phaseII_D02, that's hour 24 out of 149 for HUP 140
# Processing hour 25 in HUP140_phaseII_D02, that's hour 25 out of 149 for HUP 140
# Processing hour 26 in HUP140_phaseII_D02, that's hour 26 out of 149 for HUP 140
# Processing hour 27 in HUP140_phaseII_D02, that's hour 27 out of 149 for HUP 140
# Processing hour 28 in HUP140_phaseII_D02, that's hour 28 out of 149 for HUP 140
# Processing hour 29 in HUP140_phaseII_D02, that's hour 29 out of 149 for HUP 140
# Processing hour 30 in HUP140_phaseII_D02, that's hour 30 out of 149 for HUP 140
# Processing hour 31 in HUP140_phaseII_D02, that's hour 31 out of 149 for HUP 140
# Processing hour 32 in HUP140_phaseII_D02, that's hour 32 out of 149 for HUP 140
# Processing hour 33 in HUP140_phaseII_D02, that's hour 33 out of 149 for HUP 140
# Processing hour 34 in HUP140_phaseII_D02, that's hour 34 out of 149 for HUP 140
# Processing hour 35 in HUP140_phaseII_D02, that's hour 35 out of 149 for HUP 140
# Processing hour 36 in HUP140_phaseII_D02, that's hour 36 out of 149 for HUP 140
# Processing hour 37 in HUP140_phaseII_D02, that's hour 37 out of 149 for HUP 140
# Processing hour 38 in HUP140_phaseII_D02, that's hour 38 out of 149 for HUP 140
# Processing hour 39 in HUP140_phaseII_D02, that's hour 39 out of 149 for HUP 140
# Processing hour 40 in HUP140_phaseII_D02, that's hour 40 out of 149 for HUP 140
# Processing hour 41 in HUP140_phaseII_D02, that's hour 41 out of 149 for HUP 140
# Processing hour 42 in HUP140_phaseII_D02, that's hour 42 out of 149 for HUP 140
# Processing hour 43 in HUP140_phaseII_D02, that's hour 43 out of 149 for HUP 140
# Processing hour 44 in HUP140_phaseII_D02, that's hour 44 out of 149 for HUP 140
# Processing hour 45 in HUP140_phaseII_D02, that's hour 45 out of 149 for HUP 140
# Processing hour 46 in HUP140_phaseII_D02, that's hour 46 out of 149 for HUP 140
# Processing hour 47 in HUP140_phaseII_D02, that's hour 47 out of 149 for HUP 140
# Processing hour 48 in HUP140_phaseII_D02, that's hour 48 out of 149 for HUP 140
# Processing hour 49 in HUP140_phaseII_D02, that's hour 49 out of 149 for HUP 140
# Processing hour 50 in HUP140_phaseII_D02, that's hour 50 out of 149 for HUP 140
# Processing hour 51 in HUP140_phaseII_D02, that's hour 51 out of 149 for HUP 140
# Processing hour 52 in HUP140_phaseII_D02, that's hour 52 out of 149 for HUP 140
# Processing hour 53 in HUP140_phaseII_D02, that's hour 53 out of 149 for HUP 140
# Processing hour 54 in HUP140_phaseII_D02, that's hour 54 out of 149 for HUP 140
# Processing hour 55 in HUP140_phaseII_D02, that's hour 55 out of 149 for HUP 140
# Processing hour 56 in HUP140_phaseII_D02, that's hour 56 out of 149 for HUP 140
# Processing hour 57 in HUP140_phaseII_D02, that's hour 57 out of 149 for HUP 140
# Processing hour 58 in HUP140_phaseII_D02, that's hour 58 out of 149 for HUP 140
# Processing hour 59 in HUP140_phaseII_D02, that's hour 59 out of 149 for HUP 140
# Processing hour 60 in HUP140_phaseII_D02, that's hour 60 out of 149 for HUP 140
# Processing hour 61 in HUP140_phaseII_D02, that's hour 61 out of 149 for HUP 140
# Processing hour 62 in HUP140_phaseII_D02, that's hour 62 out of 149 for HUP 140
# Processing hour 63 in HUP140_phaseII_D02, that's hour 63 out of 149 for HUP 140
# Processing hour 64 in HUP140_phaseII_D02, that's hour 64 out of 149 for HUP 140
# Processing hour 65 in HUP140_phaseII_D02, that's hour 65 out of 149 for HUP 140
# Processing hour 66 in HUP140_phaseII_D02, that's hour 66 out of 149 for HUP 140
# Processing hour 67 in HUP140_phaseII_D02, that's hour 67 out of 149 for HUP 140
# Processing hour 68 in HUP140_phaseII_D02, that's hour 68 out of 149 for HUP 140
# Processing hour 69 in HUP140_phaseII_D02, that's hour 69 out of 149 for HUP 140
# Processing hour 70 in HUP140_phaseII_D02, that's hour 70 out of 149 for HUP 140
# Processing hour 71 in HUP140_phaseII_D02, that's hour 71 out of 149 for HUP 140
# Processing hour 72 in HUP140_phaseII_D02, that's hour 72 out of 149 for HUP 140
# Processing hour 73 in HUP140_phaseII_D02, that's hour 73 out of 149 for HUP 140
# Processing hour 74 in HUP140_phaseII_D02, that's hour 74 out of 149 for HUP 140
# Processing hour 75 in HUP140_phaseII_D02, that's hour 75 out of 149 for HUP 140
# Processing hour 76 in HUP140_phaseII_D02, that's hour 76 out of 149 for HUP 140
# Processing hour 77 in HUP140_phaseII_D02, that's hour 77 out of 149 for HUP 140
# Processing hour 78 in HUP140_phaseII_D02, that's hour 78 out of 149 for HUP 140
# Processing hour 79 in HUP140_phaseII_D02, that's hour 79 out of 149 for HUP 140
# Processing hour 80 in HUP140_phaseII_D02, that's hour 80 out of 149 for HUP 140
# Processing hour 81 in HUP140_phaseII_D02, that's hour 81 out of 149 for HUP 140
# Processing hour 82 in HUP140_phaseII_D02, that's hour 82 out of 149 for HUP 140
# Processing hour 83 in HUP140_phaseII_D02, that's hour 83 out of 149 for HUP 140
# Processing hour 84 in HUP140_phaseII_D02, that's hour 84 out of 149 for HUP 140
# Processing hour 85 in HUP140_phaseII_D02, that's hour 85 out of 149 for HUP 140
# Processing hour 86 in HUP140_phaseII_D02, that's hour 86 out of 149 for HUP 140
# Processing hour 87 in HUP140_phaseII_D02, that's hour 87 out of 149 for HUP 140
# Processing hour 88 in HUP140_phaseII_D02, that's hour 88 out of 149 for HUP 140
# Processing hour 89 in HUP140_phaseII_D02, that's hour 89 out of 149 for HUP 140
# Processing hour 90 in HUP140_phaseII_D02, that's hour 90 out of 149 for HUP 140
# Processing hour 91 in HUP140_phaseII_D02, that's hour 91 out of 149 for HUP 140
# Processing hour 92 in HUP140_phaseII_D02, that's hour 92 out of 149 for HUP 140
# Processing hour 93 in HUP140_phaseII_D02, that's hour 93 out of 149 for HUP 140
# Processing hour 94 in HUP140_phaseII_D02, that's hour 94 out of 149 for HUP 140
# Processing hour 95 in HUP140_phaseII_D02, that's hour 95 out of 149 for HUP 140
# Processing hour 96 in HUP140_phaseII_D02, that's hour 96 out of 149 for HUP 140
# Processing hour 97 in HUP140_phaseII_D02, that's hour 97 out of 149 for HUP 140
# Processing hour 98 in HUP140_phaseII_D02, that's hour 98 out of 149 for HUP 140
# Processing hour 99 in HUP140_phaseII_D02, that's hour 99 out of 149 for HUP 140
# Processing hour 100 in HUP140_phaseII_D02, that's hour 100 out of 149 for HUP 140
# Processing hour 101 in HUP140_phaseII_D02, that's hour 101 out of 149 for HUP 140
# Processing hour 102 in HUP140_phaseII_D02, that's hour 102 out of 149 for HUP 140
# Processing hour 103 in HUP140_phaseII_D02, that's hour 103 out of 149 for HUP 140
# Processing hour 104 in HUP140_phaseII_D02, that's hour 104 out of 149 for HUP 140
# Processing hour 105 in HUP140_phaseII_D02, that's hour 105 out of 149 for HUP 140
# Processing hour 106 in HUP140_phaseII_D02, that's hour 106 out of 149 for HUP 140
# Processing hour 107 in HUP140_phaseII_D02, that's hour 107 out of 149 for HUP 140
# Processing hour 108 in HUP140_phaseII_D02, that's hour 108 out of 149 for HUP 140
# Processing hour 109 in HUP140_phaseII_D02, that's hour 109 out of 149 for HUP 140
# Processing hour 110 in HUP140_phaseII_D02, that's hour 110 out of 149 for HUP 140
# Processing hour 111 in HUP140_phaseII_D02, that's hour 111 out of 149 for HUP 140
# Processing hour 112 in HUP140_phaseII_D02, that's hour 112 out of 149 for HUP 140
# Processing hour 113 in HUP140_phaseII_D02, that's hour 113 out of 149 for HUP 140
# Processing hour 114 in HUP140_phaseII_D02, that's hour 114 out of 149 for HUP 140
# Processing hour 115 in HUP140_phaseII_D02, that's hour 115 out of 149 for HUP 140
# Processing hour 116 in HUP140_phaseII_D02, that's hour 116 out of 149 for HUP 140
# Processing hour 117 in HUP140_phaseII_D02, that's hour 117 out of 149 for HUP 140
# Processing hour 118 in HUP140_phaseII_D02, that's hour 118 out of 149 for HUP 140
# Processing hour 119 in HUP140_phaseII_D02, that's hour 119 out of 149 for HUP 140
# Processing hour 120 in HUP140_phaseII_D02, that's hour 120 out of 149 for HUP 140
# Processing hour 121 in HUP140_phaseII_D02, that's hour 121 out of 149 for HUP 140
# Processing hour 122 in HUP140_phaseII_D02, that's hour 122 out of 149 for HUP 140
# Processing hour 123 in HUP140_phaseII_D02, that's hour 123 out of 149 for HUP 140
# Processing hour 124 in HUP140_phaseII_D02, that's hour 124 out of 149 for HUP 140
# Processing hour 125 in HUP140_phaseII_D02, that's hour 125 out of 149 for HUP 140
# Processing hour 126 in HUP140_phaseII_D02, that's hour 126 out of 149 for HUP 140
# Processing hour 127 in HUP140_phaseII_D02, that's hour 127 out of 149 for HUP 140
# Processing hour 128 in HUP140_phaseII_D02, that's hour 128 out of 149 for HUP 140
# HUP140_phaseII_D01
# Processing hour 0 in HUP140_phaseII_D01, that's hour 129 out of 149 for HUP 140
# Skipping 1 for HUP140_phaseII_D01
# Processing hour 2 in HUP140_phaseII_D01, that's hour 131 out of 149 for HUP 140
# Processing hour 3 in HUP140_phaseII_D01, that's hour 132 out of 149 for HUP 140
# Processing hour 4 in HUP140_phaseII_D01, that's hour 133 out of 149 for HUP 140
# Processing hour 5 in HUP140_phaseII_D01, that's hour 134 out of 149 for HUP 140
# Processing hour 6 in HUP140_phaseII_D01, that's hour 135 out of 149 for HUP 140
# Processing hour 7 in HUP140_phaseII_D01, that's hour 136 out of 149 for HUP 140
# Processing hour 8 in HUP140_phaseII_D01, that's hour 137 out of 149 for HUP 140
# Processing hour 9 in HUP140_phaseII_D01, that's hour 138 out of 149 for HUP 140
# Processing hour 10 in HUP140_phaseII_D01, that's hour 139 out of 149 for HUP 140
# Processing hour 11 in HUP140_phaseII_D01, that's hour 140 out of 149 for HUP 140
# Processing hour 12 in HUP140_phaseII_D01, that's hour 141 out of 149 for HUP 140
# Processing hour 13 in HUP140_phaseII_D01, that's hour 142 out of 149 for HUP 140
# Processing hour 14 in HUP140_phaseII_D01, that's hour 143 out of 149 for HUP 140
# Processing hour 15 in HUP140_phaseII_D01, that's hour 144 out of 149 for HUP 140
# Processing hour 16 in HUP140_phaseII_D01, that's hour 145 out of 149 for HUP 140
# Processing hour 17 in HUP140_phaseII_D01, that's hour 146 out of 149 for HUP 140
# Processing hour 18 in HUP140_phaseII_D01, that's hour 147 out of 149 for HUP 140
# Processing hour 19 in HUP140_phaseII_D01, that's hour 148 out of 149 for HUP 140
# [0.1066534  0.13374299 0.1321505  0.11939817 0.12530759 0.15067943
#  0.14114418 0.14884553 0.13307514 0.13274209 0.13511125 0.13720046
#  0.12933875 0.14179379 0.124691   0.12701486 0.11575211 0.10676841
#  0.12310831 0.11506041 0.11438263 0.10469328 0.11357562 0.12160143
#  0.12427931 0.10007262 0.11265151 0.13655905 0.12970758 0.12798893
#  0.13399596 0.14358625 0.13888011 0.13228709 0.13066602 0.12465466
#  0.12147871 0.13569926 0.12516631 0.12376345 0.12477538 0.11658886
#  0.10964253 0.11100128 0.11841097 0.10133341 0.127676   0.11124163
#  0.11906196 0.11904325 0.12152441 0.12072892 0.1319894  0.1345268
#  0.13901931 0.13084281 0.12878577 0.12146333 0.13617689 0.13347604
#  0.13873885 0.1355524  0.12866797 0.1357857  0.1261818  0.11633587
#  0.0976724  0.10433962 0.11180913 0.13531095 0.12389521 0.11072388
#  0.1328363  0.11768012 0.12934296 0.13862692 0.13092501 0.14396849
#  0.12777461 0.12854089 0.13316782 0.13190607 0.1240351  0.13109344
#  0.12737934 0.13178754 0.1245625  0.12998169 0.12052313 0.12800772
#  0.10616711 0.1102725  0.12363232 0.10423179 0.10260205 0.10725717
#  0.10800458 0.11140924 0.11542728 0.10510347 0.12986874 0.11923538
#  0.12801132 0.11283185 0.10640317 0.11150561 0.11652112 0.11386663
#  0.12902483 0.11719644 0.11822317 0.12069845 0.12016373 0.11167287
#  0.11503609 0.09431928 0.11708989 0.0999801  0.11632798 0.12381437
#  0.13335222 0.10752672 0.1205668  0.11979951 0.12257756 0.12326451
#  0.1336311  0.12477748 0.12350272 0.18111229        nan 0.18188409
#  0.11472979 0.12616197 0.13833561 0.12156398 0.13319308 0.12297437
#  0.11747805 0.11958471 0.11399452 0.1148542  0.11373375 0.11909497
#  0.11159931 0.1174136  0.11817256 0.12154669 0.12434988]
# HUP 141, rid 294
# HUP141_phaseII
# Processing hour 0 in HUP141_phaseII, that's hour 0 out of 147 for HUP 141
# Processing hour 1 in HUP141_phaseII, that's hour 1 out of 147 for HUP 141
# Processing hour 2 in HUP141_phaseII, that's hour 2 out of 147 for HUP 141
# Processing hour 3 in HUP141_phaseII, that's hour 3 out of 147 for HUP 141
# Processing hour 4 in HUP141_phaseII, that's hour 4 out of 147 for HUP 141
# Processing hour 5 in HUP141_phaseII, that's hour 5 out of 147 for HUP 141
# Processing hour 6 in HUP141_phaseII, that's hour 6 out of 147 for HUP 141
# Processing hour 7 in HUP141_phaseII, that's hour 7 out of 147 for HUP 141
# Processing hour 8 in HUP141_phaseII, that's hour 8 out of 147 for HUP 141
# Processing hour 9 in HUP141_phaseII, that's hour 9 out of 147 for HUP 141
# Processing hour 10 in HUP141_phaseII, that's hour 10 out of 147 for HUP 141
# Processing hour 11 in HUP141_phaseII, that's hour 11 out of 147 for HUP 141
# Processing hour 12 in HUP141_phaseII, that's hour 12 out of 147 for HUP 141
# Processing hour 13 in HUP141_phaseII, that's hour 13 out of 147 for HUP 141
# Processing hour 14 in HUP141_phaseII, that's hour 14 out of 147 for HUP 141
# Processing hour 15 in HUP141_phaseII, that's hour 15 out of 147 for HUP 141
# Processing hour 16 in HUP141_phaseII, that's hour 16 out of 147 for HUP 141
# Processing hour 17 in HUP141_phaseII, that's hour 17 out of 147 for HUP 141
# Processing hour 18 in HUP141_phaseII, that's hour 18 out of 147 for HUP 141
# Processing hour 19 in HUP141_phaseII, that's hour 19 out of 147 for HUP 141
# Processing hour 20 in HUP141_phaseII, that's hour 20 out of 147 for HUP 141
# Processing hour 21 in HUP141_phaseII, that's hour 21 out of 147 for HUP 141
# Processing hour 22 in HUP141_phaseII, that's hour 22 out of 147 for HUP 141
# Processing hour 23 in HUP141_phaseII, that's hour 23 out of 147 for HUP 141
# Processing hour 24 in HUP141_phaseII, that's hour 24 out of 147 for HUP 141
# Processing hour 25 in HUP141_phaseII, that's hour 25 out of 147 for HUP 141
# Processing hour 26 in HUP141_phaseII, that's hour 26 out of 147 for HUP 141
# Processing hour 27 in HUP141_phaseII, that's hour 27 out of 147 for HUP 141
# Processing hour 28 in HUP141_phaseII, that's hour 28 out of 147 for HUP 141
# Processing hour 29 in HUP141_phaseII, that's hour 29 out of 147 for HUP 141
# Processing hour 30 in HUP141_phaseII, that's hour 30 out of 147 for HUP 141
# Processing hour 31 in HUP141_phaseII, that's hour 31 out of 147 for HUP 141
# Processing hour 32 in HUP141_phaseII, that's hour 32 out of 147 for HUP 141
# Processing hour 33 in HUP141_phaseII, that's hour 33 out of 147 for HUP 141
# Processing hour 34 in HUP141_phaseII, that's hour 34 out of 147 for HUP 141
# Processing hour 35 in HUP141_phaseII, that's hour 35 out of 147 for HUP 141
# Processing hour 36 in HUP141_phaseII, that's hour 36 out of 147 for HUP 141
# Processing hour 37 in HUP141_phaseII, that's hour 37 out of 147 for HUP 141
# Processing hour 38 in HUP141_phaseII, that's hour 38 out of 147 for HUP 141
# Processing hour 39 in HUP141_phaseII, that's hour 39 out of 147 for HUP 141
# Processing hour 40 in HUP141_phaseII, that's hour 40 out of 147 for HUP 141
# Processing hour 41 in HUP141_phaseII, that's hour 41 out of 147 for HUP 141
# Processing hour 42 in HUP141_phaseII, that's hour 42 out of 147 for HUP 141
# Processing hour 43 in HUP141_phaseII, that's hour 43 out of 147 for HUP 141
# Processing hour 44 in HUP141_phaseII, that's hour 44 out of 147 for HUP 141
# Processing hour 45 in HUP141_phaseII, that's hour 45 out of 147 for HUP 141
# Processing hour 46 in HUP141_phaseII, that's hour 46 out of 147 for HUP 141
# Processing hour 47 in HUP141_phaseII, that's hour 47 out of 147 for HUP 141
# Processing hour 48 in HUP141_phaseII, that's hour 48 out of 147 for HUP 141
# Processing hour 49 in HUP141_phaseII, that's hour 49 out of 147 for HUP 141
# Processing hour 50 in HUP141_phaseII, that's hour 50 out of 147 for HUP 141
# Processing hour 51 in HUP141_phaseII, that's hour 51 out of 147 for HUP 141
# Processing hour 52 in HUP141_phaseII, that's hour 52 out of 147 for HUP 141
# Processing hour 53 in HUP141_phaseII, that's hour 53 out of 147 for HUP 141
# Processing hour 54 in HUP141_phaseII, that's hour 54 out of 147 for HUP 141
# Processing hour 55 in HUP141_phaseII, that's hour 55 out of 147 for HUP 141
# Processing hour 56 in HUP141_phaseII, that's hour 56 out of 147 for HUP 141
# Processing hour 57 in HUP141_phaseII, that's hour 57 out of 147 for HUP 141
# Processing hour 58 in HUP141_phaseII, that's hour 58 out of 147 for HUP 141
# Skipping 59 for HUP141_phaseII
# Processing hour 60 in HUP141_phaseII, that's hour 60 out of 147 for HUP 141
# Processing hour 61 in HUP141_phaseII, that's hour 61 out of 147 for HUP 141
# Processing hour 62 in HUP141_phaseII, that's hour 62 out of 147 for HUP 141
# Processing hour 63 in HUP141_phaseII, that's hour 63 out of 147 for HUP 141
# Processing hour 64 in HUP141_phaseII, that's hour 64 out of 147 for HUP 141
# Processing hour 65 in HUP141_phaseII, that's hour 65 out of 147 for HUP 141
# Processing hour 66 in HUP141_phaseII, that's hour 66 out of 147 for HUP 141
# Processing hour 67 in HUP141_phaseII, that's hour 67 out of 147 for HUP 141
# Processing hour 68 in HUP141_phaseII, that's hour 68 out of 147 for HUP 141
# Processing hour 69 in HUP141_phaseII, that's hour 69 out of 147 for HUP 141
# Processing hour 70 in HUP141_phaseII, that's hour 70 out of 147 for HUP 141
# Processing hour 71 in HUP141_phaseII, that's hour 71 out of 147 for HUP 141
# Processing hour 72 in HUP141_phaseII, that's hour 72 out of 147 for HUP 141
# Processing hour 73 in HUP141_phaseII, that's hour 73 out of 147 for HUP 141
# Processing hour 74 in HUP141_phaseII, that's hour 74 out of 147 for HUP 141
# Processing hour 75 in HUP141_phaseII, that's hour 75 out of 147 for HUP 141
# Processing hour 76 in HUP141_phaseII, that's hour 76 out of 147 for HUP 141
# Processing hour 77 in HUP141_phaseII, that's hour 77 out of 147 for HUP 141
# Processing hour 78 in HUP141_phaseII, that's hour 78 out of 147 for HUP 141
# Processing hour 79 in HUP141_phaseII, that's hour 79 out of 147 for HUP 141
# Processing hour 80 in HUP141_phaseII, that's hour 80 out of 147 for HUP 141
# Processing hour 81 in HUP141_phaseII, that's hour 81 out of 147 for HUP 141
# Processing hour 82 in HUP141_phaseII, that's hour 82 out of 147 for HUP 141
# Processing hour 83 in HUP141_phaseII, that's hour 83 out of 147 for HUP 141
# Processing hour 84 in HUP141_phaseII, that's hour 84 out of 147 for HUP 141
# Processing hour 85 in HUP141_phaseII, that's hour 85 out of 147 for HUP 141
# Processing hour 86 in HUP141_phaseII, that's hour 86 out of 147 for HUP 141
# Processing hour 87 in HUP141_phaseII, that's hour 87 out of 147 for HUP 141
# Processing hour 88 in HUP141_phaseII, that's hour 88 out of 147 for HUP 141
# Processing hour 89 in HUP141_phaseII, that's hour 89 out of 147 for HUP 141
# Processing hour 90 in HUP141_phaseII, that's hour 90 out of 147 for HUP 141
# Processing hour 91 in HUP141_phaseII, that's hour 91 out of 147 for HUP 141
# Processing hour 92 in HUP141_phaseII, that's hour 92 out of 147 for HUP 141
# Processing hour 93 in HUP141_phaseII, that's hour 93 out of 147 for HUP 141
# Processing hour 94 in HUP141_phaseII, that's hour 94 out of 147 for HUP 141
# Processing hour 95 in HUP141_phaseII, that's hour 95 out of 147 for HUP 141
# Processing hour 96 in HUP141_phaseII, that's hour 96 out of 147 for HUP 141
# Processing hour 97 in HUP141_phaseII, that's hour 97 out of 147 for HUP 141
# Processing hour 98 in HUP141_phaseII, that's hour 98 out of 147 for HUP 141
# Processing hour 99 in HUP141_phaseII, that's hour 99 out of 147 for HUP 141
# Processing hour 100 in HUP141_phaseII, that's hour 100 out of 147 for HUP 141
# Processing hour 101 in HUP141_phaseII, that's hour 101 out of 147 for HUP 141
# Processing hour 102 in HUP141_phaseII, that's hour 102 out of 147 for HUP 141
# Processing hour 103 in HUP141_phaseII, that's hour 103 out of 147 for HUP 141
# Processing hour 104 in HUP141_phaseII, that's hour 104 out of 147 for HUP 141
# Processing hour 105 in HUP141_phaseII, that's hour 105 out of 147 for HUP 141
# Processing hour 106 in HUP141_phaseII, that's hour 106 out of 147 for HUP 141
# Processing hour 107 in HUP141_phaseII, that's hour 107 out of 147 for HUP 141
# Processing hour 108 in HUP141_phaseII, that's hour 108 out of 147 for HUP 141
# Processing hour 109 in HUP141_phaseII, that's hour 109 out of 147 for HUP 141
# Processing hour 110 in HUP141_phaseII, that's hour 110 out of 147 for HUP 141
# Skipping 111 for HUP141_phaseII
# Processing hour 112 in HUP141_phaseII, that's hour 112 out of 147 for HUP 141
# Processing hour 113 in HUP141_phaseII, that's hour 113 out of 147 for HUP 141
# Processing hour 114 in HUP141_phaseII, that's hour 114 out of 147 for HUP 141
# Processing hour 115 in HUP141_phaseII, that's hour 115 out of 147 for HUP 141
# Processing hour 116 in HUP141_phaseII, that's hour 116 out of 147 for HUP 141
# Processing hour 117 in HUP141_phaseII, that's hour 117 out of 147 for HUP 141
# Processing hour 118 in HUP141_phaseII, that's hour 118 out of 147 for HUP 141
# Processing hour 119 in HUP141_phaseII, that's hour 119 out of 147 for HUP 141
# Processing hour 120 in HUP141_phaseII, that's hour 120 out of 147 for HUP 141
# Processing hour 121 in HUP141_phaseII, that's hour 121 out of 147 for HUP 141
# Processing hour 122 in HUP141_phaseII, that's hour 122 out of 147 for HUP 141
# Processing hour 123 in HUP141_phaseII, that's hour 123 out of 147 for HUP 141
# Processing hour 124 in HUP141_phaseII, that's hour 124 out of 147 for HUP 141
# Processing hour 125 in HUP141_phaseII, that's hour 125 out of 147 for HUP 141
# Processing hour 126 in HUP141_phaseII, that's hour 126 out of 147 for HUP 141
# Processing hour 127 in HUP141_phaseII, that's hour 127 out of 147 for HUP 141
# Processing hour 128 in HUP141_phaseII, that's hour 128 out of 147 for HUP 141
# Processing hour 129 in HUP141_phaseII, that's hour 129 out of 147 for HUP 141
# Processing hour 130 in HUP141_phaseII, that's hour 130 out of 147 for HUP 141
# Processing hour 131 in HUP141_phaseII, that's hour 131 out of 147 for HUP 141
# Processing hour 132 in HUP141_phaseII, that's hour 132 out of 147 for HUP 141
# Processing hour 133 in HUP141_phaseII, that's hour 133 out of 147 for HUP 141
# Processing hour 134 in HUP141_phaseII, that's hour 134 out of 147 for HUP 141
# Processing hour 135 in HUP141_phaseII, that's hour 135 out of 147 for HUP 141
# Processing hour 136 in HUP141_phaseII, that's hour 136 out of 147 for HUP 141
# Processing hour 137 in HUP141_phaseII, that's hour 137 out of 147 for HUP 141
# Processing hour 138 in HUP141_phaseII, that's hour 138 out of 147 for HUP 141
# Processing hour 139 in HUP141_phaseII, that's hour 139 out of 147 for HUP 141
# Processing hour 140 in HUP141_phaseII, that's hour 140 out of 147 for HUP 141
# Processing hour 141 in HUP141_phaseII, that's hour 141 out of 147 for HUP 141
# Processing hour 142 in HUP141_phaseII, that's hour 142 out of 147 for HUP 141
# Processing hour 143 in HUP141_phaseII, that's hour 143 out of 147 for HUP 141
# Processing hour 144 in HUP141_phaseII, that's hour 144 out of 147 for HUP 141
# Processing hour 145 in HUP141_phaseII, that's hour 145 out of 147 for HUP 141
# Processing hour 146 in HUP141_phaseII, that's hour 146 out of 147 for HUP 141
# [0.08087629 0.14031191 0.15015337 0.14141794 0.1429649  0.13434397
#  0.14363032 0.13933143 0.14258656 0.13955611 0.14294857 0.13712209
#  0.13727906 0.14602004 0.18101643 0.14609749 0.15101451 0.14201498
#  0.14548225 0.16622698 0.14868689 0.16123929 0.15360494 0.14806031
#  0.14123154 0.15339861 0.15824576 0.15588475 0.16545926 0.15385633
#  0.14380628 0.1518916  0.14738291 0.16159175 0.16229425 0.15108639
#  0.17766406 0.15067087 0.14234964 0.16663558 0.15532681 0.17394284
#  0.1625798  0.17247241 0.15968587 0.16617944 0.15314576 0.14975778
#  0.14047784 0.15491956 0.15709046 0.1582474  0.16982487 0.16552507
#  0.1685159  0.17493826 0.16525203 0.16729038 0.15080088        nan
#  0.16542341 0.16751452 0.14700916 0.15741544 0.15428332 0.15406589
#  0.16115152 0.14723618 0.15603711 0.15458498 0.15721588 0.15857528
#  0.14941955 0.16323951 0.14738537 0.16096562 0.16042736 0.16072147
#  0.16328653 0.15529499 0.16862596 0.16530538 0.16390539 0.1730941
#  0.16977052 0.14246099 0.14276797 0.13973028 0.15735632 0.15527823
#  0.14531018 0.15989009 0.16407453 0.15834613 0.16884381 0.1586614
#  0.16050232 0.16451898 0.15033968 0.14955263 0.16023671 0.16495006
#  0.16875632 0.17035525 0.16062127 0.16217642 0.14180573 0.15557439
#  0.14357775 0.13073771 0.14748758        nan 0.15806125 0.14880833
#  0.15586195 0.16600981 0.17637108 0.16413651 0.1634429  0.17164909
#  0.1691068  0.15971045 0.17095258 0.15851474 0.15180415 0.16205471
#  0.15832907 0.16880433 0.15612448 0.15393334 0.15448255 0.15771486
#  0.16145281 0.13174399 0.1343079  0.13204612 0.15800667 0.15703517
#  0.14674699 0.16378442 0.16604551 0.15520214 0.15024738 0.16079631
#  0.15993886 0.16123724 0.15413422]
# HUP 142, rid 295
# HUP142_phaseII
# Processing hour 0 in HUP142_phaseII, that's hour 0 out of 312 for HUP 142
# Processing hour 1 in HUP142_phaseII, that's hour 1 out of 312 for HUP 142
# Processing hour 2 in HUP142_phaseII, that's hour 2 out of 312 for HUP 142
# Processing hour 3 in HUP142_phaseII, that's hour 3 out of 312 for HUP 142
# Processing hour 4 in HUP142_phaseII, that's hour 4 out of 312 for HUP 142
# Processing hour 5 in HUP142_phaseII, that's hour 5 out of 312 for HUP 142
# Processing hour 6 in HUP142_phaseII, that's hour 6 out of 312 for HUP 142
# Processing hour 7 in HUP142_phaseII, that's hour 7 out of 312 for HUP 142
# Processing hour 8 in HUP142_phaseII, that's hour 8 out of 312 for HUP 142
# Processing hour 9 in HUP142_phaseII, that's hour 9 out of 312 for HUP 142
# Processing hour 10 in HUP142_phaseII, that's hour 10 out of 312 for HUP 142
# Processing hour 11 in HUP142_phaseII, that's hour 11 out of 312 for HUP 142
# Processing hour 12 in HUP142_phaseII, that's hour 12 out of 312 for HUP 142
# Processing hour 13 in HUP142_phaseII, that's hour 13 out of 312 for HUP 142
# Processing hour 14 in HUP142_phaseII, that's hour 14 out of 312 for HUP 142
# Processing hour 15 in HUP142_phaseII, that's hour 15 out of 312 for HUP 142
# Processing hour 16 in HUP142_phaseII, that's hour 16 out of 312 for HUP 142
# Processing hour 17 in HUP142_phaseII, that's hour 17 out of 312 for HUP 142
# Processing hour 18 in HUP142_phaseII, that's hour 18 out of 312 for HUP 142
# Processing hour 19 in HUP142_phaseII, that's hour 19 out of 312 for HUP 142
# Processing hour 20 in HUP142_phaseII, that's hour 20 out of 312 for HUP 142
# Processing hour 21 in HUP142_phaseII, that's hour 21 out of 312 for HUP 142
# Processing hour 22 in HUP142_phaseII, that's hour 22 out of 312 for HUP 142
# Processing hour 23 in HUP142_phaseII, that's hour 23 out of 312 for HUP 142
# Processing hour 24 in HUP142_phaseII, that's hour 24 out of 312 for HUP 142
# Processing hour 25 in HUP142_phaseII, that's hour 25 out of 312 for HUP 142
# Processing hour 26 in HUP142_phaseII, that's hour 26 out of 312 for HUP 142
# Processing hour 27 in HUP142_phaseII, that's hour 27 out of 312 for HUP 142
# Processing hour 28 in HUP142_phaseII, that's hour 28 out of 312 for HUP 142
# Processing hour 29 in HUP142_phaseII, that's hour 29 out of 312 for HUP 142
# Processing hour 30 in HUP142_phaseII, that's hour 30 out of 312 for HUP 142
# Processing hour 31 in HUP142_phaseII, that's hour 31 out of 312 for HUP 142
# Processing hour 32 in HUP142_phaseII, that's hour 32 out of 312 for HUP 142
# Processing hour 33 in HUP142_phaseII, that's hour 33 out of 312 for HUP 142
# Processing hour 34 in HUP142_phaseII, that's hour 34 out of 312 for HUP 142
# Processing hour 35 in HUP142_phaseII, that's hour 35 out of 312 for HUP 142
# Processing hour 36 in HUP142_phaseII, that's hour 36 out of 312 for HUP 142
# Processing hour 37 in HUP142_phaseII, that's hour 37 out of 312 for HUP 142
# Processing hour 38 in HUP142_phaseII, that's hour 38 out of 312 for HUP 142
# Processing hour 39 in HUP142_phaseII, that's hour 39 out of 312 for HUP 142
# Processing hour 40 in HUP142_phaseII, that's hour 40 out of 312 for HUP 142
# Processing hour 41 in HUP142_phaseII, that's hour 41 out of 312 for HUP 142
# Processing hour 42 in HUP142_phaseII, that's hour 42 out of 312 for HUP 142
# Processing hour 43 in HUP142_phaseII, that's hour 43 out of 312 for HUP 142
# Processing hour 44 in HUP142_phaseII, that's hour 44 out of 312 for HUP 142
# Processing hour 45 in HUP142_phaseII, that's hour 45 out of 312 for HUP 142
# Processing hour 46 in HUP142_phaseII, that's hour 46 out of 312 for HUP 142
# Processing hour 47 in HUP142_phaseII, that's hour 47 out of 312 for HUP 142
# Processing hour 48 in HUP142_phaseII, that's hour 48 out of 312 for HUP 142
# Processing hour 49 in HUP142_phaseII, that's hour 49 out of 312 for HUP 142
# Processing hour 50 in HUP142_phaseII, that's hour 50 out of 312 for HUP 142
# Processing hour 51 in HUP142_phaseII, that's hour 51 out of 312 for HUP 142
# Processing hour 52 in HUP142_phaseII, that's hour 52 out of 312 for HUP 142
# Processing hour 53 in HUP142_phaseII, that's hour 53 out of 312 for HUP 142
# Processing hour 54 in HUP142_phaseII, that's hour 54 out of 312 for HUP 142
# Processing hour 55 in HUP142_phaseII, that's hour 55 out of 312 for HUP 142
# Processing hour 56 in HUP142_phaseII, that's hour 56 out of 312 for HUP 142
# Processing hour 57 in HUP142_phaseII, that's hour 57 out of 312 for HUP 142
# Processing hour 58 in HUP142_phaseII, that's hour 58 out of 312 for HUP 142
# Processing hour 59 in HUP142_phaseII, that's hour 59 out of 312 for HUP 142
# Processing hour 60 in HUP142_phaseII, that's hour 60 out of 312 for HUP 142
# Processing hour 61 in HUP142_phaseII, that's hour 61 out of 312 for HUP 142
# Processing hour 62 in HUP142_phaseII, that's hour 62 out of 312 for HUP 142
# Processing hour 63 in HUP142_phaseII, that's hour 63 out of 312 for HUP 142
# Processing hour 64 in HUP142_phaseII, that's hour 64 out of 312 for HUP 142
# Processing hour 65 in HUP142_phaseII, that's hour 65 out of 312 for HUP 142
# Processing hour 66 in HUP142_phaseII, that's hour 66 out of 312 for HUP 142
# Processing hour 67 in HUP142_phaseII, that's hour 67 out of 312 for HUP 142
# Processing hour 68 in HUP142_phaseII, that's hour 68 out of 312 for HUP 142
# Processing hour 69 in HUP142_phaseII, that's hour 69 out of 312 for HUP 142
# Processing hour 70 in HUP142_phaseII, that's hour 70 out of 312 for HUP 142
# Processing hour 71 in HUP142_phaseII, that's hour 71 out of 312 for HUP 142
# Processing hour 72 in HUP142_phaseII, that's hour 72 out of 312 for HUP 142
# Processing hour 73 in HUP142_phaseII, that's hour 73 out of 312 for HUP 142
# Processing hour 74 in HUP142_phaseII, that's hour 74 out of 312 for HUP 142
# Processing hour 75 in HUP142_phaseII, that's hour 75 out of 312 for HUP 142
# Processing hour 76 in HUP142_phaseII, that's hour 76 out of 312 for HUP 142
# Processing hour 77 in HUP142_phaseII, that's hour 77 out of 312 for HUP 142
# Processing hour 78 in HUP142_phaseII, that's hour 78 out of 312 for HUP 142
# Processing hour 79 in HUP142_phaseII, that's hour 79 out of 312 for HUP 142
# Processing hour 80 in HUP142_phaseII, that's hour 80 out of 312 for HUP 142
# Processing hour 81 in HUP142_phaseII, that's hour 81 out of 312 for HUP 142
# Processing hour 82 in HUP142_phaseII, that's hour 82 out of 312 for HUP 142
# ...
# Processing hour 190 in HUP171_phaseII, that's hour 190 out of 287 for HUP 171
# Processing hour 191 in HUP171_phaseII, that's hour 191 out of 287 for HUP 171
# Processing hour 192 in HUP171_phaseII, that's hour 192 out of 287 for HUP 171
# Processing hour 193 in HUP171_phaseII, that's hour 193 out of 287 for HUP 171
# Processing hour 194 in HUP171_phaseII, that's hour 194 out of 287 for HUP 171
# Processing hour 195 in HUP171_phaseII, that's hour 195 out of 287 for HUP 171
# Processing hour 196 in HUP171_phaseII, that's hour 196 out of 287 for HUP 171
# Processing hour 197 in HUP171_phaseII, that's hour 197 out of 287 for HUP 171
# Processing hour 198 in HUP171_phaseII, that's hour 198 out of 287 for HUP 171
# Processing hour 199 in HUP171_phaseII, that's hour 199 out of 287 for HUP 171
# Processing hour 200 in HUP171_phaseII, that's hour 200 out of 287 for HUP 171
# Processing hour 201 in HUP171_phaseII, that's hour 201 out of 287 for HUP 171
# Processing hour 202 in HUP171_phaseII, that's hour 202 out of 287 for HUP 171
# Processing hour 203 in HUP171_phaseII, that's hour 203 out of 287 for HUP 171
# Processing hour 204 in HUP171_phaseII, that's hour 204 out of 287 for HUP 171
# Processing hour 205 in HUP171_phaseII, that's hour 205 out of 287 for HUP 171
# Processing hour 206 in HUP171_phaseII, that's hour 206 out of 287 for HUP 171
# Processing hour 207 in HUP171_phaseII, that's hour 207 out of 287 for HUP 171
# Processing hour 208 in HUP171_phaseII, that's hour 208 out of 287 for HUP 171
# Processing hour 209 in HUP171_phaseII, that's hour 209 out of 287 for HUP 171
# Processing hour 210 in HUP171_phaseII, that's hour 210 out of 287 for HUP 171
# Processing hour 211 in HUP171_phaseII, that's hour 211 out of 287 for HUP 171
# Processing hour 212 in HUP171_phaseII, that's hour 212 out of 287 for HUP 171
# Processing hour 213 in HUP171_phaseII, that's hour 213 out of 287 for HUP 171
# Processing hour 214 in HUP171_phaseII, that's hour 214 out of 287 for HUP 171
# Processing hour 215 in HUP171_phaseII, that's hour 215 out of 287 for HUP 171
# Processing hour 216 in HUP171_phaseII, that's hour 216 out of 287 for HUP 171
# Processing hour 217 in HUP171_phaseII, that's hour 217 out of 287 for HUP 171
# Processing hour 218 in HUP171_phaseII, that's hour 218 out of 287 for HUP 171
# Processing hour 219 in HUP171_phaseII, that's hour 219 out of 287 for HUP 171
# Processing hour 220 in HUP171_phaseII, that's hour 220 out of 287 for HUP 171
# Processing hour 221 in HUP171_phaseII, that's hour 221 out of 287 for HUP 171
# Processing hour 222 in HUP171_phaseII, that's hour 222 out of 287 for HUP 171
# Processing hour 223 in HUP171_phaseII, that's hour 223 out of 287 for HUP 171
# Processing hour 224 in HUP171_phaseII, that's hour 224 out of 287 for HUP 171
# Processing hour 225 in HUP171_phaseII, that's hour 225 out of 287 for HUP 171
# Processing hour 226 in HUP171_phaseII, that's hour 226 out of 287 for HUP 171
# Processing hour 227 in HUP171_phaseII, that's hour 227 out of 287 for HUP 171
# Processing hour 228 in HUP171_phaseII, that's hour 228 out of 287 for HUP 171
# Processing hour 229 in HUP171_phaseII, that's hour 229 out of 287 for HUP 171
# Processing hour 230 in HUP171_phaseII, that's hour 230 out of 287 for HUP 171
# Processing hour 231 in HUP171_phaseII, that's hour 231 out of 287 for HUP 171
# Processing hour 232 in HUP171_phaseII, that's hour 232 out of 287 for HUP 171
# Processing hour 233 in HUP171_phaseII, that's hour 233 out of 287 for HUP 171
# Processing hour 234 in HUP171_phaseII, that's hour 234 out of 287 for HUP 171
# Processing hour 235 in HUP171_phaseII, that's hour 235 out of 287 for HUP 171
# Processing hour 236 in HUP171_phaseII, that's hour 236 out of 287 for HUP 171
# Processing hour 237 in HUP171_phaseII, that's hour 237 out of 287 for HUP 171
# Processing hour 238 in HUP171_phaseII, that's hour 238 out of 287 for HUP 171
# Processing hour 239 in HUP171_phaseII, that's hour 239 out of 287 for HUP 171
# Processing hour 240 in HUP171_phaseII, that's hour 240 out of 287 for HUP 171
# Processing hour 241 in HUP171_phaseII, that's hour 241 out of 287 for HUP 171
# Processing hour 242 in HUP171_phaseII, that's hour 242 out of 287 for HUP 171
# Processing hour 243 in HUP171_phaseII, that's hour 243 out of 287 for HUP 171
# Processing hour 244 in HUP171_phaseII, that's hour 244 out of 287 for HUP 171
# Processing hour 245 in HUP171_phaseII, that's hour 245 out of 287 for HUP 171
# Processing hour 246 in HUP171_phaseII, that's hour 246 out of 287 for HUP 171
# Processing hour 247 in HUP171_phaseII, that's hour 247 out of 287 for HUP 171
# Processing hour 248 in HUP171_phaseII, that's hour 248 out of 287 for HUP 171
# Processing hour 249 in HUP171_phaseII, that's hour 249 out of 287 for HUP 171
# Processing hour 250 in HUP171_phaseII, that's hour 250 out of 287 for HUP 171
# Processing hour 251 in HUP171_phaseII, that's hour 251 out of 287 for HUP 171
# Processing hour 252 in HUP171_phaseII, that's hour 252 out of 287 for HUP 171
# Processing hour 253 in HUP171_phaseII, that's hour 253 out of 287 for HUP 171
# Processing hour 254 in HUP171_phaseII, that's hour 254 out of 287 for HUP 171
# Processing hour 255 in HUP171_phaseII, that's hour 255 out of 287 for HUP 171
# Processing hour 256 in HUP171_phaseII, that's hour 256 out of 287 for HUP 171
# Processing hour 257 in HUP171_phaseII, that's hour 257 out of 287 for HUP 171
# Processing hour 258 in HUP171_phaseII, that's hour 258 out of 287 for HUP 171
# Processing hour 259 in HUP171_phaseII, that's hour 259 out of 287 for HUP 171
# Processing hour 260 in HUP171_phaseII, that's hour 260 out of 287 for HUP 171
# Processing hour 261 in HUP171_phaseII, that's hour 261 out of 287 for HUP 171
# Processing hour 262 in HUP171_phaseII, that's hour 262 out of 287 for HUP 171
# Processing hour 263 in HUP171_phaseII, that's hour 263 out of 287 for HUP 171
# Processing hour 264 in HUP171_phaseII, that's hour 264 out of 287 for HUP 171
# Processing hour 265 in HUP171_phaseII, that's hour 265 out of 287 for HUP 171
# Processing hour 266 in HUP171_phaseII, that's hour 266 out of 287 for HUP 171
# Processing hour 267 in HUP171_phaseII, that's hour 267 out of 287 for HUP 171
# Processing hour 268 in HUP171_phaseII, that's hour 268 out of 287 for HUP 171
# Processing hour 269 in HUP171_phaseII, that's hour 269 out of 287 for HUP 171
# Processing hour 270 in HUP171_phaseII, that's hour 270 out of 287 for HUP 171
# Processing hour 271 in HUP171_phaseII, that's hour 271 out of 287 for HUP 171
# Processing hour 272 in HUP171_phaseII, that's hour 272 out of 287 for HUP 171
# Processing hour 273 in HUP171_phaseII, that's hour 273 out of 287 for HUP 171
# Processing hour 274 in HUP171_phaseII, that's hour 274 out of 287 for HUP 171
# Processing hour 275 in HUP171_phaseII, that's hour 275 out of 287 for HUP 171
# Processing hour 276 in HUP171_phaseII, that's hour 276 out of 287 for HUP 171
# Processing hour 277 in HUP171_phaseII, that's hour 277 out of 287 for HUP 171
# Processing hour 278 in HUP171_phaseII, that's hour 278 out of 287 for HUP 171
# Processing hour 279 in HUP171_phaseII, that's hour 279 out of 287 for HUP 171
# Processing hour 280 in HUP171_phaseII, that's hour 280 out of 287 for HUP 171
# Processing hour 281 in HUP171_phaseII, that's hour 281 out of 287 for HUP 171
# Processing hour 282 in HUP171_phaseII, that's hour 282 out of 287 for HUP 171
# Processing hour 283 in HUP171_phaseII, that's hour 283 out of 287 for HUP 171
# Processing hour 284 in HUP171_phaseII, that's hour 284 out of 287 for HUP 171
# Processing hour 285 in HUP171_phaseII, that's hour 285 out of 287 for HUP 171
# Processing hour 286 in HUP171_phaseII, that's hour 286 out of 287 for HUP 171
# [0.10626728 0.04861594 0.0966583  0.08748348 0.10614988 0.09753133
#  0.09309642 0.090544   0.09791336 0.09899963 0.09913145 0.10061545
#  0.09478041 0.09023334 0.09295739 0.09297021 0.08307247 0.09938804
#  0.10093815 0.09176742 0.09049713 0.09160207 0.10040314 0.0833848
#  0.09926105 0.10098565 0.11065791 0.10169315 0.1075344  0.10139133
#  0.09514759 0.0966377  0.10063948 0.10443414 0.10260688 0.09927171
#  0.08285028 0.09234274 0.09474821 0.09901954 0.10900753 0.09548194
#  0.09800846 0.09320004 0.100865          nan 0.10418915 0.08398615
#  0.09084292 0.09534678 0.10102124 0.09869431 0.10453157 0.09933817
#  0.09877519 0.09223907 0.10117566 0.09904078 0.10235793 0.09378943
#  0.1087205  0.09537975 0.10100194 0.09504001 0.095389   0.08597518
#  0.093245   0.0957972  0.10255858 0.10376888 0.10285835 0.09547209
#  0.09325825 0.08969406 0.09765339 0.10172579 0.10529617 0.10467705
#  0.09775479 0.09834638 0.10186024 0.10451945 0.10494127 0.09609413
#  0.10359218 0.08589339 0.09262928 0.08824684 0.09378087 0.10455694
#  0.09786669 0.09312802 0.0937788  0.09808285 0.10058731 0.08772373
#  0.08947733 0.10032234 0.09799993 0.10190025 0.10108671 0.10112297
#  0.09478316 0.09617768 0.09709875 0.10290007 0.09828489 0.09902499
#  0.09714792 0.08400885 0.08497429 0.09836335 0.09188474 0.09682802
#  0.09444963 0.09770541 0.10106161 0.09914096 0.10194067 0.07867953
#  0.09475776 0.08840614 0.09842169 0.09506972 0.09861283 0.10750502
#  0.09683994 0.10227029 0.09662044 0.09626611 0.09783686 0.10147091
#  0.10033422 0.09958148 0.08677326        nan 0.09699271 0.08602849
#  0.08991368 0.09193067 0.1069821  0.09328891 0.11389314 0.1083047
#  0.11426018 0.10803355 0.10484578 0.1101592  0.1108564  0.11416249
#  0.11548225 0.0969565  0.10595762 0.0837568  0.08734594 0.08895383
#  0.08653942 0.10131221 0.09084361 0.10365554 0.08972295 0.10096777
#  0.1032996  0.1032042  0.09361196        nan        nan 0.10740042
#  0.10737721 0.09492128 0.09207913 0.10927558 0.10681823 0.10781299
#  0.08926197 0.08592952 0.10419623 0.10610431 0.08869232 0.07729438
#  0.09415978 0.09237291 0.10533061 0.09608738 0.09880913 0.09372873
#  0.09805642 0.09167169 0.09367938 0.09411416 0.09772849 0.08121751
#  0.09826966 0.09506056 0.10412701 0.09412036 0.10065199 0.09120761
#  0.10055549 0.08654469 0.09453414 0.09872451 0.09744276 0.10408907
#  0.09611135 0.09704203 0.09843918 0.08638124 0.09558473 0.09216189
#  0.09965238 0.0844186  0.10496049 0.10152001 0.09181632 0.0973722
#  0.08894491 0.08978151 0.08984892 0.09432521 0.0914659  0.09486274
#  0.09653188 0.09211648 0.08932871 0.09726176 0.08557326 0.08889252
#  0.09195592 0.0945447  0.09945421 0.0858312  0.09374997 0.09407501
#  0.09583171 0.10039035 0.09044261 0.0906216  0.08569787 0.09436333
#  0.09783922 0.09462684 0.08767886 0.09315888 0.10483985 0.10653221
#  0.10050562 0.09713038 0.09777353 0.10746888 0.09379402 0.09196233
#  0.09464358 0.09598262 0.09094567 0.08961827 0.08468331 0.09899293
#  0.09500727 0.09692026 0.10364941 0.10199846 0.09326311 0.08949323
#  0.11295439 0.10089759 0.0986469  0.10245752 0.1006363  0.0557383
#  0.05616667 0.05662606 0.05548616 0.0565361  0.05522474 0.05600318
#  0.05520604 0.05451031 0.05416558 0.0539633  0.0569302  0.05380975
#  0.05471066 0.05393346 0.05486031 0.05199915 0.05487481]
# HUP 172, rid 440
# HUP172_phaseII
# Processing hour 0 in HUP172_phaseII, that's hour 0 out of 240 for HUP 172
# Processing hour 1 in HUP172_phaseII, that's hour 1 out of 240 for HUP 172
# Processing hour 2 in HUP172_phaseII, that's hour 2 out of 240 for HUP 172
# Processing hour 3 in HUP172_phaseII, that's hour 3 out of 240 for HUP 172
# Processing hour 4 in HUP172_phaseII, that's hour 4 out of 240 for HUP 172
# Processing hour 5 in HUP172_phaseII, that's hour 5 out of 240 for HUP 172
# Processing hour 6 in HUP172_phaseII, that's hour 6 out of 240 for HUP 172
# Processing hour 7 in HUP172_phaseII, that's hour 7 out of 240 for HUP 172
# Processing hour 8 in HUP172_phaseII, that's hour 8 out of 240 for HUP 172
# Processing hour 9 in HUP172_phaseII, that's hour 9 out of 240 for HUP 172
# Processing hour 10 in HUP172_phaseII, that's hour 10 out of 240 for HUP 172
# Processing hour 11 in HUP172_phaseII, that's hour 11 out of 240 for HUP 172
# Processing hour 12 in HUP172_phaseII, that's hour 12 out of 240 for HUP 172
# Processing hour 13 in HUP172_phaseII, that's hour 13 out of 240 for HUP 172
# Processing hour 14 in HUP172_phaseII, that's hour 14 out of 240 for HUP 172
# Processing hour 15 in HUP172_phaseII, that's hour 15 out of 240 for HUP 172
# Processing hour 16 in HUP172_phaseII, that's hour 16 out of 240 for HUP 172
# Processing hour 17 in HUP172_phaseII, that's hour 17 out of 240 for HUP 172
# Processing hour 18 in HUP172_phaseII, that's hour 18 out of 240 for HUP 172
# Processing hour 19 in HUP172_phaseII, that's hour 19 out of 240 for HUP 172
# Processing hour 20 in HUP172_phaseII, that's hour 20 out of 240 for HUP 172
# Processing hour 21 in HUP172_phaseII, that's hour 21 out of 240 for HUP 172
# Processing hour 22 in HUP172_phaseII, that's hour 22 out of 240 for HUP 172
# Processing hour 23 in HUP172_phaseII, that's hour 23 out of 240 for HUP 172
# Processing hour 24 in HUP172_phaseII, that's hour 24 out of 240 for HUP 172
# Processing hour 25 in HUP172_phaseII, that's hour 25 out of 240 for HUP 172
# Processing hour 26 in HUP172_phaseII, that's hour 26 out of 240 for HUP 172
# Processing hour 27 in HUP172_phaseII, that's hour 27 out of 240 for HUP 172
# Processing hour 28 in HUP172_phaseII, that's hour 28 out of 240 for HUP 172
# Processing hour 29 in HUP172_phaseII, that's hour 29 out of 240 for HUP 172
# Processing hour 30 in HUP172_phaseII, that's hour 30 out of 240 for HUP 172
# Processing hour 31 in HUP172_phaseII, that's hour 31 out of 240 for HUP 172
# Processing hour 32 in HUP172_phaseII, that's hour 32 out of 240 for HUP 172
# Processing hour 33 in HUP172_phaseII, that's hour 33 out of 240 for HUP 172
# Processing hour 34 in HUP172_phaseII, that's hour 34 out of 240 for HUP 172
# Processing hour 35 in HUP172_phaseII, that's hour 35 out of 240 for HUP 172
# Processing hour 36 in HUP172_phaseII, that's hour 36 out of 240 for HUP 172
# Processing hour 37 in HUP172_phaseII, that's hour 37 out of 240 for HUP 172
# Processing hour 38 in HUP172_phaseII, that's hour 38 out of 240 for HUP 172
# Processing hour 39 in HUP172_phaseII, that's hour 39 out of 240 for HUP 172
# Processing hour 40 in HUP172_phaseII, that's hour 40 out of 240 for HUP 172
# Skipping 41 for HUP172_phaseII
# Processing hour 42 in HUP172_phaseII, that's hour 42 out of 240 for HUP 172
# Processing hour 43 in HUP172_phaseII, that's hour 43 out of 240 for HUP 172
# Processing hour 44 in HUP172_phaseII, that's hour 44 out of 240 for HUP 172
# Processing hour 45 in HUP172_phaseII, that's hour 45 out of 240 for HUP 172
# Processing hour 46 in HUP172_phaseII, that's hour 46 out of 240 for HUP 172
# Processing hour 47 in HUP172_phaseII, that's hour 47 out of 240 for HUP 172
# Processing hour 48 in HUP172_phaseII, that's hour 48 out of 240 for HUP 172
# Processing hour 49 in HUP172_phaseII, that's hour 49 out of 240 for HUP 172
# Processing hour 50 in HUP172_phaseII, that's hour 50 out of 240 for HUP 172
# Processing hour 51 in HUP172_phaseII, that's hour 51 out of 240 for HUP 172
# Processing hour 52 in HUP172_phaseII, that's hour 52 out of 240 for HUP 172
# Processing hour 53 in HUP172_phaseII, that's hour 53 out of 240 for HUP 172
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 34
#      32 try:
#      33     with open(full_path, "rb") as f:
# ---> 34         eeg_segment_df = pickle.load(f)
#      35         channel_labels = eeg_segment_df.columns.values.tolist()
#      36         eeg_segment_df = eeg_segment_df.T
#
# File /mnt/leif/littlab/users/devinma/Libraries/miniconda3/lib/python3.11/site-packages/pandas/_libs/internals.pyx:575, in pandas._libs.internals._unpickle_block()
#
# File /mnt/leif/littlab/users/devinma/Libraries/miniconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:2172, in new_block(values, placement, ndim)
#    2168     values = maybe_coerce_values(values)
#    2169     return klass(values, ndim=2, placement=placement)
# -> 2172 def new_block(values, placement, *, ndim: int) -> Block:
#    2173     # caller is responsible for ensuring values is NOT a PandasArray
#    2175     if not isinstance(placement, BlockPlacement):
#    2176         placement = BlockPlacement(placement)
#
# KeyboardInterrupt:

# %%
# channel_labels = eeg_segment_df.columns.values.tolist()
# channel_types_df = check_channel_types(channel_labels)
# seeg_electrodes_df = channel_types_df.loc[channel_types_df["type"] == "seeg"]
# # Find the rows in patient_electrodes_df that correspond to seeg_electrodes
# seeg_electrodes_df = patient_electrodes_df.loc[
#     patient_electrodes_df["name"].isin(seeg_electrodes_df.name.to_numpy(dtype=str))
# ]

# # Find the ones that have label not 'EmptyLabel'
# grey_matter_seeg_electrodes_df = seeg_electrodes_df.loc[
#     seeg_electrodes_df["label"] != "EmptyLabel"
# ]

# grey_matter_seeg_electrode_labels = grey_matter_seeg_electrodes_df.name.to_numpy(
#     dtype=str
# )
# eeg_segment_df = eeg_segment_df[grey_matter_seeg_electrode_labels]
