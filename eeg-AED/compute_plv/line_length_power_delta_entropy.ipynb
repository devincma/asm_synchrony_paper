# %% [markdown]
# # Line Length & Power

# %%
import numpy as np
import os, pickle
import pandas as pd
from scipy import signal
from scipy.fft import fft
from scipy.signal import hilbert

from ieeg_utils import *

IEEG_DIRECTORY = "../../../Data/ieeg/all/2_min"
KURAMOTO_DIRECTORY = "../../../Data/plv/kuramoto"

# %%
def calculate_synchrony(time_series):
    """
    Calculate the Kuramoto order parameter for a set of time series
    Args:
        time_series (np.array): 2D array where each row is a time series
    Returns:
        np.array: Kuramoto order parameter for each time point
    """
    # Extract the number of time series and the number of time points
    N, _ = time_series.shape
    # Apply the Hilbert Transform to get an analytical signal
    analytical_signals = hilbert(time_series)
    assert analytical_signals.shape == time_series.shape
    # Extract the instantaneous phase for each time series using np.angle
    phases = np.angle(analytical_signals, deg=False)
    assert phases.shape == time_series.shape
    # Compute the Kuramoto order parameter for each time point
    # 1j*1j == -1
    r_t = np.abs(np.sum(np.exp(1j * phases), axis=0)) / N
    R = np.mean(r_t)
    return r_t, R


def calculate_entropy(synchrony, num_bins=24):
    # Calculate the probability distribution by binning the synchrony values
    hist, _ = np.histogram(synchrony, bins=num_bins)
    probabilities = hist / np.sum(hist)

    # Calculate the entropy
    entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)
    return entropy

# %%
nina_patient_hup_ids = pd.read_excel("../../../Data/HUP_implant_dates.xlsx")
nina_patient_hup_ids = nina_patient_hup_ids["hup_id"].to_numpy()
nina_patient_hup_ids
# Out:
# array([225, 224, 223, 221, 219, 217, 216, 215, 214, 213, 211, 210, 209,
#        208, 207, 206, 205, 204, 202, 201, 199, 197, 196, 195, 194, 193,
#        192, 191, 190, 189, 188, 187, 186, 185, 184, 182, 181, 180, 179,
#        178, 177, 175, 174, 173, 172, 171, 170, 169, 168, 167, 166, 165,
#        164, 163, 162, 161, 160, 159, 158, 157, 156, 155, 154, 153, 152,
#        151, 150, 149, 148, 147, 146, 145, 144, 143, 142, 141, 140, 139,
#        138, 137])

# %%
selected_patient_hup_ids = [
    143,
    146,
    149,
    153,
    157,
    158,
    165,
    169,
    171,
    177,
    181,
    190,
    205,
    210,
    216,
]

# %%
# Create a mapping between patient ids and the index of the patient in the patients_df dataframe
patient_hup_id_to_index = {}
for i, patient_id in enumerate(nina_patient_hup_ids):
    patient_hup_id_to_index[patient_id] = i
# patient_hup_id_to_index

# %%
ieeg_offset_row1_df = pd.read_excel("../../../Data/ieeg_offset/row_1.xlsx", header=None)
ieeg_offset_row2_df = pd.read_excel("../../../Data/ieeg_offset/row_2.xlsx", header=None)
ieeg_offset_row3_df = pd.read_excel("../../../Data/ieeg_offset/row_3.xlsx", header=None)

# %%
# Load master_elecs.csv from ./data/
master_elecs_df = pd.read_csv("../../../Data/master_elecs.csv")

# only take the numbers in rid column
master_elecs_df["rid"] = master_elecs_df["rid"].str.extract("(\d+)", expand=False)
master_elecs_df["rid"] = master_elecs_df["rid"].astype(int)

# Drop mni_x, mni_y, mni_z, mm_x, mm_y, mm_z columns
master_elecs_df = master_elecs_df.drop(
    columns=["mni_x", "mni_y", "mni_z", "mm_x", "mm_y", "mm_z"]
)

master_elecs_df
# Out:
#        rid   name     vox_x     vox_y     vox_z                   label  \
# 0       13  LST01   80.6116  106.5480   64.5941  left inferior temporal
# 1       13  LST02   72.0779  109.4150   63.1223  left inferior temporal
# 2       13  LST03   64.9060  112.3760   68.7455              EmptyLabel
# 3       13  LST04   65.0210  114.6600   78.2339    left middle temporal
# 4       13  MST01  131.7410   64.3756   70.4205           right lingual
# ...    ...    ...       ...       ...       ...                     ...
# 14212  785   RB08  154.2550  114.2730  136.7560              EmptyLabel
# 14213  785   RB09  159.1350  111.9920  136.6960              EmptyLabel
# 14214  785   RB10  164.7520  109.9030  137.7640   right middle temporal
# 14215  785   RB11  169.6320  107.6220  137.7040   right middle temporal
# 14216  785   RB12  175.1210  105.8310  137.7080              EmptyLabel
#
#          soz resected  spike_rate  engel
# 0      False    False    1.091902    1.0
# 1      False    False    1.091902    1.0
# 2      False    False    1.419472    1.0
# 3      False    False    0.655141    1.0
# 4       True    False    3.439490    1.0
# ...      ...      ...         ...    ...
# 14212  False      NaN    0.369914    1.0
# 14213  False      NaN    0.665845    1.0
# 14214  False      NaN    4.586930    1.0
# 14215  False      NaN    2.071517    1.0
# 14216  False      NaN    5.104809    1.0
#
# [14217 rows x 10 columns]

# %%
# Load rid_hup_table.csv from ./data/
rid_hup_table_df = pd.read_csv("../../../Data/rid_hup_table.csv")
# Drop the t3_subject_id and ieegportalsubjno columns
rid_hup_table_df = rid_hup_table_df.drop(columns=["t3_subject_id", "ieegportalsubjno"])
rid_hup_table_df
# Out:
#      record_id  hupsubjno
# 0          623         35
# 1          624         36
# 2          625         37
# 3          626         38
# 4          627         39
# ..         ...        ...
# 212        534        250
# 213        923        251
# 214        918        252
# 215        864        253
# 216        675        254
#
# [217 rows x 2 columns]

# %%
def bipolar_montage(data: np.ndarray, ch_types: pd.DataFrame) -> np.ndarray:
    """_summary_

    Args:
        data (np.ndarray): _description_
        ch_types (pd.DataFrame): _description_

    Returns:
        np.ndarray: _description_
    """

    n_ch = len(ch_types)
    new_ch_types = []
    for ind, row in ch_types.iterrows():
        # do only if type is ecog or seeg
        if row["type"] not in ["ecog", "seeg"]:
            continue

        ch1 = row["name"]

        ch2 = ch_types.loc[
            (ch_types["lead"] == row["lead"])
            & (ch_types["contact"] == row["contact"] + 1),
            "name",
        ]
        if len(ch2) > 0:
            ch2 = ch2.iloc[0]
            entry = {
                "name": ch1 + "-" + ch2,
                "type": row["type"],
                "idx1": ind,
                "idx2": ch_types.loc[ch_types["name"] == ch2].index[0],
            }
            new_ch_types.append(entry)

    new_ch_types = pd.DataFrame(new_ch_types)
    # apply montage to data
    new_data = np.empty((len(new_ch_types), data.shape[1]))
    for ind, row in new_ch_types.iterrows():
        new_data[ind, :] = data[row["idx1"], :] - data[row["idx2"], :]

    return new_data, new_ch_types

# %%
def identify_bad_channels(values, channel_indices, channel_labels, fs):
    """
    Identifies 'bad' channels in an EEG dataset based on various criteria such as high variance, missing data,
    crossing absolute threshold, high variance above baseline, and 60 Hz noise.

    Parameters:
    values (numpy.ndarray): A 2D array of EEG data where each column is a different channel and each row is a reading.
    channel_indices (list): A list containing indices of channels to be analyzed.
    channel_labels (list): A list of channel labels.
    fs (float): The sampling frequency.

    Returns:
    bad (list): A list of 'bad' channel indices.
    details (dict): A dictionary containing the reasons why each channel was marked as 'bad'. Keys are 'noisy', 'nans',
                    'zeros', 'var', 'higher_std', and 'high_voltage'. Each key maps to a list of channel indices.
    """

    # set parameters
    tile = 99
    mult = 10
    num_above = 1
    abs_thresh = 5e3
    percent_60_hz = 0.99
    mult_std = 10

    bad = []
    high_ch = []
    nan_ch = []
    zero_ch = []
    high_var_ch = []
    noisy_ch = []
    all_std = np.full(len(channel_indices), np.nan)

    for i in range(len(channel_indices)):
        bad_ch = 0
        ich = channel_indices[i]
        eeg = values[:, ich]
        bl = np.nanmedian(eeg)

        all_std[i] = np.nanstd(eeg)

        if np.sum(np.isnan(eeg)) > 0.5 * len(eeg):
            bad.append(ich)
            nan_ch.append(ich)
            continue

        if np.sum(eeg == 0) > 0.5 * len(eeg):
            bad.append(ich)
            zero_ch.append(ich)
            continue

        if np.sum(np.abs(eeg - bl) > abs_thresh) > 10:
            bad.append(ich)
            bad_ch = 1
            high_ch.append(ich)

        if bad_ch == 1:
            continue

        pct = np.percentile(eeg, [100 - tile, tile])
        thresh = [bl - mult * (bl - pct[0]), bl + mult * (pct[1] - bl)]
        sum_outside = np.sum((eeg > thresh[1]) | (eeg < thresh[0]))

        if sum_outside >= num_above:
            bad_ch = 1

        if bad_ch == 1:
            bad.append(ich)
            high_var_ch.append(ich)
            continue

        Y = fft(eeg - np.nanmean(eeg))

        P = np.abs(Y) ** 2
        freqs = np.linspace(0, fs, len(P) + 1)
        freqs = freqs[:-1]
        P = P[: int(np.ceil(len(P) / 2))]
        freqs = freqs[: int(np.ceil(len(freqs) / 2))]

        total_P = np.sum(P)
        if total_P != 0 and not np.isnan(total_P):
            P_60Hz = np.sum(P[(freqs > 58) & (freqs < 62)]) / total_P
        else:
            P_60Hz = 0  # or any other value that makes sense in the context

        if P_60Hz > percent_60_hz:
            bad_ch = 1

        if bad_ch == 1:
            bad.append(ich)
            noisy_ch.append(ich)
            continue

    median_std = np.nanmedian(all_std)
    higher_std = [
        channel_indices[i]
        for i in range(len(all_std))
        if all_std[i] > mult_std * median_std
    ]
    bad_std = [ch for ch in higher_std if ch not in bad]
    bad.extend(bad_std)

    details = {
        "noisy": noisy_ch,
        "nans": nan_ch,
        "zeros": zero_ch,
        "var": high_var_ch,
        "higher_std": bad_std,
        "high_voltage": high_ch,
    }

    return bad, details

# %%
# Create an empty dictionary to store all the data
data_dict = {"dataset_name": [], "max_hour": [], "sample_rate": [], "hup_id": []}

# Iterate through the directory
for filename in os.listdir(IEEG_DIRECTORY):
    if filename.endswith(".pkl"):  # Only process .pkl files
        # Split the filename to get the dataset_name, hour, and sample_rate
        parts = filename.split("_")
        dataset_name = "_".join(parts[:-4])  # Exclude the '_hr' from the dataset_name
        hour = int(parts[-3])
        sample_rate = int(parts[-1].split(".")[0])

        # Extract hup_id from dataset_name
        hup_id = dataset_name.split("_")[0].split("HUP")[1]

        # If the dataset_name is already in the dictionary, update the max_hour
        if dataset_name in data_dict["dataset_name"]:
            index = data_dict["dataset_name"].index(dataset_name)
            data_dict["max_hour"][index] = max(data_dict["max_hour"][index], hour)
        else:
            # Else, add the dataset_name, hour, sample_rate and hup_id to the dictionary
            data_dict["dataset_name"].append(dataset_name)
            data_dict["max_hour"].append(hour)
            data_dict["sample_rate"].append(sample_rate)
            data_dict["hup_id"].append(hup_id)

# Create a DataFrame from the dictionary
datasets_df = pd.DataFrame(data_dict)
# Make max_hour and sample_rate and hup_id integers
datasets_df["max_hour"] = datasets_df["max_hour"].astype(int)
datasets_df["sample_rate"] = datasets_df["sample_rate"].astype(int)
datasets_df["hup_id"] = datasets_df["hup_id"].astype(int)
# Sort by hup_id
datasets_df = datasets_df.sort_values(by=["hup_id"])
# Reset the index
datasets_df = datasets_df.reset_index(drop=True)
# Create a column called max_hour_count that is the max_hour + 1
datasets_df["max_hour_count"] = datasets_df["max_hour"] + 1
datasets_df
# Out:
#           dataset_name  max_hour  sample_rate  hup_id  max_hour_count
# 0       HUP138_phaseII       172         1024     138             173
# 1   HUP140_phaseII_D02       128         1024     140             129
# 2   HUP140_phaseII_D01        19         1024     140              20
# 3       HUP141_phaseII       146          512     141             147
# 4       HUP142_phaseII       311          512     142             312
# ..                 ...       ...          ...     ...             ...
# 81  HUP215_phaseII_D01        14         2048     215              15
# 82  HUP216_phaseII_D01       143          512     216             144
# 83  HUP216_phaseII_D02       144          512     216             145
# 84      HUP223_phaseII       135         1024     223             136
# 85      HUP224_phaseII       145         1024     224             146
#
# [86 rows x 5 columns]

# %%
frequency_bands = {
    "delta": (0.5, 4),
    "theta": (4, 8),
    "alpha": (8, 12),
    "beta": (12, 30),
    "gamma": (30, 100),
}

# %%
def process_eeg_data(
    data,
    sample_rate,
    band_pass_freq,
    notch_freq=60,
):
    """
    Applies a notch filter and a bandpass filter to the input data along each row.

    The notch filter helps eliminate noise at a specified frequency (default is 50Hz).
    The bandpass filter only allows frequencies within a specified range to pass through (default is 100-125Hz).

    Parameters:
    data (numpy.ndarray): Input data where each row represents a channel and each column represents a sample.
    sample_rate (float): The sampling rate of the data in Hz.
    notch_freq (float, optional): The frequency to be eliminated by the notch filter in Hz. Defaults to 50Hz.
    band_pass_freq (tuple, optional): The lower and upper frequency limits of the bandpass filter in Hz. Defaults to (100, 125Hz).

    Returns:
    numpy.ndarray: The filtered data, with the same shape as the input data.
    """

    # Apply notch filter to eliminate 60Hz noise
    notch_b, notch_a = signal.iirnotch(notch_freq, 30, sample_rate)
    data_notch_filtered = signal.filtfilt(notch_b, notch_a, data, axis=1)

    if band_pass_freq is None:
        return data_notch_filtered

    # Apply bandpass filter
    band_pass_b, band_pass_a = signal.butter(
        2, band_pass_freq, btype="band", fs=sample_rate
    )
    data_band_pass_filtered = signal.filtfilt(
        band_pass_b, band_pass_a, data_notch_filtered, axis=1
    )

    return data_band_pass_filtered

# %%
for patient_hup_id in selected_patient_hup_ids:
    # Find the value of record_id in rid_hup_table_df where hupsubjno == patient_hup_id
    patient_rid = rid_hup_table_df[rid_hup_table_df["hupsubjno"] == patient_hup_id][
        "record_id"
    ].values[0]
    # Get the row in datasets_df corresponding to the patient_hup_id
    rows_df = datasets_df[datasets_df["hup_id"] == patient_hup_id]
    # Sort rows_df by dataset_name
    rows_df = rows_df.sort_values(by=["dataset_name"])
    rows_df = rows_df.reset_index(drop=True)
    patient_electrodes_df = master_elecs_df.loc[master_elecs_df["rid"] == patient_rid]
    print(f"HUP {patient_hup_id}, rid {patient_rid}")

    # Add up all the max_hours for rows_df
    total_max_hour_count = rows_df["max_hour_count"].sum()

    ##########################################
    # Create empty vectors to save the data
    ##########################################
    plv_vector_to_save = np.zeros(total_max_hour_count)
    current_hour = 0

    for dataset_idx, dataset_row in rows_df.iterrows():
        # Get the dataset_name, max_hour, and sample_rate
        dataset_name = dataset_row["dataset_name"]
        max_hour_count = dataset_row["max_hour_count"]
        sample_rate = dataset_row["sample_rate"]
        print(dataset_name)

        for hour in range(max_hour_count):
            # Get the filename
            filename = f"{dataset_name}_hr_{hour}_fs_{sample_rate}.pkl"
            # Get the full path to the file
            full_path = os.path.join(IEEG_DIRECTORY, filename)

            # Load the data
            try:
                with open(full_path, "rb") as f:
                    eeg_segment_df = pickle.load(f)
            except FileNotFoundError:
                print(f"Skipping {hour} for {dataset_name}")
                plv_vector_to_save[current_hour] = np.nan
                current_hour += 1
                continue

            print(
                f"Processing hour {hour} in {dataset_name}, that's hour {current_hour} out of {total_max_hour_count} for HUP {patient_hup_id}"
            )
            channel_labels = eeg_segment_df.columns.values.tolist()
            channel_indices = np.arange(len(channel_labels))

            bad_channel_indicies, bad_details = identify_bad_channels(
                eeg_segment_df.to_numpy(dtype=float),
                channel_indices,
                channel_labels,
                sample_rate,
            )

            # Get the labels of the good indicies
            good_channel_labels = np.delete(channel_labels, bad_channel_indicies)

            # Skip this hour if there are less than 2 good channels, i.e., unable to create a bipolar montage
            if len(good_channel_labels) < 2:
                print(
                    f"Skipping {hour} for {dataset_name} because there are less than 2 good channels"
                )
                plv_vector_to_save[current_hour] = np.nan
                current_hour += 1
                continue

            good_channel_types_df = check_channel_types(good_channel_labels)

            try:
                bipolar_eeg_data, bipolar_channel_types_df = bipolar_montage(
                    ((eeg_segment_df[good_channel_labels]).T).to_numpy(),
                    good_channel_types_df,
                )
            except Exception as error:
                print(
                    f"Skipping {hour} for {dataset_name} because of an error in bipolar_montage"
                )
                print(error)
                continue

            if len(bipolar_eeg_data) == 0:
                print(
                    f"Skipping {hour} for {dataset_name} because there's less than 1 good channel after bipolar_montage"
                )
                plv_vector_to_save[current_hour] = np.nan
                current_hour += 1
                continue

            bipolar_eeg_data_filtered = process_eeg_data(
                data=bipolar_eeg_data,
                sample_rate=sample_rate,
                band_pass_freq=frequency_bands["delta"],
                notch_freq=60,
            )

            ##########################################
            # Compute hourly features
            ##########################################

            r_t, _ = calculate_synchrony(bipolar_eeg_data_filtered)
            entropy = calculate_entropy(r_t)
            plv_vector_to_save[current_hour] = entropy
            current_hour += 1

    ##########################################
    # Save files
    ##########################################
    np.save(
        f"{KURAMOTO_DIRECTORY}/delta_entropy/HUP_{patient_hup_id}.npy",
        plv_vector_to_save,
    )
# Out:
# HUP 143, rid 206
# HUP143_phaseII
# Processing hour 0 in HUP143_phaseII, that's hour 0 out of 240 for HUP 143
# Skipping 0 for HUP143_phaseII because there are less than 2 good channels
# Skipping 1 for HUP143_phaseII
# Skipping 2 for HUP143_phaseII
# Skipping 3 for HUP143_phaseII
# Skipping 4 for HUP143_phaseII
# Processing hour 5 in HUP143_phaseII, that's hour 5 out of 240 for HUP 143
# Skipping 5 for HUP143_phaseII because there's less than 1 good channel after bipolar_montage
# Processing hour 6 in HUP143_phaseII, that's hour 6 out of 240 for HUP 143
# Processing hour 7 in HUP143_phaseII, that's hour 7 out of 240 for HUP 143
# Processing hour 8 in HUP143_phaseII, that's hour 8 out of 240 for HUP 143
# Processing hour 9 in HUP143_phaseII, that's hour 9 out of 240 for HUP 143
# Processing hour 10 in HUP143_phaseII, that's hour 10 out of 240 for HUP 143
# Processing hour 11 in HUP143_phaseII, that's hour 11 out of 240 for HUP 143
# Processing hour 12 in HUP143_phaseII, that's hour 12 out of 240 for HUP 143
# Processing hour 13 in HUP143_phaseII, that's hour 13 out of 240 for HUP 143
# Processing hour 14 in HUP143_phaseII, that's hour 14 out of 240 for HUP 143
# Processing hour 15 in HUP143_phaseII, that's hour 15 out of 240 for HUP 143
# Processing hour 16 in HUP143_phaseII, that's hour 16 out of 240 for HUP 143
# Processing hour 17 in HUP143_phaseII, that's hour 17 out of 240 for HUP 143
# Processing hour 18 in HUP143_phaseII, that's hour 18 out of 240 for HUP 143
# Processing hour 19 in HUP143_phaseII, that's hour 19 out of 240 for HUP 143
# Processing hour 20 in HUP143_phaseII, that's hour 20 out of 240 for HUP 143
# Processing hour 21 in HUP143_phaseII, that's hour 21 out of 240 for HUP 143
# Processing hour 22 in HUP143_phaseII, that's hour 22 out of 240 for HUP 143
# Processing hour 23 in HUP143_phaseII, that's hour 23 out of 240 for HUP 143
# Processing hour 24 in HUP143_phaseII, that's hour 24 out of 240 for HUP 143
# Processing hour 25 in HUP143_phaseII, that's hour 25 out of 240 for HUP 143
# Processing hour 26 in HUP143_phaseII, that's hour 26 out of 240 for HUP 143
# Processing hour 27 in HUP143_phaseII, that's hour 27 out of 240 for HUP 143
# Processing hour 28 in HUP143_phaseII, that's hour 28 out of 240 for HUP 143
# Processing hour 29 in HUP143_phaseII, that's hour 29 out of 240 for HUP 143
# Processing hour 30 in HUP143_phaseII, that's hour 30 out of 240 for HUP 143
# Processing hour 31 in HUP143_phaseII, that's hour 31 out of 240 for HUP 143
# Processing hour 32 in HUP143_phaseII, that's hour 32 out of 240 for HUP 143
# Processing hour 33 in HUP143_phaseII, that's hour 33 out of 240 for HUP 143
# Processing hour 34 in HUP143_phaseII, that's hour 34 out of 240 for HUP 143
# Processing hour 35 in HUP143_phaseII, that's hour 35 out of 240 for HUP 143
# Processing hour 36 in HUP143_phaseII, that's hour 36 out of 240 for HUP 143
# Processing hour 37 in HUP143_phaseII, that's hour 37 out of 240 for HUP 143
# Processing hour 38 in HUP143_phaseII, that's hour 38 out of 240 for HUP 143
# Processing hour 39 in HUP143_phaseII, that's hour 39 out of 240 for HUP 143
# Processing hour 40 in HUP143_phaseII, that's hour 40 out of 240 for HUP 143
# Processing hour 41 in HUP143_phaseII, that's hour 41 out of 240 for HUP 143
# Processing hour 42 in HUP143_phaseII, that's hour 42 out of 240 for HUP 143
# Processing hour 43 in HUP143_phaseII, that's hour 43 out of 240 for HUP 143
# Processing hour 44 in HUP143_phaseII, that's hour 44 out of 240 for HUP 143
# Processing hour 45 in HUP143_phaseII, that's hour 45 out of 240 for HUP 143
# Processing hour 46 in HUP143_phaseII, that's hour 46 out of 240 for HUP 143
# Processing hour 47 in HUP143_phaseII, that's hour 47 out of 240 for HUP 143
# Processing hour 48 in HUP143_phaseII, that's hour 48 out of 240 for HUP 143
# Processing hour 49 in HUP143_phaseII, that's hour 49 out of 240 for HUP 143
# Processing hour 50 in HUP143_phaseII, that's hour 50 out of 240 for HUP 143
# Processing hour 51 in HUP143_phaseII, that's hour 51 out of 240 for HUP 143
# Processing hour 52 in HUP143_phaseII, that's hour 52 out of 240 for HUP 143
# Processing hour 53 in HUP143_phaseII, that's hour 53 out of 240 for HUP 143
# Processing hour 54 in HUP143_phaseII, that's hour 54 out of 240 for HUP 143
# Processing hour 55 in HUP143_phaseII, that's hour 55 out of 240 for HUP 143
# Processing hour 56 in HUP143_phaseII, that's hour 56 out of 240 for HUP 143
# Processing hour 57 in HUP143_phaseII, that's hour 57 out of 240 for HUP 143
# Processing hour 58 in HUP143_phaseII, that's hour 58 out of 240 for HUP 143
# Processing hour 59 in HUP143_phaseII, that's hour 59 out of 240 for HUP 143
# Processing hour 60 in HUP143_phaseII, that's hour 60 out of 240 for HUP 143
# Processing hour 61 in HUP143_phaseII, that's hour 61 out of 240 for HUP 143
# Processing hour 62 in HUP143_phaseII, that's hour 62 out of 240 for HUP 143
# Processing hour 63 in HUP143_phaseII, that's hour 63 out of 240 for HUP 143
# Processing hour 64 in HUP143_phaseII, that's hour 64 out of 240 for HUP 143
# Processing hour 65 in HUP143_phaseII, that's hour 65 out of 240 for HUP 143
# Processing hour 66 in HUP143_phaseII, that's hour 66 out of 240 for HUP 143
# Processing hour 67 in HUP143_phaseII, that's hour 67 out of 240 for HUP 143
# Processing hour 68 in HUP143_phaseII, that's hour 68 out of 240 for HUP 143
# Processing hour 69 in HUP143_phaseII, that's hour 69 out of 240 for HUP 143
# Processing hour 70 in HUP143_phaseII, that's hour 70 out of 240 for HUP 143
# Processing hour 71 in HUP143_phaseII, that's hour 71 out of 240 for HUP 143
# Processing hour 72 in HUP143_phaseII, that's hour 72 out of 240 for HUP 143
# Processing hour 73 in HUP143_phaseII, that's hour 73 out of 240 for HUP 143
# Processing hour 74 in HUP143_phaseII, that's hour 74 out of 240 for HUP 143
# Processing hour 75 in HUP143_phaseII, that's hour 75 out of 240 for HUP 143
# Processing hour 76 in HUP143_phaseII, that's hour 76 out of 240 for HUP 143
# Processing hour 77 in HUP143_phaseII, that's hour 77 out of 240 for HUP 143
# Processing hour 78 in HUP143_phaseII, that's hour 78 out of 240 for HUP 143
# Processing hour 79 in HUP143_phaseII, that's hour 79 out of 240 for HUP 143
# Processing hour 80 in HUP143_phaseII, that's hour 80 out of 240 for HUP 143
# Processing hour 81 in HUP143_phaseII, that's hour 81 out of 240 for HUP 143
# Processing hour 82 in HUP143_phaseII, that's hour 82 out of 240 for HUP 143
# Processing hour 83 in HUP143_phaseII, that's hour 83 out of 240 for HUP 143
# Processing hour 84 in HUP143_phaseII, that's hour 84 out of 240 for HUP 143
# Processing hour 85 in HUP143_phaseII, that's hour 85 out of 240 for HUP 143
# Processing hour 86 in HUP143_phaseII, that's hour 86 out of 240 for HUP 143
# Processing hour 87 in HUP143_phaseII, that's hour 87 out of 240 for HUP 143
# Processing hour 88 in HUP143_phaseII, that's hour 88 out of 240 for HUP 143
# Processing hour 89 in HUP143_phaseII, that's hour 89 out of 240 for HUP 143
# Processing hour 90 in HUP143_phaseII, that's hour 90 out of 240 for HUP 143
# Processing hour 91 in HUP143_phaseII, that's hour 91 out of 240 for HUP 143
# Processing hour 92 in HUP143_phaseII, that's hour 92 out of 240 for HUP 143
# Processing hour 93 in HUP143_phaseII, that's hour 93 out of 240 for HUP 143
# Processing hour 94 in HUP143_phaseII, that's hour 94 out of 240 for HUP 143
# Processing hour 95 in HUP143_phaseII, that's hour 95 out of 240 for HUP 143
# Processing hour 96 in HUP143_phaseII, that's hour 96 out of 240 for HUP 143
# Processing hour 97 in HUP143_phaseII, that's hour 97 out of 240 for HUP 143
# Processing hour 98 in HUP143_phaseII, that's hour 98 out of 240 for HUP 143
# Processing hour 99 in HUP143_phaseII, that's hour 99 out of 240 for HUP 143
# Processing hour 100 in HUP143_phaseII, that's hour 100 out of 240 for HUP 143
# Processing hour 101 in HUP143_phaseII, that's hour 101 out of 240 for HUP 143
# Processing hour 102 in HUP143_phaseII, that's hour 102 out of 240 for HUP 143
# Processing hour 103 in HUP143_phaseII, that's hour 103 out of 240 for HUP 143
# Processing hour 104 in HUP143_phaseII, that's hour 104 out of 240 for HUP 143
# Processing hour 105 in HUP143_phaseII, that's hour 105 out of 240 for HUP 143
# Processing hour 106 in HUP143_phaseII, that's hour 106 out of 240 for HUP 143
# Processing hour 107 in HUP143_phaseII, that's hour 107 out of 240 for HUP 143
# Processing hour 108 in HUP143_phaseII, that's hour 108 out of 240 for HUP 143
# Processing hour 109 in HUP143_phaseII, that's hour 109 out of 240 for HUP 143
# Processing hour 110 in HUP143_phaseII, that's hour 110 out of 240 for HUP 143
# Processing hour 111 in HUP143_phaseII, that's hour 111 out of 240 for HUP 143
# Processing hour 112 in HUP143_phaseII, that's hour 112 out of 240 for HUP 143
# Processing hour 113 in HUP143_phaseII, that's hour 113 out of 240 for HUP 143
# Processing hour 114 in HUP143_phaseII, that's hour 114 out of 240 for HUP 143
# Processing hour 115 in HUP143_phaseII, that's hour 115 out of 240 for HUP 143
# Processing hour 116 in HUP143_phaseII, that's hour 116 out of 240 for HUP 143
# Processing hour 117 in HUP143_phaseII, that's hour 117 out of 240 for HUP 143
# Processing hour 118 in HUP143_phaseII, that's hour 118 out of 240 for HUP 143
# Processing hour 119 in HUP143_phaseII, that's hour 119 out of 240 for HUP 143
# Processing hour 120 in HUP143_phaseII, that's hour 120 out of 240 for HUP 143
# Processing hour 121 in HUP143_phaseII, that's hour 121 out of 240 for HUP 143
# Processing hour 122 in HUP143_phaseII, that's hour 122 out of 240 for HUP 143
# Processing hour 123 in HUP143_phaseII, that's hour 123 out of 240 for HUP 143
# Processing hour 124 in HUP143_phaseII, that's hour 124 out of 240 for HUP 143
# Processing hour 125 in HUP143_phaseII, that's hour 125 out of 240 for HUP 143
# Processing hour 126 in HUP143_phaseII, that's hour 126 out of 240 for HUP 143
# Processing hour 127 in HUP143_phaseII, that's hour 127 out of 240 for HUP 143
# Processing hour 128 in HUP143_phaseII, that's hour 128 out of 240 for HUP 143
# Processing hour 129 in HUP143_phaseII, that's hour 129 out of 240 for HUP 143
# Processing hour 130 in HUP143_phaseII, that's hour 130 out of 240 for HUP 143
# Processing hour 131 in HUP143_phaseII, that's hour 131 out of 240 for HUP 143
# Processing hour 132 in HUP143_phaseII, that's hour 132 out of 240 for HUP 143
# Processing hour 133 in HUP143_phaseII, that's hour 133 out of 240 for HUP 143
# Processing hour 134 in HUP143_phaseII, that's hour 134 out of 240 for HUP 143
# Processing hour 135 in HUP143_phaseII, that's hour 135 out of 240 for HUP 143
# Processing hour 136 in HUP143_phaseII, that's hour 136 out of 240 for HUP 143
# Processing hour 137 in HUP143_phaseII, that's hour 137 out of 240 for HUP 143
# Processing hour 138 in HUP143_phaseII, that's hour 138 out of 240 for HUP 143
# Processing hour 139 in HUP143_phaseII, that's hour 139 out of 240 for HUP 143
# Processing hour 140 in HUP143_phaseII, that's hour 140 out of 240 for HUP 143
# Processing hour 141 in HUP143_phaseII, that's hour 141 out of 240 for HUP 143
# Processing hour 142 in HUP143_phaseII, that's hour 142 out of 240 for HUP 143
# Processing hour 143 in HUP143_phaseII, that's hour 143 out of 240 for HUP 143
# Processing hour 144 in HUP143_phaseII, that's hour 144 out of 240 for HUP 143
# Processing hour 145 in HUP143_phaseII, that's hour 145 out of 240 for HUP 143
# Processing hour 146 in HUP143_phaseII, that's hour 146 out of 240 for HUP 143
# Processing hour 147 in HUP143_phaseII, that's hour 147 out of 240 for HUP 143
# Processing hour 148 in HUP143_phaseII, that's hour 148 out of 240 for HUP 143
# Processing hour 149 in HUP143_phaseII, that's hour 149 out of 240 for HUP 143
# Processing hour 150 in HUP143_phaseII, that's hour 150 out of 240 for HUP 143
# Processing hour 151 in HUP143_phaseII, that's hour 151 out of 240 for HUP 143
# Processing hour 152 in HUP143_phaseII, that's hour 152 out of 240 for HUP 143
# Processing hour 153 in HUP143_phaseII, that's hour 153 out of 240 for HUP 143
# Processing hour 154 in HUP143_phaseII, that's hour 154 out of 240 for HUP 143
# Processing hour 155 in HUP143_phaseII, that's hour 155 out of 240 for HUP 143
# Processing hour 156 in HUP143_phaseII, that's hour 156 out of 240 for HUP 143
# Processing hour 157 in HUP143_phaseII, that's hour 157 out of 240 for HUP 143
# Processing hour 158 in HUP143_phaseII, that's hour 158 out of 240 for HUP 143
# Processing hour 159 in HUP143_phaseII, that's hour 159 out of 240 for HUP 143
# Processing hour 160 in HUP143_phaseII, that's hour 160 out of 240 for HUP 143
# Processing hour 161 in HUP143_phaseII, that's hour 161 out of 240 for HUP 143
# Processing hour 162 in HUP143_phaseII, that's hour 162 out of 240 for HUP 143
# Processing hour 163 in HUP143_phaseII, that's hour 163 out of 240 for HUP 143
# Processing hour 164 in HUP143_phaseII, that's hour 164 out of 240 for HUP 143
# Processing hour 165 in HUP143_phaseII, that's hour 165 out of 240 for HUP 143
# Processing hour 166 in HUP143_phaseII, that's hour 166 out of 240 for HUP 143
# Processing hour 167 in HUP143_phaseII, that's hour 167 out of 240 for HUP 143
# Processing hour 168 in HUP143_phaseII, that's hour 168 out of 240 for HUP 143
# Processing hour 169 in HUP143_phaseII, that's hour 169 out of 240 for HUP 143
# Processing hour 170 in HUP143_phaseII, that's hour 170 out of 240 for HUP 143
# Processing hour 171 in HUP143_phaseII, that's hour 171 out of 240 for HUP 143
# Processing hour 172 in HUP143_phaseII, that's hour 172 out of 240 for HUP 143
# Processing hour 173 in HUP143_phaseII, that's hour 173 out of 240 for HUP 143
# Processing hour 174 in HUP143_phaseII, that's hour 174 out of 240 for HUP 143
# Processing hour 175 in HUP143_phaseII, that's hour 175 out of 240 for HUP 143
# Processing hour 176 in HUP143_phaseII, that's hour 176 out of 240 for HUP 143
# Processing hour 177 in HUP143_phaseII, that's hour 177 out of 240 for HUP 143
# Processing hour 178 in HUP143_phaseII, that's hour 178 out of 240 for HUP 143
# Processing hour 179 in HUP143_phaseII, that's hour 179 out of 240 for HUP 143
# Processing hour 180 in HUP143_phaseII, that's hour 180 out of 240 for HUP 143
# Processing hour 181 in HUP143_phaseII, that's hour 181 out of 240 for HUP 143
# Processing hour 182 in HUP143_phaseII, that's hour 182 out of 240 for HUP 143
# Processing hour 183 in HUP143_phaseII, that's hour 183 out of 240 for HUP 143
# Processing hour 184 in HUP143_phaseII, that's hour 184 out of 240 for HUP 143
# Processing hour 185 in HUP143_phaseII, that's hour 185 out of 240 for HUP 143
# Processing hour 186 in HUP143_phaseII, that's hour 186 out of 240 for HUP 143
# Processing hour 187 in HUP143_phaseII, that's hour 187 out of 240 for HUP 143
# Processing hour 188 in HUP143_phaseII, that's hour 188 out of 240 for HUP 143
# Processing hour 189 in HUP143_phaseII, that's hour 189 out of 240 for HUP 143
# Processing hour 190 in HUP143_phaseII, that's hour 190 out of 240 for HUP 143
# Processing hour 191 in HUP143_phaseII, that's hour 191 out of 240 for HUP 143
# Processing hour 192 in HUP143_phaseII, that's hour 192 out of 240 for HUP 143
# Processing hour 193 in HUP143_phaseII, that's hour 193 out of 240 for HUP 143
# Processing hour 194 in HUP143_phaseII, that's hour 194 out of 240 for HUP 143
# Processing hour 195 in HUP143_phaseII, that's hour 195 out of 240 for HUP 143
# Processing hour 196 in HUP143_phaseII, that's hour 196 out of 240 for HUP 143
# Processing hour 197 in HUP143_phaseII, that's hour 197 out of 240 for HUP 143
# Processing hour 198 in HUP143_phaseII, that's hour 198 out of 240 for HUP 143
# Processing hour 199 in HUP143_phaseII, that's hour 199 out of 240 for HUP 143
# Processing hour 200 in HUP143_phaseII, that's hour 200 out of 240 for HUP 143
# Processing hour 201 in HUP143_phaseII, that's hour 201 out of 240 for HUP 143
# Processing hour 202 in HUP143_phaseII, that's hour 202 out of 240 for HUP 143
# Processing hour 203 in HUP143_phaseII, that's hour 203 out of 240 for HUP 143
# Processing hour 204 in HUP143_phaseII, that's hour 204 out of 240 for HUP 143
# Processing hour 205 in HUP143_phaseII, that's hour 205 out of 240 for HUP 143
# Processing hour 206 in HUP143_phaseII, that's hour 206 out of 240 for HUP 143
# Processing hour 207 in HUP143_phaseII, that's hour 207 out of 240 for HUP 143
# Processing hour 208 in HUP143_phaseII, that's hour 208 out of 240 for HUP 143
# Processing hour 209 in HUP143_phaseII, that's hour 209 out of 240 for HUP 143
# Processing hour 210 in HUP143_phaseII, that's hour 210 out of 240 for HUP 143
# Processing hour 211 in HUP143_phaseII, that's hour 211 out of 240 for HUP 143
# Processing hour 212 in HUP143_phaseII, that's hour 212 out of 240 for HUP 143
# Processing hour 213 in HUP143_phaseII, that's hour 213 out of 240 for HUP 143
# Processing hour 214 in HUP143_phaseII, that's hour 214 out of 240 for HUP 143
# Processing hour 215 in HUP143_phaseII, that's hour 215 out of 240 for HUP 143
# Processing hour 216 in HUP143_phaseII, that's hour 216 out of 240 for HUP 143
# Processing hour 217 in HUP143_phaseII, that's hour 217 out of 240 for HUP 143
# Processing hour 218 in HUP143_phaseII, that's hour 218 out of 240 for HUP 143
# Processing hour 219 in HUP143_phaseII, that's hour 219 out of 240 for HUP 143
# Processing hour 220 in HUP143_phaseII, that's hour 220 out of 240 for HUP 143
# Processing hour 221 in HUP143_phaseII, that's hour 221 out of 240 for HUP 143
# Processing hour 222 in HUP143_phaseII, that's hour 222 out of 240 for HUP 143
# Processing hour 223 in HUP143_phaseII, that's hour 223 out of 240 for HUP 143
# Processing hour 224 in HUP143_phaseII, that's hour 224 out of 240 for HUP 143
# Processing hour 225 in HUP143_phaseII, that's hour 225 out of 240 for HUP 143
# Processing hour 226 in HUP143_phaseII, that's hour 226 out of 240 for HUP 143
# Processing hour 227 in HUP143_phaseII, that's hour 227 out of 240 for HUP 143
# Processing hour 228 in HUP143_phaseII, that's hour 228 out of 240 for HUP 143
# Processing hour 229 in HUP143_phaseII, that's hour 229 out of 240 for HUP 143
# Processing hour 230 in HUP143_phaseII, that's hour 230 out of 240 for HUP 143
# Processing hour 231 in HUP143_phaseII, that's hour 231 out of 240 for HUP 143
# Processing hour 232 in HUP143_phaseII, that's hour 232 out of 240 for HUP 143
# Processing hour 233 in HUP143_phaseII, that's hour 233 out of 240 for HUP 143
# Processing hour 234 in HUP143_phaseII, that's hour 234 out of 240 for HUP 143
# Processing hour 235 in HUP143_phaseII, that's hour 235 out of 240 for HUP 143
# Processing hour 236 in HUP143_phaseII, that's hour 236 out of 240 for HUP 143
# Processing hour 237 in HUP143_phaseII, that's hour 237 out of 240 for HUP 143
# Processing hour 238 in HUP143_phaseII, that's hour 238 out of 240 for HUP 143
# Processing hour 239 in HUP143_phaseII, that's hour 239 out of 240 for HUP 143
# Skipping 239 for HUP143_phaseII because there are less than 2 good channels
# HUP 146, rid 301
# HUP146_phaseII
# Processing hour 0 in HUP146_phaseII, that's hour 0 out of 365 for HUP 146
# Skipping 1 for HUP146_phaseII
# Processing hour 2 in HUP146_phaseII, that's hour 2 out of 365 for HUP 146
# Skipping 3 for HUP146_phaseII
# Processing hour 4 in HUP146_phaseII, that's hour 4 out of 365 for HUP 146
# Processing hour 5 in HUP146_phaseII, that's hour 5 out of 365 for HUP 146
# Skipping 5 for HUP146_phaseII because there's less than 1 good channel after bipolar_montage
# Processing hour 6 in HUP146_phaseII, that's hour 6 out of 365 for HUP 146
# Processing hour 7 in HUP146_phaseII, that's hour 7 out of 365 for HUP 146
# Processing hour 8 in HUP146_phaseII, that's hour 8 out of 365 for HUP 146
# Processing hour 9 in HUP146_phaseII, that's hour 9 out of 365 for HUP 146
# Processing hour 10 in HUP146_phaseII, that's hour 10 out of 365 for HUP 146
# Processing hour 11 in HUP146_phaseII, that's hour 11 out of 365 for HUP 146
# Processing hour 12 in HUP146_phaseII, that's hour 12 out of 365 for HUP 146
# Processing hour 13 in HUP146_phaseII, that's hour 13 out of 365 for HUP 146
# Processing hour 14 in HUP146_phaseII, that's hour 14 out of 365 for HUP 146
# Processing hour 15 in HUP146_phaseII, that's hour 15 out of 365 for HUP 146
# Processing hour 16 in HUP146_phaseII, that's hour 16 out of 365 for HUP 146
# Processing hour 17 in HUP146_phaseII, that's hour 17 out of 365 for HUP 146
# Processing hour 18 in HUP146_phaseII, that's hour 18 out of 365 for HUP 146
# Processing hour 19 in HUP146_phaseII, that's hour 19 out of 365 for HUP 146
# Processing hour 20 in HUP146_phaseII, that's hour 20 out of 365 for HUP 146
# Processing hour 21 in HUP146_phaseII, that's hour 21 out of 365 for HUP 146
# Processing hour 22 in HUP146_phaseII, that's hour 22 out of 365 for HUP 146
# Processing hour 23 in HUP146_phaseII, that's hour 23 out of 365 for HUP 146
# Processing hour 24 in HUP146_phaseII, that's hour 24 out of 365 for HUP 146
# Processing hour 25 in HUP146_phaseII, that's hour 25 out of 365 for HUP 146
# Processing hour 26 in HUP146_phaseII, that's hour 26 out of 365 for HUP 146
# Processing hour 27 in HUP146_phaseII, that's hour 27 out of 365 for HUP 146
# Processing hour 28 in HUP146_phaseII, that's hour 28 out of 365 for HUP 146
# Processing hour 29 in HUP146_phaseII, that's hour 29 out of 365 for HUP 146
# Processing hour 30 in HUP146_phaseII, that's hour 30 out of 365 for HUP 146
# Processing hour 31 in HUP146_phaseII, that's hour 31 out of 365 for HUP 146
# Processing hour 32 in HUP146_phaseII, that's hour 32 out of 365 for HUP 146
# Processing hour 33 in HUP146_phaseII, that's hour 33 out of 365 for HUP 146
# Processing hour 34 in HUP146_phaseII, that's hour 34 out of 365 for HUP 146
# Processing hour 35 in HUP146_phaseII, that's hour 35 out of 365 for HUP 146
# Processing hour 36 in HUP146_phaseII, that's hour 36 out of 365 for HUP 146
# Processing hour 37 in HUP146_phaseII, that's hour 37 out of 365 for HUP 146
# Processing hour 38 in HUP146_phaseII, that's hour 38 out of 365 for HUP 146
# Processing hour 39 in HUP146_phaseII, that's hour 39 out of 365 for HUP 146
# Processing hour 40 in HUP146_phaseII, that's hour 40 out of 365 for HUP 146
# Processing hour 41 in HUP146_phaseII, that's hour 41 out of 365 for HUP 146
# Processing hour 42 in HUP146_phaseII, that's hour 42 out of 365 for HUP 146
# Processing hour 43 in HUP146_phaseII, that's hour 43 out of 365 for HUP 146
# Processing hour 44 in HUP146_phaseII, that's hour 44 out of 365 for HUP 146
# Processing hour 45 in HUP146_phaseII, that's hour 45 out of 365 for HUP 146
# Processing hour 46 in HUP146_phaseII, that's hour 46 out of 365 for HUP 146
# Processing hour 47 in HUP146_phaseII, that's hour 47 out of 365 for HUP 146
# Processing hour 48 in HUP146_phaseII, that's hour 48 out of 365 for HUP 146
# Processing hour 49 in HUP146_phaseII, that's hour 49 out of 365 for HUP 146
# Processing hour 50 in HUP146_phaseII, that's hour 50 out of 365 for HUP 146
# Processing hour 51 in HUP146_phaseII, that's hour 51 out of 365 for HUP 146
# Processing hour 52 in HUP146_phaseII, that's hour 52 out of 365 for HUP 146
# Processing hour 53 in HUP146_phaseII, that's hour 53 out of 365 for HUP 146
# Processing hour 54 in HUP146_phaseII, that's hour 54 out of 365 for HUP 146
# Processing hour 55 in HUP146_phaseII, that's hour 55 out of 365 for HUP 146
# Processing hour 56 in HUP146_phaseII, that's hour 56 out of 365 for HUP 146
# Processing hour 57 in HUP146_phaseII, that's hour 57 out of 365 for HUP 146
# Processing hour 58 in HUP146_phaseII, that's hour 58 out of 365 for HUP 146
# Processing hour 59 in HUP146_phaseII, that's hour 59 out of 365 for HUP 146
# Processing hour 60 in HUP146_phaseII, that's hour 60 out of 365 for HUP 146
# Processing hour 61 in HUP146_phaseII, that's hour 61 out of 365 for HUP 146
# Processing hour 62 in HUP146_phaseII, that's hour 62 out of 365 for HUP 146
# Processing hour 63 in HUP146_phaseII, that's hour 63 out of 365 for HUP 146
# Processing hour 64 in HUP146_phaseII, that's hour 64 out of 365 for HUP 146
# Processing hour 65 in HUP146_phaseII, that's hour 65 out of 365 for HUP 146
# Processing hour 66 in HUP146_phaseII, that's hour 66 out of 365 for HUP 146
# Processing hour 67 in HUP146_phaseII, that's hour 67 out of 365 for HUP 146
# Processing hour 68 in HUP146_phaseII, that's hour 68 out of 365 for HUP 146
# Processing hour 69 in HUP146_phaseII, that's hour 69 out of 365 for HUP 146
# Processing hour 70 in HUP146_phaseII, that's hour 70 out of 365 for HUP 146
# Processing hour 71 in HUP146_phaseII, that's hour 71 out of 365 for HUP 146
# Processing hour 72 in HUP146_phaseII, that's hour 72 out of 365 for HUP 146
# Processing hour 73 in HUP146_phaseII, that's hour 73 out of 365 for HUP 146
# Processing hour 74 in HUP146_phaseII, that's hour 74 out of 365 for HUP 146
# Processing hour 75 in HUP146_phaseII, that's hour 75 out of 365 for HUP 146
# Processing hour 76 in HUP146_phaseII, that's hour 76 out of 365 for HUP 146
# Processing hour 77 in HUP146_phaseII, that's hour 77 out of 365 for HUP 146
# Processing hour 78 in HUP146_phaseII, that's hour 78 out of 365 for HUP 146
# Processing hour 79 in HUP146_phaseII, that's hour 79 out of 365 for HUP 146
# Processing hour 80 in HUP146_phaseII, that's hour 80 out of 365 for HUP 146
# Processing hour 81 in HUP146_phaseII, that's hour 81 out of 365 for HUP 146
# Processing hour 82 in HUP146_phaseII, that's hour 82 out of 365 for HUP 146
# Processing hour 83 in HUP146_phaseII, that's hour 83 out of 365 for HUP 146
# Processing hour 84 in HUP146_phaseII, that's hour 84 out of 365 for HUP 146
# Processing hour 85 in HUP146_phaseII, that's hour 85 out of 365 for HUP 146
# Processing hour 86 in HUP146_phaseII, that's hour 86 out of 365 for HUP 146
# Processing hour 87 in HUP146_phaseII, that's hour 87 out of 365 for HUP 146
# Processing hour 88 in HUP146_phaseII, that's hour 88 out of 365 for HUP 146
# Processing hour 89 in HUP146_phaseII, that's hour 89 out of 365 for HUP 146
# Processing hour 90 in HUP146_phaseII, that's hour 90 out of 365 for HUP 146
# Processing hour 91 in HUP146_phaseII, that's hour 91 out of 365 for HUP 146
# Processing hour 92 in HUP146_phaseII, that's hour 92 out of 365 for HUP 146
# Processing hour 93 in HUP146_phaseII, that's hour 93 out of 365 for HUP 146
# Processing hour 94 in HUP146_phaseII, that's hour 94 out of 365 for HUP 146
# Processing hour 95 in HUP146_phaseII, that's hour 95 out of 365 for HUP 146
# Processing hour 96 in HUP146_phaseII, that's hour 96 out of 365 for HUP 146
# Processing hour 97 in HUP146_phaseII, that's hour 97 out of 365 for HUP 146
# Processing hour 98 in HUP146_phaseII, that's hour 98 out of 365 for HUP 146
# Processing hour 99 in HUP146_phaseII, that's hour 99 out of 365 for HUP 146
# Processing hour 100 in HUP146_phaseII, that's hour 100 out of 365 for HUP 146
# Processing hour 101 in HUP146_phaseII, that's hour 101 out of 365 for HUP 146
# Processing hour 102 in HUP146_phaseII, that's hour 102 out of 365 for HUP 146
# Processing hour 103 in HUP146_phaseII, that's hour 103 out of 365 for HUP 146
# Processing hour 104 in HUP146_phaseII, that's hour 104 out of 365 for HUP 146
# Processing hour 105 in HUP146_phaseII, that's hour 105 out of 365 for HUP 146
# Processing hour 106 in HUP146_phaseII, that's hour 106 out of 365 for HUP 146
# Processing hour 107 in HUP146_phaseII, that's hour 107 out of 365 for HUP 146
# Processing hour 108 in HUP146_phaseII, that's hour 108 out of 365 for HUP 146
# Processing hour 109 in HUP146_phaseII, that's hour 109 out of 365 for HUP 146
# Processing hour 110 in HUP146_phaseII, that's hour 110 out of 365 for HUP 146
# Processing hour 111 in HUP146_phaseII, that's hour 111 out of 365 for HUP 146
# Processing hour 112 in HUP146_phaseII, that's hour 112 out of 365 for HUP 146
# Processing hour 113 in HUP146_phaseII, that's hour 113 out of 365 for HUP 146
# Processing hour 114 in HUP146_phaseII, that's hour 114 out of 365 for HUP 146
# Processing hour 115 in HUP146_phaseII, that's hour 115 out of 365 for HUP 146
# Processing hour 116 in HUP146_phaseII, that's hour 116 out of 365 for HUP 146
# Processing hour 117 in HUP146_phaseII, that's hour 117 out of 365 for HUP 146
# Processing hour 118 in HUP146_phaseII, that's hour 118 out of 365 for HUP 146
# Processing hour 119 in HUP146_phaseII, that's hour 119 out of 365 for HUP 146
# Processing hour 120 in HUP146_phaseII, that's hour 120 out of 365 for HUP 146
# Processing hour 121 in HUP146_phaseII, that's hour 121 out of 365 for HUP 146
# Processing hour 122 in HUP146_phaseII, that's hour 122 out of 365 for HUP 146
# Processing hour 123 in HUP146_phaseII, that's hour 123 out of 365 for HUP 146
# Processing hour 124 in HUP146_phaseII, that's hour 124 out of 365 for HUP 146
# Processing hour 125 in HUP146_phaseII, that's hour 125 out of 365 for HUP 146
# Processing hour 126 in HUP146_phaseII, that's hour 126 out of 365 for HUP 146
# Processing hour 127 in HUP146_phaseII, that's hour 127 out of 365 for HUP 146
# Processing hour 128 in HUP146_phaseII, that's hour 128 out of 365 for HUP 146
# Processing hour 129 in HUP146_phaseII, that's hour 129 out of 365 for HUP 146
# Processing hour 130 in HUP146_phaseII, that's hour 130 out of 365 for HUP 146
# Processing hour 131 in HUP146_phaseII, that's hour 131 out of 365 for HUP 146
# Processing hour 132 in HUP146_phaseII, that's hour 132 out of 365 for HUP 146
# Processing hour 133 in HUP146_phaseII, that's hour 133 out of 365 for HUP 146
# Processing hour 134 in HUP146_phaseII, that's hour 134 out of 365 for HUP 146
# Processing hour 135 in HUP146_phaseII, that's hour 135 out of 365 for HUP 146
# Processing hour 136 in HUP146_phaseII, that's hour 136 out of 365 for HUP 146
# Processing hour 137 in HUP146_phaseII, that's hour 137 out of 365 for HUP 146
# Processing hour 138 in HUP146_phaseII, that's hour 138 out of 365 for HUP 146
# Processing hour 139 in HUP146_phaseII, that's hour 139 out of 365 for HUP 146
# Processing hour 140 in HUP146_phaseII, that's hour 140 out of 365 for HUP 146
# Processing hour 141 in HUP146_phaseII, that's hour 141 out of 365 for HUP 146
# Processing hour 142 in HUP146_phaseII, that's hour 142 out of 365 for HUP 146
# Processing hour 143 in HUP146_phaseII, that's hour 143 out of 365 for HUP 146
# Processing hour 144 in HUP146_phaseII, that's hour 144 out of 365 for HUP 146
# Processing hour 145 in HUP146_phaseII, that's hour 145 out of 365 for HUP 146
# Processing hour 146 in HUP146_phaseII, that's hour 146 out of 365 for HUP 146
# Processing hour 147 in HUP146_phaseII, that's hour 147 out of 365 for HUP 146
# Processing hour 148 in HUP146_phaseII, that's hour 148 out of 365 for HUP 146
# Processing hour 149 in HUP146_phaseII, that's hour 149 out of 365 for HUP 146
# Processing hour 150 in HUP146_phaseII, that's hour 150 out of 365 for HUP 146
# Processing hour 151 in HUP146_phaseII, that's hour 151 out of 365 for HUP 146
# Processing hour 152 in HUP146_phaseII, that's hour 152 out of 365 for HUP 146
# Processing hour 153 in HUP146_phaseII, that's hour 153 out of 365 for HUP 146
# Processing hour 154 in HUP146_phaseII, that's hour 154 out of 365 for HUP 146
# Processing hour 155 in HUP146_phaseII, that's hour 155 out of 365 for HUP 146
# Processing hour 156 in HUP146_phaseII, that's hour 156 out of 365 for HUP 146
# Processing hour 157 in HUP146_phaseII, that's hour 157 out of 365 for HUP 146
# Processing hour 158 in HUP146_phaseII, that's hour 158 out of 365 for HUP 146
# Processing hour 159 in HUP146_phaseII, that's hour 159 out of 365 for HUP 146
# Processing hour 160 in HUP146_phaseII, that's hour 160 out of 365 for HUP 146
# Processing hour 161 in HUP146_phaseII, that's hour 161 out of 365 for HUP 146
# Processing hour 162 in HUP146_phaseII, that's hour 162 out of 365 for HUP 146
# Processing hour 163 in HUP146_phaseII, that's hour 163 out of 365 for HUP 146
# Processing hour 164 in HUP146_phaseII, that's hour 164 out of 365 for HUP 146
# Processing hour 165 in HUP146_phaseII, that's hour 165 out of 365 for HUP 146
# Processing hour 166 in HUP146_phaseII, that's hour 166 out of 365 for HUP 146
# Processing hour 167 in HUP146_phaseII, that's hour 167 out of 365 for HUP 146
# Processing hour 168 in HUP146_phaseII, that's hour 168 out of 365 for HUP 146
# Processing hour 169 in HUP146_phaseII, that's hour 169 out of 365 for HUP 146
# Processing hour 170 in HUP146_phaseII, that's hour 170 out of 365 for HUP 146
# Processing hour 171 in HUP146_phaseII, that's hour 171 out of 365 for HUP 146
# Processing hour 172 in HUP146_phaseII, that's hour 172 out of 365 for HUP 146
# Processing hour 173 in HUP146_phaseII, that's hour 173 out of 365 for HUP 146
# Processing hour 174 in HUP146_phaseII, that's hour 174 out of 365 for HUP 146
# Processing hour 175 in HUP146_phaseII, that's hour 175 out of 365 for HUP 146
# Processing hour 176 in HUP146_phaseII, that's hour 176 out of 365 for HUP 146
# Processing hour 177 in HUP146_phaseII, that's hour 177 out of 365 for HUP 146
# Processing hour 178 in HUP146_phaseII, that's hour 178 out of 365 for HUP 146
# Processing hour 179 in HUP146_phaseII, that's hour 179 out of 365 for HUP 146
# Processing hour 180 in HUP146_phaseII, that's hour 180 out of 365 for HUP 146
# Processing hour 181 in HUP146_phaseII, that's hour 181 out of 365 for HUP 146
# Processing hour 182 in HUP146_phaseII, that's hour 182 out of 365 for HUP 146
# Processing hour 183 in HUP146_phaseII, that's hour 183 out of 365 for HUP 146
# Processing hour 184 in HUP146_phaseII, that's hour 184 out of 365 for HUP 146
# Processing hour 185 in HUP146_phaseII, that's hour 185 out of 365 for HUP 146
# Processing hour 186 in HUP146_phaseII, that's hour 186 out of 365 for HUP 146
# Processing hour 187 in HUP146_phaseII, that's hour 187 out of 365 for HUP 146
# Processing hour 188 in HUP146_phaseII, that's hour 188 out of 365 for HUP 146
# Processing hour 189 in HUP146_phaseII, that's hour 189 out of 365 for HUP 146
# Processing hour 190 in HUP146_phaseII, that's hour 190 out of 365 for HUP 146
# Processing hour 191 in HUP146_phaseII, that's hour 191 out of 365 for HUP 146
# Processing hour 192 in HUP146_phaseII, that's hour 192 out of 365 for HUP 146
# Processing hour 193 in HUP146_phaseII, that's hour 193 out of 365 for HUP 146
# Processing hour 194 in HUP146_phaseII, that's hour 194 out of 365 for HUP 146
# Processing hour 195 in HUP146_phaseII, that's hour 195 out of 365 for HUP 146
# Processing hour 196 in HUP146_phaseII, that's hour 196 out of 365 for HUP 146
# Processing hour 197 in HUP146_phaseII, that's hour 197 out of 365 for HUP 146
# Processing hour 198 in HUP146_phaseII, that's hour 198 out of 365 for HUP 146
# Processing hour 199 in HUP146_phaseII, that's hour 199 out of 365 for HUP 146
# Processing hour 200 in HUP146_phaseII, that's hour 200 out of 365 for HUP 146
# Processing hour 201 in HUP146_phaseII, that's hour 201 out of 365 for HUP 146
# Processing hour 202 in HUP146_phaseII, that's hour 202 out of 365 for HUP 146
# Processing hour 203 in HUP146_phaseII, that's hour 203 out of 365 for HUP 146
# Processing hour 204 in HUP146_phaseII, that's hour 204 out of 365 for HUP 146
# Processing hour 205 in HUP146_phaseII, that's hour 205 out of 365 for HUP 146
# Processing hour 206 in HUP146_phaseII, that's hour 206 out of 365 for HUP 146
# Processing hour 207 in HUP146_phaseII, that's hour 207 out of 365 for HUP 146
# Processing hour 208 in HUP146_phaseII, that's hour 208 out of 365 for HUP 146
# Processing hour 209 in HUP146_phaseII, that's hour 209 out of 365 for HUP 146
# Processing hour 210 in HUP146_phaseII, that's hour 210 out of 365 for HUP 146
# Processing hour 211 in HUP146_phaseII, that's hour 211 out of 365 for HUP 146
# Processing hour 212 in HUP146_phaseII, that's hour 212 out of 365 for HUP 146
# Processing hour 213 in HUP146_phaseII, that's hour 213 out of 365 for HUP 146
# Processing hour 214 in HUP146_phaseII, that's hour 214 out of 365 for HUP 146
# Processing hour 215 in HUP146_phaseII, that's hour 215 out of 365 for HUP 146
# Processing hour 216 in HUP146_phaseII, that's hour 216 out of 365 for HUP 146
# Processing hour 217 in HUP146_phaseII, that's hour 217 out of 365 for HUP 146
# Processing hour 218 in HUP146_phaseII, that's hour 218 out of 365 for HUP 146
# Skipping 219 for HUP146_phaseII
# Skipping 220 for HUP146_phaseII
# Skipping 221 for HUP146_phaseII
# Skipping 222 for HUP146_phaseII
# Skipping 223 for HUP146_phaseII
# Skipping 224 for HUP146_phaseII
# Skipping 225 for HUP146_phaseII
# Skipping 226 for HUP146_phaseII
# Skipping 227 for HUP146_phaseII
# Skipping 228 for HUP146_phaseII
# Skipping 229 for HUP146_phaseII
# Skipping 230 for HUP146_phaseII
# Skipping 231 for HUP146_phaseII
# Skipping 232 for HUP146_phaseII
# Skipping 233 for HUP146_phaseII
# Skipping 234 for HUP146_phaseII
# Skipping 235 for HUP146_phaseII
# Processing hour 236 in HUP146_phaseII, that's hour 236 out of 365 for HUP 146
# Processing hour 237 in HUP146_phaseII, that's hour 237 out of 365 for HUP 146
# Processing hour 238 in HUP146_phaseII, that's hour 238 out of 365 for HUP 146
# Processing hour 239 in HUP146_phaseII, that's hour 239 out of 365 for HUP 146
# Processing hour 240 in HUP146_phaseII, that's hour 240 out of 365 for HUP 146
# Processing hour 241 in HUP146_phaseII, that's hour 241 out of 365 for HUP 146
# Processing hour 242 in HUP146_phaseII, that's hour 242 out of 365 for HUP 146
# Processing hour 243 in HUP146_phaseII, that's hour 243 out of 365 for HUP 146
# Processing hour 244 in HUP146_phaseII, that's hour 244 out of 365 for HUP 146
# Processing hour 245 in HUP146_phaseII, that's hour 245 out of 365 for HUP 146
# Processing hour 246 in HUP146_phaseII, that's hour 246 out of 365 for HUP 146
# Processing hour 247 in HUP146_phaseII, that's hour 247 out of 365 for HUP 146
# Processing hour 248 in HUP146_phaseII, that's hour 248 out of 365 for HUP 146
# Processing hour 249 in HUP146_phaseII, that's hour 249 out of 365 for HUP 146
# Processing hour 250 in HUP146_phaseII, that's hour 250 out of 365 for HUP 146
# Processing hour 251 in HUP146_phaseII, that's hour 251 out of 365 for HUP 146
# Processing hour 252 in HUP146_phaseII, that's hour 252 out of 365 for HUP 146
# Processing hour 253 in HUP146_phaseII, that's hour 253 out of 365 for HUP 146
# Processing hour 254 in HUP146_phaseII, that's hour 254 out of 365 for HUP 146
# Processing hour 255 in HUP146_phaseII, that's hour 255 out of 365 for HUP 146
# Processing hour 256 in HUP146_phaseII, that's hour 256 out of 365 for HUP 146
# Processing hour 257 in HUP146_phaseII, that's hour 257 out of 365 for HUP 146
# Processing hour 258 in HUP146_phaseII, that's hour 258 out of 365 for HUP 146
# Processing hour 259 in HUP146_phaseII, that's hour 259 out of 365 for HUP 146
# Processing hour 260 in HUP146_phaseII, that's hour 260 out of 365 for HUP 146
# Processing hour 261 in HUP146_phaseII, that's hour 261 out of 365 for HUP 146
# Processing hour 262 in HUP146_phaseII, that's hour 262 out of 365 for HUP 146
# Processing hour 263 in HUP146_phaseII, that's hour 263 out of 365 for HUP 146
# Processing hour 264 in HUP146_phaseII, that's hour 264 out of 365 for HUP 146
# Processing hour 265 in HUP146_phaseII, that's hour 265 out of 365 for HUP 146
# Processing hour 266 in HUP146_phaseII, that's hour 266 out of 365 for HUP 146
# Processing hour 267 in HUP146_phaseII, that's hour 267 out of 365 for HUP 146
# Processing hour 268 in HUP146_phaseII, that's hour 268 out of 365 for HUP 146
# Processing hour 269 in HUP146_phaseII, that's hour 269 out of 365 for HUP 146
# Processing hour 270 in HUP146_phaseII, that's hour 270 out of 365 for HUP 146
# Processing hour 271 in HUP146_phaseII, that's hour 271 out of 365 for HUP 146
# Processing hour 272 in HUP146_phaseII, that's hour 272 out of 365 for HUP 146
# Processing hour 273 in HUP146_phaseII, that's hour 273 out of 365 for HUP 146
# Processing hour 274 in HUP146_phaseII, that's hour 274 out of 365 for HUP 146
# Processing hour 275 in HUP146_phaseII, that's hour 275 out of 365 for HUP 146
# Processing hour 276 in HUP146_phaseII, that's hour 276 out of 365 for HUP 146
# Processing hour 277 in HUP146_phaseII, that's hour 277 out of 365 for HUP 146
# Processing hour 278 in HUP146_phaseII, that's hour 278 out of 365 for HUP 146
# Processing hour 279 in HUP146_phaseII, that's hour 279 out of 365 for HUP 146
# Processing hour 280 in HUP146_phaseII, that's hour 280 out of 365 for HUP 146
# Processing hour 281 in HUP146_phaseII, that's hour 281 out of 365 for HUP 146
# Processing hour 282 in HUP146_phaseII, that's hour 282 out of 365 for HUP 146
# Processing hour 283 in HUP146_phaseII, that's hour 283 out of 365 for HUP 146
# Processing hour 284 in HUP146_phaseII, that's hour 284 out of 365 for HUP 146
# Processing hour 285 in HUP146_phaseII, that's hour 285 out of 365 for HUP 146
# Processing hour 286 in HUP146_phaseII, that's hour 286 out of 365 for HUP 146
# Processing hour 287 in HUP146_phaseII, that's hour 287 out of 365 for HUP 146
# Processing hour 288 in HUP146_phaseII, that's hour 288 out of 365 for HUP 146
# Processing hour 289 in HUP146_phaseII, that's hour 289 out of 365 for HUP 146
# Processing hour 290 in HUP146_phaseII, that's hour 290 out of 365 for HUP 146
# Processing hour 291 in HUP146_phaseII, that's hour 291 out of 365 for HUP 146
# Processing hour 292 in HUP146_phaseII, that's hour 292 out of 365 for HUP 146
# Processing hour 293 in HUP146_phaseII, that's hour 293 out of 365 for HUP 146
# Processing hour 294 in HUP146_phaseII, that's hour 294 out of 365 for HUP 146
# Processing hour 295 in HUP146_phaseII, that's hour 295 out of 365 for HUP 146
# Processing hour 296 in HUP146_phaseII, that's hour 296 out of 365 for HUP 146
# Processing hour 297 in HUP146_phaseII, that's hour 297 out of 365 for HUP 146
# Processing hour 298 in HUP146_phaseII, that's hour 298 out of 365 for HUP 146
# Processing hour 299 in HUP146_phaseII, that's hour 299 out of 365 for HUP 146
# Processing hour 300 in HUP146_phaseII, that's hour 300 out of 365 for HUP 146
# Processing hour 301 in HUP146_phaseII, that's hour 301 out of 365 for HUP 146
# Processing hour 302 in HUP146_phaseII, that's hour 302 out of 365 for HUP 146
# Processing hour 303 in HUP146_phaseII, that's hour 303 out of 365 for HUP 146
# Processing hour 304 in HUP146_phaseII, that's hour 304 out of 365 for HUP 146
# Processing hour 305 in HUP146_phaseII, that's hour 305 out of 365 for HUP 146
# Processing hour 306 in HUP146_phaseII, that's hour 306 out of 365 for HUP 146
# Processing hour 307 in HUP146_phaseII, that's hour 307 out of 365 for HUP 146
# Processing hour 308 in HUP146_phaseII, that's hour 308 out of 365 for HUP 146
# Processing hour 309 in HUP146_phaseII, that's hour 309 out of 365 for HUP 146
# Processing hour 310 in HUP146_phaseII, that's hour 310 out of 365 for HUP 146
# Processing hour 311 in HUP146_phaseII, that's hour 311 out of 365 for HUP 146
# Processing hour 312 in HUP146_phaseII, that's hour 312 out of 365 for HUP 146
# Processing hour 313 in HUP146_phaseII, that's hour 313 out of 365 for HUP 146
# Processing hour 314 in HUP146_phaseII, that's hour 314 out of 365 for HUP 146
# Processing hour 315 in HUP146_phaseII, that's hour 315 out of 365 for HUP 146
# Processing hour 316 in HUP146_phaseII, that's hour 316 out of 365 for HUP 146
# Processing hour 317 in HUP146_phaseII, that's hour 317 out of 365 for HUP 146
# Processing hour 318 in HUP146_phaseII, that's hour 318 out of 365 for HUP 146
# Processing hour 319 in HUP146_phaseII, that's hour 319 out of 365 for HUP 146
# Processing hour 320 in HUP146_phaseII, that's hour 320 out of 365 for HUP 146
# Processing hour 321 in HUP146_phaseII, that's hour 321 out of 365 for HUP 146
# Processing hour 322 in HUP146_phaseII, that's hour 322 out of 365 for HUP 146
# Processing hour 323 in HUP146_phaseII, that's hour 323 out of 365 for HUP 146
# Processing hour 324 in HUP146_phaseII, that's hour 324 out of 365 for HUP 146
# Processing hour 325 in HUP146_phaseII, that's hour 325 out of 365 for HUP 146
# Processing hour 326 in HUP146_phaseII, that's hour 326 out of 365 for HUP 146
# Processing hour 327 in HUP146_phaseII, that's hour 327 out of 365 for HUP 146
# Processing hour 328 in HUP146_phaseII, that's hour 328 out of 365 for HUP 146
# Processing hour 329 in HUP146_phaseII, that's hour 329 out of 365 for HUP 146
# Processing hour 330 in HUP146_phaseII, that's hour 330 out of 365 for HUP 146
# Processing hour 331 in HUP146_phaseII, that's hour 331 out of 365 for HUP 146
# Processing hour 332 in HUP146_phaseII, that's hour 332 out of 365 for HUP 146
# Processing hour 333 in HUP146_phaseII, that's hour 333 out of 365 for HUP 146
# Processing hour 334 in HUP146_phaseII, that's hour 334 out of 365 for HUP 146
# Processing hour 335 in HUP146_phaseII, that's hour 335 out of 365 for HUP 146
# Processing hour 336 in HUP146_phaseII, that's hour 336 out of 365 for HUP 146
# Processing hour 337 in HUP146_phaseII, that's hour 337 out of 365 for HUP 146
# Processing hour 338 in HUP146_phaseII, that's hour 338 out of 365 for HUP 146
# Processing hour 339 in HUP146_phaseII, that's hour 339 out of 365 for HUP 146
# Processing hour 340 in HUP146_phaseII, that's hour 340 out of 365 for HUP 146
# Processing hour 341 in HUP146_phaseII, that's hour 341 out of 365 for HUP 146
# Processing hour 342 in HUP146_phaseII, that's hour 342 out of 365 for HUP 146
# Processing hour 343 in HUP146_phaseII, that's hour 343 out of 365 for HUP 146
# Processing hour 344 in HUP146_phaseII, that's hour 344 out of 365 for HUP 146
# Processing hour 345 in HUP146_phaseII, that's hour 345 out of 365 for HUP 146
# Processing hour 346 in HUP146_phaseII, that's hour 346 out of 365 for HUP 146
# Processing hour 347 in HUP146_phaseII, that's hour 347 out of 365 for HUP 146
# Processing hour 348 in HUP146_phaseII, that's hour 348 out of 365 for HUP 146
# Processing hour 349 in HUP146_phaseII, that's hour 349 out of 365 for HUP 146
# Processing hour 350 in HUP146_phaseII, that's hour 350 out of 365 for HUP 146
# Processing hour 351 in HUP146_phaseII, that's hour 351 out of 365 for HUP 146
# Processing hour 352 in HUP146_phaseII, that's hour 352 out of 365 for HUP 146
# Processing hour 353 in HUP146_phaseII, that's hour 353 out of 365 for HUP 146
# Processing hour 354 in HUP146_phaseII, that's hour 354 out of 365 for HUP 146
# Processing hour 355 in HUP146_phaseII, that's hour 355 out of 365 for HUP 146
# Processing hour 356 in HUP146_phaseII, that's hour 356 out of 365 for HUP 146
# Processing hour 357 in HUP146_phaseII, that's hour 357 out of 365 for HUP 146
# Processing hour 358 in HUP146_phaseII, that's hour 358 out of 365 for HUP 146
# Processing hour 359 in HUP146_phaseII, that's hour 359 out of 365 for HUP 146
# Processing hour 360 in HUP146_phaseII, that's hour 360 out of 365 for HUP 146
# Processing hour 361 in HUP146_phaseII, that's hour 361 out of 365 for HUP 146
# Processing hour 362 in HUP146_phaseII, that's hour 362 out of 365 for HUP 146
# Processing hour 363 in HUP146_phaseII, that's hour 363 out of 365 for HUP 146
# Processing hour 364 in HUP146_phaseII, that's hour 364 out of 365 for HUP 146
# HUP 149, rid 240
# HUP149_phaseII_D01
# Processing hour 0 in HUP149_phaseII_D01, that's hour 0 out of 525 for HUP 149
# Processing hour 1 in HUP149_phaseII_D01, that's hour 1 out of 525 for HUP 149
# Processing hour 2 in HUP149_phaseII_D01, that's hour 2 out of 525 for HUP 149
# Processing hour 3 in HUP149_phaseII_D01, that's hour 3 out of 525 for HUP 149
# Processing hour 4 in HUP149_phaseII_D01, that's hour 4 out of 525 for HUP 149
# Processing hour 5 in HUP149_phaseII_D01, that's hour 5 out of 525 for HUP 149
# Processing hour 6 in HUP149_phaseII_D01, that's hour 6 out of 525 for HUP 149
# Processing hour 7 in HUP149_phaseII_D01, that's hour 7 out of 525 for HUP 149
# Processing hour 8 in HUP149_phaseII_D01, that's hour 8 out of 525 for HUP 149
# Processing hour 9 in HUP149_phaseII_D01, that's hour 9 out of 525 for HUP 149
# Processing hour 10 in HUP149_phaseII_D01, that's hour 10 out of 525 for HUP 149
# Processing hour 11 in HUP149_phaseII_D01, that's hour 11 out of 525 for HUP 149
# Processing hour 12 in HUP149_phaseII_D01, that's hour 12 out of 525 for HUP 149
# Processing hour 13 in HUP149_phaseII_D01, that's hour 13 out of 525 for HUP 149
# Processing hour 14 in HUP149_phaseII_D01, that's hour 14 out of 525 for HUP 149
# Processing hour 15 in HUP149_phaseII_D01, that's hour 15 out of 525 for HUP 149
# Processing hour 16 in HUP149_phaseII_D01, that's hour 16 out of 525 for HUP 149
# Processing hour 17 in HUP149_phaseII_D01, that's hour 17 out of 525 for HUP 149
# Processing hour 18 in HUP149_phaseII_D01, that's hour 18 out of 525 for HUP 149
# Processing hour 19 in HUP149_phaseII_D01, that's hour 19 out of 525 for HUP 149
# Processing hour 20 in HUP149_phaseII_D01, that's hour 20 out of 525 for HUP 149
# Processing hour 21 in HUP149_phaseII_D01, that's hour 21 out of 525 for HUP 149
# HUP149_phaseII_D02
# Processing hour 0 in HUP149_phaseII_D02, that's hour 22 out of 525 for HUP 149
# ...
# Processing hour 138 in HUP153_phaseII_D01, that's hour 138 out of 307 for HUP 153
# Processing hour 139 in HUP153_phaseII_D01, that's hour 139 out of 307 for HUP 153
# Processing hour 140 in HUP153_phaseII_D01, that's hour 140 out of 307 for HUP 153
# Processing hour 141 in HUP153_phaseII_D01, that's hour 141 out of 307 for HUP 153
# Processing hour 142 in HUP153_phaseII_D01, that's hour 142 out of 307 for HUP 153
# Processing hour 143 in HUP153_phaseII_D01, that's hour 143 out of 307 for HUP 153
# Processing hour 144 in HUP153_phaseII_D01, that's hour 144 out of 307 for HUP 153
# Processing hour 145 in HUP153_phaseII_D01, that's hour 145 out of 307 for HUP 153
# Processing hour 146 in HUP153_phaseII_D01, that's hour 146 out of 307 for HUP 153
# Processing hour 147 in HUP153_phaseII_D01, that's hour 147 out of 307 for HUP 153
# Processing hour 148 in HUP153_phaseII_D01, that's hour 148 out of 307 for HUP 153
# Processing hour 149 in HUP153_phaseII_D01, that's hour 149 out of 307 for HUP 153
# Processing hour 150 in HUP153_phaseII_D01, that's hour 150 out of 307 for HUP 153
# Processing hour 151 in HUP153_phaseII_D01, that's hour 151 out of 307 for HUP 153
# Processing hour 152 in HUP153_phaseII_D01, that's hour 152 out of 307 for HUP 153
# Processing hour 153 in HUP153_phaseII_D01, that's hour 153 out of 307 for HUP 153
# Processing hour 154 in HUP153_phaseII_D01, that's hour 154 out of 307 for HUP 153
# Processing hour 155 in HUP153_phaseII_D01, that's hour 155 out of 307 for HUP 153
# Processing hour 156 in HUP153_phaseII_D01, that's hour 156 out of 307 for HUP 153
# Processing hour 157 in HUP153_phaseII_D01, that's hour 157 out of 307 for HUP 153
# Processing hour 158 in HUP153_phaseII_D01, that's hour 158 out of 307 for HUP 153
# Processing hour 159 in HUP153_phaseII_D01, that's hour 159 out of 307 for HUP 153
# Processing hour 160 in HUP153_phaseII_D01, that's hour 160 out of 307 for HUP 153
# Processing hour 161 in HUP153_phaseII_D01, that's hour 161 out of 307 for HUP 153
# Processing hour 162 in HUP153_phaseII_D01, that's hour 162 out of 307 for HUP 153
# Processing hour 163 in HUP153_phaseII_D01, that's hour 163 out of 307 for HUP 153
# Processing hour 164 in HUP153_phaseII_D01, that's hour 164 out of 307 for HUP 153
# Processing hour 165 in HUP153_phaseII_D01, that's hour 165 out of 307 for HUP 153
# Processing hour 166 in HUP153_phaseII_D01, that's hour 166 out of 307 for HUP 153
# HUP153_phaseII_D02
# Processing hour 0 in HUP153_phaseII_D02, that's hour 167 out of 307 for HUP 153
# Processing hour 1 in HUP153_phaseII_D02, that's hour 168 out of 307 for HUP 153
# Processing hour 2 in HUP153_phaseII_D02, that's hour 169 out of 307 for HUP 153
# Processing hour 3 in HUP153_phaseII_D02, that's hour 170 out of 307 for HUP 153
# Processing hour 4 in HUP153_phaseII_D02, that's hour 171 out of 307 for HUP 153
# Processing hour 5 in HUP153_phaseII_D02, that's hour 172 out of 307 for HUP 153
# Processing hour 6 in HUP153_phaseII_D02, that's hour 173 out of 307 for HUP 153
# Processing hour 7 in HUP153_phaseII_D02, that's hour 174 out of 307 for HUP 153
# Processing hour 8 in HUP153_phaseII_D02, that's hour 175 out of 307 for HUP 153
# Processing hour 9 in HUP153_phaseII_D02, that's hour 176 out of 307 for HUP 153
# Processing hour 10 in HUP153_phaseII_D02, that's hour 177 out of 307 for HUP 153
# Processing hour 11 in HUP153_phaseII_D02, that's hour 178 out of 307 for HUP 153
# Processing hour 12 in HUP153_phaseII_D02, that's hour 179 out of 307 for HUP 153
# Processing hour 13 in HUP153_phaseII_D02, that's hour 180 out of 307 for HUP 153
# Processing hour 14 in HUP153_phaseII_D02, that's hour 181 out of 307 for HUP 153
# Processing hour 15 in HUP153_phaseII_D02, that's hour 182 out of 307 for HUP 153
# Processing hour 16 in HUP153_phaseII_D02, that's hour 183 out of 307 for HUP 153
# Processing hour 17 in HUP153_phaseII_D02, that's hour 184 out of 307 for HUP 153
# Processing hour 18 in HUP153_phaseII_D02, that's hour 185 out of 307 for HUP 153
# Processing hour 19 in HUP153_phaseII_D02, that's hour 186 out of 307 for HUP 153
# Processing hour 20 in HUP153_phaseII_D02, that's hour 187 out of 307 for HUP 153
# Processing hour 21 in HUP153_phaseII_D02, that's hour 188 out of 307 for HUP 153
# Processing hour 22 in HUP153_phaseII_D02, that's hour 189 out of 307 for HUP 153
# Processing hour 23 in HUP153_phaseII_D02, that's hour 190 out of 307 for HUP 153
# Processing hour 24 in HUP153_phaseII_D02, that's hour 191 out of 307 for HUP 153
# Processing hour 25 in HUP153_phaseII_D02, that's hour 192 out of 307 for HUP 153
# Processing hour 26 in HUP153_phaseII_D02, that's hour 193 out of 307 for HUP 153
# Processing hour 27 in HUP153_phaseII_D02, that's hour 194 out of 307 for HUP 153
# Processing hour 28 in HUP153_phaseII_D02, that's hour 195 out of 307 for HUP 153
# Processing hour 29 in HUP153_phaseII_D02, that's hour 196 out of 307 for HUP 153
# Processing hour 30 in HUP153_phaseII_D02, that's hour 197 out of 307 for HUP 153
# Processing hour 31 in HUP153_phaseII_D02, that's hour 198 out of 307 for HUP 153
# Processing hour 32 in HUP153_phaseII_D02, that's hour 199 out of 307 for HUP 153
# Processing hour 33 in HUP153_phaseII_D02, that's hour 200 out of 307 for HUP 153
# Processing hour 34 in HUP153_phaseII_D02, that's hour 201 out of 307 for HUP 153
# Processing hour 35 in HUP153_phaseII_D02, that's hour 202 out of 307 for HUP 153
# Processing hour 36 in HUP153_phaseII_D02, that's hour 203 out of 307 for HUP 153
# Processing hour 37 in HUP153_phaseII_D02, that's hour 204 out of 307 for HUP 153
# Processing hour 38 in HUP153_phaseII_D02, that's hour 205 out of 307 for HUP 153
# Processing hour 39 in HUP153_phaseII_D02, that's hour 206 out of 307 for HUP 153
# Processing hour 40 in HUP153_phaseII_D02, that's hour 207 out of 307 for HUP 153
# Processing hour 41 in HUP153_phaseII_D02, that's hour 208 out of 307 for HUP 153
# Processing hour 42 in HUP153_phaseII_D02, that's hour 209 out of 307 for HUP 153
# Processing hour 43 in HUP153_phaseII_D02, that's hour 210 out of 307 for HUP 153
# Processing hour 44 in HUP153_phaseII_D02, that's hour 211 out of 307 for HUP 153
# Processing hour 45 in HUP153_phaseII_D02, that's hour 212 out of 307 for HUP 153
# Processing hour 46 in HUP153_phaseII_D02, that's hour 213 out of 307 for HUP 153
# Processing hour 47 in HUP153_phaseII_D02, that's hour 214 out of 307 for HUP 153
# Processing hour 48 in HUP153_phaseII_D02, that's hour 215 out of 307 for HUP 153
# Processing hour 49 in HUP153_phaseII_D02, that's hour 216 out of 307 for HUP 153
# Processing hour 50 in HUP153_phaseII_D02, that's hour 217 out of 307 for HUP 153
# Processing hour 51 in HUP153_phaseII_D02, that's hour 218 out of 307 for HUP 153
# Processing hour 52 in HUP153_phaseII_D02, that's hour 219 out of 307 for HUP 153
# Processing hour 53 in HUP153_phaseII_D02, that's hour 220 out of 307 for HUP 153
# Processing hour 54 in HUP153_phaseII_D02, that's hour 221 out of 307 for HUP 153
# Processing hour 55 in HUP153_phaseII_D02, that's hour 222 out of 307 for HUP 153
# Processing hour 56 in HUP153_phaseII_D02, that's hour 223 out of 307 for HUP 153
# Processing hour 57 in HUP153_phaseII_D02, that's hour 224 out of 307 for HUP 153
# Processing hour 58 in HUP153_phaseII_D02, that's hour 225 out of 307 for HUP 153
# Processing hour 59 in HUP153_phaseII_D02, that's hour 226 out of 307 for HUP 153
# Processing hour 60 in HUP153_phaseII_D02, that's hour 227 out of 307 for HUP 153
# Processing hour 61 in HUP153_phaseII_D02, that's hour 228 out of 307 for HUP 153
# Processing hour 62 in HUP153_phaseII_D02, that's hour 229 out of 307 for HUP 153
# Processing hour 63 in HUP153_phaseII_D02, that's hour 230 out of 307 for HUP 153
# Processing hour 64 in HUP153_phaseII_D02, that's hour 231 out of 307 for HUP 153
# Processing hour 65 in HUP153_phaseII_D02, that's hour 232 out of 307 for HUP 153
# Processing hour 66 in HUP153_phaseII_D02, that's hour 233 out of 307 for HUP 153
# Processing hour 67 in HUP153_phaseII_D02, that's hour 234 out of 307 for HUP 153
# Processing hour 68 in HUP153_phaseII_D02, that's hour 235 out of 307 for HUP 153
# Processing hour 69 in HUP153_phaseII_D02, that's hour 236 out of 307 for HUP 153
# Processing hour 70 in HUP153_phaseII_D02, that's hour 237 out of 307 for HUP 153
# Processing hour 71 in HUP153_phaseII_D02, that's hour 238 out of 307 for HUP 153
# Processing hour 72 in HUP153_phaseII_D02, that's hour 239 out of 307 for HUP 153
# Processing hour 73 in HUP153_phaseII_D02, that's hour 240 out of 307 for HUP 153
# Processing hour 74 in HUP153_phaseII_D02, that's hour 241 out of 307 for HUP 153
# Processing hour 75 in HUP153_phaseII_D02, that's hour 242 out of 307 for HUP 153
# Processing hour 76 in HUP153_phaseII_D02, that's hour 243 out of 307 for HUP 153
# Processing hour 77 in HUP153_phaseII_D02, that's hour 244 out of 307 for HUP 153
# Processing hour 78 in HUP153_phaseII_D02, that's hour 245 out of 307 for HUP 153
# Processing hour 79 in HUP153_phaseII_D02, that's hour 246 out of 307 for HUP 153
# Processing hour 80 in HUP153_phaseII_D02, that's hour 247 out of 307 for HUP 153
# Processing hour 81 in HUP153_phaseII_D02, that's hour 248 out of 307 for HUP 153
# Processing hour 82 in HUP153_phaseII_D02, that's hour 249 out of 307 for HUP 153
# Processing hour 83 in HUP153_phaseII_D02, that's hour 250 out of 307 for HUP 153
# Processing hour 84 in HUP153_phaseII_D02, that's hour 251 out of 307 for HUP 153
# Processing hour 85 in HUP153_phaseII_D02, that's hour 252 out of 307 for HUP 153
# Processing hour 86 in HUP153_phaseII_D02, that's hour 253 out of 307 for HUP 153
# Processing hour 87 in HUP153_phaseII_D02, that's hour 254 out of 307 for HUP 153
# Processing hour 88 in HUP153_phaseII_D02, that's hour 255 out of 307 for HUP 153
# Processing hour 89 in HUP153_phaseII_D02, that's hour 256 out of 307 for HUP 153
# Processing hour 90 in HUP153_phaseII_D02, that's hour 257 out of 307 for HUP 153
# Processing hour 91 in HUP153_phaseII_D02, that's hour 258 out of 307 for HUP 153
# Processing hour 92 in HUP153_phaseII_D02, that's hour 259 out of 307 for HUP 153
# Processing hour 93 in HUP153_phaseII_D02, that's hour 260 out of 307 for HUP 153
# Processing hour 94 in HUP153_phaseII_D02, that's hour 261 out of 307 for HUP 153
# Processing hour 95 in HUP153_phaseII_D02, that's hour 262 out of 307 for HUP 153
# Processing hour 96 in HUP153_phaseII_D02, that's hour 263 out of 307 for HUP 153
# Processing hour 97 in HUP153_phaseII_D02, that's hour 264 out of 307 for HUP 153
# Processing hour 98 in HUP153_phaseII_D02, that's hour 265 out of 307 for HUP 153
# Processing hour 99 in HUP153_phaseII_D02, that's hour 266 out of 307 for HUP 153
# Processing hour 100 in HUP153_phaseII_D02, that's hour 267 out of 307 for HUP 153
# Processing hour 101 in HUP153_phaseII_D02, that's hour 268 out of 307 for HUP 153
# Processing hour 102 in HUP153_phaseII_D02, that's hour 269 out of 307 for HUP 153
# Processing hour 103 in HUP153_phaseII_D02, that's hour 270 out of 307 for HUP 153
# Processing hour 104 in HUP153_phaseII_D02, that's hour 271 out of 307 for HUP 153
# Processing hour 105 in HUP153_phaseII_D02, that's hour 272 out of 307 for HUP 153
# Processing hour 106 in HUP153_phaseII_D02, that's hour 273 out of 307 for HUP 153
# Processing hour 107 in HUP153_phaseII_D02, that's hour 274 out of 307 for HUP 153
# Processing hour 108 in HUP153_phaseII_D02, that's hour 275 out of 307 for HUP 153
# Processing hour 109 in HUP153_phaseII_D02, that's hour 276 out of 307 for HUP 153
# Processing hour 110 in HUP153_phaseII_D02, that's hour 277 out of 307 for HUP 153
# Processing hour 111 in HUP153_phaseII_D02, that's hour 278 out of 307 for HUP 153
# Processing hour 112 in HUP153_phaseII_D02, that's hour 279 out of 307 for HUP 153
# Processing hour 113 in HUP153_phaseII_D02, that's hour 280 out of 307 for HUP 153
# Processing hour 114 in HUP153_phaseII_D02, that's hour 281 out of 307 for HUP 153
# Processing hour 115 in HUP153_phaseII_D02, that's hour 282 out of 307 for HUP 153
# Processing hour 116 in HUP153_phaseII_D02, that's hour 283 out of 307 for HUP 153
# Processing hour 117 in HUP153_phaseII_D02, that's hour 284 out of 307 for HUP 153
# Processing hour 118 in HUP153_phaseII_D02, that's hour 285 out of 307 for HUP 153
# Processing hour 119 in HUP153_phaseII_D02, that's hour 286 out of 307 for HUP 153
# Processing hour 120 in HUP153_phaseII_D02, that's hour 287 out of 307 for HUP 153
# Processing hour 121 in HUP153_phaseII_D02, that's hour 288 out of 307 for HUP 153
# Processing hour 122 in HUP153_phaseII_D02, that's hour 289 out of 307 for HUP 153
# Processing hour 123 in HUP153_phaseII_D02, that's hour 290 out of 307 for HUP 153
# Processing hour 124 in HUP153_phaseII_D02, that's hour 291 out of 307 for HUP 153
# Processing hour 125 in HUP153_phaseII_D02, that's hour 292 out of 307 for HUP 153
# Processing hour 126 in HUP153_phaseII_D02, that's hour 293 out of 307 for HUP 153
# Processing hour 127 in HUP153_phaseII_D02, that's hour 294 out of 307 for HUP 153
# Processing hour 128 in HUP153_phaseII_D02, that's hour 295 out of 307 for HUP 153
# Processing hour 129 in HUP153_phaseII_D02, that's hour 296 out of 307 for HUP 153
# Processing hour 130 in HUP153_phaseII_D02, that's hour 297 out of 307 for HUP 153
# Processing hour 131 in HUP153_phaseII_D02, that's hour 298 out of 307 for HUP 153
# Processing hour 132 in HUP153_phaseII_D02, that's hour 299 out of 307 for HUP 153
# Processing hour 133 in HUP153_phaseII_D02, that's hour 300 out of 307 for HUP 153
# Processing hour 134 in HUP153_phaseII_D02, that's hour 301 out of 307 for HUP 153
# Processing hour 135 in HUP153_phaseII_D02, that's hour 302 out of 307 for HUP 153
# Processing hour 136 in HUP153_phaseII_D02, that's hour 303 out of 307 for HUP 153
# Processing hour 137 in HUP153_phaseII_D02, that's hour 304 out of 307 for HUP 153
# Processing hour 138 in HUP153_phaseII_D02, that's hour 305 out of 307 for HUP 153
# Processing hour 139 in HUP153_phaseII_D02, that's hour 306 out of 307 for HUP 153
# HUP 157, rid 365
# HUP157_phaseII
# Processing hour 0 in HUP157_phaseII, that's hour 0 out of 191 for HUP 157
# Processing hour 1 in HUP157_phaseII, that's hour 1 out of 191 for HUP 157
# Skipping 1 for HUP157_phaseII because there's less than 1 good channel after bipolar_montage
# Processing hour 2 in HUP157_phaseII, that's hour 2 out of 191 for HUP 157
# Processing hour 3 in HUP157_phaseII, that's hour 3 out of 191 for HUP 157
# Skipping 3 for HUP157_phaseII because there are less than 2 good channels
# Processing hour 4 in HUP157_phaseII, that's hour 4 out of 191 for HUP 157
# Processing hour 5 in HUP157_phaseII, that's hour 5 out of 191 for HUP 157
# Processing hour 6 in HUP157_phaseII, that's hour 6 out of 191 for HUP 157
# Processing hour 7 in HUP157_phaseII, that's hour 7 out of 191 for HUP 157
# Processing hour 8 in HUP157_phaseII, that's hour 8 out of 191 for HUP 157
# Processing hour 9 in HUP157_phaseII, that's hour 9 out of 191 for HUP 157
# Processing hour 10 in HUP157_phaseII, that's hour 10 out of 191 for HUP 157
# Processing hour 11 in HUP157_phaseII, that's hour 11 out of 191 for HUP 157
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 39
#      37 try:
#      38     with open(full_path, "rb") as f:
# ---> 39         eeg_segment_df = pickle.load(f)
#      40 except FileNotFoundError:
#      41     print(f"Skipping {hour} for {dataset_name}")
#
# File /mnt/leif/littlab/users/devinma/Libraries/miniconda3/lib/python3.11/site-packages/pandas/_libs/internals.pyx:575, in pandas._libs.internals._unpickle_block()
#
# File /mnt/leif/littlab/users/devinma/Libraries/miniconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:2172, in new_block(values, placement, ndim)
#    2168     values = maybe_coerce_values(values)
#    2169     return klass(values, ndim=2, placement=placement)
# -> 2172 def new_block(values, placement, *, ndim: int) -> Block:
#    2173     # caller is responsible for ensuring values is NOT a PandasArray
#    2175     if not isinstance(placement, BlockPlacement):
#    2176         placement = BlockPlacement(placement)
#
# KeyboardInterrupt:
