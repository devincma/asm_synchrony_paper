# %% [markdown]
# # Download iEEG

# %%
from ieeg.auth import Session
import pandas as pd
import matlab.engine
import math
import os
from ieeg_utils import *
import numpy as np
from numpy import pi, NaN

# %% [markdown]
# ## Load data

# %%
patients_df = pd.read_excel("./data/selected_patients.xlsx")
patients_df
# Out:
#     hup_id           region lateralization  weight_kg  r_id
# 0      138  mesial temporal           left       84.4   278
# 1      140  mesial temporal           left       56.7   320
# 2      141  mesial temporal          right       85.7   294
# 3      142  mesial temporal           left       65.3   295
# 4      162  mesial temporal           left       47.1   412
# 5      163  mesial temporal           left       82.1   279
# 6      164  mesial temporal           left       95.3   386
# 7      173  mesial temporal          right       76.6    31
# 8      181  mesial temporal           left       63.0   490
# 9      185  mesial temporal           left       76.2   332
# 10     187  mesial temporal          right       86.2   522
# 11     190  mesial temporal           left      105.4   405
# 12     202  mesial temporal           left       89.0   646
# 13     204  mesial temporal           left       82.1   596
# 14     217  mesial temporal          right       58.5   679
# 15     219  mesial temporal          right      101.6   695
# 16     221  mesial temporal          right      124.3   621
# 17     223  mesial temporal           left      101.4   785

# %%
# Load master_elecs.csv from ./data/
master_elecs_df = pd.read_csv("./data/master_elecs.csv")

# only take the numbers in rid column
master_elecs_df["rid"] = master_elecs_df["rid"].str.extract("(\d+)", expand=False)
master_elecs_df["rid"] = master_elecs_df["rid"].astype(int)

# Drop mni_x, mni_y, mni_z, mm_x, mm_y, mm_z columns
master_elecs_df = master_elecs_df.drop(
    columns=["mni_x", "mni_y", "mni_z", "mm_x", "mm_y", "mm_z"]
)

master_elecs_df
# Out:
#        rid   name     vox_x     vox_y     vox_z                   label  \
# 0       13  LST01   80.6116  106.5480   64.5941  left inferior temporal
# 1       13  LST02   72.0779  109.4150   63.1223  left inferior temporal
# 2       13  LST03   64.9060  112.3760   68.7455              EmptyLabel
# 3       13  LST04   65.0210  114.6600   78.2339    left middle temporal
# 4       13  MST01  131.7410   64.3756   70.4205           right lingual
# ...    ...    ...       ...       ...       ...                     ...
# 14212  785   RB08  154.2550  114.2730  136.7560              EmptyLabel
# 14213  785   RB09  159.1350  111.9920  136.6960              EmptyLabel
# 14214  785   RB10  164.7520  109.9030  137.7640   right middle temporal
# 14215  785   RB11  169.6320  107.6220  137.7040   right middle temporal
# 14216  785   RB12  175.1210  105.8310  137.7080              EmptyLabel
#
#          soz resected  spike_rate  engel
# 0      False    False    1.091902    1.0
# 1      False    False    1.091902    1.0
# 2      False    False    1.419472    1.0
# 3      False    False    0.655141    1.0
# 4       True    False    3.439490    1.0
# ...      ...      ...         ...    ...
# 14212  False      NaN    0.369914    1.0
# 14213  False      NaN    0.665845    1.0
# 14214  False      NaN    4.586930    1.0
# 14215  False      NaN    2.071517    1.0
# 14216  False      NaN    5.104809    1.0
#
# [14217 rows x 10 columns]

# %%
# Load rid_hup_table.csv from ./data/
rid_hup_table_df = pd.read_csv("./data/rid_hup_table.csv")
# Drop the t3_subject_id and ieegportalsubjno columns
rid_hup_table_df = rid_hup_table_df.drop(columns=["t3_subject_id", "ieegportalsubjno"])
rid_hup_table_df
# Out:
#      record_id  hupsubjno
# 0          623         35
# 1          624         36
# 2          625         37
# 3          626         38
# 4          627         39
# ..         ...        ...
# 212        534        250
# 213        923        251
# 214        918        252
# 215        864        253
# 216        675        254
#
# [217 rows x 2 columns]

# %%
patient_hup_ids = patients_df.hup_id.to_numpy()
patient_weights = patients_df.weight_kg.to_numpy()
assert len(patient_hup_ids) == len(patient_weights)
len(patient_hup_ids)
# Out:
# 18

# %%
all_patient_hup_ids = pd.read_excel("./data/HUP_implant_dates.xlsx")
all_patient_hup_ids = all_patient_hup_ids["ptID"].to_numpy()
all_patient_hup_ids
# Out:
# array([225, 224, 223, 221, 219, 217, 216, 215, 214, 213, 211, 210, 209,
#        208, 207, 206, 205, 204, 202, 201, 199, 197, 196, 195, 194, 193,
#        192, 191, 190, 189, 188, 187, 186, 185, 184, 182, 181, 180, 179,
#        178, 177, 175, 174, 173, 172, 171, 170, 169, 168, 167, 166, 165,
#        164, 163, 162, 161, 160, 159, 158, 157, 156, 155, 154, 153, 152,
#        151, 150, 149, 148, 147, 146, 145, 144, 143, 142, 141, 140, 139,
#        138, 137])

# %%
# Create a mapping between patient ids and the index of the patient in the patients_df dataframe
patient_hup_id_to_index = {}
for i, patient_id in enumerate(all_patient_hup_ids):
    patient_hup_id_to_index[patient_id] = i
patient_hup_id_to_index
# Out:
# {225: 0,
#  224: 1,
#  223: 2,
#  221: 3,
#  219: 4,
#  217: 5,
#  216: 6,
#  215: 7,
#  214: 8,
#  213: 9,
#  211: 10,
#  210: 11,
#  209: 12,
#  208: 13,
#  207: 14,
#  206: 15,
#  205: 16,
#  204: 17,
#  202: 18,
#  201: 19,
#  199: 20,
#  197: 21,
#  196: 22,
#  195: 23,
#  194: 24,
#  193: 25,
#  192: 26,
#  191: 27,
#  190: 28,
#  189: 29,
#  188: 30,
#  187: 31,
#  186: 32,
#  185: 33,
#  184: 34,
#  182: 35,
#  181: 36,
#  180: 37,
#  179: 38,
#  178: 39,
#  177: 40,
#  175: 41,
#  174: 42,
#  173: 43,
#  172: 44,
#  171: 45,
#  170: 46,
#  169: 47,
#  168: 48,
#  167: 49,
#  166: 50,
#  165: 51,
#  164: 52,
#  163: 53,
#  162: 54,
#  161: 55,
#  160: 56,
#  159: 57,
#  158: 58,
#  157: 59,
#  156: 60,
#  155: 61,
#  154: 62,
#  153: 63,
#  152: 64,
#  151: 65,
#  150: 66,
#  149: 67,
#  148: 68,
#  147: 69,
#  146: 70,
#  145: 71,
#  144: 72,
#  143: 73,
#  142: 74,
#  141: 75,
#  140: 76,
#  139: 77,
#  138: 78,
#  137: 79}

# %%
ieeg_offset_row1_df = pd.read_excel("./data/ieeg_offset/row_1.xlsx", header=None)
ieeg_offset_row2_df = pd.read_excel("./data/ieeg_offset/row_2.xlsx", header=None)
ieeg_offset_row3_df = pd.read_excel("./data/ieeg_offset/row_3.xlsx", header=None)

# %%
# Load ./data/ieeg_starts.xlsx into a dataframe
ieeg_starts_df = pd.read_excel("./data/ieeg_starts.xlsx")
ieeg_starts_df
# Out:
#     hup_id  ieeg_start
# 0      225   38.024167
# 1      224   37.582778
# 2      223   32.985556
# 3      221   37.690000
# 4      219   33.396667
# ..     ...         ...
# 75     141   37.249444
# 76     140   35.197500
# 77     139   37.151667
# 78     138   37.529444
# 79     137   13.654444
#
# [80 rows x 2 columns]

# %%
eng = matlab.engine.start_matlab()
nina_path = eng.genpath("/Volumes/USERS/nghosn3/Pioneer/spikes-AED/aed_dose_modeling")
eng.addpath(nina_path, nargout=0)

# %%
get_aed_curve_kg_res = eng.get_aed_curve_kg(patient_hup_ids, patient_weights, nargout=4)
# Out:
# HUP138
# HUP138 has medications with NaN dose: lacosamide
# HUP140
# HUP141
# HUP141 has medications with NaN dose:
# HUP142
# HUP162
# HUP163
# HUP164
# HUP173
# HUP173 has medications with NaN dose:
# HUP181
# HUP185
# HUP185 has medications with NaN dose:
# HUP187
# HUP187 has medications with NaN dose:
# HUP190
# HUP190 has medications with NaN dose: clobazamclobazam
# HUP190 has medications with NaN dose:
# HUP202
#
# Unable to parse spd for SIG Take 15 mg (1.5 tablets) am and 30 mg (3 tablets) pm
# HUP202 has medications with NaN dose:
# HUP204
# HUP217
# HUP217 has medications with NaN dose:
# HUP219
# HUP219 has medications with NaN dose:
# HUP221
# HUP223
# HUP223 has medications with NaN dose:

# %%
dose_curves_res = get_aed_curve_kg_res[0]
tHr_res = get_aed_curve_kg_res[1]
med_names_res = get_aed_curve_kg_res[3]
assert (
    len(dose_curves_res) == len(tHr_res) == len(med_names_res) == len(patient_hup_ids)
)
print(len(dose_curves_res), len(tHr_res), len(med_names_res), len(patient_hup_ids))
# Out:
# 18 18 18 18

# %%
devin_path = eng.genpath("./matlab")
eng.addpath(devin_path, nargout=0)

# %% [markdown]
# ## Download

# %%
def create_pwd_file(username, password, fname=None):
    if fname is None:
        fname = "{}_ieeglogin.bin".format(username[:3])
    with open(fname, "wb") as f:
        f.write(password.encode())
    print("-- -- IEEG password file saved -- --")


create_pwd_file("dma", "mycqEv-pevfo4-roqfan")

with open("dma_ieeglogin.bin", "r") as f:
    session = Session("dma", f.read())
# Out:
# -- -- IEEG password file saved -- --

# %%
# Delete rows with hup_id == 138, 140, 181
patients_df = patients_df.drop(
    patients_df[patients_df["hup_id"].isin([138, 140, 181])].index
)
patients_df
# Out:
#     hup_id           region lateralization  weight_kg  r_id
# 2      141  mesial temporal          right       85.7   294
# 3      142  mesial temporal           left       65.3   295
# 4      162  mesial temporal           left       47.1   412
# 5      163  mesial temporal           left       82.1   279
# 6      164  mesial temporal           left       95.3   386
# 7      173  mesial temporal          right       76.6    31
# 9      185  mesial temporal           left       76.2   332
# 10     187  mesial temporal          right       86.2   522
# 11     190  mesial temporal           left      105.4   405
# 12     202  mesial temporal           left       89.0   646
# 13     204  mesial temporal           left       82.1   596
# 14     217  mesial temporal          right       58.5   679
# 15     219  mesial temporal          right      101.6   695
# 16     221  mesial temporal          right      124.3   621
# 17     223  mesial temporal           left      101.4   785

# %%
for i, row in patients_df.iterrows():
    # Get patient id and weight
    patient_hup_id, patient_weight = row.hup_id, row.weight_kg
    patient_idx = patient_hup_id_to_index[patient_hup_id]

    #########################################
    # Run matlab script
    #########################################
    # Find the ieeg_start value for patient_hup_id in ieeg_starts_df and convert it into float
    ieeg_start_hrs = float(
        ieeg_starts_df.loc[
            ieeg_starts_df["hup_id"] == patient_hup_id, "ieeg_start"
        ].values[0]
    )
    aligned_emu_start_time_hrs = round(ieeg_start_hrs)

    seizure_times_sec = np.array(
        eng.get_seizure_times(f"HUP{patient_hup_id}", nargout=2)[0]
    )
    seizure_times_sec = seizure_times_sec + (ieeg_start_hrs * 3600)

    #########################################
    # Get ieeg dataset name
    #########################################
    ieeg_dataset_names = []
    # Check if ieeg_offset_row1_df[patient_idx] is all NaNs
    if ieeg_offset_row1_df[patient_idx].isnull().values.all():
        ieeg_dataset_names = [f"HUP{patient_hup_id}_phaseII"]
    else:
        ieeg_dataset_names = ieeg_offset_row1_df[patient_idx].dropna().to_list()

    print(f"HUP{patient_hup_id} has {str(ieeg_dataset_names)} datasets")

    #########################################
    # Check tables
    #########################################

    if rid_hup_table_df.loc[rid_hup_table_df["hupsubjno"] == patient_hup_id].empty:
        print(f"HUP{patient_hup_id} has no info on rid_hup_table sheet")
        continue

    patient_rid = int(
        rid_hup_table_df.loc[rid_hup_table_df["hupsubjno"] == patient_hup_id].record_id
    )

    print(f"HUP{patient_hup_id} has rid {patient_rid}")

    patient_electrodes_df = master_elecs_df.loc[master_elecs_df["rid"] == patient_rid]

    if patient_electrodes_df.empty:
        print(f"HUP{patient_hup_id} has no info on master electrode sheet")
        continue

    #########################################
    # Get AED dose
    #########################################
    all_tHr = tHr_res[i]

    tmp = []
    for dose in all_tHr:
        dose = np.array(dose).flatten()
        tmp.append(dose)
    all_tHr_plot = np.array(tmp, dtype=object)

    assert all(
        [all_tHr_plot[i][-1] == all_tHr_plot[0][-1] for i in range(len(all_tHr_plot))]
    ), "The last element of each array in all_tHr_plot should be the same"

    # Construct the time axis
    emu_start_time_hrs = min([all_tHr_plot[i][0] for i in range(len(all_tHr_plot))])
    emu_end_time_hrs = all_tHr_plot[0][-1]
    max_dose_duration_hrs = emu_end_time_hrs - emu_start_time_hrs

    #########################################
    # Get iEEG data
    #########################################

    for dataset_idx, dataset_name in enumerate(ieeg_dataset_names):
        print(f"Opening {dataset_name}")

        #########################################
        # Get the useful channels
        #########################################
        ds = session.open_dataset(dataset_name)
        channel_labels = ds.get_channel_labels()
        channel_types_df = check_channel_types(channel_labels)

        seeg_electrodes_df = channel_types_df.loc[channel_types_df["type"] == "seeg"]

        # Find the rows in patient_electrodes_df that correspond to seeg_electrodes
        seeg_electrodes_df = patient_electrodes_df.loc[
            patient_electrodes_df["name"].isin(
                seeg_electrodes_df.name.to_numpy(dtype=str)
            )
        ]
        # Find the ones that have label not 'EmptyLabel'
        grey_matter_seeg_electrodes_df = seeg_electrodes_df.loc[
            seeg_electrodes_df["label"] != "EmptyLabel"
        ]

        # Find the indices of the names of the grey matter electrodes in channel_types_df
        grey_matter_seeg_electrodes_indices = channel_types_df.loc[
            channel_types_df["name"].isin(grey_matter_seeg_electrodes_df.name)
        ].copy()  # Added .copy() here to create a new DataFrame

        all_indices = grey_matter_seeg_electrodes_indices.name.to_numpy(dtype=str)

        #########################################
        # Get iEEG data
        #########################################

        for hour in range(int(max_dose_duration_hrs) + 1):
            print(f"Getting iEEG data for hour {hour}")
            duration_usec = 4.8e8  # 8 minute
            start_time_usec = hour * 3600 * 1e6
            stop_time_usec = start_time_usec + duration_usec

            try:
                local_res, sample_rate = get_iEEG_data(
                    "dma",
                    "dma_ieeglogin.bin",
                    dataset_name,
                    start_time_usec,
                    stop_time_usec,
                    select_electrodes=all_indices,
                )
            except Exception as e:
                # handle the exception
                break

            assert local_res.shape[1] == len(grey_matter_seeg_electrodes_indices)

            # Drop rows that has any nan
            local_res = local_res.dropna(axis=0, how="any")

            # Check if local_res is empty
            if not local_res.empty:
                # Try Save local_res to a pickle file
                with open(
                    f"/Users/devinma/8min/{dataset_name}_hr_{hour}_fs_{int(sample_rate)}.pkl",
                    "wb",
                ) as f:
                    pickle.dump(local_res, f)
# Out:
# HUP141 has ['HUP141_phaseII'] datasets
# HUP141 has rid 294
# Opening HUP141_phaseII
# Getting iEEG data for hour 0
# Getting iEEG data for hour 1
# Getting iEEG data for hour 2
# Getting iEEG data for hour 3
# Getting iEEG data for hour 4
# Getting iEEG data for hour 5
# Getting iEEG data for hour 6
# Getting iEEG data for hour 7
# Getting iEEG data for hour 8
# Getting iEEG data for hour 9
# Getting iEEG data for hour 10
# Getting iEEG data for hour 11
# Getting iEEG data for hour 12
# Getting iEEG data for hour 13
# Getting iEEG data for hour 14
# Getting iEEG data for hour 15
# Getting iEEG data for hour 16
# Getting iEEG data for hour 17
# Getting iEEG data for hour 18
# Getting iEEG data for hour 19
# Getting iEEG data for hour 20
# Getting iEEG data for hour 21
# Getting iEEG data for hour 22
# Getting iEEG data for hour 23
# Getting iEEG data for hour 24
# Getting iEEG data for hour 25
# Getting iEEG data for hour 26
# Getting iEEG data for hour 27
# Getting iEEG data for hour 28
# Getting iEEG data for hour 29
# Getting iEEG data for hour 30
# Getting iEEG data for hour 31
# Getting iEEG data for hour 32
# Getting iEEG data for hour 33
# Getting iEEG data for hour 34
# Getting iEEG data for hour 35
# Getting iEEG data for hour 36
# Getting iEEG data for hour 37
# Getting iEEG data for hour 38
# Getting iEEG data for hour 39
# Getting iEEG data for hour 40
# Getting iEEG data for hour 41
# Getting iEEG data for hour 42
# Getting iEEG data for hour 43
# Getting iEEG data for hour 44
# Getting iEEG data for hour 45
# Getting iEEG data for hour 46
# Getting iEEG data for hour 47
# Getting iEEG data for hour 48
# Getting iEEG data for hour 49
# Getting iEEG data for hour 50
# Getting iEEG data for hour 51
# Getting iEEG data for hour 52
# Getting iEEG data for hour 53
# Getting iEEG data for hour 54
# Getting iEEG data for hour 55
# Getting iEEG data for hour 56
# Getting iEEG data for hour 57
# Getting iEEG data for hour 58
# Getting iEEG data for hour 59
# Getting iEEG data for hour 60
# Getting iEEG data for hour 61
# Getting iEEG data for hour 62
# Getting iEEG data for hour 63
# Getting iEEG data for hour 64
# Getting iEEG data for hour 65
# Getting iEEG data for hour 66
# Getting iEEG data for hour 67
# Getting iEEG data for hour 68
# Getting iEEG data for hour 69
# Getting iEEG data for hour 70
# Getting iEEG data for hour 71
# Getting iEEG data for hour 72
# Getting iEEG data for hour 73
# Getting iEEG data for hour 74
# Getting iEEG data for hour 75
# Getting iEEG data for hour 76
# Getting iEEG data for hour 77
# Getting iEEG data for hour 78
# Getting iEEG data for hour 79
# Getting iEEG data for hour 80
# Getting iEEG data for hour 81
# Getting iEEG data for hour 82
# Getting iEEG data for hour 83
# Getting iEEG data for hour 84
# Getting iEEG data for hour 85
# Getting iEEG data for hour 86
# Getting iEEG data for hour 87
# Getting iEEG data for hour 88
# Getting iEEG data for hour 89
# Getting iEEG data for hour 90
# Getting iEEG data for hour 91
# Getting iEEG data for hour 92
# Getting iEEG data for hour 93
# Getting iEEG data for hour 94
# Getting iEEG data for hour 95
# Getting iEEG data for hour 96
# Getting iEEG data for hour 97
# Getting iEEG data for hour 98
# Getting iEEG data for hour 99
# Getting iEEG data for hour 100
# Getting iEEG data for hour 101
# Getting iEEG data for hour 102
# Getting iEEG data for hour 103
# Getting iEEG data for hour 104
# Getting iEEG data for hour 105
# Getting iEEG data for hour 106
# Getting iEEG data for hour 107
# Getting iEEG data for hour 108
# Getting iEEG data for hour 109
# Getting iEEG data for hour 110
# Getting iEEG data for hour 111
# Getting iEEG data for hour 112
# Getting iEEG data for hour 113
# Getting iEEG data for hour 114
# Getting iEEG data for hour 115
# Getting iEEG data for hour 116
# Getting iEEG data for hour 117
# Getting iEEG data for hour 118
# Getting iEEG data for hour 119
# Getting iEEG data for hour 120
# Getting iEEG data for hour 121
# Getting iEEG data for hour 122
# Getting iEEG data for hour 123
# Getting iEEG data for hour 124
# Getting iEEG data for hour 125
# Getting iEEG data for hour 126
# Getting iEEG data for hour 127
# Getting iEEG data for hour 128
# Getting iEEG data for hour 129
# Getting iEEG data for hour 130
# Getting iEEG data for hour 131
# Getting iEEG data for hour 132
# Getting iEEG data for hour 133
# Getting iEEG data for hour 134
# Getting iEEG data for hour 135
# Getting iEEG data for hour 136
# Getting iEEG data for hour 137
# Getting iEEG data for hour 138
# Getting iEEG data for hour 139
# Getting iEEG data for hour 140
# Getting iEEG data for hour 141
# Getting iEEG data for hour 142
# Getting iEEG data for hour 143
# Getting iEEG data for hour 144
# Getting iEEG data for hour 145
# Getting iEEG data for hour 146
# Getting iEEG data for hour 147
# Getting iEEG data for hour 148
# Getting iEEG data for hour 149
# Getting iEEG data for hour 150
# Getting iEEG data for hour 151
# Getting iEEG data for hour 152
# Getting iEEG data for hour 153
# Getting iEEG data for hour 154
# Getting iEEG data for hour 155
# Getting iEEG data for hour 156
# Getting iEEG data for hour 157
# Getting iEEG data for hour 158
# Getting iEEG data for hour 159
# Getting iEEG data for hour 160
# Getting iEEG data for hour 161
# Getting iEEG data for hour 162
# Getting iEEG data for hour 163
# Getting iEEG data for hour 164
# Getting iEEG data for hour 165
# Getting iEEG data for hour 166
# Getting iEEG data for hour 167
# Getting iEEG data for hour 168
# Getting iEEG data for hour 169
# Getting iEEG data for hour 170
# Getting iEEG data for hour 171
# Getting iEEG data for hour 172
# Getting iEEG data for hour 173
# Getting iEEG data for hour 174
# Getting iEEG data for hour 175
# Getting iEEG data for hour 176
# HUP142 has ['HUP142_phaseII'] datasets
# HUP142 has rid 295
# Opening HUP142_phaseII
# Getting iEEG data for hour 0
# Getting iEEG data for hour 1
# Getting iEEG data for hour 2
# Getting iEEG data for hour 3
# Getting iEEG data for hour 4
# Getting iEEG data for hour 5
# Getting iEEG data for hour 6
# Getting iEEG data for hour 7
# Getting iEEG data for hour 8
# Getting iEEG data for hour 9
# Getting iEEG data for hour 10
# Getting iEEG data for hour 11
# Getting iEEG data for hour 12
# Getting iEEG data for hour 13
# Getting iEEG data for hour 14
# Getting iEEG data for hour 15
# Getting iEEG data for hour 16
# Getting iEEG data for hour 17
# Getting iEEG data for hour 18
# Getting iEEG data for hour 19
# Getting iEEG data for hour 20
# Getting iEEG data for hour 21
# Getting iEEG data for hour 22
# Getting iEEG data for hour 23
# Getting iEEG data for hour 24
# Getting iEEG data for hour 25
# Getting iEEG data for hour 26
# Getting iEEG data for hour 27
# Getting iEEG data for hour 28
# Getting iEEG data for hour 29
# Getting iEEG data for hour 30
# Getting iEEG data for hour 31
# Getting iEEG data for hour 32
# Getting iEEG data for hour 33
# Getting iEEG data for hour 34
# Getting iEEG data for hour 35
# Getting iEEG data for hour 36
# Getting iEEG data for hour 37
# Getting iEEG data for hour 38
# Getting iEEG data for hour 39
# Getting iEEG data for hour 40
# Getting iEEG data for hour 41
# Getting iEEG data for hour 42
# Getting iEEG data for hour 43
# Getting iEEG data for hour 44
# Getting iEEG data for hour 45
# Getting iEEG data for hour 46
# Getting iEEG data for hour 47
# Getting iEEG data for hour 48
# Getting iEEG data for hour 49
# Getting iEEG data for hour 50
# Getting iEEG data for hour 51
# Getting iEEG data for hour 52
# Getting iEEG data for hour 53
# Getting iEEG data for hour 54
# Getting iEEG data for hour 55
# Getting iEEG data for hour 56
# Getting iEEG data for hour 57
# Getting iEEG data for hour 58
# Getting iEEG data for hour 59
# Getting iEEG data for hour 60
# Getting iEEG data for hour 61
# Getting iEEG data for hour 62
# Getting iEEG data for hour 63
# Getting iEEG data for hour 64
# Getting iEEG data for hour 65
# Getting iEEG data for hour 66
# Getting iEEG data for hour 67
# Getting iEEG data for hour 68
# Getting iEEG data for hour 69
# Getting iEEG data for hour 70
# Getting iEEG data for hour 71
# Getting iEEG data for hour 72
# Getting iEEG data for hour 73
# Getting iEEG data for hour 74
# Getting iEEG data for hour 75
# Getting iEEG data for hour 76
# Getting iEEG data for hour 77
# Getting iEEG data for hour 78
# Getting iEEG data for hour 79
# Getting iEEG data for hour 80
# Getting iEEG data for hour 81
# Getting iEEG data for hour 82
# Getting iEEG data for hour 83
# Getting iEEG data for hour 84
# Getting iEEG data for hour 85
# Getting iEEG data for hour 86
# Getting iEEG data for hour 87
# Getting iEEG data for hour 88
# Getting iEEG data for hour 89
# Getting iEEG data for hour 90
# Getting iEEG data for hour 91
# Getting iEEG data for hour 92
# Getting iEEG data for hour 93
# Getting iEEG data for hour 94
# Getting iEEG data for hour 95
# Getting iEEG data for hour 96
# Getting iEEG data for hour 97
# Getting iEEG data for hour 98
# Getting iEEG data for hour 99
# Getting iEEG data for hour 100
# Getting iEEG data for hour 101
# Getting iEEG data for hour 102
# Getting iEEG data for hour 103
# Getting iEEG data for hour 104
# Getting iEEG data for hour 105
# Getting iEEG data for hour 106
# Getting iEEG data for hour 107
# Getting iEEG data for hour 108
# Getting iEEG data for hour 109
# Getting iEEG data for hour 110
# Getting iEEG data for hour 111
# Getting iEEG data for hour 112
# Getting iEEG data for hour 113
# Getting iEEG data for hour 114
# Getting iEEG data for hour 115
# Getting iEEG data for hour 116
# Getting iEEG data for hour 117
# Getting iEEG data for hour 118
# Getting iEEG data for hour 119
# Getting iEEG data for hour 120
# Getting iEEG data for hour 121
# Getting iEEG data for hour 122
# Getting iEEG data for hour 123
# Getting iEEG data for hour 124
# Getting iEEG data for hour 125
# Getting iEEG data for hour 126
# Getting iEEG data for hour 127
# Getting iEEG data for hour 128
# Getting iEEG data for hour 129
# Getting iEEG data for hour 130
# Getting iEEG data for hour 131
# Getting iEEG data for hour 132
# Getting iEEG data for hour 133
# Getting iEEG data for hour 134
# Getting iEEG data for hour 135
# Getting iEEG data for hour 136
# Getting iEEG data for hour 137
# Getting iEEG data for hour 138
# Getting iEEG data for hour 139
# Getting iEEG data for hour 140
# Getting iEEG data for hour 141
# Getting iEEG data for hour 142
# Getting iEEG data for hour 143
# Getting iEEG data for hour 144
# Getting iEEG data for hour 145
# Getting iEEG data for hour 146
# Getting iEEG data for hour 147
# Getting iEEG data for hour 148
# Getting iEEG data for hour 149
# Getting iEEG data for hour 150
# Getting iEEG data for hour 151
# Getting iEEG data for hour 152
# Getting iEEG data for hour 153
# Getting iEEG data for hour 154
# Getting iEEG data for hour 155
# Getting iEEG data for hour 156
# Getting iEEG data for hour 157
# Getting iEEG data for hour 158
# Getting iEEG data for hour 159
# Getting iEEG data for hour 160
# Getting iEEG data for hour 161
# Getting iEEG data for hour 162
# Getting iEEG data for hour 163
# Getting iEEG data for hour 164
# Getting iEEG data for hour 165
# Getting iEEG data for hour 166
# Getting iEEG data for hour 167
# Getting iEEG data for hour 168
# Getting iEEG data for hour 169
# Getting iEEG data for hour 170
# Getting iEEG data for hour 171
# Getting iEEG data for hour 172
# Getting iEEG data for hour 173
# Getting iEEG data for hour 174
# Getting iEEG data for hour 175
# Getting iEEG data for hour 176
# Getting iEEG data for hour 177
# Getting iEEG data for hour 178
# Getting iEEG data for hour 179
# Getting iEEG data for hour 180
# Getting iEEG data for hour 181
# Getting iEEG data for hour 182
# Getting iEEG data for hour 183
# Getting iEEG data for hour 184
# Getting iEEG data for hour 185
# Getting iEEG data for hour 186
# Getting iEEG data for hour 187
# Getting iEEG data for hour 188
# Getting iEEG data for hour 189
# Getting iEEG data for hour 190
# Getting iEEG data for hour 191
# Getting iEEG data for hour 192
# Getting iEEG data for hour 193
# Getting iEEG data for hour 194
# Getting iEEG data for hour 195
# Getting iEEG data for hour 196
# Getting iEEG data for hour 197
# Getting iEEG data for hour 198
# Getting iEEG data for hour 199
# Getting iEEG data for hour 200
# Getting iEEG data for hour 201
# Getting iEEG data for hour 202
# Getting iEEG data for hour 203
# Getting iEEG data for hour 204
# Getting iEEG data for hour 205
# Getting iEEG data for hour 206
# Getting iEEG data for hour 207
# Getting iEEG data for hour 208
# Getting iEEG data for hour 209
# Getting iEEG data for hour 210
# Getting iEEG data for hour 211
# Getting iEEG data for hour 212
# Getting iEEG data for hour 213
# Getting iEEG data for hour 214
# Getting iEEG data for hour 215
# Getting iEEG data for hour 216
# Getting iEEG data for hour 217
# Getting iEEG data for hour 218
# Getting iEEG data for hour 219
# Getting iEEG data for hour 220
# Getting iEEG data for hour 221
# Getting iEEG data for hour 222
# Getting iEEG data for hour 223
# Getting iEEG data for hour 224
# Getting iEEG data for hour 225
# Getting iEEG data for hour 226
# Getting iEEG data for hour 227
# Getting iEEG data for hour 228
# Getting iEEG data for hour 229
# Getting iEEG data for hour 230
# Getting iEEG data for hour 231
# Getting iEEG data for hour 232
# Getting iEEG data for hour 233
# Getting iEEG data for hour 234
# Getting iEEG data for hour 235
# Getting iEEG data for hour 236
# Getting iEEG data for hour 237
# Getting iEEG data for hour 238
# Getting iEEG data for hour 239
# Getting iEEG data for hour 240
# Getting iEEG data for hour 241
# Getting iEEG data for hour 242
# Getting iEEG data for hour 243
# Getting iEEG data for hour 244
# Getting iEEG data for hour 245
# Getting iEEG data for hour 246
# Getting iEEG data for hour 247
# Getting iEEG data for hour 248
# Getting iEEG data for hour 249
# Getting iEEG data for hour 250
# Getting iEEG data for hour 251
# Getting iEEG data for hour 252
# Getting iEEG data for hour 253
# Getting iEEG data for hour 254
# Getting iEEG data for hour 255
# Getting iEEG data for hour 256
# Getting iEEG data for hour 257
# Getting iEEG data for hour 258
# Getting iEEG data for hour 259
# Getting iEEG data for hour 260
# Getting iEEG data for hour 261
# Getting iEEG data for hour 262
# Getting iEEG data for hour 263
# Getting iEEG data for hour 264
# Getting iEEG data for hour 265
# Getting iEEG data for hour 266
# Getting iEEG data for hour 267
# Getting iEEG data for hour 268
# Getting iEEG data for hour 269
# Getting iEEG data for hour 270
# Getting iEEG data for hour 271
# Getting iEEG data for hour 272
# Getting iEEG data for hour 273
# Getting iEEG data for hour 274
# Getting iEEG data for hour 275
# Getting iEEG data for hour 276
# Getting iEEG data for hour 277
# Getting iEEG data for hour 278
# Getting iEEG data for hour 279
# Getting iEEG data for hour 280
# Getting iEEG data for hour 281
# Getting iEEG data for hour 282
# Getting iEEG data for hour 283
# Getting iEEG data for hour 284
# Getting iEEG data for hour 285
# Getting iEEG data for hour 286
# Getting iEEG data for hour 287
# Getting iEEG data for hour 288
# Getting iEEG data for hour 289
# Getting iEEG data for hour 290
# Getting iEEG data for hour 291
# Getting iEEG data for hour 292
# Getting iEEG data for hour 293
# Getting iEEG data for hour 294
# Getting iEEG data for hour 295
# Getting iEEG data for hour 296
# Getting iEEG data for hour 297
# Getting iEEG data for hour 298
# Getting iEEG data for hour 299
# Getting iEEG data for hour 300
# Getting iEEG data for hour 301
# Getting iEEG data for hour 302
# Getting iEEG data for hour 303
# Getting iEEG data for hour 304
# Getting iEEG data for hour 305
# Getting iEEG data for hour 306
# Getting iEEG data for hour 307
# Getting iEEG data for hour 308
# Getting iEEG data for hour 309
# Getting iEEG data for hour 310
# Getting iEEG data for hour 311
# Getting iEEG data for hour 312
# Getting iEEG data for hour 313
# Getting iEEG data for hour 314
# Getting iEEG data for hour 315
# Getting iEEG data for hour 316
# Getting iEEG data for hour 317
# Getting iEEG data for hour 318
# Getting iEEG data for hour 319
# Getting iEEG data for hour 320
# Getting iEEG data for hour 321
# Getting iEEG data for hour 322
# Getting iEEG data for hour 323
# Getting iEEG data for hour 324
# Getting iEEG data for hour 325
# Getting iEEG data for hour 326
# Getting iEEG data for hour 327
# Getting iEEG data for hour 328
# Getting iEEG data for hour 329
# Getting iEEG data for hour 330
# Getting iEEG data for hour 331
# Getting iEEG data for hour 332
# Getting iEEG data for hour 333
# Getting iEEG data for hour 334
# Getting iEEG data for hour 335
# Getting iEEG data for hour 336
# Getting iEEG data for hour 337
# Getting iEEG data for hour 338
# HUP162 has ['HUP162_phaseII'] datasets
# HUP162 has rid 412
# HUP162 has no info on master electrode sheet
# HUP163 has ['HUP163_phaseII'] datasets
# HUP163 has rid 279
# HUP163 has no info on master electrode sheet
# HUP164 has ['HUP164_phaseII'] datasets
# HUP164 has rid 386
# HUP164 has no info on master electrode sheet
# HUP173 has ['HUP173_phaseII'] datasets
# HUP173 has rid 31
# Opening HUP173_phaseII
# Getting iEEG data for hour 0
# Getting iEEG data for hour 1
# Getting iEEG data for hour 2
# Getting iEEG data for hour 3
# Getting iEEG data for hour 4
# Getting iEEG data for hour 5
# Getting iEEG data for hour 6
# Getting iEEG data for hour 7
# Getting iEEG data for hour 8
# Getting iEEG data for hour 9
# Getting iEEG data for hour 10
# Getting iEEG data for hour 11
# Getting iEEG data for hour 12
# Getting iEEG data for hour 13
# Getting iEEG data for hour 14
# Getting iEEG data for hour 15
# Getting iEEG data for hour 16
# Getting iEEG data for hour 17
# Getting iEEG data for hour 18
# Getting iEEG data for hour 19
# Getting iEEG data for hour 20
# Getting iEEG data for hour 21
# Getting iEEG data for hour 22
# Getting iEEG data for hour 23
# Getting iEEG data for hour 24
# Getting iEEG data for hour 25
# Getting iEEG data for hour 26
# Getting iEEG data for hour 27
# Getting iEEG data for hour 28
# Getting iEEG data for hour 29
# Getting iEEG data for hour 30
# Getting iEEG data for hour 31
# Getting iEEG data for hour 32
# Getting iEEG data for hour 33
# Getting iEEG data for hour 34
# Getting iEEG data for hour 35
# Getting iEEG data for hour 36
# Getting iEEG data for hour 37
# Getting iEEG data for hour 38
# Getting iEEG data for hour 39
# Getting iEEG data for hour 40
# Getting iEEG data for hour 41
# Getting iEEG data for hour 42
# Getting iEEG data for hour 43
# Getting iEEG data for hour 44
# Getting iEEG data for hour 45
# Getting iEEG data for hour 46
# Getting iEEG data for hour 47
# Getting iEEG data for hour 48
# Getting iEEG data for hour 49
# Getting iEEG data for hour 50
# Getting iEEG data for hour 51
# Getting iEEG data for hour 52
# Getting iEEG data for hour 53
# Getting iEEG data for hour 54
# Getting iEEG data for hour 55
# Getting iEEG data for hour 56
# Getting iEEG data for hour 57
# Getting iEEG data for hour 58
# Getting iEEG data for hour 59
# Getting iEEG data for hour 60
# Getting iEEG data for hour 61
# Getting iEEG data for hour 62
# Getting iEEG data for hour 63
# Getting iEEG data for hour 64
# Getting iEEG data for hour 65
# Getting iEEG data for hour 66
# Getting iEEG data for hour 67
# Getting iEEG data for hour 68
# Getting iEEG data for hour 69
# Getting iEEG data for hour 70
# Getting iEEG data for hour 71
# Getting iEEG data for hour 72
# Getting iEEG data for hour 73
# Getting iEEG data for hour 74
# Getting iEEG data for hour 75
# Getting iEEG data for hour 76
# Getting iEEG data for hour 77
# Getting iEEG data for hour 78
# Getting iEEG data for hour 79
# Getting iEEG data for hour 80
# Getting iEEG data for hour 81
# Getting iEEG data for hour 82
# Getting iEEG data for hour 83
# Getting iEEG data for hour 84
# Getting iEEG data for hour 85
# Getting iEEG data for hour 86
# Getting iEEG data for hour 87
# Getting iEEG data for hour 88
# Getting iEEG data for hour 89
# Getting iEEG data for hour 90
# Getting iEEG data for hour 91
# Getting iEEG data for hour 92
# Getting iEEG data for hour 93
# Getting iEEG data for hour 94
# Getting iEEG data for hour 95
# Getting iEEG data for hour 96
# Getting iEEG data for hour 97
# Getting iEEG data for hour 98
# Getting iEEG data for hour 99
# Getting iEEG data for hour 100
# Getting iEEG data for hour 101
# Getting iEEG data for hour 102
# Getting iEEG data for hour 103
# Getting iEEG data for hour 104
# Getting iEEG data for hour 105
# Getting iEEG data for hour 106
# Getting iEEG data for hour 107
# Getting iEEG data for hour 108
# Getting iEEG data for hour 109
# Getting iEEG data for hour 110
# Getting iEEG data for hour 111
# Getting iEEG data for hour 112
# Getting iEEG data for hour 113
# Getting iEEG data for hour 114
# Getting iEEG data for hour 115
# Getting iEEG data for hour 116
# Getting iEEG data for hour 117
# Getting iEEG data for hour 118
# Getting iEEG data for hour 119
# Getting iEEG data for hour 120
# Getting iEEG data for hour 121
# Getting iEEG data for hour 122
# Getting iEEG data for hour 123
# Getting iEEG data for hour 124
# Getting iEEG data for hour 125
# Getting iEEG data for hour 126
# Getting iEEG data for hour 127
# Getting iEEG data for hour 128
# Getting iEEG data for hour 129
# Getting iEEG data for hour 130
# Getting iEEG data for hour 131
# Getting iEEG data for hour 132
# Getting iEEG data for hour 133
# Getting iEEG data for hour 134
# Getting iEEG data for hour 135
# Getting iEEG data for hour 136
# Getting iEEG data for hour 137
# Getting iEEG data for hour 138
# Getting iEEG data for hour 139
# Getting iEEG data for hour 140
# Getting iEEG data for hour 141
# Getting iEEG data for hour 142
# Getting iEEG data for hour 143
# Getting iEEG data for hour 144
# Getting iEEG data for hour 145
# Getting iEEG data for hour 146
# Getting iEEG data for hour 147
# Getting iEEG data for hour 148
# Getting iEEG data for hour 149
# Getting iEEG data for hour 150
# Getting iEEG data for hour 151
# Getting iEEG data for hour 152
# Getting iEEG data for hour 153
# Getting iEEG data for hour 154
# Getting iEEG data for hour 155
# Getting iEEG data for hour 156
# Getting iEEG data for hour 157
# Getting iEEG data for hour 158
# Getting iEEG data for hour 159
# Getting iEEG data for hour 160
# Getting iEEG data for hour 161
# Getting iEEG data for hour 162
# Getting iEEG data for hour 163
# Getting iEEG data for hour 164
# Getting iEEG data for hour 165
# Getting iEEG data for hour 166
# Getting iEEG data for hour 167
# Getting iEEG data for hour 168
# Getting iEEG data for hour 169
# Getting iEEG data for hour 170
# Getting iEEG data for hour 171
# Getting iEEG data for hour 172
# Getting iEEG data for hour 173
# Getting iEEG data for hour 174
# Getting iEEG data for hour 175
# Getting iEEG data for hour 176
# Getting iEEG data for hour 177
# Getting iEEG data for hour 178
# Getting iEEG data for hour 179
# Getting iEEG data for hour 180
# Getting iEEG data for hour 181
# Getting iEEG data for hour 182
# Getting iEEG data for hour 183
# Getting iEEG data for hour 184
# Getting iEEG data for hour 185
# Getting iEEG data for hour 186
# Getting iEEG data for hour 187
# Getting iEEG data for hour 188
# Getting iEEG data for hour 189
# Getting iEEG data for hour 190
# Getting iEEG data for hour 191
# Getting iEEG data for hour 192
# Getting iEEG data for hour 193
# Getting iEEG data for hour 194
# Getting iEEG data for hour 195
# Getting iEEG data for hour 196
# Getting iEEG data for hour 197
# Getting iEEG data for hour 198
# Getting iEEG data for hour 199
# Getting iEEG data for hour 200
# Getting iEEG data for hour 201
# Getting iEEG data for hour 202
# Getting iEEG data for hour 203
# Getting iEEG data for hour 204
# Getting iEEG data for hour 205
# Getting iEEG data for hour 206
# Getting iEEG data for hour 207
# Getting iEEG data for hour 208
# Getting iEEG data for hour 209
# Getting iEEG data for hour 210
# Getting iEEG data for hour 211
# Getting iEEG data for hour 212
# Getting iEEG data for hour 213
# Getting iEEG data for hour 214
# Getting iEEG data for hour 215
# Getting iEEG data for hour 216
# Getting iEEG data for hour 217
# Getting iEEG data for hour 218
# Getting iEEG data for hour 219
# Getting iEEG data for hour 220
# Getting iEEG data for hour 221
# Getting iEEG data for hour 222
# Getting iEEG data for hour 223
# Getting iEEG data for hour 224
# Getting iEEG data for hour 225
# Getting iEEG data for hour 226
# Getting iEEG data for hour 227
# Getting iEEG data for hour 228
# Getting iEEG data for hour 229
# Getting iEEG data for hour 230
# Getting iEEG data for hour 231
# Getting iEEG data for hour 232
# Getting iEEG data for hour 233
# Getting iEEG data for hour 234
# Getting iEEG data for hour 235
# Getting iEEG data for hour 236
# Getting iEEG data for hour 237
# Getting iEEG data for hour 238
# Getting iEEG data for hour 239
# Getting iEEG data for hour 240
# Getting iEEG data for hour 241
# Getting iEEG data for hour 242
# Getting iEEG data for hour 243
# Getting iEEG data for hour 244
# Getting iEEG data for hour 245
# Getting iEEG data for hour 246
# Getting iEEG data for hour 247
# Getting iEEG data for hour 248
# Getting iEEG data for hour 249
# Getting iEEG data for hour 250
# Getting iEEG data for hour 251
# Getting iEEG data for hour 252
# Getting iEEG data for hour 253
# Getting iEEG data for hour 254
# Getting iEEG data for hour 255
# Getting iEEG data for hour 256
# Getting iEEG data for hour 257
# Getting iEEG data for hour 258
# Getting iEEG data for hour 259
# Getting iEEG data for hour 260
# Getting iEEG data for hour 261
# Getting iEEG data for hour 262
# Getting iEEG data for hour 263
# Getting iEEG data for hour 264
# Getting iEEG data for hour 265
# Getting iEEG data for hour 266
# Getting iEEG data for hour 267
# HUP185 has ['HUP185_phaseII'] datasets
# HUP185 has rid 332
# Opening HUP185_phaseII
# Getting iEEG data for hour 0
# Getting iEEG data for hour 1
# Getting iEEG data for hour 2
# Getting iEEG data for hour 3
# Getting iEEG data for hour 4
# Getting iEEG data for hour 5
# Getting iEEG data for hour 6
# Getting iEEG data for hour 7
# Getting iEEG data for hour 8
# Getting iEEG data for hour 9
# Getting iEEG data for hour 10
# Getting iEEG data for hour 11
# Getting iEEG data for hour 12
# Getting iEEG data for hour 13
# Getting iEEG data for hour 14
# Getting iEEG data for hour 15
# Getting iEEG data for hour 16
# Getting iEEG data for hour 17
# Getting iEEG data for hour 18
# Getting iEEG data for hour 19
# Getting iEEG data for hour 20
# Getting iEEG data for hour 21
# Getting iEEG data for hour 22
# Getting iEEG data for hour 23
# Getting iEEG data for hour 24
# Getting iEEG data for hour 25
# Getting iEEG data for hour 26
# Getting iEEG data for hour 27
# Getting iEEG data for hour 28
# Getting iEEG data for hour 29
# Getting iEEG data for hour 30
# Getting iEEG data for hour 31
# Getting iEEG data for hour 32
# Getting iEEG data for hour 33
# Getting iEEG data for hour 34
# Getting iEEG data for hour 35
# Getting iEEG data for hour 36
# Getting iEEG data for hour 37
# Getting iEEG data for hour 38
# Getting iEEG data for hour 39
# Getting iEEG data for hour 40
# Getting iEEG data for hour 41
# Getting iEEG data for hour 42
# Getting iEEG data for hour 43
# Getting iEEG data for hour 44
# Getting iEEG data for hour 45
# Getting iEEG data for hour 46
# Getting iEEG data for hour 47
# Getting iEEG data for hour 48
# Getting iEEG data for hour 49
# Getting iEEG data for hour 50
# Getting iEEG data for hour 51
# Getting iEEG data for hour 52
# Getting iEEG data for hour 53
# Getting iEEG data for hour 54
# Getting iEEG data for hour 55
# Getting iEEG data for hour 56
# Getting iEEG data for hour 57
# Getting iEEG data for hour 58
# Getting iEEG data for hour 59
# Getting iEEG data for hour 60
# Getting iEEG data for hour 61
# Getting iEEG data for hour 62
# Getting iEEG data for hour 63
# Getting iEEG data for hour 64
# Getting iEEG data for hour 65
# Getting iEEG data for hour 66
# Getting iEEG data for hour 67
# Getting iEEG data for hour 68
# Getting iEEG data for hour 69
# Getting iEEG data for hour 70
# Getting iEEG data for hour 71
# Getting iEEG data for hour 72
# Getting iEEG data for hour 73
# Getting iEEG data for hour 74
# Getting iEEG data for hour 75
# Getting iEEG data for hour 76
# Getting iEEG data for hour 77
# Getting iEEG data for hour 78
# Getting iEEG data for hour 79
# Getting iEEG data for hour 80
# Getting iEEG data for hour 81
# Getting iEEG data for hour 82
# Getting iEEG data for hour 83
# Getting iEEG data for hour 84
# Getting iEEG data for hour 85
# Getting iEEG data for hour 86
# Getting iEEG data for hour 87
# Getting iEEG data for hour 88
# Getting iEEG data for hour 89
# Getting iEEG data for hour 90
# Getting iEEG data for hour 91
# Getting iEEG data for hour 92
# Getting iEEG data for hour 93
# Getting iEEG data for hour 94
# Getting iEEG data for hour 95
# Getting iEEG data for hour 96
# Getting iEEG data for hour 97
# Getting iEEG data for hour 98
# Getting iEEG data for hour 99
# Getting iEEG data for hour 100
# Getting iEEG data for hour 101
# Getting iEEG data for hour 102
# Getting iEEG data for hour 103
# Getting iEEG data for hour 104
# Getting iEEG data for hour 105
# Getting iEEG data for hour 106
# Getting iEEG data for hour 107
# Getting iEEG data for hour 108
# Getting iEEG data for hour 109
# Getting iEEG data for hour 110
# Getting iEEG data for hour 111
# Getting iEEG data for hour 112
# Getting iEEG data for hour 113
# Getting iEEG data for hour 114
# Getting iEEG data for hour 115
# Getting iEEG data for hour 116
# Getting iEEG data for hour 117
# Getting iEEG data for hour 118
# Getting iEEG data for hour 119
# Getting iEEG data for hour 120
# Getting iEEG data for hour 121
# Getting iEEG data for hour 122
# Getting iEEG data for hour 123
# Getting iEEG data for hour 124
# Getting iEEG data for hour 125
# Getting iEEG data for hour 126
# Getting iEEG data for hour 127
# Getting iEEG data for hour 128
# Getting iEEG data for hour 129
# Getting iEEG data for hour 130
# Getting iEEG data for hour 131
# Getting iEEG data for hour 132
# Getting iEEG data for hour 133
# Getting iEEG data for hour 134
# Getting iEEG data for hour 135
# Getting iEEG data for hour 136
# Getting iEEG data for hour 137
# Getting iEEG data for hour 138
# Getting iEEG data for hour 139
# Getting iEEG data for hour 140
# Getting iEEG data for hour 141
# Getting iEEG data for hour 142
# Getting iEEG data for hour 143
# Getting iEEG data for hour 144
# Getting iEEG data for hour 145
# Getting iEEG data for hour 146
# Getting iEEG data for hour 147
# Getting iEEG data for hour 148
# Getting iEEG data for hour 149
# Getting iEEG data for hour 150
# Getting iEEG data for hour 151
# Getting iEEG data for hour 152
# Getting iEEG data for hour 153
# Getting iEEG data for hour 154
# Getting iEEG data for hour 155
# Getting iEEG data for hour 156
# Getting iEEG data for hour 157
# Getting iEEG data for hour 158
# Getting iEEG data for hour 159
# Getting iEEG data for hour 160
# Getting iEEG data for hour 161
# Getting iEEG data for hour 162
# Getting iEEG data for hour 163
# Getting iEEG data for hour 164
# Getting iEEG data for hour 165
# Getting iEEG data for hour 166
# Getting iEEG data for hour 167
# Getting iEEG data for hour 168
# Getting iEEG data for hour 169
# Getting iEEG data for hour 170
# Getting iEEG data for hour 171
# Getting iEEG data for hour 172
# Getting iEEG data for hour 173
# Getting iEEG data for hour 174
# Getting iEEG data for hour 175
# Getting iEEG data for hour 176
# Getting iEEG data for hour 177
# Getting iEEG data for hour 178
# Getting iEEG data for hour 179
# Getting iEEG data for hour 180
# Getting iEEG data for hour 181
# Getting iEEG data for hour 182
# Getting iEEG data for hour 183
# Getting iEEG data for hour 184
# Getting iEEG data for hour 185
# Getting iEEG data for hour 186
# Getting iEEG data for hour 187
# Getting iEEG data for hour 188
# Getting iEEG data for hour 189
# Getting iEEG data for hour 190
# Getting iEEG data for hour 191
# Getting iEEG data for hour 192
# Getting iEEG data for hour 193
# Getting iEEG data for hour 194
# Getting iEEG data for hour 195
# Getting iEEG data for hour 196
# Getting iEEG data for hour 197
# Getting iEEG data for hour 198
# Getting iEEG data for hour 199
# Getting iEEG data for hour 200
# Getting iEEG data for hour 201
# Getting iEEG data for hour 202
# Getting iEEG data for hour 203
# Getting iEEG data for hour 204
# Getting iEEG data for hour 205
# Getting iEEG data for hour 206
# Getting iEEG data for hour 207
# Getting iEEG data for hour 208
# Getting iEEG data for hour 209
# Getting iEEG data for hour 210
# Getting iEEG data for hour 211
# Getting iEEG data for hour 212
# Getting iEEG data for hour 213
# Getting iEEG data for hour 214
# Getting iEEG data for hour 215
# Getting iEEG data for hour 216
# Getting iEEG data for hour 217
# Getting iEEG data for hour 218
# Getting iEEG data for hour 219
# Getting iEEG data for hour 220
# Getting iEEG data for hour 221
# Getting iEEG data for hour 222
# Getting iEEG data for hour 223
# Getting iEEG data for hour 224
# Getting iEEG data for hour 225
# Getting iEEG data for hour 226
# Getting iEEG data for hour 227
# Getting iEEG data for hour 228
# Getting iEEG data for hour 229
# Getting iEEG data for hour 230
# Getting iEEG data for hour 231
# Getting iEEG data for hour 232
# Getting iEEG data for hour 233
# Getting iEEG data for hour 234
# Getting iEEG data for hour 235
# Getting iEEG data for hour 236
# Getting iEEG data for hour 237
# Getting iEEG data for hour 238
# Getting iEEG data for hour 239
# Getting iEEG data for hour 240
# Getting iEEG data for hour 241
# Getting iEEG data for hour 242
# Getting iEEG data for hour 243
# Getting iEEG data for hour 244
# Getting iEEG data for hour 245
# Getting iEEG data for hour 246
# Getting iEEG data for hour 247
# Getting iEEG data for hour 248
# Getting iEEG data for hour 249
# Getting iEEG data for hour 250
# Getting iEEG data for hour 251
# Getting iEEG data for hour 252
# Getting iEEG data for hour 253
# Getting iEEG data for hour 254
# Getting iEEG data for hour 255
# Getting iEEG data for hour 256
# Getting iEEG data for hour 257
# Getting iEEG data for hour 258
# Getting iEEG data for hour 259
# Getting iEEG data for hour 260
# Getting iEEG data for hour 261
# Getting iEEG data for hour 262
# Getting iEEG data for hour 263
# Getting iEEG data for hour 264
# Getting iEEG data for hour 265
# Getting iEEG data for hour 266
# Getting iEEG data for hour 267
# HUP187 has ['HUP187_phaseII'] datasets
# HUP187 has rid 522
# Opening HUP187_phaseII
# Getting iEEG data for hour 0
# Getting iEEG data for hour 1
# Getting iEEG data for hour 2
# Getting iEEG data for hour 3
# Getting iEEG data for hour 4
# Getting iEEG data for hour 5
# Getting iEEG data for hour 6
# Getting iEEG data for hour 7
# Getting iEEG data for hour 8
# Getting iEEG data for hour 9
# Getting iEEG data for hour 10
# Getting iEEG data for hour 11
# Getting iEEG data for hour 12
# Getting iEEG data for hour 13
# Getting iEEG data for hour 14
# Getting iEEG data for hour 15
# Getting iEEG data for hour 16
# Getting iEEG data for hour 17
# Getting iEEG data for hour 18
# Getting iEEG data for hour 19
# Getting iEEG data for hour 20
# Getting iEEG data for hour 21
# Getting iEEG data for hour 22
# Getting iEEG data for hour 23
# Getting iEEG data for hour 24
# Getting iEEG data for hour 25
# Getting iEEG data for hour 26
# Getting iEEG data for hour 27
# Getting iEEG data for hour 28
# Getting iEEG data for hour 29
# Getting iEEG data for hour 30
# Getting iEEG data for hour 31
# Getting iEEG data for hour 32
# Getting iEEG data for hour 33
# Getting iEEG data for hour 34
# Getting iEEG data for hour 35
# Getting iEEG data for hour 36
# Getting iEEG data for hour 37
# Getting iEEG data for hour 38
# Getting iEEG data for hour 39
# Getting iEEG data for hour 40
# Getting iEEG data for hour 41
# Getting iEEG data for hour 42
# Getting iEEG data for hour 43
# Getting iEEG data for hour 44
# Getting iEEG data for hour 45
# Getting iEEG data for hour 46
# Getting iEEG data for hour 47
# Getting iEEG data for hour 48
# Getting iEEG data for hour 49
# Getting iEEG data for hour 50
# Getting iEEG data for hour 51
# Getting iEEG data for hour 52
# Getting iEEG data for hour 53
# Getting iEEG data for hour 54
# Getting iEEG data for hour 55
# Getting iEEG data for hour 56
# Getting iEEG data for hour 57
# Getting iEEG data for hour 58
# Getting iEEG data for hour 59
# Getting iEEG data for hour 60
# Getting iEEG data for hour 61
# Getting iEEG data for hour 62
# Getting iEEG data for hour 63
# Getting iEEG data for hour 64
# Getting iEEG data for hour 65
# Getting iEEG data for hour 66
# Getting iEEG data for hour 67
# Getting iEEG data for hour 68
# Getting iEEG data for hour 69
# Getting iEEG data for hour 70
# Getting iEEG data for hour 71
# Getting iEEG data for hour 72
# Getting iEEG data for hour 73
# Getting iEEG data for hour 74
# Getting iEEG data for hour 75
# Getting iEEG data for hour 76
# Getting iEEG data for hour 77
# Getting iEEG data for hour 78
# Getting iEEG data for hour 79
# Getting iEEG data for hour 80
# Getting iEEG data for hour 81
# Getting iEEG data for hour 82
# Getting iEEG data for hour 83
# Getting iEEG data for hour 84
# Getting iEEG data for hour 85
# Getting iEEG data for hour 86
# Getting iEEG data for hour 87
# Getting iEEG data for hour 88
# Getting iEEG data for hour 89
# Getting iEEG data for hour 90
# Getting iEEG data for hour 91
# Getting iEEG data for hour 92
# Getting iEEG data for hour 93
# Getting iEEG data for hour 94
# Getting iEEG data for hour 95
# Getting iEEG data for hour 96
# Getting iEEG data for hour 97
# Getting iEEG data for hour 98
# Getting iEEG data for hour 99
# Getting iEEG data for hour 100
# Getting iEEG data for hour 101
# Getting iEEG data for hour 102
# Getting iEEG data for hour 103
# Getting iEEG data for hour 104
# Getting iEEG data for hour 105
# Getting iEEG data for hour 106
# Getting iEEG data for hour 107
# Getting iEEG data for hour 108
# Getting iEEG data for hour 109
# Getting iEEG data for hour 110
# Getting iEEG data for hour 111
# Getting iEEG data for hour 112
# Getting iEEG data for hour 113
# Getting iEEG data for hour 114
# Getting iEEG data for hour 115
# Getting iEEG data for hour 116
# Getting iEEG data for hour 117
# Getting iEEG data for hour 118
# Getting iEEG data for hour 119
# Getting iEEG data for hour 120
# Getting iEEG data for hour 121
# Getting iEEG data for hour 122
# Getting iEEG data for hour 123
# Getting iEEG data for hour 124
# Getting iEEG data for hour 125
# Getting iEEG data for hour 126
# Getting iEEG data for hour 127
# Getting iEEG data for hour 128
# Getting iEEG data for hour 129
# Getting iEEG data for hour 130
# Getting iEEG data for hour 131
# Getting iEEG data for hour 132
# Getting iEEG data for hour 133
# Getting iEEG data for hour 134
# Getting iEEG data for hour 135
# Getting iEEG data for hour 136
# Getting iEEG data for hour 137
# Getting iEEG data for hour 138
# Getting iEEG data for hour 139
# Getting iEEG data for hour 140
# Getting iEEG data for hour 141
# Getting iEEG data for hour 142
# Getting iEEG data for hour 143
# Getting iEEG data for hour 144
# Getting iEEG data for hour 145
# Getting iEEG data for hour 146
# Getting iEEG data for hour 147
# Getting iEEG data for hour 148
# Getting iEEG data for hour 149
# Getting iEEG data for hour 150
# Getting iEEG data for hour 151
# Getting iEEG data for hour 152
# Getting iEEG data for hour 153
# Getting iEEG data for hour 154
# Getting iEEG data for hour 155
# Getting iEEG data for hour 156
# Getting iEEG data for hour 157
# Getting iEEG data for hour 158
# Getting iEEG data for hour 159
# Getting iEEG data for hour 160
# Getting iEEG data for hour 161
# Getting iEEG data for hour 162
# Getting iEEG data for hour 163
# Getting iEEG data for hour 164
# Getting iEEG data for hour 165
# Getting iEEG data for hour 166
# Getting iEEG data for hour 167
# Getting iEEG data for hour 168
# Getting iEEG data for hour 169
# Getting iEEG data for hour 170
# Getting iEEG data for hour 171
# Getting iEEG data for hour 172
# Getting iEEG data for hour 173
# Getting iEEG data for hour 174
# Getting iEEG data for hour 175
# Getting iEEG data for hour 176
# Getting iEEG data for hour 177
# Getting iEEG data for hour 178
# Getting iEEG data for hour 179
# Getting iEEG data for hour 180
# Getting iEEG data for hour 181
# Getting iEEG data for hour 182
# Getting iEEG data for hour 183
# Getting iEEG data for hour 184
# Getting iEEG data for hour 185
# HUP190 has ['HUP190_phaseII'] datasets
# HUP190 has rid 405
# Opening HUP190_phaseII
# Getting iEEG data for hour 0
# Getting iEEG data for hour 1
# Getting iEEG data for hour 2
# Getting iEEG data for hour 3
# Getting iEEG data for hour 4
# Getting iEEG data for hour 5
# Getting iEEG data for hour 6
# Getting iEEG data for hour 7
# Getting iEEG data for hour 8
# Getting iEEG data for hour 9
# Getting iEEG data for hour 10
# Getting iEEG data for hour 11
# Getting iEEG data for hour 12
# Getting iEEG data for hour 13
# Getting iEEG data for hour 14
# Getting iEEG data for hour 15
# Getting iEEG data for hour 16
# Getting iEEG data for hour 17
# Getting iEEG data for hour 18
# Getting iEEG data for hour 19
# Getting iEEG data for hour 20
# Getting iEEG data for hour 21
# Getting iEEG data for hour 22
# Getting iEEG data for hour 23
# Getting iEEG data for hour 24
# Getting iEEG data for hour 25
# Getting iEEG data for hour 26
# Getting iEEG data for hour 27
# Getting iEEG data for hour 28
# Getting iEEG data for hour 29
# Getting iEEG data for hour 30
# Getting iEEG data for hour 31
# Getting iEEG data for hour 32
# Getting iEEG data for hour 33
# Getting iEEG data for hour 34
# Getting iEEG data for hour 35
# Getting iEEG data for hour 36
# Getting iEEG data for hour 37
# Getting iEEG data for hour 38
# Getting iEEG data for hour 39
# Getting iEEG data for hour 40
# Getting iEEG data for hour 41
# Getting iEEG data for hour 42
# Getting iEEG data for hour 43
# Getting iEEG data for hour 44
# Getting iEEG data for hour 45
# Getting iEEG data for hour 46
# Getting iEEG data for hour 47
# Getting iEEG data for hour 48
# Getting iEEG data for hour 49
# Getting iEEG data for hour 50
# Getting iEEG data for hour 51
# Getting iEEG data for hour 52
# Getting iEEG data for hour 53
# Getting iEEG data for hour 54
# Getting iEEG data for hour 55
# Getting iEEG data for hour 56
# Getting iEEG data for hour 57
# Getting iEEG data for hour 58
# Getting iEEG data for hour 59
# Getting iEEG data for hour 60
# Getting iEEG data for hour 61
# Getting iEEG data for hour 62
# Getting iEEG data for hour 63
# Getting iEEG data for hour 64
# Getting iEEG data for hour 65
# Getting iEEG data for hour 66
# Getting iEEG data for hour 67
# Getting iEEG data for hour 68
# Getting iEEG data for hour 69
# Getting iEEG data for hour 70
# Getting iEEG data for hour 71
# Getting iEEG data for hour 72
# Getting iEEG data for hour 73
# Getting iEEG data for hour 74
# Getting iEEG data for hour 75
# Getting iEEG data for hour 76
# Getting iEEG data for hour 77
# Getting iEEG data for hour 78
# Getting iEEG data for hour 79
# Getting iEEG data for hour 80
# Getting iEEG data for hour 81
# Getting iEEG data for hour 82
# Getting iEEG data for hour 83
# Getting iEEG data for hour 84
# Getting iEEG data for hour 85
# Getting iEEG data for hour 86
# Getting iEEG data for hour 87
# Getting iEEG data for hour 88
# Getting iEEG data for hour 89
# Getting iEEG data for hour 90
# Getting iEEG data for hour 91
# Getting iEEG data for hour 92
# Getting iEEG data for hour 93
# Getting iEEG data for hour 94
# Getting iEEG data for hour 95
# Getting iEEG data for hour 96
# Getting iEEG data for hour 97
# Getting iEEG data for hour 98
# Getting iEEG data for hour 99
# Getting iEEG data for hour 100
# Getting iEEG data for hour 101
# Getting iEEG data for hour 102
# Getting iEEG data for hour 103
# Getting iEEG data for hour 104
# Getting iEEG data for hour 105
# Getting iEEG data for hour 106
# Getting iEEG data for hour 107
# Getting iEEG data for hour 108
# Getting iEEG data for hour 109
# Getting iEEG data for hour 110
# Getting iEEG data for hour 111
# Getting iEEG data for hour 112
# Getting iEEG data for hour 113
# Getting iEEG data for hour 114
# Getting iEEG data for hour 115
# Getting iEEG data for hour 116
# Getting iEEG data for hour 117
# Getting iEEG data for hour 118
# Getting iEEG data for hour 119
# Getting iEEG data for hour 120
# Getting iEEG data for hour 121
# Getting iEEG data for hour 122
# Getting iEEG data for hour 123
# Getting iEEG data for hour 124
# Getting iEEG data for hour 125
# Getting iEEG data for hour 126
# Getting iEEG data for hour 127
# Getting iEEG data for hour 128
# Getting iEEG data for hour 129
# Getting iEEG data for hour 130
# Getting iEEG data for hour 131
# Getting iEEG data for hour 132
# Getting iEEG data for hour 133
# Getting iEEG data for hour 134
# Getting iEEG data for hour 135
# Getting iEEG data for hour 136
# Getting iEEG data for hour 137
# Getting iEEG data for hour 138
# Getting iEEG data for hour 139
# Getting iEEG data for hour 140
# Getting iEEG data for hour 141
# Getting iEEG data for hour 142
# Getting iEEG data for hour 143
# Getting iEEG data for hour 144
# Getting iEEG data for hour 145
# Getting iEEG data for hour 146
# Getting iEEG data for hour 147
# Getting iEEG data for hour 148
# Getting iEEG data for hour 149
# Getting iEEG data for hour 150
# Getting iEEG data for hour 151
# Getting iEEG data for hour 152
# Getting iEEG data for hour 153
# Getting iEEG data for hour 154
# Getting iEEG data for hour 155
# Getting iEEG data for hour 156
# Getting iEEG data for hour 157
# Getting iEEG data for hour 158
# Getting iEEG data for hour 159
# Getting iEEG data for hour 160
# Getting iEEG data for hour 161
# Getting iEEG data for hour 162
# Getting iEEG data for hour 163
# Getting iEEG data for hour 164
# Getting iEEG data for hour 165
# Getting iEEG data for hour 166
# Getting iEEG data for hour 167
# Getting iEEG data for hour 168
# Getting iEEG data for hour 169
# Getting iEEG data for hour 170
# Getting iEEG data for hour 171
# Getting iEEG data for hour 172
# Getting iEEG data for hour 173
# Getting iEEG data for hour 174
# Getting iEEG data for hour 175
# Getting iEEG data for hour 176
# Getting iEEG data for hour 177
# Getting iEEG data for hour 178
# Getting iEEG data for hour 179
# Getting iEEG data for hour 180
# Getting iEEG data for hour 181
# Getting iEEG data for hour 182
# Getting iEEG data for hour 183
# Getting iEEG data for hour 184
# Getting iEEG data for hour 185
# Getting iEEG data for hour 186
# Getting iEEG data for hour 187
# Getting iEEG data for hour 188
# Getting iEEG data for hour 189
# Getting iEEG data for hour 190
# Getting iEEG data for hour 191
# Getting iEEG data for hour 192
# Getting iEEG data for hour 193
# Getting iEEG data for hour 194
# Getting iEEG data for hour 195
# Getting iEEG data for hour 196
# Getting iEEG data for hour 197
# Getting iEEG data for hour 198
# Getting iEEG data for hour 199
# Getting iEEG data for hour 200
# Getting iEEG data for hour 201
# Getting iEEG data for hour 202
# Getting iEEG data for hour 203
# Getting iEEG data for hour 204
# Getting iEEG data for hour 205
# Getting iEEG data for hour 206
# Getting iEEG data for hour 207
# Getting iEEG data for hour 208
# Getting iEEG data for hour 209
# Getting iEEG data for hour 210
# Getting iEEG data for hour 211
# Getting iEEG data for hour 212
# Getting iEEG data for hour 213
# Getting iEEG data for hour 214
# Getting iEEG data for hour 215
# Getting iEEG data for hour 216
# Getting iEEG data for hour 217
# Getting iEEG data for hour 218
# Getting iEEG data for hour 219
# Getting iEEG data for hour 220
# Getting iEEG data for hour 221
# Getting iEEG data for hour 222
# Getting iEEG data for hour 223
# Getting iEEG data for hour 224
# Getting iEEG data for hour 225
# Getting iEEG data for hour 226
# Getting iEEG data for hour 227
# Getting iEEG data for hour 228
# Getting iEEG data for hour 229
# Getting iEEG data for hour 230
# Getting iEEG data for hour 231
# Getting iEEG data for hour 232
# Getting iEEG data for hour 233
# Getting iEEG data for hour 234
# Getting iEEG data for hour 235
# Getting iEEG data for hour 236
# Getting iEEG data for hour 237
# Getting iEEG data for hour 238
# Getting iEEG data for hour 239
# Getting iEEG data for hour 240
# Getting iEEG data for hour 241
# Getting iEEG data for hour 242
# Getting iEEG data for hour 243
# Getting iEEG data for hour 244
# Getting iEEG data for hour 245
# Getting iEEG data for hour 246
# Getting iEEG data for hour 247
# Getting iEEG data for hour 248
# Getting iEEG data for hour 249
# Getting iEEG data for hour 250
# Getting iEEG data for hour 251
# Getting iEEG data for hour 252
# Getting iEEG data for hour 253
# Getting iEEG data for hour 254
# Getting iEEG data for hour 255
# Getting iEEG data for hour 256
# Getting iEEG data for hour 257
# Getting iEEG data for hour 258
# Getting iEEG data for hour 259
# Getting iEEG data for hour 260
# Getting iEEG data for hour 261
# Getting iEEG data for hour 262
# Getting iEEG data for hour 263
# Getting iEEG data for hour 264
# Getting iEEG data for hour 265
# Getting iEEG data for hour 266
# Getting iEEG data for hour 267
# Getting iEEG data for hour 268
# Getting iEEG data for hour 269
# Getting iEEG data for hour 270
# Getting iEEG data for hour 271
# Getting iEEG data for hour 272
# Getting iEEG data for hour 273
# Getting iEEG data for hour 274
# Getting iEEG data for hour 275
# Getting iEEG data for hour 276
# Getting iEEG data for hour 277
# Getting iEEG data for hour 278
# Getting iEEG data for hour 279
# Getting iEEG data for hour 280
# Getting iEEG data for hour 281
# Getting iEEG data for hour 282
# Getting iEEG data for hour 283
# Getting iEEG data for hour 284
# Getting iEEG data for hour 285
# Getting iEEG data for hour 286
# Getting iEEG data for hour 287
# Getting iEEG data for hour 288
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[36], line 143
#     137 if not local_res.empty:
#     138     # Try Save local_res to a pickle file
#     139     with open(
#     140         f"/Users/devinma/8min/{dataset_name}_hr_{hour}_fs_{int(sample_rate)}.pkl",
#     141         "wb",
#     142     ) as f:
# --> 143         pickle.dump(local_res, f)
#
# OSError: [Errno 28] No space left on device
