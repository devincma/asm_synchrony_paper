# %% [markdown]
# # AED & EEG

# %% [markdown]
# ## Install libraries

# %%
import math, os, re, pickle
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats, interpolate
from scipy.fft import fft
import numpy as np
from numpy import NaN

from signal_processing import *
from ieeg_utils import *

# %% [markdown]
# ## Load data

# %%
patients_df = pd.read_excel("../../Data/selected_patients.xlsx")
patients_df
# Out:
#     hup_id           region lateralization  weight_kg  r_id
# 0      138  mesial temporal           left       84.4   278
# 1      140  mesial temporal           left       56.7   320
# 2      141  mesial temporal          right       85.7   294
# 3      142  mesial temporal           left       65.3   295
# 4      162  mesial temporal           left       47.1   412
# 5      163  mesial temporal           left       82.1   279
# 6      164  mesial temporal           left       95.3   386
# 7      173  mesial temporal          right       76.6    31
# 8      181  mesial temporal           left       63.0   490
# 9      185  mesial temporal           left       76.2   332
# 10     187  mesial temporal          right       86.2   522
# 11     190  mesial temporal           left      105.4   405
# 12     202  mesial temporal           left       89.0   646
# 13     204  mesial temporal           left       82.1   596
# 14     217  mesial temporal          right       58.5   679
# 15     219  mesial temporal          right      101.6   695
# 16     221  mesial temporal          right      124.3   621
# 17     223  mesial temporal           left      101.4   785

# %%
# Load master_elecs.csv from ./data/
master_elecs_df = pd.read_csv("../../Data/master_elecs.csv")

# only take the numbers in rid column
master_elecs_df["rid"] = master_elecs_df["rid"].str.extract("(\d+)", expand=False)
master_elecs_df["rid"] = master_elecs_df["rid"].astype(int)

# Drop mni_x, mni_y, mni_z, mm_x, mm_y, mm_z columns
master_elecs_df = master_elecs_df.drop(
    columns=["mni_x", "mni_y", "mni_z", "mm_x", "mm_y", "mm_z"]
)

master_elecs_df
# Out:
#        rid   name     vox_x     vox_y     vox_z                   label  \
# 0       13  LST01   80.6116  106.5480   64.5941  left inferior temporal
# 1       13  LST02   72.0779  109.4150   63.1223  left inferior temporal
# 2       13  LST03   64.9060  112.3760   68.7455              EmptyLabel
# 3       13  LST04   65.0210  114.6600   78.2339    left middle temporal
# 4       13  MST01  131.7410   64.3756   70.4205           right lingual
# ...    ...    ...       ...       ...       ...                     ...
# 14212  785   RB08  154.2550  114.2730  136.7560              EmptyLabel
# 14213  785   RB09  159.1350  111.9920  136.6960              EmptyLabel
# 14214  785   RB10  164.7520  109.9030  137.7640   right middle temporal
# 14215  785   RB11  169.6320  107.6220  137.7040   right middle temporal
# 14216  785   RB12  175.1210  105.8310  137.7080              EmptyLabel
#
#          soz resected  spike_rate  engel
# 0      False    False    1.091902    1.0
# 1      False    False    1.091902    1.0
# 2      False    False    1.419472    1.0
# 3      False    False    0.655141    1.0
# 4       True    False    3.439490    1.0
# ...      ...      ...         ...    ...
# 14212  False      NaN    0.369914    1.0
# 14213  False      NaN    0.665845    1.0
# 14214  False      NaN    4.586930    1.0
# 14215  False      NaN    2.071517    1.0
# 14216  False      NaN    5.104809    1.0
#
# [14217 rows x 10 columns]

# %%
# Load rid_hup_table.csv from ./data/
rid_hup_table_df = pd.read_csv("../../Data/rid_hup_table.csv")
# Drop the t3_subject_id and ieegportalsubjno columns
rid_hup_table_df = rid_hup_table_df.drop(columns=["t3_subject_id", "ieegportalsubjno"])
rid_hup_table_df
# Out:
#      record_id  hupsubjno
# 0          623         35
# 1          624         36
# 2          625         37
# 3          626         38
# 4          627         39
# ..         ...        ...
# 212        534        250
# 213        923        251
# 214        918        252
# 215        864        253
# 216        675        254
#
# [217 rows x 2 columns]

# %%
# Load aed_ref_ranges.xlsx from ./data/
aed_ref_ranges_df = pd.read_excel("../../Data/aed_ref_ranges.xlsx")
# Lowercase Drug column
aed_ref_ranges_df["Drug"] = aed_ref_ranges_df["Drug"].str.lower()
# show unique units
# print(aed_ref_ranges_df["Unit"].unique())
# mg/L and ug/mL are the same
# If Unit is ng/mL, convert to ug/mL
aed_ref_ranges_df.loc[aed_ref_ranges_df["Unit"] == "ng/mL", "Min"] = (
    aed_ref_ranges_df["Min"] / 1000
)
aed_ref_ranges_df.loc[aed_ref_ranges_df["Unit"] == "ng/mL", "Max"] = (
    aed_ref_ranges_df["Max"] / 1000
)
# Add a column that takes the average of Min and Max
aed_ref_ranges_df["Avg"] = (aed_ref_ranges_df["Min"] + aed_ref_ranges_df["Max"]) / 2
aed_ref_ranges_df
# Out:
#                    Drug    Min     Max   Unit     Avg
# 0         levetiracetam  12.00   46.00   mg/L  29.000
# 1         carbamazepine   4.00   10.00   mg/L   7.000
# 2         oxcarbazepine   3.00   35.00  ug/mL  19.000
# 3              clobazam   0.03    0.30  ng/mL   0.165
# 4   n-desmethylclobazam   0.30    3.00  ng/mL   1.650
# 5            topiramate   5.00   20.00   mg/L  12.500
# 6         valproic acid  50.00  125.00  ug/mL  87.500
# 7            lacosamide   1.00   10.00  ug/mL   5.500
# 8             felbamate  30.00   60.00  ug/mL  45.000
# 9           lamotrigine   2.50   15.00   mg/L   8.750
# 10           clonazepam   0.02    0.07  ng/mL   0.045
# 11           zonisamide  10.00   40.00   mg/L  25.000
# 12           pregabalin   2.00   10.00  ug/mL   6.000
# 13            phenytoin  10.00   20.00  ug/mL  15.000
# 14         brivaracetam   0.20    2.00  ug/mL   1.100
# 15      eslicarbazepine   3.00   26.00   mg/L  14.500
# 16           gabapentin   3.00   21.00   mg/L  12.000
# 17           rufinamide   4.00   31.00   mg/L  17.500

# %%
patient_hup_ids = patients_df.hup_id.to_numpy()
patient_weights = patients_df.weight_kg.to_numpy()
assert len(patient_hup_ids) == len(patient_weights)
len(patient_hup_ids)
# Out:
# 18

# %%
all_patient_hup_ids = pd.read_excel("../../Data/HUP_implant_dates.xlsx")
all_patient_hup_ids = all_patient_hup_ids["ptID"].to_numpy()
all_patient_hup_ids
# Out:
# array([225, 224, 223, 221, 219, 217, 216, 215, 214, 213, 211, 210, 209,
#        208, 207, 206, 205, 204, 202, 201, 199, 197, 196, 195, 194, 193,
#        192, 191, 190, 189, 188, 187, 186, 185, 184, 182, 181, 180, 179,
#        178, 177, 175, 174, 173, 172, 171, 170, 169, 168, 167, 166, 165,
#        164, 163, 162, 161, 160, 159, 158, 157, 156, 155, 154, 153, 152,
#        151, 150, 149, 148, 147, 146, 145, 144, 143, 142, 141, 140, 139,
#        138, 137])

# %%
# Create a mapping between patient ids and the index of the patient in the patients_df dataframe
patient_hup_id_to_index = {}
for i, patient_id in enumerate(all_patient_hup_ids):
    patient_hup_id_to_index[patient_id] = i

# %%
ieeg_offset_row1_df = pd.read_excel("../../Data/ieeg_offset/row_1.xlsx", header=None)
ieeg_offset_row2_df = pd.read_excel("../../Data/ieeg_offset/row_2.xlsx", header=None)
ieeg_offset_row3_df = pd.read_excel("../../Data/ieeg_offset/row_3.xlsx", header=None)

# %%
# Load ./data/ieeg_starts.xlsx into a dataframe
ieeg_starts_df = pd.read_excel("../../Data/ieeg_starts.xlsx")
ieeg_starts_df
# Out:
#     hup_id  ieeg_start
# 0      225   38.024167
# 1      224   37.582778
# 2      223   32.985556
# 3      221   37.690000
# 4      219   33.396667
# ..     ...         ...
# 75     141   37.249444
# 76     140   35.197500
# 77     139   37.151667
# 78     138   37.529444
# 79     137   13.654444
#
# [80 rows x 2 columns]

# %% [markdown]
# ## 3: EEG Experiments

# %%
directory_path = "../../Data/ieeg/mesial_temporal_left_right/5_min/"

# %% [markdown]
# ### 3.0 Helper Functions

# %%
# def create_pwd_file(username, password, fname=None):
#     if fname is None:
#         fname = "{}_ieeglogin.bin".format(username[:3])
#     with open(fname, "wb") as f:
#         f.write(password.encode())
#     print("-- -- IEEG password file saved -- --")


# create_pwd_file("dma", "mycqEv-pevfo4-roqfan")

# with open("dma_ieeglogin.bin", "r") as f:
#     session = Session("dma", f.read())

# %%
def identify_bad_channels(values, channel_indices, channel_labels, fs):
    """
    Identifies 'bad' channels in an EEG dataset based on various criteria such as high variance, missing data,
    crossing absolute threshold, high variance above baseline, and 60 Hz noise.

    Parameters:
    values (numpy.ndarray): A 2D array of EEG data where each column is a different channel and each row is a reading.
    channel_indices (list): A list containing indices of channels to be analyzed.
    channel_labels (list): A list of channel labels.
    fs (float): The sampling frequency.

    Returns:
    bad (list): A list of 'bad' channel indices.
    details (dict): A dictionary containing the reasons why each channel was marked as 'bad'. Keys are 'noisy', 'nans',
                    'zeros', 'var', 'higher_std', and 'high_voltage'. Each key maps to a list of channel indices.
    """

    # set parameters
    tile = 99
    mult = 10
    num_above = 1
    abs_thresh = 5e3
    percent_60_hz = 0.99
    mult_std = 10

    bad = []
    high_ch = []
    nan_ch = []
    zero_ch = []
    high_var_ch = []
    noisy_ch = []
    all_std = np.full(len(channel_indices), NaN)

    for i in range(len(channel_indices)):
        bad_ch = 0
        ich = channel_indices[i]
        eeg = values[:, ich]
        bl = np.nanmedian(eeg)

        all_std[i] = np.nanstd(eeg)

        if np.sum(np.isnan(eeg)) > 0.5 * len(eeg):
            bad.append(ich)
            nan_ch.append(ich)
            continue

        if np.sum(eeg == 0) > 0.5 * len(eeg):
            bad.append(ich)
            zero_ch.append(ich)
            continue

        if np.sum(np.abs(eeg - bl) > abs_thresh) > 10:
            bad.append(ich)
            bad_ch = 1
            high_ch.append(ich)

        if bad_ch == 1:
            continue

        pct = np.percentile(eeg, [100 - tile, tile])
        thresh = [bl - mult * (bl - pct[0]), bl + mult * (pct[1] - bl)]
        sum_outside = np.sum((eeg > thresh[1]) | (eeg < thresh[0]))

        if sum_outside >= num_above:
            bad_ch = 1

        if bad_ch == 1:
            bad.append(ich)
            high_var_ch.append(ich)
            continue

        Y = fft(eeg - np.nanmean(eeg))

        P = np.abs(Y) ** 2
        freqs = np.linspace(0, fs, len(P) + 1)
        freqs = freqs[:-1]
        P = P[: int(np.ceil(len(P) / 2))]
        freqs = freqs[: int(np.ceil(len(freqs) / 2))]

        P_60Hz = np.sum(P[(freqs > 58) & (freqs < 62)]) / np.sum(P)

        if P_60Hz > percent_60_hz:
            bad_ch = 1

        if bad_ch == 1:
            bad.append(ich)
            noisy_ch.append(ich)
            continue

    median_std = np.nanmedian(all_std)
    higher_std = [
        channel_indices[i]
        for i in range(len(all_std))
        if all_std[i] > mult_std * median_std
    ]
    bad_std = [ch for ch in higher_std if ch not in bad]
    bad.extend(bad_std)

    details = {
        "noisy": noisy_ch,
        "nans": nan_ch,
        "zeros": zero_ch,
        "var": high_var_ch,
        "higher_std": bad_std,
        "high_voltage": high_ch,
    }

    return bad, details

# %%
def parse_files_in_directory(directory_path):
    # Initialize dictionaries for HUP id to maximum hour and sample rate
    max_hours = {}
    sample_rates = {}

    # Iterate over each file in the directory
    for filename in os.listdir(directory_path):
        # Check if filename contains "D0"
        if "D0" in filename:
            continue
        # Use regular expression to extract the values from the filename
        match = re.match(r"HUP(\d+)_phaseII_hr_(\d+)_fs_(\d+).pkl", filename)
        if match:
            hup_id, hour, sample_rate = map(int, match.groups())

            # If this HUP id is not in max_hours dictionary, or the current hour is greater
            # than the stored maximum hour, update the maximum hour
            if hup_id not in max_hours or hour > max_hours[hup_id]:
                max_hours[hup_id] = hour

            # If this HUP id is not in the sample_rates dictionary, add it
            if hup_id not in sample_rates:
                sample_rates[hup_id] = sample_rate

    # Convert the dictionaries into lists
    hup_ids = list(max_hours.keys())
    max_hours = list(max_hours.values())
    sample_rates = [sample_rates[hup_id] for hup_id in hup_ids]

    return hup_ids, max_hours, sample_rates


# Call the function
hup_ids, max_hours, sample_rates = parse_files_in_directory(directory_path)

# create a dataframe with the HUP id, maximum hour, and sample rate, sort by HUP id
datasets_df = pd.DataFrame(
    {"hup_id": hup_ids, "max_hour": max_hours, "sample_rate": sample_rates}
)
datasets_df = datasets_df.sort_values(by="hup_id")
datasets_df = datasets_df.reset_index(drop=True)
datasets_df
# Out:
#    hup_id  max_hour  sample_rate
# 0     138       172         1024
# 1     141       146          512
# 2     142       311          512
# 3     173       237          256
# 4     185       232          512
# 5     187       177          512
# 6     190       306         1024
# 7     202       190          512
# 8     204       122          512
# 9     223       135         1024

# %%
def create_bipolar_montage(data, channel_names):
    """
    A bipolar montage is a type of arrangement in electrophysiology (like EEG) where each channel shows
    the difference in electrical potential between two different electrodes.

    Args:
        data (numpy.array or similar): A 2D array containing the EEG (or similar) data.
        Each column corresponds to a channel and each row to a time point.

        channel_names (list or similar): An array-like structure with the names of the channels.
        Channel names are expected to follow this format: (Letter)(Letter)[Letter](Number)(Number).

    Returns:
        tuple: A tuple containing two numpy arrays. The first array is the bipolar data and the second array
        is the corresponding channel names.
    """
    channel_names = np.array(channel_names)

    num_channels = len(channel_names)
    bipolar_df = None
    count = 0

    # Iterate over each channel
    for i in range(num_channels - 1):
        channel1_name = channel_names[i]

        # Generate the name of the next sequential channel
        channel2_name = channel1_name[0:2] + f"{(int(channel1_name[2:4]) + 1):02d}"

        # Check if the next sequential channel exists
        channel2_index = np.where(channel_names == channel2_name)[0]

        if len(channel2_index) > 0:
            # Create bipolar channel by subtracting the data of channel2 from channel1
            bipolar_channel = pd.Series(
                (data[:, i] - data[:, channel2_index[0]])
            ).rename(channel1_name)

            # If this is the first bipolar channel, initialize the dataframe
            if count == 0:
                bipolar_df = pd.DataFrame(bipolar_channel)
                count += 1
            else:
                # If the dataframe is already initialized, add the new bipolar channel to it
                bipolar_df = pd.concat(
                    [bipolar_df, pd.DataFrame(bipolar_channel)], axis=1
                )

    return bipolar_df

# %% [markdown]
# ### 3.2.2: Artifact Rejection

# %%
# Determine number of rows and columns for subplots
num_plots = len(datasets_df)
num_cols = 3
num_rows = math.ceil(num_plots / num_cols)

# Create a figure with a subplot for each row in datasets_df
fig, axs = plt.subplots(num_rows, num_cols, figsize=(num_cols * 3.5, num_rows * 3.5))

# Flatten the axis array for easy iteration, and iterate only up to num_plots
axs = axs.flatten()[:num_plots]

# Iterate over each row of datasets_df
for i, row in datasets_df.iterrows():
    print(f"Processing HUP{row['hup_id']}")
    patient_hup_id = row["hup_id"]
    max_hour = row["max_hour"]
    sample_rate = row["sample_rate"]

    hours = []
    percent_of_bad_channels = []

    for eeg_hour in range(max_hour + 1):
        filename = f"HUP{patient_hup_id}_phaseII_hr_{eeg_hour}_fs_{sample_rate}.pkl"
        try:
            with open(f"{directory_path}{filename}", "rb") as f:
                eeg_segment_df = pickle.load(f)
        except FileNotFoundError:
            continue

        print(f"Processing HUP{patient_hup_id} hour {eeg_hour}")

        channel_labels = eeg_segment_df.columns.to_numpy(dtype=str)
        channel_indices = np.arange(len(channel_labels))

        bad_channel_indicies, bad_details = identify_bad_channels(
            eeg_segment_df.to_numpy(dtype=float),
            channel_indices,
            channel_labels,
            sample_rate,
        )
        hours.append(eeg_hour)
        percent_of_bad_channels.append(len(bad_channel_indicies) / len(channel_indices))

    # assert len(percent_of_bad_channels) == max_hour + 1

    # plot the number of bad channels for this patient over x axis which is the hour
    axs[i].plot(hours, percent_of_bad_channels)
    axs[i].set_title(f"HUP {patient_hup_id}")
    axs[i].set_xlabel("Hour")
    axs[i].set_ylabel("% of bad channels")
    axs[i].set_ylim([0, 1])

# Adjust layout and display
plt.tight_layout()
plt.show()
# Out:
# Processing HUP138
# Processing HUP138 hour 0
# Processing HUP138 hour 1
# Processing HUP138 hour 2
# Processing HUP138 hour 3
# Processing HUP138 hour 4
# Processing HUP138 hour 5
# Processing HUP138 hour 6
# Processing HUP138 hour 7
# Processing HUP138 hour 8
# Processing HUP138 hour 9
# Processing HUP138 hour 11
# Processing HUP138 hour 12
# Processing HUP138 hour 13
# Processing HUP138 hour 14
# Processing HUP138 hour 15
# Processing HUP138 hour 16
# Processing HUP138 hour 17
# Processing HUP138 hour 18
# Processing HUP138 hour 19
# Processing HUP138 hour 20
# Processing HUP138 hour 21
# Processing HUP138 hour 22
# Processing HUP138 hour 23
# Processing HUP138 hour 24
# Processing HUP138 hour 25
# Processing HUP138 hour 26
# Processing HUP138 hour 27
# Processing HUP138 hour 28
# Processing HUP138 hour 29
# Processing HUP138 hour 30
# Processing HUP138 hour 31
# Processing HUP138 hour 32
# Processing HUP138 hour 33
# Processing HUP138 hour 34
# Processing HUP138 hour 35
# Processing HUP138 hour 36
# Processing HUP138 hour 37
# Processing HUP138 hour 38
# Processing HUP138 hour 39
# Processing HUP138 hour 40
# Processing HUP138 hour 41
# Processing HUP138 hour 42
# Processing HUP138 hour 43
# Processing HUP138 hour 44
# Processing HUP138 hour 45
# Processing HUP138 hour 46
# Processing HUP138 hour 47
# Processing HUP138 hour 48
# Processing HUP138 hour 49
# Processing HUP138 hour 50
# Processing HUP138 hour 51
# Processing HUP138 hour 52
# Processing HUP138 hour 53
# Processing HUP138 hour 54
# Processing HUP138 hour 55
# Processing HUP138 hour 56
# Processing HUP138 hour 57
# Processing HUP138 hour 58
# Processing HUP138 hour 59
# Processing HUP138 hour 60
# Processing HUP138 hour 61
# Processing HUP138 hour 62
# Processing HUP138 hour 63
# Processing HUP138 hour 64
# Processing HUP138 hour 65
# Processing HUP138 hour 66
# Processing HUP138 hour 67
# Processing HUP138 hour 68
# Processing HUP138 hour 69
# Processing HUP138 hour 70
# Processing HUP138 hour 71
# Processing HUP138 hour 72
# Processing HUP138 hour 73
# Processing HUP138 hour 74
# Processing HUP138 hour 75
# Processing HUP138 hour 76
# Processing HUP138 hour 77
# Processing HUP138 hour 78
# Processing HUP138 hour 79
# Processing HUP138 hour 80
# Processing HUP138 hour 81
# Processing HUP138 hour 82
# Processing HUP138 hour 83
# Processing HUP138 hour 84
# Processing HUP138 hour 85
# Processing HUP138 hour 86
# Processing HUP138 hour 87
# Processing HUP138 hour 88
# Processing HUP138 hour 89
# Processing HUP138 hour 90
# Processing HUP138 hour 91
# Processing HUP138 hour 92
# Processing HUP138 hour 93
# Processing HUP138 hour 94
# Processing HUP138 hour 95
# Processing HUP138 hour 96
# Processing HUP138 hour 97
# Processing HUP138 hour 98
# Processing HUP138 hour 99
# /tmp/ipykernel_13579/1045330125.py:80: RuntimeWarning: invalid value encountered in scalar divide
#   P_60Hz = np.sum(P[(freqs > 58) & (freqs < 62)]) / np.sum(P)
# Processing HUP138 hour 100
# Processing HUP138 hour 101
# Processing HUP138 hour 102
# Processing HUP138 hour 103
# Processing HUP138 hour 104
# Processing HUP138 hour 105
# Processing HUP138 hour 106
# Processing HUP138 hour 107
# Processing HUP138 hour 108
# Processing HUP138 hour 109
# Processing HUP138 hour 110
# Processing HUP138 hour 111
# Processing HUP138 hour 112
# Processing HUP138 hour 113
# Processing HUP138 hour 114
# Processing HUP138 hour 115
# Processing HUP138 hour 116
# Processing HUP138 hour 117
# Processing HUP138 hour 118
# Processing HUP138 hour 119
# Processing HUP138 hour 120
# Processing HUP138 hour 121
# Processing HUP138 hour 122
# Processing HUP138 hour 123
# Processing HUP138 hour 124
# Processing HUP138 hour 125
# Processing HUP138 hour 126
# Processing HUP138 hour 127
# Processing HUP138 hour 128
# Processing HUP138 hour 129
# Processing HUP138 hour 130
# Processing HUP138 hour 131
# Processing HUP138 hour 132
# Processing HUP138 hour 133
# Processing HUP138 hour 134
# Processing HUP138 hour 135
# Processing HUP138 hour 136
# Processing HUP138 hour 137
# Processing HUP138 hour 138
# Processing HUP138 hour 139
# Processing HUP138 hour 140
# Processing HUP138 hour 141
# Processing HUP138 hour 142
# Processing HUP138 hour 143
# Processing HUP138 hour 144
# Processing HUP138 hour 145
# Processing HUP138 hour 146
# Processing HUP138 hour 147
# Processing HUP138 hour 148
# Processing HUP138 hour 149
# Processing HUP138 hour 150
# Processing HUP138 hour 151
# Processing HUP138 hour 152
# Processing HUP138 hour 153
# Processing HUP138 hour 154
# Processing HUP138 hour 155
# Processing HUP138 hour 156
# Processing HUP138 hour 157
# Processing HUP138 hour 158
# Processing HUP138 hour 159
# Processing HUP138 hour 160
# Processing HUP138 hour 161
# Processing HUP138 hour 162
# Processing HUP138 hour 163
# Processing HUP138 hour 164
# Processing HUP138 hour 165
# Processing HUP138 hour 166
# Processing HUP138 hour 167
# Processing HUP138 hour 168
# Processing HUP138 hour 169
# Processing HUP138 hour 170
# Processing HUP138 hour 171
# Processing HUP138 hour 172
# Processing HUP141
# Processing HUP141 hour 0
# Processing HUP141 hour 1
# Processing HUP141 hour 2
# Processing HUP141 hour 3
# Processing HUP141 hour 4
# Processing HUP141 hour 5
# Processing HUP141 hour 6
# Processing HUP141 hour 7
# Processing HUP141 hour 8
# Processing HUP141 hour 9
# Processing HUP141 hour 10
# Processing HUP141 hour 11
# Processing HUP141 hour 12
# Processing HUP141 hour 13
# Processing HUP141 hour 14
# Processing HUP141 hour 15
# Processing HUP141 hour 16
# Processing HUP141 hour 17
# Processing HUP141 hour 18
# Processing HUP141 hour 19
# Processing HUP141 hour 20
# Processing HUP141 hour 21
# Processing HUP141 hour 22
# Processing HUP141 hour 23
# Processing HUP141 hour 24
# Processing HUP141 hour 25
# Processing HUP141 hour 26
# Processing HUP141 hour 27
# Processing HUP141 hour 28
# Processing HUP141 hour 29
# Processing HUP141 hour 30
# Processing HUP141 hour 31
# Processing HUP141 hour 32
# Processing HUP141 hour 33
# Processing HUP141 hour 34
# Processing HUP141 hour 35
# Processing HUP141 hour 36
# Processing HUP141 hour 37
# Processing HUP141 hour 38
# Processing HUP141 hour 39
# Processing HUP141 hour 40
# Processing HUP141 hour 41
# Processing HUP141 hour 42
# Processing HUP141 hour 43
# Processing HUP141 hour 44
# Processing HUP141 hour 45
# Processing HUP141 hour 46
# Processing HUP141 hour 47
# Processing HUP141 hour 48
# Processing HUP141 hour 49
# Processing HUP141 hour 50
# Processing HUP141 hour 51
# Processing HUP141 hour 52
# Processing HUP141 hour 53
# Processing HUP141 hour 54
# Processing HUP141 hour 55
# Processing HUP141 hour 56
# Processing HUP141 hour 57
# Processing HUP141 hour 58
# Processing HUP141 hour 60
# Processing HUP141 hour 61
# Processing HUP141 hour 62
# Processing HUP141 hour 63
# Processing HUP141 hour 64
# Processing HUP141 hour 65
# Processing HUP141 hour 66
# Processing HUP141 hour 67
# Processing HUP141 hour 68
# Processing HUP141 hour 69
# Processing HUP141 hour 70
# Processing HUP141 hour 71
# Processing HUP141 hour 72
# Processing HUP141 hour 73
# Processing HUP141 hour 74
# Processing HUP141 hour 75
# Processing HUP141 hour 76
# Processing HUP141 hour 77
# Processing HUP141 hour 78
# Processing HUP141 hour 79
# Processing HUP141 hour 80
# Processing HUP141 hour 81
# Processing HUP141 hour 82
# Processing HUP141 hour 83
# Processing HUP141 hour 84
# Processing HUP141 hour 85
# Processing HUP141 hour 86
# Processing HUP141 hour 87
# Processing HUP141 hour 88
# Processing HUP141 hour 89
# Processing HUP141 hour 90
# Processing HUP141 hour 91
# Processing HUP141 hour 92
# Processing HUP141 hour 93
# Processing HUP141 hour 94
# Processing HUP141 hour 95
# Processing HUP141 hour 96
# Processing HUP141 hour 97
# Processing HUP141 hour 98
# Processing HUP141 hour 99
# Processing HUP141 hour 100
# Processing HUP141 hour 101
# Processing HUP141 hour 102
# Processing HUP141 hour 103
# Processing HUP141 hour 104
# Processing HUP141 hour 105
# Processing HUP141 hour 106
# Processing HUP141 hour 107
# Processing HUP141 hour 108
# Processing HUP141 hour 109
# Processing HUP141 hour 110
# Processing HUP141 hour 112
# Processing HUP141 hour 113
# Processing HUP141 hour 114
# Processing HUP141 hour 115
# Processing HUP141 hour 116
# Processing HUP141 hour 117
# Processing HUP141 hour 118
# Processing HUP141 hour 119
# Processing HUP141 hour 120
# Processing HUP141 hour 121
# Processing HUP141 hour 122
# Processing HUP141 hour 123
# Processing HUP141 hour 124
# Processing HUP141 hour 125
# Processing HUP141 hour 126
# Processing HUP141 hour 127
# Processing HUP141 hour 128
# Processing HUP141 hour 129
# Processing HUP141 hour 130
# Processing HUP141 hour 131
# Processing HUP141 hour 132
# Processing HUP141 hour 133
# Processing HUP141 hour 134
# Processing HUP141 hour 135
# Processing HUP141 hour 136
# Processing HUP141 hour 137
# Processing HUP141 hour 138
# Processing HUP141 hour 139
# Processing HUP141 hour 140
# Processing HUP141 hour 141
# Processing HUP141 hour 142
# Processing HUP141 hour 143
# Processing HUP141 hour 144
# Processing HUP141 hour 145
# Processing HUP141 hour 146
# Processing HUP142
# Processing HUP142 hour 0
# Processing HUP142 hour 1
# Processing HUP142 hour 2
# Processing HUP142 hour 3
# Processing HUP142 hour 4
# Processing HUP142 hour 5
# Processing HUP142 hour 6
# Processing HUP142 hour 7
# Processing HUP142 hour 8
# Processing HUP142 hour 9
# Processing HUP142 hour 10
# Processing HUP142 hour 11
# Processing HUP142 hour 12
# Processing HUP142 hour 13
# Processing HUP142 hour 14
# Processing HUP142 hour 15
# Processing HUP142 hour 16
# Processing HUP142 hour 17
# Processing HUP142 hour 18
# Processing HUP142 hour 19
# Processing HUP142 hour 20
# Processing HUP142 hour 21
# Processing HUP142 hour 22
# Processing HUP142 hour 23
# Processing HUP142 hour 24
# Processing HUP142 hour 25
# Processing HUP142 hour 26
# Processing HUP142 hour 27
# Processing HUP142 hour 28
# Processing HUP142 hour 29
# Processing HUP142 hour 30
# Processing HUP142 hour 31
# Processing HUP142 hour 32
# Processing HUP142 hour 33
# Processing HUP142 hour 34
# Processing HUP142 hour 35
# Processing HUP142 hour 36
# Processing HUP142 hour 37
# Processing HUP142 hour 38
# Processing HUP142 hour 39
# Processing HUP142 hour 40
# Processing HUP142 hour 41
# Processing HUP142 hour 42
# Processing HUP142 hour 43
# Processing HUP142 hour 44
# Processing HUP142 hour 45
# Processing HUP142 hour 46
# Processing HUP142 hour 47
# Processing HUP142 hour 48
# Processing HUP142 hour 49
# Processing HUP142 hour 50
# Processing HUP142 hour 51
# Processing HUP142 hour 52
# Processing HUP142 hour 53
# Processing HUP142 hour 54
# Processing HUP142 hour 55
# Processing HUP142 hour 56
# Processing HUP142 hour 57
# Processing HUP142 hour 58
# Processing HUP142 hour 59
# Processing HUP142 hour 60
# Processing HUP142 hour 61
# Processing HUP142 hour 62
# Processing HUP142 hour 63
# Processing HUP142 hour 64
# Processing HUP142 hour 65
# Processing HUP142 hour 66
# Processing HUP142 hour 67
# Processing HUP142 hour 68
# Processing HUP142 hour 69
# Processing HUP142 hour 70
# Processing HUP142 hour 71
# Processing HUP142 hour 72
# Processing HUP142 hour 73
# Processing HUP142 hour 74
# Processing HUP142 hour 75
# Processing HUP142 hour 76
# Processing HUP142 hour 77
# Processing HUP142 hour 78
# Processing HUP142 hour 79
# Processing HUP142 hour 80
# Processing HUP142 hour 81
# Processing HUP142 hour 82
# Processing HUP142 hour 83
# Processing HUP142 hour 84
# Processing HUP142 hour 85
# Processing HUP142 hour 86
# Processing HUP142 hour 87
# Processing HUP142 hour 88
# Processing HUP142 hour 89
# Processing HUP142 hour 90
# Processing HUP142 hour 91
# Processing HUP142 hour 92
# Processing HUP142 hour 93
# Processing HUP142 hour 94
# Processing HUP142 hour 95
# Processing HUP142 hour 96
# Processing HUP142 hour 97
# Processing HUP142 hour 98
# Processing HUP142 hour 99
# Processing HUP142 hour 100
# Processing HUP142 hour 101
# Processing HUP142 hour 102
# Processing HUP142 hour 103
# Processing HUP142 hour 104
# Processing HUP142 hour 105
# Processing HUP142 hour 106
# Processing HUP142 hour 107
# Processing HUP142 hour 108
# Processing HUP142 hour 109
# Processing HUP142 hour 110
# Processing HUP142 hour 111
# Processing HUP142 hour 112
# Processing HUP142 hour 113
# Processing HUP142 hour 114
# Processing HUP142 hour 115
# Processing HUP142 hour 116
# Processing HUP142 hour 117
# Processing HUP142 hour 118
# Processing HUP142 hour 119
# Processing HUP142 hour 120
# Processing HUP142 hour 121
# Processing HUP142 hour 122
# Processing HUP142 hour 123
# Processing HUP142 hour 124
# Processing HUP142 hour 125
# Processing HUP142 hour 126
# Processing HUP142 hour 127
# Processing HUP142 hour 128
# Processing HUP142 hour 129
# Processing HUP142 hour 130
# Processing HUP142 hour 131
# Processing HUP142 hour 132
# Processing HUP142 hour 133
# Processing HUP142 hour 134
# Processing HUP142 hour 135
# Processing HUP142 hour 136
# Processing HUP142 hour 137
# Processing HUP142 hour 138
# Processing HUP142 hour 139
# Processing HUP142 hour 140
# Processing HUP142 hour 141
# Processing HUP142 hour 142
# Processing HUP142 hour 143
# Processing HUP142 hour 144
# Processing HUP142 hour 145
# Processing HUP142 hour 146
# Processing HUP142 hour 147
# Processing HUP142 hour 148
# Processing HUP142 hour 149
# Processing HUP142 hour 150
# Processing HUP142 hour 151
# Processing HUP142 hour 152
# Processing HUP142 hour 153
# Processing HUP142 hour 154
# Processing HUP142 hour 155
# Processing HUP142 hour 156
# Processing HUP142 hour 157
# Processing HUP142 hour 158
# Processing HUP142 hour 159
# Processing HUP142 hour 160
# Processing HUP142 hour 161
# Processing HUP142 hour 162
# Processing HUP142 hour 163
# Processing HUP142 hour 164
# Processing HUP142 hour 165
# Processing HUP142 hour 166
# Processing HUP142 hour 167
# Processing HUP142 hour 168
# Processing HUP142 hour 169
# Processing HUP142 hour 170
# Processing HUP142 hour 171
# Processing HUP142 hour 172
# Processing HUP142 hour 173
# Processing HUP142 hour 174
# Processing HUP142 hour 175
# Processing HUP142 hour 176
# Processing HUP142 hour 177
# Processing HUP142 hour 178
# Processing HUP142 hour 179
# Processing HUP142 hour 180
# Processing HUP142 hour 181
# Processing HUP142 hour 182
# Processing HUP142 hour 183
# Processing HUP142 hour 184
# Processing HUP142 hour 185
# Processing HUP142 hour 186
# Processing HUP142 hour 187
# Processing HUP142 hour 188
# Processing HUP142 hour 189
# Processing HUP142 hour 190
# Processing HUP142 hour 191
# Processing HUP142 hour 192
# Processing HUP142 hour 193
# Processing HUP142 hour 194
# Processing HUP142 hour 195
# Processing HUP142 hour 196
# Processing HUP142 hour 197
# Processing HUP142 hour 198
# Processing HUP142 hour 199
# Processing HUP142 hour 200
# Processing HUP142 hour 201
# Processing HUP142 hour 202
# Processing HUP142 hour 203
# Processing HUP142 hour 204
# Processing HUP142 hour 205
# Processing HUP142 hour 206
# Processing HUP142 hour 207
# Processing HUP142 hour 208
# Processing HUP142 hour 209
# Processing HUP142 hour 210
# Processing HUP142 hour 211
# Processing HUP142 hour 212
# Processing HUP142 hour 213
# Processing HUP142 hour 214
# Processing HUP142 hour 215
# Processing HUP142 hour 216
# Processing HUP142 hour 217
# Processing HUP142 hour 218
# Processing HUP142 hour 219
# Processing HUP142 hour 220
# Processing HUP142 hour 221
# Processing HUP142 hour 222
# Processing HUP142 hour 223
# Processing HUP142 hour 224
# Processing HUP142 hour 225
# Processing HUP142 hour 226
# Processing HUP142 hour 227
# Processing HUP142 hour 228
# Processing HUP142 hour 229
# Processing HUP142 hour 230
# Processing HUP142 hour 231
# Processing HUP142 hour 232
# Processing HUP142 hour 233
# Processing HUP142 hour 234
# Processing HUP142 hour 235
# Processing HUP142 hour 236
# Processing HUP142 hour 237
# Processing HUP142 hour 238
# Processing HUP142 hour 239
# Processing HUP142 hour 240
# Processing HUP142 hour 241
# Processing HUP142 hour 242
# Processing HUP142 hour 243
# Processing HUP142 hour 244
# Processing HUP142 hour 245
# Processing HUP142 hour 246
# Processing HUP142 hour 247
# Processing HUP142 hour 248
# Processing HUP142 hour 249
# Processing HUP142 hour 250
# Processing HUP142 hour 251
# Processing HUP142 hour 252
# Processing HUP142 hour 253
# Processing HUP142 hour 254
# Processing HUP142 hour 255
# Processing HUP142 hour 256
# Processing HUP142 hour 257
# Processing HUP142 hour 258
# Processing HUP142 hour 259
# Processing HUP142 hour 260
# Processing HUP142 hour 261
# Processing HUP142 hour 262
# Processing HUP142 hour 263
# Processing HUP142 hour 264
# Processing HUP142 hour 265
# Processing HUP142 hour 266
# Processing HUP142 hour 267
# Processing HUP142 hour 268
# Processing HUP142 hour 269
# Processing HUP142 hour 270
# Processing HUP142 hour 271
# Processing HUP142 hour 272
# Processing HUP142 hour 273
# Processing HUP142 hour 274
# Processing HUP142 hour 275
# Processing HUP142 hour 276
# Processing HUP142 hour 277
# Processing HUP142 hour 278
# Processing HUP142 hour 279
# Processing HUP142 hour 280
# Processing HUP142 hour 281
# Processing HUP142 hour 282
# Processing HUP142 hour 283
# Processing HUP142 hour 284
# Processing HUP142 hour 285
# Processing HUP142 hour 286
# Processing HUP142 hour 287
# Processing HUP142 hour 288
# Processing HUP142 hour 289
# Processing HUP142 hour 290
# Processing HUP142 hour 291
# Processing HUP142 hour 292
# Processing HUP142 hour 293
# Processing HUP142 hour 294
# Processing HUP142 hour 295
# Processing HUP142 hour 296
# Processing HUP142 hour 297
# Processing HUP142 hour 298
# Processing HUP142 hour 299
# Processing HUP142 hour 300
# Processing HUP142 hour 301
# Processing HUP142 hour 302
# Processing HUP142 hour 303
# Processing HUP142 hour 304
# Processing HUP142 hour 305
# Processing HUP142 hour 306
# Processing HUP142 hour 307
# Processing HUP142 hour 308
# Processing HUP142 hour 309
# Processing HUP142 hour 310
# Processing HUP142 hour 311
# Processing HUP173
# Processing HUP173 hour 0
# Processing HUP173 hour 1
# Processing HUP173 hour 2
# Processing HUP173 hour 3
# Processing HUP173 hour 4
# Processing HUP173 hour 5
# Processing HUP173 hour 6
# Processing HUP173 hour 7
# Processing HUP173 hour 8
# Processing HUP173 hour 9
# Processing HUP173 hour 10
# Processing HUP173 hour 11
# Processing HUP173 hour 12
# Processing HUP173 hour 13
# Processing HUP173 hour 14
# Processing HUP173 hour 15
# Processing HUP173 hour 16
# Processing HUP173 hour 17
# Processing HUP173 hour 18
# Processing HUP173 hour 19
# Processing HUP173 hour 20
# Processing HUP173 hour 21
# Processing HUP173 hour 22
# Processing HUP173 hour 23
# Processing HUP173 hour 24
# Processing HUP173 hour 25
# Processing HUP173 hour 26
# Processing HUP173 hour 27
# Processing HUP173 hour 28
# Processing HUP173 hour 29
# Processing HUP173 hour 30
# Processing HUP173 hour 31
# Processing HUP173 hour 32
# Processing HUP173 hour 33
# Processing HUP173 hour 34
# Processing HUP173 hour 35
# Processing HUP173 hour 36
# Processing HUP173 hour 37
# Processing HUP173 hour 38
# Processing HUP173 hour 39
# Processing HUP173 hour 40
# Processing HUP173 hour 41
# Processing HUP173 hour 42
# Processing HUP173 hour 43
# Processing HUP173 hour 44
# Processing HUP173 hour 45
# Processing HUP173 hour 46
# Processing HUP173 hour 48
# Processing HUP173 hour 49
# Processing HUP173 hour 50
# Processing HUP173 hour 51
# Processing HUP173 hour 52
# Processing HUP173 hour 53
# Processing HUP173 hour 54
# Processing HUP173 hour 55
# Processing HUP173 hour 56
# Processing HUP173 hour 57
# Processing HUP173 hour 58
# Processing HUP173 hour 59
# Processing HUP173 hour 60
# Processing HUP173 hour 61
# Processing HUP173 hour 62
# Processing HUP173 hour 63
# Processing HUP173 hour 64
# Processing HUP173 hour 65
# Processing HUP173 hour 66
# Processing HUP173 hour 67
# Processing HUP173 hour 68
# Processing HUP173 hour 69
# Processing HUP173 hour 70
# Processing HUP173 hour 71
# Processing HUP173 hour 72
# Processing HUP173 hour 73
# Processing HUP173 hour 74
# Processing HUP173 hour 75
# Processing HUP173 hour 76
# Processing HUP173 hour 77
# Processing HUP173 hour 78
# Processing HUP173 hour 79
# Processing HUP173 hour 80
# Processing HUP173 hour 81
# Processing HUP173 hour 82
# Processing HUP173 hour 83
# Processing HUP173 hour 84
# Processing HUP173 hour 85
# Processing HUP173 hour 86
# Processing HUP173 hour 87
# Processing HUP173 hour 88
# Processing HUP173 hour 89
# Processing HUP173 hour 90
# Processing HUP173 hour 91
# Processing HUP173 hour 92
# Processing HUP173 hour 93
# Processing HUP173 hour 94
# Processing HUP173 hour 95
# Processing HUP173 hour 96
# Processing HUP173 hour 97
# Processing HUP173 hour 98
# Processing HUP173 hour 99
# Processing HUP173 hour 100
# Processing HUP173 hour 101
# Processing HUP173 hour 102
# Processing HUP173 hour 103
# Processing HUP173 hour 104
# Processing HUP173 hour 105
# Processing HUP173 hour 106
# Processing HUP173 hour 107
# Processing HUP173 hour 108
# Processing HUP173 hour 109
# Processing HUP173 hour 110
# Processing HUP173 hour 111
# Processing HUP173 hour 112
# Processing HUP173 hour 113
# Processing HUP173 hour 114
# Processing HUP173 hour 115
# Processing HUP173 hour 116
# Processing HUP173 hour 117
# Processing HUP173 hour 118
# Processing HUP173 hour 119
# Processing HUP173 hour 120
# Processing HUP173 hour 121
# Processing HUP173 hour 122
# Processing HUP173 hour 123
# Processing HUP173 hour 124
# Processing HUP173 hour 125
# Processing HUP173 hour 126
# Processing HUP173 hour 127
# Processing HUP173 hour 128
# Processing HUP173 hour 129
# Processing HUP173 hour 130
# Processing HUP173 hour 131
# Processing HUP173 hour 132
# Processing HUP173 hour 133
# Processing HUP173 hour 134
# Processing HUP173 hour 135
# Processing HUP173 hour 136
# Processing HUP173 hour 137
# Processing HUP173 hour 138
# Processing HUP173 hour 139
# Processing HUP173 hour 140
# Processing HUP173 hour 141
# Processing HUP173 hour 142
# Processing HUP173 hour 143
# Processing HUP173 hour 144
# Processing HUP173 hour 145
# Processing HUP173 hour 146
# Processing HUP173 hour 147
# Processing HUP173 hour 148
# Processing HUP173 hour 149
# Processing HUP173 hour 150
# Processing HUP173 hour 151
# Processing HUP173 hour 152
# Processing HUP173 hour 153
# Processing HUP173 hour 154
# Processing HUP173 hour 155
# Processing HUP173 hour 156
# Processing HUP173 hour 157
# Processing HUP173 hour 158
# Processing HUP173 hour 159
# Processing HUP173 hour 160
# Processing HUP173 hour 161
# Processing HUP173 hour 162
# Processing HUP173 hour 163
# Processing HUP173 hour 164
# Processing HUP173 hour 165
# Processing HUP173 hour 166
# Processing HUP173 hour 167
# Processing HUP173 hour 168
# Processing HUP173 hour 169
# Processing HUP173 hour 170
# Processing HUP173 hour 171
# Processing HUP173 hour 172
# Processing HUP173 hour 173
# Processing HUP173 hour 174
# Processing HUP173 hour 175
# Processing HUP173 hour 176
# Processing HUP173 hour 177
# Processing HUP173 hour 178
# Processing HUP173 hour 179
# Processing HUP173 hour 180
# Processing HUP173 hour 181
# Processing HUP173 hour 182
# Processing HUP173 hour 183
# Processing HUP173 hour 184
# Processing HUP173 hour 185
# Processing HUP173 hour 186
# Processing HUP173 hour 187
# Processing HUP173 hour 188
# Processing HUP173 hour 189
# Processing HUP173 hour 190
# Processing HUP173 hour 191
# Processing HUP173 hour 192
# Processing HUP173 hour 193
# Processing HUP173 hour 194
# Processing HUP173 hour 195
# Processing HUP173 hour 196
# Processing HUP173 hour 197
# Processing HUP173 hour 198
# Processing HUP173 hour 199
# Processing HUP173 hour 200
# Processing HUP173 hour 201
# Processing HUP173 hour 202
# Processing HUP173 hour 203
# Processing HUP173 hour 204
# Processing HUP173 hour 205
# Processing HUP173 hour 206
# Processing HUP173 hour 207
# Processing HUP173 hour 208
# Processing HUP173 hour 209
# Processing HUP173 hour 210
# Processing HUP173 hour 211
# Processing HUP173 hour 212
# Processing HUP173 hour 213
# Processing HUP173 hour 214
# Processing HUP173 hour 215
# Processing HUP173 hour 216
# Processing HUP173 hour 217
# Processing HUP173 hour 218
# Processing HUP173 hour 219
# Processing HUP173 hour 220
# Processing HUP173 hour 221
# Processing HUP173 hour 222
# Processing HUP173 hour 223
# Processing HUP173 hour 224
# Processing HUP173 hour 225
# Processing HUP173 hour 226
# Processing HUP173 hour 227
# Processing HUP173 hour 228
# Processing HUP173 hour 229
# Processing HUP173 hour 230
# Processing HUP173 hour 231
# Processing HUP173 hour 232
# Processing HUP173 hour 233
# Processing HUP173 hour 234
# Processing HUP173 hour 235
# Processing HUP173 hour 236
# Processing HUP173 hour 237
# Processing HUP185
# Processing HUP185 hour 0
# Processing HUP185 hour 1
# Processing HUP185 hour 2
# Processing HUP185 hour 3
# Processing HUP185 hour 5
# Processing HUP185 hour 6
# Processing HUP185 hour 7
# Processing HUP185 hour 8
# Processing HUP185 hour 9
# Processing HUP185 hour 10
# Processing HUP185 hour 11
# Processing HUP185 hour 12
# Processing HUP185 hour 13
# Processing HUP185 hour 14
# Processing HUP185 hour 15
# Processing HUP185 hour 16
# Processing HUP185 hour 17
# Processing HUP185 hour 18
# Processing HUP185 hour 19
# Processing HUP185 hour 20
# Processing HUP185 hour 21
# Processing HUP185 hour 22
# Processing HUP185 hour 23
# Processing HUP185 hour 24
# Processing HUP185 hour 25
# Processing HUP185 hour 26
# Processing HUP185 hour 27
# Processing HUP185 hour 28
# Processing HUP185 hour 29
# Processing HUP185 hour 30
# Processing HUP185 hour 31
# Processing HUP185 hour 32
# Processing HUP185 hour 41
# Processing HUP185 hour 42
# Processing HUP185 hour 43
# Processing HUP185 hour 44
# Processing HUP185 hour 45
# Processing HUP185 hour 46
# Processing HUP185 hour 47
# Processing HUP185 hour 48
# Processing HUP185 hour 49
# Processing HUP185 hour 50
# Processing HUP185 hour 51
# Processing HUP185 hour 52
# Processing HUP185 hour 53
# Processing HUP185 hour 54
# Processing HUP185 hour 55
# Processing HUP185 hour 56
# Processing HUP185 hour 57
# Processing HUP185 hour 58
# Processing HUP185 hour 59
# Processing HUP185 hour 60
# Processing HUP185 hour 61
# Processing HUP185 hour 62
# Processing HUP185 hour 63
# Processing HUP185 hour 64
# Processing HUP185 hour 65
# Processing HUP185 hour 66
# Processing HUP185 hour 67
# Processing HUP185 hour 68
# Processing HUP185 hour 69
# Processing HUP185 hour 70
# Processing HUP185 hour 71
# Processing HUP185 hour 72
# Processing HUP185 hour 73
# Processing HUP185 hour 74
# Processing HUP185 hour 75
# Processing HUP185 hour 76
# Processing HUP185 hour 77
# Processing HUP185 hour 78
# Processing HUP185 hour 79
# Processing HUP185 hour 80
# Processing HUP185 hour 81
# Processing HUP185 hour 82
# Processing HUP185 hour 83
# Processing HUP185 hour 84
# Processing HUP185 hour 85
# Processing HUP185 hour 86
# Processing HUP185 hour 87
# Processing HUP185 hour 88
# Processing HUP185 hour 89
# Processing HUP185 hour 90
# Processing HUP185 hour 91
# Processing HUP185 hour 92
# Processing HUP185 hour 93
# Processing HUP185 hour 94
# Processing HUP185 hour 95
# Processing HUP185 hour 96
# Processing HUP185 hour 97
# Processing HUP185 hour 98
# Processing HUP185 hour 99
# Processing HUP185 hour 100
# Processing HUP185 hour 101
# Processing HUP185 hour 102
# Processing HUP185 hour 103
# Processing HUP185 hour 104
# Processing HUP185 hour 105
# Processing HUP185 hour 106
# Processing HUP185 hour 107
# Processing HUP185 hour 108
# Processing HUP185 hour 109
# Processing HUP185 hour 110
# Processing HUP185 hour 111
# Processing HUP185 hour 112
# Processing HUP185 hour 113
# Processing HUP185 hour 114
# Processing HUP185 hour 115
# Processing HUP185 hour 116
# Processing HUP185 hour 117
# Processing HUP185 hour 118
# Processing HUP185 hour 119
# Processing HUP185 hour 120
# Processing HUP185 hour 121
# Processing HUP185 hour 122
# Processing HUP185 hour 123
# Processing HUP185 hour 124
# Processing HUP185 hour 125
# Processing HUP185 hour 126
# Processing HUP185 hour 127
# Processing HUP185 hour 128
# Processing HUP185 hour 129
# Processing HUP185 hour 130
# Processing HUP185 hour 131
# Processing HUP185 hour 132
# Processing HUP185 hour 133
# Processing HUP185 hour 134
# Processing HUP185 hour 135
# Processing HUP185 hour 136
# Processing HUP185 hour 137
# Processing HUP185 hour 138
# Processing HUP185 hour 139
# Processing HUP185 hour 140
# Processing HUP185 hour 141
# Processing HUP185 hour 142
# Processing HUP185 hour 143
# Processing HUP185 hour 144
# Processing HUP185 hour 145
# Processing HUP185 hour 152
# Processing HUP185 hour 153
# Processing HUP185 hour 154
# Processing HUP185 hour 155
# Processing HUP185 hour 156
# Processing HUP185 hour 157
# Processing HUP185 hour 158
# Processing HUP185 hour 159
# Processing HUP185 hour 160
# Processing HUP185 hour 161
# Processing HUP185 hour 162
# Processing HUP185 hour 163
# Processing HUP185 hour 164
# Processing HUP185 hour 165
# Processing HUP185 hour 166
# Processing HUP185 hour 167
# Processing HUP185 hour 168
# Processing HUP185 hour 169
# Processing HUP185 hour 170
# Processing HUP185 hour 171
# Processing HUP185 hour 172
# Processing HUP185 hour 173
# Processing HUP185 hour 174
# Processing HUP185 hour 175
# Processing HUP185 hour 176
# Processing HUP185 hour 177
# Processing HUP185 hour 178
# Processing HUP185 hour 179
# Processing HUP185 hour 180
# Processing HUP185 hour 181
# Processing HUP185 hour 182
# Processing HUP185 hour 183
# Processing HUP185 hour 184
# Processing HUP185 hour 185
# Processing HUP185 hour 186
# Processing HUP185 hour 187
# Processing HUP185 hour 188
# Processing HUP185 hour 189
# Processing HUP185 hour 190
# Processing HUP185 hour 191
# Processing HUP185 hour 192
# Processing HUP185 hour 193
# Processing HUP185 hour 194
# Processing HUP185 hour 195
# Processing HUP185 hour 196
# Processing HUP185 hour 197
# Processing HUP185 hour 198
# Processing HUP185 hour 199
# Processing HUP185 hour 200
# Processing HUP185 hour 201
# Processing HUP185 hour 202
# Processing HUP185 hour 203
# Processing HUP185 hour 204
# Processing HUP185 hour 205
# Processing HUP185 hour 206
# Processing HUP185 hour 207
# Processing HUP185 hour 208
# Processing HUP185 hour 209
# Processing HUP185 hour 210
# Processing HUP185 hour 211
# Processing HUP185 hour 212
# Processing HUP185 hour 213
# Processing HUP185 hour 214
# Processing HUP185 hour 215
# Processing HUP185 hour 216
# Processing HUP185 hour 217
# Processing HUP185 hour 218
# Processing HUP185 hour 219
# Processing HUP185 hour 220
# Processing HUP185 hour 221
# Processing HUP185 hour 222
# Processing HUP185 hour 223
# Processing HUP185 hour 224
# Processing HUP185 hour 225
# Processing HUP185 hour 226
# Processing HUP185 hour 227
# Processing HUP185 hour 228
# Processing HUP185 hour 229
# Processing HUP185 hour 230
# Processing HUP185 hour 231
# Processing HUP185 hour 232
# Processing HUP187
# Processing HUP187 hour 0
# Processing HUP187 hour 1
# Processing HUP187 hour 2
# Processing HUP187 hour 3
# Processing HUP187 hour 4
# Processing HUP187 hour 5
# Processing HUP187 hour 6
# Processing HUP187 hour 7
# Processing HUP187 hour 8
# Processing HUP187 hour 9
# Processing HUP187 hour 10
# Processing HUP187 hour 11
# Processing HUP187 hour 12
# Processing HUP187 hour 13
# Processing HUP187 hour 14
# Processing HUP187 hour 15
# Processing HUP187 hour 16
# Processing HUP187 hour 17
# Processing HUP187 hour 18
# Processing HUP187 hour 19
# Processing HUP187 hour 20
# Processing HUP187 hour 21
# Processing HUP187 hour 22
# Processing HUP187 hour 23
# Processing HUP187 hour 24
# Processing HUP187 hour 25
# Processing HUP187 hour 26
# Processing HUP187 hour 27
# Processing HUP187 hour 28
# Processing HUP187 hour 29
# Processing HUP187 hour 30
# Processing HUP187 hour 31
# Processing HUP187 hour 32
# Processing HUP187 hour 33
# Processing HUP187 hour 34
# Processing HUP187 hour 35
# Processing HUP187 hour 36
# Processing HUP187 hour 37
# Processing HUP187 hour 38
# Processing HUP187 hour 39
# Processing HUP187 hour 40
# Processing HUP187 hour 41
# Processing HUP187 hour 42
# Processing HUP187 hour 43
# Processing HUP187 hour 44
# Processing HUP187 hour 45
# Processing HUP187 hour 46
# Processing HUP187 hour 47
# Processing HUP187 hour 48
# Processing HUP187 hour 49
# Processing HUP187 hour 50
# Processing HUP187 hour 51
# Processing HUP187 hour 52
# Processing HUP187 hour 53
# Processing HUP187 hour 54
# Processing HUP187 hour 55
# Processing HUP187 hour 56
# Processing HUP187 hour 57
# Processing HUP187 hour 58
# Processing HUP187 hour 59
# Processing HUP187 hour 60
# Processing HUP187 hour 61
# Processing HUP187 hour 62
# Processing HUP187 hour 63
# Processing HUP187 hour 64
# Processing HUP187 hour 65
# Processing HUP187 hour 66
# Processing HUP187 hour 67
# Processing HUP187 hour 68
# Processing HUP187 hour 69
# Processing HUP187 hour 70
# Processing HUP187 hour 71
# Processing HUP187 hour 72
# Processing HUP187 hour 73
# Processing HUP187 hour 74
# Processing HUP187 hour 75
# Processing HUP187 hour 76
# Processing HUP187 hour 77
# Processing HUP187 hour 78
# Processing HUP187 hour 79
# Processing HUP187 hour 80
# Processing HUP187 hour 81
# Processing HUP187 hour 82
# Processing HUP187 hour 83
# Processing HUP187 hour 84
# Processing HUP187 hour 85
# Processing HUP187 hour 86
# Processing HUP187 hour 87
# Processing HUP187 hour 88
# Processing HUP187 hour 89
# Processing HUP187 hour 90
# Processing HUP187 hour 91
# Processing HUP187 hour 92
# Processing HUP187 hour 93
# Processing HUP187 hour 94
# Processing HUP187 hour 95
# Processing HUP187 hour 96
# Processing HUP187 hour 97
# Processing HUP187 hour 98
# Processing HUP187 hour 99
# Processing HUP187 hour 100
# Processing HUP187 hour 101
# Processing HUP187 hour 102
# Processing HUP187 hour 103
# Processing HUP187 hour 104
# Processing HUP187 hour 105
# Processing HUP187 hour 106
# Processing HUP187 hour 107
# Processing HUP187 hour 108
# Processing HUP187 hour 109
# Processing HUP187 hour 110
# Processing HUP187 hour 111
# Processing HUP187 hour 112
# Processing HUP187 hour 113
# Processing HUP187 hour 114
# Processing HUP187 hour 115
# Processing HUP187 hour 116
# Processing HUP187 hour 117
# Processing HUP187 hour 118
# Processing HUP187 hour 119
# Processing HUP187 hour 120
# Processing HUP187 hour 121
# Processing HUP187 hour 122
# Processing HUP187 hour 123
# Processing HUP187 hour 124
# Processing HUP187 hour 125
# Processing HUP187 hour 126
# Processing HUP187 hour 127
# Processing HUP187 hour 128
# Processing HUP187 hour 129
# Processing HUP187 hour 130
# Processing HUP187 hour 131
# Processing HUP187 hour 132
# Processing HUP187 hour 133
# Processing HUP187 hour 134
# Processing HUP187 hour 135
# Processing HUP187 hour 136
# Processing HUP187 hour 137
# Processing HUP187 hour 138
# Processing HUP187 hour 142
# Processing HUP187 hour 143
# Processing HUP187 hour 144
# Processing HUP187 hour 145
# Processing HUP187 hour 146
# Processing HUP187 hour 147
# Processing HUP187 hour 148
# Processing HUP187 hour 149
# Processing HUP187 hour 150
# Processing HUP187 hour 151
# Processing HUP187 hour 152
# Processing HUP187 hour 153
# Processing HUP187 hour 154
# Processing HUP187 hour 155
# Processing HUP187 hour 156
# Processing HUP187 hour 157
# Processing HUP187 hour 158
# Processing HUP187 hour 159
# Processing HUP187 hour 160
# Processing HUP187 hour 161
# Processing HUP187 hour 162
# Processing HUP187 hour 163
# Processing HUP187 hour 164
# Processing HUP187 hour 165
# Processing HUP187 hour 166
# Processing HUP187 hour 167
# Processing HUP187 hour 168
# Processing HUP187 hour 169
# Processing HUP187 hour 170
# Processing HUP187 hour 171
# Processing HUP187 hour 172
# Processing HUP187 hour 173
# Processing HUP187 hour 174
# Processing HUP187 hour 175
# Processing HUP187 hour 176
# Processing HUP187 hour 177
# Processing HUP190
# Processing HUP190 hour 0
# Processing HUP190 hour 1
# Processing HUP190 hour 2
# Processing HUP190 hour 3
# Processing HUP190 hour 4
# Processing HUP190 hour 5
# Processing HUP190 hour 6
# Processing HUP190 hour 7
# Processing HUP190 hour 8
# Processing HUP190 hour 9
# Processing HUP190 hour 10
# Processing HUP190 hour 11
# Processing HUP190 hour 12
# Processing HUP190 hour 13
# Processing HUP190 hour 14
# Processing HUP190 hour 15
# Processing HUP190 hour 16
# Processing HUP190 hour 17
# Processing HUP190 hour 18
# Processing HUP190 hour 19
# Processing HUP190 hour 20
# Processing HUP190 hour 21
# Processing HUP190 hour 22
# Processing HUP190 hour 23
# Processing HUP190 hour 24
# Processing HUP190 hour 25
# Processing HUP190 hour 26
# Processing HUP190 hour 27
# Processing HUP190 hour 28
# Processing HUP190 hour 29
# Processing HUP190 hour 30
# Processing HUP190 hour 31
# Processing HUP190 hour 32
# Processing HUP190 hour 33
# Processing HUP190 hour 34
# Processing HUP190 hour 35
# Processing HUP190 hour 36
# Processing HUP190 hour 37
# Processing HUP190 hour 38
# Processing HUP190 hour 39
# Processing HUP190 hour 40
# Processing HUP190 hour 41
# Processing HUP190 hour 42
# Processing HUP190 hour 43
# Processing HUP190 hour 44
# Processing HUP190 hour 45
# Processing HUP190 hour 46
# Processing HUP190 hour 47
# Processing HUP190 hour 48
# Processing HUP190 hour 49
# Processing HUP190 hour 50
# Processing HUP190 hour 51
# Processing HUP190 hour 52
# Processing HUP190 hour 53
# Processing HUP190 hour 54
# Processing HUP190 hour 55
# Processing HUP190 hour 56
# Processing HUP190 hour 57
# Processing HUP190 hour 58
# Processing HUP190 hour 59
# Processing HUP190 hour 60
# Processing HUP190 hour 61
# Processing HUP190 hour 62
# Processing HUP190 hour 63
# Processing HUP190 hour 64
# Processing HUP190 hour 65
# Processing HUP190 hour 66
# Processing HUP190 hour 67
# Processing HUP190 hour 68
# Processing HUP190 hour 69
# Processing HUP190 hour 70
# Processing HUP190 hour 71
# Processing HUP190 hour 72
# Processing HUP190 hour 73
# Processing HUP190 hour 74
# Processing HUP190 hour 75
# Processing HUP190 hour 76
# Processing HUP190 hour 77
# Processing HUP190 hour 78
# Processing HUP190 hour 79
# Processing HUP190 hour 80
# Processing HUP190 hour 81
# Processing HUP190 hour 82
# Processing HUP190 hour 83
# Processing HUP190 hour 84
# Processing HUP190 hour 85
# Processing HUP190 hour 86
# Processing HUP190 hour 87
# Processing HUP190 hour 88
# Processing HUP190 hour 89
# Processing HUP190 hour 90
# Processing HUP190 hour 91
# Processing HUP190 hour 92
# Processing HUP190 hour 93
# Processing HUP190 hour 94
# Processing HUP190 hour 95
# Processing HUP190 hour 96
# Processing HUP190 hour 97
# Processing HUP190 hour 98
# Processing HUP190 hour 99
# Processing HUP190 hour 100
# Processing HUP190 hour 101
# Processing HUP190 hour 102
# Processing HUP190 hour 103
# Processing HUP190 hour 104
# Processing HUP190 hour 105
# Processing HUP190 hour 106
# Processing HUP190 hour 107
# Processing HUP190 hour 108
# Processing HUP190 hour 109
# Processing HUP190 hour 110
# Processing HUP190 hour 111
# Processing HUP190 hour 112
# Processing HUP190 hour 113
# Processing HUP190 hour 114
# Processing HUP190 hour 115
# Processing HUP190 hour 116
# Processing HUP190 hour 117
# Processing HUP190 hour 118
# Processing HUP190 hour 119
# Processing HUP190 hour 120
# Processing HUP190 hour 121
# Processing HUP190 hour 122
# Processing HUP190 hour 123
# Processing HUP190 hour 124
# Processing HUP190 hour 125
# Processing HUP190 hour 126
# Processing HUP190 hour 127
# Processing HUP190 hour 128
# Processing HUP190 hour 129
# Processing HUP190 hour 130
# Processing HUP190 hour 131
# Processing HUP190 hour 132
# Processing HUP190 hour 133
# Processing HUP190 hour 134
# Processing HUP190 hour 135
# Processing HUP190 hour 136
# Processing HUP190 hour 137
# Processing HUP190 hour 138
# Processing HUP190 hour 139
# Processing HUP190 hour 140
# Processing HUP190 hour 141
# Processing HUP190 hour 142
# Processing HUP190 hour 143
# Processing HUP190 hour 144
# Processing HUP190 hour 145
# Processing HUP190 hour 146
# Processing HUP190 hour 147
# Processing HUP190 hour 148
# Processing HUP190 hour 149
# Processing HUP190 hour 150
# Processing HUP190 hour 151
# Processing HUP190 hour 152
# Processing HUP190 hour 153
# Processing HUP190 hour 154
# Processing HUP190 hour 155
# Processing HUP190 hour 156
# Processing HUP190 hour 157
# Processing HUP190 hour 158
# Processing HUP190 hour 159
# Processing HUP190 hour 160
# Processing HUP190 hour 161
# Processing HUP190 hour 162
# Processing HUP190 hour 163
# Processing HUP190 hour 164
# Processing HUP190 hour 165
# Processing HUP190 hour 166
# Processing HUP190 hour 167
# Processing HUP190 hour 168
# Processing HUP190 hour 169
# Processing HUP190 hour 170
# Processing HUP190 hour 171
# Processing HUP190 hour 172
# Processing HUP190 hour 173
# Processing HUP190 hour 174
# Processing HUP190 hour 175
# Processing HUP190 hour 176
# Processing HUP190 hour 177
# Processing HUP190 hour 178
# Processing HUP190 hour 179
# Processing HUP190 hour 180
# Processing HUP190 hour 181
# Processing HUP190 hour 182
# Processing HUP190 hour 183
# Processing HUP190 hour 184
# Processing HUP190 hour 185
# Processing HUP190 hour 186
# Processing HUP190 hour 187
# Processing HUP190 hour 188
# Processing HUP190 hour 189
# Processing HUP190 hour 190
# Processing HUP190 hour 191
# Processing HUP190 hour 192
# Processing HUP190 hour 193
# Processing HUP190 hour 194
# Processing HUP190 hour 195
# Processing HUP190 hour 196
# Processing HUP190 hour 197
# Processing HUP190 hour 198
# Processing HUP190 hour 199
# Processing HUP190 hour 200
# Processing HUP190 hour 201
# Processing HUP190 hour 202
# Processing HUP190 hour 203
# Processing HUP190 hour 204
# Processing HUP190 hour 205
# Processing HUP190 hour 206
# Processing HUP190 hour 207
# Processing HUP190 hour 208
# Processing HUP190 hour 209
# Processing HUP190 hour 210
# Processing HUP190 hour 211
# Processing HUP190 hour 212
# Processing HUP190 hour 213
# Processing HUP190 hour 214
# Processing HUP190 hour 215
# Processing HUP190 hour 216
# Processing HUP190 hour 217
# Processing HUP190 hour 218
# Processing HUP190 hour 219
# Processing HUP190 hour 220
# Processing HUP190 hour 221
# Processing HUP190 hour 222
# Processing HUP190 hour 223
# Processing HUP190 hour 224
# Processing HUP190 hour 225
# Processing HUP190 hour 226
# Processing HUP190 hour 227
# Processing HUP190 hour 228
# Processing HUP190 hour 229
# Processing HUP190 hour 230
# Processing HUP190 hour 231
# Processing HUP190 hour 232
# Processing HUP190 hour 233
# Processing HUP190 hour 234
# Processing HUP190 hour 235
# Processing HUP190 hour 236
# Processing HUP190 hour 237
# Processing HUP190 hour 238
# Processing HUP190 hour 239
# Processing HUP190 hour 240
# Processing HUP190 hour 241
# Processing HUP190 hour 242
# Processing HUP190 hour 243
# Processing HUP190 hour 244
# Processing HUP190 hour 245
# Processing HUP190 hour 246
# Processing HUP190 hour 247
# Processing HUP190 hour 248
# Processing HUP190 hour 249
# Processing HUP190 hour 250
# Processing HUP190 hour 251
# Processing HUP190 hour 252
# Processing HUP190 hour 253
# Processing HUP190 hour 254
# Processing HUP190 hour 255
# Processing HUP190 hour 256
# Processing HUP190 hour 257
# Processing HUP190 hour 258
# Processing HUP190 hour 259
# Processing HUP190 hour 260
# Processing HUP190 hour 261
# Processing HUP190 hour 262
# Processing HUP190 hour 263
# Processing HUP190 hour 264
# Processing HUP190 hour 265
# Processing HUP190 hour 266
# Processing HUP190 hour 267
# Processing HUP190 hour 268
# Processing HUP190 hour 269
# Processing HUP190 hour 270
# Processing HUP190 hour 271
# Processing HUP190 hour 272
# Processing HUP190 hour 273
# Processing HUP190 hour 274
# Processing HUP190 hour 275
# Processing HUP190 hour 276
# Processing HUP190 hour 277
# Processing HUP190 hour 278
# Processing HUP190 hour 279
# Processing HUP190 hour 280
# Processing HUP190 hour 281
# Processing HUP190 hour 282
# Processing HUP190 hour 283
# Processing HUP190 hour 284
# Processing HUP190 hour 285
# Processing HUP190 hour 286
# Processing HUP190 hour 287
# Processing HUP190 hour 288
# Processing HUP190 hour 289
# Processing HUP190 hour 290
# Processing HUP190 hour 291
# Processing HUP190 hour 292
# Processing HUP190 hour 293
# Processing HUP190 hour 294
# Processing HUP190 hour 295
# Processing HUP190 hour 296
# Processing HUP190 hour 297
# Processing HUP190 hour 298
# Processing HUP190 hour 299
# Processing HUP190 hour 300
# Processing HUP190 hour 301
# Processing HUP190 hour 302
# Processing HUP190 hour 303
# Processing HUP190 hour 304
# Processing HUP190 hour 305
# Processing HUP190 hour 306
# Processing HUP202
# Processing HUP202 hour 0
# Processing HUP202 hour 1
# Processing HUP202 hour 2
# Processing HUP202 hour 3
# Processing HUP202 hour 4
# Processing HUP202 hour 5
# Processing HUP202 hour 6
# Processing HUP202 hour 7
# Processing HUP202 hour 8
# Processing HUP202 hour 9
# Processing HUP202 hour 10
# Processing HUP202 hour 11
# Processing HUP202 hour 12
# Processing HUP202 hour 13
# Processing HUP202 hour 14
# Processing HUP202 hour 15
# Processing HUP202 hour 16
# Processing HUP202 hour 17
# Processing HUP202 hour 18
# Processing HUP202 hour 19
# Processing HUP202 hour 20
# Processing HUP202 hour 21
# Processing HUP202 hour 22
# Processing HUP202 hour 23
# Processing HUP202 hour 24
# Processing HUP202 hour 25
# Processing HUP202 hour 26
# Processing HUP202 hour 27
# Processing HUP202 hour 28
# Processing HUP202 hour 29
# Processing HUP202 hour 30
# Processing HUP202 hour 31
# Processing HUP202 hour 32
# Processing HUP202 hour 33
# Processing HUP202 hour 34
# Processing HUP202 hour 35
# Processing HUP202 hour 36
# Processing HUP202 hour 37
# Processing HUP202 hour 38
# Processing HUP202 hour 39
# Processing HUP202 hour 40
# Processing HUP202 hour 41
# Processing HUP202 hour 42
# Processing HUP202 hour 43
# Processing HUP202 hour 44
# Processing HUP202 hour 45
# Processing HUP202 hour 46
# Processing HUP202 hour 47
# Processing HUP202 hour 48
# Processing HUP202 hour 49
# Processing HUP202 hour 50
# Processing HUP202 hour 51
# Processing HUP202 hour 52
# Processing HUP202 hour 53
# Processing HUP202 hour 54
# Processing HUP202 hour 55
# Processing HUP202 hour 56
# Processing HUP202 hour 57
# Processing HUP202 hour 58
# Processing HUP202 hour 59
# Processing HUP202 hour 60
# Processing HUP202 hour 61
# Processing HUP202 hour 62
# Processing HUP202 hour 63
# Processing HUP202 hour 64
# Processing HUP202 hour 65
# Processing HUP202 hour 66
# Processing HUP202 hour 67
# Processing HUP202 hour 68
# Processing HUP202 hour 69
# Processing HUP202 hour 70
# Processing HUP202 hour 71
# Processing HUP202 hour 72
# Processing HUP202 hour 73
# Processing HUP202 hour 74
# Processing HUP202 hour 75
# Processing HUP202 hour 76
# Processing HUP202 hour 77
# Processing HUP202 hour 78
# Processing HUP202 hour 79
# Processing HUP202 hour 80
# Processing HUP202 hour 81
# Processing HUP202 hour 82
# Processing HUP202 hour 83
# Processing HUP202 hour 84
# Processing HUP202 hour 85
# Processing HUP202 hour 86
# Processing HUP202 hour 87
# Processing HUP202 hour 88
# Processing HUP202 hour 89
# Processing HUP202 hour 90
# Processing HUP202 hour 91
# Processing HUP202 hour 92
# Processing HUP202 hour 93
# Processing HUP202 hour 94
# Processing HUP202 hour 95
# Processing HUP202 hour 96
# Processing HUP202 hour 97
# Processing HUP202 hour 98
# Processing HUP202 hour 99
# Processing HUP202 hour 100
# Processing HUP202 hour 101
# Processing HUP202 hour 102
# Processing HUP202 hour 103
# Processing HUP202 hour 104
# Processing HUP202 hour 105
# Processing HUP202 hour 106
# Processing HUP202 hour 107
# Processing HUP202 hour 108
# Processing HUP202 hour 109
# Processing HUP202 hour 110
# Processing HUP202 hour 111
# Processing HUP202 hour 112
# Processing HUP202 hour 138
# Processing HUP202 hour 139
# Processing HUP202 hour 140
# Processing HUP202 hour 141
# Processing HUP202 hour 142
# Processing HUP202 hour 143
# Processing HUP202 hour 144
# Processing HUP202 hour 145
# Processing HUP202 hour 146
# Processing HUP202 hour 147
# Processing HUP202 hour 148
# Processing HUP202 hour 149
# Processing HUP202 hour 150
# Processing HUP202 hour 151
# Processing HUP202 hour 152
# Processing HUP202 hour 153
# Processing HUP202 hour 154
# Processing HUP202 hour 155
# Processing HUP202 hour 156
# Processing HUP202 hour 157
# Processing HUP202 hour 158
# Processing HUP202 hour 159
# Processing HUP202 hour 160
# Processing HUP202 hour 161
# Processing HUP202 hour 162
# Processing HUP202 hour 163
# Processing HUP202 hour 164
# Processing HUP202 hour 165
# Processing HUP202 hour 166
# Processing HUP202 hour 167
# Processing HUP202 hour 168
# Processing HUP202 hour 169
# Processing HUP202 hour 170
# Processing HUP202 hour 171
# Processing HUP202 hour 172
# Processing HUP202 hour 173
# Processing HUP202 hour 174
# Processing HUP202 hour 175
# Processing HUP202 hour 176
# Processing HUP202 hour 177
# Processing HUP202 hour 178
# Processing HUP202 hour 179
# Processing HUP202 hour 180
# Processing HUP202 hour 181
# Processing HUP202 hour 182
# Processing HUP202 hour 183
# Processing HUP202 hour 184
# Processing HUP202 hour 185
# Processing HUP202 hour 186
# Processing HUP202 hour 187
# Processing HUP202 hour 188
# Processing HUP202 hour 189
# Processing HUP202 hour 190
# Processing HUP204
# Processing HUP204 hour 0
# Processing HUP204 hour 1
# Processing HUP204 hour 2
# Processing HUP204 hour 3
# Processing HUP204 hour 4
# Processing HUP204 hour 5
# Processing HUP204 hour 6
# Processing HUP204 hour 7
# Processing HUP204 hour 8
# Processing HUP204 hour 9
# Processing HUP204 hour 10
# Processing HUP204 hour 11
# Processing HUP204 hour 12
# Processing HUP204 hour 13
# Processing HUP204 hour 14
# Processing HUP204 hour 15
# Processing HUP204 hour 16
# Processing HUP204 hour 17
# Processing HUP204 hour 18
# Processing HUP204 hour 19
# Processing HUP204 hour 20
# Processing HUP204 hour 21
# Processing HUP204 hour 22
# Processing HUP204 hour 23
# Processing HUP204 hour 24
# Processing HUP204 hour 25
# Processing HUP204 hour 26
# Processing HUP204 hour 27
# Processing HUP204 hour 28
# Processing HUP204 hour 29
# Processing HUP204 hour 30
# Processing HUP204 hour 31
# Processing HUP204 hour 32
# Processing HUP204 hour 33
# Processing HUP204 hour 34
# Processing HUP204 hour 35
# Processing HUP204 hour 36
# Processing HUP204 hour 37
# Processing HUP204 hour 38
# Processing HUP204 hour 39
# Processing HUP204 hour 40
# Processing HUP204 hour 41
# Processing HUP204 hour 42
# Processing HUP204 hour 43
# Processing HUP204 hour 44
# Processing HUP204 hour 45
# Processing HUP204 hour 46
# Processing HUP204 hour 47
# Processing HUP204 hour 48
# Processing HUP204 hour 49
# Processing HUP204 hour 50
# Processing HUP204 hour 51
# Processing HUP204 hour 52
# Processing HUP204 hour 53
# Processing HUP204 hour 54
# Processing HUP204 hour 55
# Processing HUP204 hour 56
# Processing HUP204 hour 57
# Processing HUP204 hour 58
# Processing HUP204 hour 59
# Processing HUP204 hour 60
# Processing HUP204 hour 61
# Processing HUP204 hour 62
# Processing HUP204 hour 63
# Processing HUP204 hour 64
# Processing HUP204 hour 65
# Processing HUP204 hour 66
# Processing HUP204 hour 67
# Processing HUP204 hour 68
# Processing HUP204 hour 69
# Processing HUP204 hour 70
# Processing HUP204 hour 71
# Processing HUP204 hour 72
# Processing HUP204 hour 73
# Processing HUP204 hour 74
# Processing HUP204 hour 75
# Processing HUP204 hour 76
# Processing HUP204 hour 77
# Processing HUP204 hour 78
# Processing HUP204 hour 79
# Processing HUP204 hour 80
# Processing HUP204 hour 81
# Processing HUP204 hour 82
# Processing HUP204 hour 83
# Processing HUP204 hour 84
# Processing HUP204 hour 85
# Processing HUP204 hour 86
# Processing HUP204 hour 87
# Processing HUP204 hour 88
# Processing HUP204 hour 89
# Processing HUP204 hour 90
# Processing HUP204 hour 91
# Processing HUP204 hour 92
# Processing HUP204 hour 99
# Processing HUP204 hour 100
# Processing HUP204 hour 101
# Processing HUP204 hour 102
# Processing HUP204 hour 103
# Processing HUP204 hour 104
# Processing HUP204 hour 105
# Processing HUP204 hour 106
# Processing HUP204 hour 107
# Processing HUP204 hour 108
# Processing HUP204 hour 109
# Processing HUP204 hour 110
# Processing HUP204 hour 111
# Processing HUP204 hour 112
# Processing HUP204 hour 113
# Processing HUP204 hour 114
# Processing HUP204 hour 115
# Processing HUP204 hour 116
# Processing HUP204 hour 117
# Processing HUP204 hour 118
# Processing HUP204 hour 119
# Processing HUP204 hour 120
# Processing HUP204 hour 121
# Processing HUP204 hour 122
# Processing HUP223
# Processing HUP223 hour 0
# Processing HUP223 hour 1
# Processing HUP223 hour 2
# Processing HUP223 hour 3
# Processing HUP223 hour 4
# Processing HUP223 hour 5
# Processing HUP223 hour 6
# Processing HUP223 hour 7
# Processing HUP223 hour 8
# Processing HUP223 hour 9
# Processing HUP223 hour 10
# Processing HUP223 hour 11
# Processing HUP223 hour 12
# Processing HUP223 hour 13
# Processing HUP223 hour 14
# Processing HUP223 hour 15
# Processing HUP223 hour 16
# Processing HUP223 hour 17
# Processing HUP223 hour 18
# Processing HUP223 hour 19
# Processing HUP223 hour 20
# Processing HUP223 hour 21
# Processing HUP223 hour 22
# Processing HUP223 hour 23
# Processing HUP223 hour 24
# Processing HUP223 hour 25
# Processing HUP223 hour 26
# Processing HUP223 hour 27
# Processing HUP223 hour 28
# Processing HUP223 hour 29
# Processing HUP223 hour 30
# Processing HUP223 hour 31
# Processing HUP223 hour 32
# Processing HUP223 hour 33
# Processing HUP223 hour 34
# Processing HUP223 hour 35
# Processing HUP223 hour 36
# Processing HUP223 hour 37
# Processing HUP223 hour 38
# Processing HUP223 hour 39
# Processing HUP223 hour 40
# Processing HUP223 hour 41
# Processing HUP223 hour 42
# Processing HUP223 hour 43
# Processing HUP223 hour 44
# Processing HUP223 hour 45
# Processing HUP223 hour 46
# Processing HUP223 hour 47
# Processing HUP223 hour 48
# Processing HUP223 hour 49
# Processing HUP223 hour 50
# Processing HUP223 hour 51
# Processing HUP223 hour 52
# Processing HUP223 hour 53
# Processing HUP223 hour 54
# Processing HUP223 hour 55
# Processing HUP223 hour 56
# Processing HUP223 hour 57
# Processing HUP223 hour 58
# Processing HUP223 hour 59
# Processing HUP223 hour 60
# Processing HUP223 hour 61
# Processing HUP223 hour 62
# Processing HUP223 hour 63
# Processing HUP223 hour 64
# Processing HUP223 hour 65
# Processing HUP223 hour 66
# Processing HUP223 hour 67
# Processing HUP223 hour 68
# Processing HUP223 hour 69
# Processing HUP223 hour 70
# Processing HUP223 hour 71
# Processing HUP223 hour 72
# Processing HUP223 hour 73
# Processing HUP223 hour 74
# Processing HUP223 hour 75
# Processing HUP223 hour 76
# Processing HUP223 hour 77
# Processing HUP223 hour 78
# Processing HUP223 hour 79
# Processing HUP223 hour 80
# Processing HUP223 hour 81
# Processing HUP223 hour 82
# Processing HUP223 hour 83
# Processing HUP223 hour 84
# Processing HUP223 hour 85
# Processing HUP223 hour 86
# Processing HUP223 hour 87
# Processing HUP223 hour 88
# Processing HUP223 hour 89
# Processing HUP223 hour 90
# Processing HUP223 hour 91
# Processing HUP223 hour 92
# Processing HUP223 hour 93
# Processing HUP223 hour 94
# Processing HUP223 hour 95
# Processing HUP223 hour 96
# Processing HUP223 hour 97
# Processing HUP223 hour 98
# Processing HUP223 hour 99
# Processing HUP223 hour 100
# Processing HUP223 hour 101
# Processing HUP223 hour 102
# Processing HUP223 hour 103
# Processing HUP223 hour 104
# Processing HUP223 hour 105
# Processing HUP223 hour 106
# Processing HUP223 hour 107
# Processing HUP223 hour 108
# Processing HUP223 hour 109
# Processing HUP223 hour 110
# Processing HUP223 hour 111
# Processing HUP223 hour 112
# Processing HUP223 hour 113
# Processing HUP223 hour 114
# Processing HUP223 hour 115
# Processing HUP223 hour 116
# Processing HUP223 hour 117
# Processing HUP223 hour 118
# Processing HUP223 hour 119
# Processing HUP223 hour 120
# Processing HUP223 hour 121
# Processing HUP223 hour 122
# Processing HUP223 hour 123
# Processing HUP223 hour 124
# Processing HUP223 hour 125
# Processing HUP223 hour 126
# Processing HUP223 hour 127
# Processing HUP223 hour 128
# Processing HUP223 hour 129
# Processing HUP223 hour 130
# Processing HUP223 hour 131
# Processing HUP223 hour 132
# Processing HUP223 hour 133
# Processing HUP223 hour 134
# Processing HUP223 hour 135

# %% [markdown]
# **Conclusions:**
# 1. Lots of "bad" channels during the first couple hours of EEG recording.
# 2. Maybe those "bad" channels have contaminated my previous analysis?

# %% [markdown]
# ### 3.2.3: First Pass with Bipolar Re-Referencing

# %%
datasets_df
# Out:
#    hup_id  max_hour  sample_rate
# 0     138       172         1024
# 1     141       146          512
# 2     142       311          512
# 3     173       237          256
# 4     185       232          512
# 5     187       177          512
# 6     190       306         1024
# 7     202       190          512
# 8     204       122          512
# 9     223       135         1024

# %%
# Select rows of patients_df that have hup_id in datasets_df
patients_df = patients_df[patients_df["hup_id"].isin(datasets_df["hup_id"])]
patients_df = patients_df.reset_index(drop=True)
patients_df
# Out:
#    hup_id           region lateralization  weight_kg  r_id
# 0     138  mesial temporal           left       84.4   278
# 1     141  mesial temporal          right       85.7   294
# 2     142  mesial temporal           left       65.3   295
# 3     173  mesial temporal          right       76.6    31
# 4     185  mesial temporal           left       76.2   332
# 5     187  mesial temporal          right       86.2   522
# 6     190  mesial temporal           left      105.4   405
# 7     202  mesial temporal           left       89.0   646
# 8     204  mesial temporal           left       82.1   596
# 9     223  mesial temporal           left      101.4   785

# %%
for i, row in patients_df.iterrows():
    # Get patient id and weight
    patient_hup_id, patient_weight = row.hup_id, row.weight_kg
    patient_idx = patient_hup_id_to_index[patient_hup_id]

    # Find the ieeg_start value for patient_hup_id in ieeg_starts_df and convert it into float
    ieeg_start_hrs = float(
        ieeg_starts_df.loc[
            ieeg_starts_df["hup_id"] == patient_hup_id, "ieeg_start"
        ].values[0]
    )
    aligned_emu_start_time_hrs = round(ieeg_start_hrs)

    seizure_times_sec = np.load(f"../../Data/seizures/times/HUP_{patient_hup_id}.npy")
    seizure_times_sec = seizure_times_sec + (ieeg_start_hrs * 3600)

    # Load HUP_{patient_hup_id}.npy from ../../Data/medications
    aed_np_file = np.load(
        f"../../Data/medications/HUP_{patient_hup_id}.npy", allow_pickle=True
    )

    all_dose_curves_plot = aed_np_file[0]
    all_tHr_plot = aed_np_file[1]
    all_med_names_plot = aed_np_file[2]

    # Construct the time axis
    emu_start_time_hrs = min([all_tHr_plot[i][0] for i in range(len(all_tHr_plot))])
    emu_end_time_hrs = all_tHr_plot[0][-1]
    max_dose_duration_hrs = emu_end_time_hrs - emu_start_time_hrs
    max_length = max([len(all_tHr_plot[i]) for i in range(len(all_tHr_plot))])
    time_axis = np.linspace(emu_start_time_hrs, emu_end_time_hrs, max_length)
    print(aligned_emu_start_time_hrs)
    # Print start and end times in one line
    print(
        f"Doses: Start time: {emu_start_time_hrs} hr, End time: {emu_end_time_hrs} hr"
    )

    sum_array = []

    # Create two subplots with shared x-axis
    fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, figsize=(9, 6))

    # Plot dose curves
    for med_idx, med_name in enumerate(all_med_names_plot):
        dose_times = all_tHr_plot[med_idx].flatten()

        # Find Avg for medication med_name in aed_ref_ranges_df
        if med_name == "lorazepam":
            ref_range = 1
        else:
            ref_range = float(
                aed_ref_ranges_df.loc[
                    aed_ref_ranges_df["Drug"] == med_name, "Avg"
                ].values[0]
            )

        # Normalize dose curve according to the middle of the reference range
        dose = all_dose_curves_plot[med_idx].flatten()
        dose = dose / ref_range

        interp_func = interpolate.interp1d(
            dose_times, dose, bounds_error=False, fill_value=0
        )
        dose_interp = interp_func(time_axis)

        if med_name != "lorazepam":
            sum_array.append(dose_interp)

        ax1.plot(time_axis, dose_interp, label=med_name.capitalize())

    # Add legends to the curves
    ax1.legend()
    ax1.set(title=f"AEDs for HUP {patient_hup_id}", ylabel="Normalized Dose")

    cumulative_dose_curve = np.sum(sum_array, axis=0)

    # cumulative_dose_curve = cumulative_dose_curve / cumulative_dose_curve.max()
    assert len(cumulative_dose_curve) == len(
        time_axis
    ), "cumulative_dose_curve and time_axis should have the same length"

    # Convert numpy arrays to pandas DataFrame
    df = pd.DataFrame(data={"Time": time_axis, "Value": cumulative_dose_curve})
    # Create a new column for the integer hour
    df["Hour"] = df["Time"].astype(int)

    # Group by hour and compute mean
    hourly_df = df.groupby("Hour").mean()
    # Create a new column for the day
    df["Day"] = (df["Time"] // 24).astype(int)
    # Group by day and compute mean
    daily_df = df.groupby("Day").mean()

    # Create an array for mean values repeated for each hour
    mean_values_repeated = np.repeat(
        daily_df["Value"].values, df.groupby("Day").size().values
    )
    assert len(mean_values_repeated) == len(
        cumulative_dose_curve
    ), "mean_values_repeated and cumulative_dose_curve should have the same length"

    # Add label to the cumulative dose curve and plot it on the second subplot
    ax2.plot(time_axis, cumulative_dose_curve, label="Cumulative dose", color="black")
    ax2.plot(
        time_axis, mean_values_repeated, label="Daily mean cumul dose", color="red"
    )
    ax2.legend()
    ax2.set(
        title=f"Cumulative Dose for HUP {patient_hup_id}",
        xlabel="Time in Epilepsy Monitoring Unit (hours)",
        ylabel="Normalized dose",
    )

    for seizure_time_sec in seizure_times_sec:
        seizure_time_hr = int(seizure_time_sec[0] / 3600)
        ax1.axvline(x=seizure_time_hr, color="red", linestyle="--")
        ax2.axvline(x=seizure_time_hr, color="red", linestyle="--")
        ax3.axvline(x=seizure_time_hr, color="red", linestyle="--")

    seizure_times_hr = seizure_times_sec / 3600

    # Draw a green vertical line on ax1 and ax2 at the time aligned_emu_start_time_hrs
    ax1.axvline(x=aligned_emu_start_time_hrs, color="black", linestyle="-")
    ax2.axvline(x=aligned_emu_start_time_hrs, color="black", linestyle="-")
    ax3.axvline(x=aligned_emu_start_time_hrs, color="black", linestyle="-")

    # Label it "iEEG Starts", give it red box around it
    ax1.text(
        aligned_emu_start_time_hrs + 0.5,
        0.8,
        "iEEG Starts",
        bbox=dict(facecolor="red", alpha=0.5),
    )

    #########################################
    # Process eeg data
    #########################################

    #########################################
    # Load iEEG data from ./data
    #########################################

    # Create a new dataframe for network metrics
    patient_network_metrics_df = pd.DataFrame(columns=["eeg_hour", "emu_hour", "plv"])

    frequency = (100, 125)

    # Get max_hour value of HUP id in datasets_df
    max_hour = int(datasets_df.loc[datasets_df["hup_id"] == patient_hup_id].max_hour)
    sample_rate = int(
        datasets_df.loc[datasets_df["hup_id"] == patient_hup_id].sample_rate
    )
    print(max_hour, sample_rate)

    eeg_end_time_hrs = max_hour
    selected_eeg_hours = []

    hourly_synchrony = []
    daily_sync = []

    for eeg_hour in range(max_hour + 1):
        print(f"Processing hour {eeg_hour} of {max_hour}")
        filename = f"HUP{patient_hup_id}_phaseII_hr_{eeg_hour}_fs_{sample_rate}.pkl"
        try:
            with open(f"{directory_path}{filename}", "rb") as f:
                eeg_segment_df = pickle.load(f)
        except FileNotFoundError:
            print(f"File {filename} not found, skipping hour {eeg_hour}")
            continue

        channel_labels = eeg_segment_df.columns.to_numpy(dtype=str)
        channel_indices = np.arange(len(channel_labels))

        bad_channel_indicies, bad_details = identify_bad_channels(
            eeg_segment_df.to_numpy(dtype=float),
            channel_indices,
            channel_labels,
            sample_rate,
        )

        # Get the labels of the good indicies
        good_channel_labels = np.delete(channel_labels, bad_channel_indicies)

        # Skip this hour if there are less than 2 good channels, i.e., unable to create a bipolar montage
        if len(good_channel_labels) < 2:
            continue

        bad_channel_labels = channel_labels[bad_channel_indicies]

        # get the data in eeg_segment_df that corresponds to the good channels
        good_channels_eeg_segment_df = eeg_segment_df[good_channel_labels]

        try:
            local_res = create_bipolar_montage(
                good_channels_eeg_segment_df.to_numpy(dtype=float), good_channel_labels
            )
        except ValueError:
            print(f"Skipping hour {eeg_hour} because ValueError")
            continue

        # Check if local_res has at least two columns, i.e., at least two good channels in the bipolar montage, otherwise skip this hour
        if local_res is None:
            print(f"Skipping hour {eeg_hour} because bipolar montage is None")
            continue

        if local_res.shape[1] < 2:
            print(
                f"Skipping hour {eeg_hour} because bipolar montage has less than 2 channels"
            )
            continue

        # These are the data we'll process
        # hourly_eeg.append(local_res)
        df_to_be_processed = local_res.T
        df_filtered = process_eeg_data(
            df_to_be_processed, sample_rate, band_pass_freq=frequency
        )
        R = calculate_kuramoto_order_parameter(df_filtered).mean()
        hourly_synchrony.append(R)
        selected_eeg_hours.append(eeg_hour)
        # Add a row to patient_network_metrics_df with hour=hour and plv=R, using pandas.concat
        patient_network_metrics_df = pd.concat(
            [
                patient_network_metrics_df,
                pd.DataFrame(
                    [[eeg_hour, eeg_hour + aligned_emu_start_time_hrs, R]],
                    columns=["eeg_hour", "emu_hour", "plv"],
                ),
            ]
        )

    if len(selected_eeg_hours) == 0:
        continue

    # Plot emu_hour in patient_network_metrics_df as the x-axis and plv as the y-axis
    ax3.plot(
        patient_network_metrics_df["emu_hour"],
        patient_network_metrics_df["plv"],
        color="green",
    )

    #########################################

    plt.subplots_adjust(hspace=0.3)  # adjust the vertical spacing
    plt.show()

    ###############################
    # Find days with no seizures
    ###############################

    # Add a column for day
    patient_network_metrics_df["emu_day"] = patient_network_metrics_df["emu_hour"] // 24

    # Initialize lists to keep track of days with no seizures
    days_with_no_seizures = []

    # Convert seizure times into days
    seizure_days = seizure_times_hr // 24
    seizure_days = seizure_days.astype(int)

    # Iterate over each emu_day in patient_network_metrics_df
    for day in patient_network_metrics_df["emu_day"].unique():
        # Check if the day had any seizures
        if day not in seizure_days:
            days_with_no_seizures.append(day)

    # Find days with the lowest and highest dosages
    day_with_lowest_dosage = min(
        days_with_no_seizures,
        key=lambda day: daily_df[
            daily_df.index.isin(patient_network_metrics_df["emu_day"])
        ].loc[day, "Value"],
    )
    day_with_highest_dosage = max(
        days_with_no_seizures,
        key=lambda day: daily_df[
            daily_df.index.isin(patient_network_metrics_df["emu_day"])
        ].loc[day, "Value"],
    )

    # Get the dosages on the lowest and highest days
    lowest_dosage = daily_df.loc[day_with_lowest_dosage, "Value"]
    highest_dosage = daily_df.loc[day_with_highest_dosage, "Value"]

    # Print the day numbers with the lowest and highest dosages
    print(f"Day with the lowest dosage: {day_with_lowest_dosage}")
    print(f"Day with the highest dosage: {day_with_highest_dosage}")

    # Plot the dosages
    plt.figure(figsize=(4, 5))
    plt.bar(
        [
            f"Lowest Day - Day {day_with_lowest_dosage}",
            f"Highest Day - Day {day_with_highest_dosage}",
        ],
        [lowest_dosage, highest_dosage],
    )
    plt.title(f"Avg Dosage on Lowest/Highest Days for HUP {patient_hup_id}")
    plt.ylabel("Average Dosage")
    plt.show()

    # Filter the synchrony_df for the day with the lowest and highest dosage
    lowest_day_sync = patient_network_metrics_df[
        patient_network_metrics_df["emu_day"] == day_with_lowest_dosage
    ]["plv"]
    highest_day_sync = patient_network_metrics_df[
        patient_network_metrics_df["emu_day"] == day_with_highest_dosage
    ]["plv"]

    # Plot the dosages
    fig, ax1 = plt.subplots(figsize=(4, 5))

    color = "tab:blue"
    ax1.set_xlabel("Days")
    ax1.set_ylabel("Average Dosage", color=color)
    ax1.bar(
        [
            f"Lowest Day - Day {day_with_lowest_dosage}",
            f"Highest Day - Day {day_with_highest_dosage}",
        ],
        [lowest_dosage, highest_dosage],
        color=color,
    )
    ax1.tick_params(axis="y", labelcolor=color)

    # Create a second y-axis
    ax2 = ax1.twinx()
    color = "tab:red"
    ax2.set_ylabel("Synchrony R", color=color)

    # Plot the box plots for the synchrony values
    bp = ax2.boxplot(
        [lowest_day_sync, highest_day_sync],
        positions=[0, 1],
        widths=0.4,
        vert=True,
        patch_artist=True,
        notch=True,
    )

    # Change color of each box
    for patch in bp["boxes"]:
        patch.set(facecolor=color)

    ax2.tick_params(axis="y", labelcolor=color)

    fig.tight_layout()
    plt.title(
        f"Avg Dosage and Synchrony on Lowest/Highest Days for HUP {patient_hup_id}"
    )
    plt.show()

# %%
# Find days with the lowest and highest dosages
day_with_lowest_dosage = min(
    days_with_no_seizures, key=lambda day: daily_df.loc[day, "Value"]
)
day_with_highest_dosage = max(
    days_with_no_seizures, key=lambda day: daily_df.loc[day, "Value"]
)
day_with_lowest_dosage, day_with_highest_dosage

# %%
patient_network_metrics_df
# Out:
#    eeg_hour emu_hour       plv emu_day
# 0         1       40  0.194191       1
# 0         2       41  0.196589       1
# 0         3       42  0.201463       1
# 0         4       43  0.195035       1
# 0         5       44  0.189543       1
# ..      ...      ...       ...     ...
# 0       233      272  0.172540      11
# 0       234      273  0.210344      11
# 0       235      274  0.179396      11
# 0       236      275  0.182096      11
# 0       237      276  0.181423      11
#
# [236 rows x 4 columns]

# %%
# Add a column for day
patient_network_metrics_df["emu_day"] = patient_network_metrics_df["emu_hour"] // 24

# Filter the synchrony_df for the day with the lowest and highest dosage
lowest_day_sync = patient_network_metrics_df[
    patient_network_metrics_df["emu_day"] == day_with_lowest_dosage
]["plv"]
highest_day_sync = patient_network_metrics_df[
    patient_network_metrics_df["emu_day"] == day_with_highest_dosage
]["plv"]

# Plot the dosages
fig, ax1 = plt.subplots(figsize=(4, 5))

color = "tab:blue"
ax1.set_xlabel("Days")
ax1.set_ylabel("Average Dosage", color=color)
ax1.bar(
    [
        f"Lowest Day - Day {day_with_lowest_dosage}",
        f"Highest Day - Day {day_with_highest_dosage}",
    ],
    [lowest_dosage, highest_dosage],
    color=color,
)
ax1.tick_params(axis="y", labelcolor=color)

# Create a second y-axis
ax2 = ax1.twinx()
color = "tab:red"
ax2.set_ylabel("Synchrony R", color=color)

# Plot the box plots for the synchrony values
bp = ax2.boxplot(
    [lowest_day_sync, highest_day_sync],
    positions=[0, 1],
    widths=0.4,
    vert=True,
    patch_artist=True,
    notch=True,
)

# Change color of each box
for patch in bp["boxes"]:
    patch.set(facecolor=color)

ax2.tick_params(axis="y", labelcolor=color)

fig.tight_layout()
plt.title(f"Avg Dosage and Synchrony on Lowest/Highest Days for HUP {patient_hup_id}")
plt.show()

# %%
# Run a t-test to see if the synchrony values are significantly different
t_stat, p_val = stats.ttest_ind(lowest_day_sync, highest_day_sync)
print(f"t-statistic: {t_stat}")
print(f"p-value: {p_val}")
# Out:
# t-statistic: 4.106030927009112
# p-value: 0.0001632589691223516
