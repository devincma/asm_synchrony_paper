# %% [markdown]
# # Build giant tables

# %%
import numpy as np
import pandas as pd
import os
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
AD_RATIO_THRESHOLD = -0.4054

# %%
# Load HUP_implant_dates.xlsx
patients_df = pd.read_excel("../../Data/HUP_implant_dates.xlsx")
patients_df
# Out:
#     hup_id      IEEG_Portal_Number Implant_Date implant_time  \
# 0      225          HUP225_phaseII   2021-10-18     07:15:00
# 1      224          HUP224_phaseII   2021-10-13     07:15:00
# 2      223          HUP223_phaseII   2021-09-29     07:15:00
# 3      221          HUP221_phaseII   2021-08-16     07:15:00
# 4      219          HUP219_phaseII   2021-07-12     07:15:00
# ..     ...                     ...          ...          ...
# 75     141          HUP141_phaseII   2017-05-24     07:15:00
# 76     140  HUP140_phaseII_D01-D02   2017-05-10     07:15:00
# 77     139          HUP139_phaseII   2017-04-26     07:15:00
# 78     138          HUP138_phaseII   2017-04-12     07:15:00
# 79     137  HUP137_phaseII_D01-D03   2017-03-22     07:15:00
#
#           Explant_Date  weight_kg
# 0  2021-10-26 17:30:00       58.5
# 1  2021-10-20 00:00:00       85.5
# 2  2021-10-08 08:21:00      101.4
# 3  2021-08-23 00:00:00      124.3
# 4  2021-07-16 08:18:00      101.6
# ..                 ...        ...
# 75 2017-06-01 00:00:00       85.7
# 76 2017-05-19 00:00:00       56.7
# 77 2017-05-09 00:00:00       69.8
# 78 2017-04-20 00:00:00       84.4
# 79 2017-03-29 13:30:00      141.3
#
# [80 rows x 6 columns]

# %%
# Create a mapping between patient ids and the index of the patient in the patients_df dataframe
patient_hup_id_to_index = {}
for i, patient_id in enumerate(patients_df["hup_id"]):
    patient_hup_id_to_index[patient_id] = i
patient_hup_id_to_index
# Out:
# {225: 0,
#  224: 1,
#  223: 2,
#  221: 3,
#  219: 4,
#  217: 5,
#  216: 6,
#  215: 7,
#  214: 8,
#  213: 9,
#  211: 10,
#  210: 11,
#  209: 12,
#  208: 13,
#  207: 14,
#  206: 15,
#  205: 16,
#  204: 17,
#  202: 18,
#  201: 19,
#  199: 20,
#  197: 21,
#  196: 22,
#  195: 23,
#  194: 24,
#  193: 25,
#  192: 26,
#  191: 27,
#  190: 28,
#  189: 29,
#  188: 30,
#  187: 31,
#  186: 32,
#  185: 33,
#  184: 34,
#  182: 35,
#  181: 36,
#  180: 37,
#  179: 38,
#  178: 39,
#  177: 40,
#  175: 41,
#  174: 42,
#  173: 43,
#  172: 44,
#  171: 45,
#  170: 46,
#  169: 47,
#  168: 48,
#  167: 49,
#  166: 50,
#  165: 51,
#  164: 52,
#  163: 53,
#  162: 54,
#  161: 55,
#  160: 56,
#  159: 57,
#  158: 58,
#  157: 59,
#  156: 60,
#  155: 61,
#  154: 62,
#  153: 63,
#  152: 64,
#  151: 65,
#  150: 66,
#  149: 67,
#  148: 68,
#  147: 69,
#  146: 70,
#  145: 71,
#  144: 72,
#  143: 73,
#  142: 74,
#  141: 75,
#  140: 76,
#  139: 77,
#  138: 78,
#  137: 79}

# %%
# Load ./data/ieeg_starts.xlsx into a dataframe
ieeg_starts_df = pd.read_excel("../../Data/ieeg_starts.xlsx")
ieeg_starts_df
# Out:
#     hup_id  ieeg_start
# 0      225   38.024167
# 1      224   37.582778
# 2      223   32.985556
# 3      221   37.690000
# 4      219   33.396667
# ..     ...         ...
# 75     141   37.249444
# 76     140   35.197500
# 77     139   37.151667
# 78     138   37.529444
# 79     137   13.654444
#
# [80 rows x 2 columns]

# %%
all_med_names = []

for i, row in patients_df.iterrows():
    # Get patient id and weight
    patient_hup_id = row.hup_id

    # Load HUP_{patient_hup_id}.npy from ../../Data/medications
    aed_np_file = np.load(
        f"../../Data/medications/HUP_{patient_hup_id}.npy", allow_pickle=True
    )

    all_dose_curves_plot = aed_np_file[0]
    all_tHr_plot = aed_np_file[1]
    all_med_names_plot = aed_np_file[2]

    # Plot dose curves
    for med_name in all_med_names_plot:
        all_med_names.append(med_name)

all_med_names = np.unique(np.array(all_med_names, dtype=str))
all_med_names
# Out:
# array(['brivaracetam', 'carbamazepine', 'clobazam', 'clonazepam',
#        'clorazepate', 'eslicarbazepine', 'felbamate', 'gabapentin',
#        'lacosamide', 'lamotrigine', 'levetiracetam', 'lorazepam',
#        'oxcarbazepine', 'phenytoin', 'pregabalin', 'rufinamide',
#        'topiramate', 'valproic acid', 'zonisamide'], dtype='<U15')

# %%
frequency_bands = {
    "delta": (0.5, 4),
    "theta": (4, 8),
    "alpha": (8, 12),
    "beta": (12, 30),
    "gamma": (30, 100),
}

# %%
for i, row in patients_df.iterrows():
    # Get patient id and weight
    patient_hup_id, patient_weight = row.hup_id, row.weight_kg
    patient_idx = patient_hup_id_to_index[patient_hup_id]

    # Find the ieeg_start value for patient_hup_id in ieeg_starts_df and convert it into float
    ieeg_start_hrs = float(
        ieeg_starts_df.loc[
            ieeg_starts_df["hup_id"] == patient_hup_id, "ieeg_start"
        ].values[0]
    )
    aligned_emu_start_time_hrs = round(ieeg_start_hrs)

    ##############################################
    # MEDICATIONS
    ##############################################

    # Load HUP_{patient_hup_id}.npy from ../../Data/medications
    aed_np_file = np.load(
        f"../../Data/medications/HUP_{patient_hup_id}.npy", allow_pickle=True
    )

    all_dose_curves_plot = aed_np_file[0]
    all_tHr_plot = aed_np_file[1]
    all_med_names_plot = aed_np_file[2]

    # Construct the time axis
    emu_start_time_hrs = min([all_tHr_plot[i][0] for i in range(len(all_tHr_plot))])
    emu_end_time_hrs = all_tHr_plot[0][-1]
    max_dose_duration_hrs = emu_end_time_hrs - emu_start_time_hrs
    max_length = max([len(all_tHr_plot[i]) for i in range(len(all_tHr_plot))])
    time_axis = np.linspace(emu_start_time_hrs, emu_end_time_hrs, max_length)

    # Create a dataframe that will hold the dose curves for all patients
    hourly_patient_features_df = pd.DataFrame(columns=["emu_time"])
    hourly_patient_features_df["emu_time"] = time_axis
    # Add a column called lorazepam that is zero everywhere
    for potential_med_name in all_med_names:
        hourly_patient_features_df[f"med_{potential_med_name}_raw"] = np.zeros(
            len(time_axis)
        )
    hourly_patient_features_df

    sum_array = []

    ##############################################
    # MEDICATIONS
    ##############################################
    for med_idx, med_name in enumerate(all_med_names_plot):
        dose_times = all_tHr_plot[med_idx].flatten()
        dose = all_dose_curves_plot[med_idx].flatten()

        interp_func = interpolate.interp1d(
            dose_times, dose, bounds_error=False, fill_value=0
        )
        dose_interp = interp_func(time_axis)

        if med_name != "lorazepam":
            sum_array.append(dose_interp)

        # Create a new column in all_dose_curves_df for the dose curve of med_name
        hourly_patient_features_df[f"med_{med_name}_raw"] = dose_interp

    cumulative_dose_curve = np.sum(sum_array, axis=0)

    # cumulative_dose_curve = cumulative_dose_curve / cumulative_dose_curve.max()
    assert len(cumulative_dose_curve) == len(
        time_axis
    ), "cumulative_dose_curve and time_axis should have the same length"

    hourly_patient_features_df["med_sum_no_lorazepam_raw"] = cumulative_dose_curve

    ##############################################
    # Group by hour and compute mean
    ##############################################
    # Create a new column for the integer hour
    hourly_patient_features_df["emu_hour"] = hourly_patient_features_df[
        "emu_time"
    ].astype(int)
    # Group by hour and compute mean
    hourly_patient_features_df = hourly_patient_features_df.groupby("emu_hour").mean()
    # Reset the index
    hourly_patient_features_df = hourly_patient_features_df.reset_index()
    # Drop the emu_time column
    hourly_patient_features_df = hourly_patient_features_df.drop(columns=["emu_time"])

    ##############################################
    # SEIZURE COUNT
    ##############################################
    seizure_times_sec = np.load(
        f"../../Data/seizures/source_mat/HUP_{patient_hup_id}.npy"
    )
    seizure_times_sec = seizure_times_sec + (ieeg_start_hrs * 3600)

    for seizure_time_sec in seizure_times_sec:
        seizure_time_hr = int(seizure_time_sec[0] / 3600)

    seizure_times_hr = seizure_times_sec / 3600

    # Add an integer column called num_seizures that is zero everywhere
    hourly_patient_features_df["num_seizures"] = np.zeros(
        len(hourly_patient_features_df), dtype=int
    )

    for sz_hr in seizure_times_hr[:, 0]:
        # Increment the num_seizures column by 1 at the index corresponding to sz_hr
        hourly_patient_features_df.loc[
            hourly_patient_features_df["emu_hour"] == int(sz_hr), "num_seizures"
        ] += 1

    ##############################################
    # ALPHA-DELTA RATIO
    ##############################################
    # Load as numpy array from ../../Data/ad_ratios/hourly/HUP_XXX.npy
    ad_ratios_np = np.load(f"../../Data/ad_ratios/hourly/HUP_{patient_hup_id}.npy")
    # create a dictionary that maps emu_hour to ad_ratios
    ad_ratios_dict = dict(
        zip(
            range(
                aligned_emu_start_time_hrs,
                aligned_emu_start_time_hrs + len(ad_ratios_np),
            ),
            ad_ratios_np,
        )
    )
    # create the new column ad_ratios by mapping from the dictionary
    hourly_patient_features_df["ad_ratio"] = hourly_patient_features_df["emu_hour"].map(
        ad_ratios_dict
    )

    ##############################################
    # AWAKE
    ##############################################
    # Add a column called awake that is 1 if ad_ratio > AD_RATIO_THRESHOLD and 0 otherwise
    hourly_patient_features_df["awake"] = (
        hourly_patient_features_df["ad_ratio"] > AD_RATIO_THRESHOLD
    ).astype(int)

    ##############################################
    # SPIKES
    ##############################################
    # Load as numpy array from ../../Data/spikes/hourly_avg/all/HUP_XXX.npy
    # load the numpy arrays
    spikes_hourly_avg_all_np = np.load(
        f"../../Data/spikes/hourly_avg/all/HUP_{patient_hup_id}.npy"
    )
    spikes_hourly_avg_soz_np = np.load(
        f"../../Data/spikes/hourly_avg/soz/HUP_{patient_hup_id}.npy"
    )
    spikes_hourly_sum_all_np = np.load(
        f"../../Data/spikes/hourly_sum/all/HUP_{patient_hup_id}.npy"
    )
    spikes_hourly_sum_soz_np = np.load(
        f"../../Data/spikes/hourly_sum/soz/HUP_{patient_hup_id}.npy"
    )

    # create dictionaries that map emu_hour to each array
    spikes_avg_all_dict = dict(
        zip(
            range(
                aligned_emu_start_time_hrs,
                aligned_emu_start_time_hrs + len(spikes_hourly_avg_all_np),
            ),
            spikes_hourly_avg_all_np,
        )
    )
    spikes_avg_soz_dict = dict(
        zip(
            range(
                aligned_emu_start_time_hrs,
                aligned_emu_start_time_hrs + len(spikes_hourly_avg_soz_np),
            ),
            spikes_hourly_avg_soz_np,
        )
    )
    spikes_sum_all_dict = dict(
        zip(
            range(
                aligned_emu_start_time_hrs,
                aligned_emu_start_time_hrs + len(spikes_hourly_sum_all_np),
            ),
            spikes_hourly_sum_all_np,
        )
    )
    spikes_sum_soz_dict = dict(
        zip(
            range(
                aligned_emu_start_time_hrs,
                aligned_emu_start_time_hrs + len(spikes_hourly_sum_soz_np),
            ),
            spikes_hourly_sum_soz_np,
        )
    )

    # create the new columns by mapping from the dictionaries
    hourly_patient_features_df["spikes_avg_all"] = hourly_patient_features_df[
        "emu_hour"
    ].map(spikes_avg_all_dict)
    hourly_patient_features_df["spikes_avg_soz"] = hourly_patient_features_df[
        "emu_hour"
    ].map(spikes_avg_soz_dict)
    hourly_patient_features_df["spikes_sum_all"] = hourly_patient_features_df[
        "emu_hour"
    ].map(spikes_sum_all_dict)
    hourly_patient_features_df["spikes_sum_soz"] = hourly_patient_features_df[
        "emu_hour"
    ].map(spikes_sum_soz_dict)

    ##############################################
    # TEAGER ENERGY
    ##############################################
    should_skip_patient_for_teager_energy = True
    for frequency_band in frequency_bands:
        try:
            teager_energy_np = np.load(
                f"../../Data/teager_energy/{frequency_band}/HUP_{patient_hup_id}.npy"
            )
        except FileNotFoundError:
            print(f"File not found for HUP {patient_hup_id} {frequency_band}")
            continue
        should_skip_patient_for_teager_energy = False

        teager_energy_dict = dict(
            zip(
                range(
                    aligned_emu_start_time_hrs,
                    aligned_emu_start_time_hrs + len(teager_energy_np),
                ),
                teager_energy_np,
            )
        )
        # create the new column ad_ratios by mapping from the dictionary
        hourly_patient_features_df[
            f"teager_energy_{frequency_band}"
        ] = hourly_patient_features_df["emu_hour"].map(teager_energy_dict)

    ##############################################
    # KURAMOTO ORDER PARAMETER
    ##############################################
    should_skip_patient_for_plv = True
    for frequency_band in frequency_bands:
        try:
            kuramoto_np = np.load(
                f"../../Data/plv/kuramoto/{frequency_band}/HUP_{patient_hup_id}.npy"
            )
        except FileNotFoundError:
            print(
                f"File not found for ../../Data/plv/kuramoto/{frequency_band}/HUP_{patient_hup_id}.npy"
            )
            continue

        should_skip_patient_for_plv = False

        kuramoto_dict = dict(
            zip(
                range(
                    aligned_emu_start_time_hrs,
                    aligned_emu_start_time_hrs + len(kuramoto_np),
                ),
                kuramoto_np,
            )
        )
        # create the new column ad_ratios by mapping from the dictionary
        hourly_patient_features_df[
            f"kuramoto_{frequency_band}"
        ] = hourly_patient_features_df["emu_hour"].map(kuramoto_dict)

    ##############################################
    # TAPER
    ##############################################

    # # Only consider the columns that represent medications
    # med_columns = [
    #     col
    #     for col in hourly_patient_features_df.columns
    #     if col.startswith("med_") and col.endswith("_raw")
    # ]

    # # Exclude columns that are all zeros and the column for lorazepam
    # non_zero_med_columns = [
    #     col
    #     for col in med_columns
    #     if hourly_patient_features_df[col].sum() != 0 and col != "med_lorazepam_raw"
    # ]

    # # Filter the first 2 days
    # df_first_2_days = hourly_patient_features_df[
    #     hourly_patient_features_df["emu_hour"] <= 23
    # ]

    # # Calculate the 20% of the peak for each medication during the first 2 days
    # peak_20_percent = df_first_2_days[non_zero_med_columns].max() * 0.3

    # # Create a dataframe where each cell is True if the dosage is below the 20% peak, and False otherwise
    # below_20_percent = hourly_patient_features_df[non_zero_med_columns].lt(
    #     peak_20_percent
    # )

    # # Get the earliest hour starting from emu_hour 24 at which at least two medications are tapered off
    # tapering_hours = below_20_percent[hourly_patient_features_df["emu_hour"] >= 24].sum(
    #     axis=1
    # )
    # first_tapering_hour = tapering_hours[tapering_hours >= 1].index.min()

    # print(first_tapering_hour, first_tapering_hour // 24 + 1)

    ##############################################
    # PLOT STUFF
    ##############################################
    print(
        f"Plotting for HUP {patient_hup_id}, {patient_hup_id_to_index[patient_hup_id]}"
    )
    # plot_stuff(hourly_patient_features_df)

    ##############################################
    # SAVE TO CSV
    ##############################################
    if should_skip_patient_for_teager_energy or should_skip_patient_for_plv:
        print(f"Skipping HUP {patient_hup_id} due to missing files")
        continue

    hourly_patient_features_df.to_csv(
        f"../../Data/giant_tables/HUP_{patient_hup_id}.csv", index=False
    )
# Out:
# File not found for HUP 225 delta
# File not found for HUP 225 theta
# File not found for HUP 225 alpha
# File not found for HUP 225 beta
# File not found for HUP 225 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_225.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_225.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_225.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_225.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_225.npy
# Plotting for HUP 225, 0
# Skipping HUP 225 due to missing files
# Plotting for HUP 224, 1
# Plotting for HUP 223, 2
# File not found for HUP 221 delta
# File not found for HUP 221 theta
# File not found for HUP 221 alpha
# File not found for HUP 221 beta
# File not found for HUP 221 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_221.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_221.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_221.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_221.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_221.npy
# Plotting for HUP 221, 3
# Skipping HUP 221 due to missing files
# File not found for HUP 219 delta
# File not found for HUP 219 theta
# File not found for HUP 219 alpha
# File not found for HUP 219 beta
# File not found for HUP 219 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_219.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_219.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_219.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_219.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_219.npy
# Plotting for HUP 219, 4
# Skipping HUP 219 due to missing files
# File not found for HUP 217 delta
# File not found for HUP 217 theta
# File not found for HUP 217 alpha
# File not found for HUP 217 beta
# File not found for HUP 217 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_217.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_217.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_217.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_217.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_217.npy
# Plotting for HUP 217, 5
# Skipping HUP 217 due to missing files
# Plotting for HUP 216, 6
# Plotting for HUP 215, 7
# File not found for HUP 214 delta
# File not found for HUP 214 theta
# File not found for HUP 214 alpha
# File not found for HUP 214 beta
# File not found for HUP 214 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_214.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_214.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_214.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_214.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_214.npy
# Plotting for HUP 214, 8
# Skipping HUP 214 due to missing files
# Plotting for HUP 213, 9
# File not found for HUP 211 delta
# File not found for HUP 211 theta
# File not found for HUP 211 alpha
# File not found for HUP 211 beta
# File not found for HUP 211 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_211.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_211.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_211.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_211.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_211.npy
# Plotting for HUP 211, 10
# Skipping HUP 211 due to missing files
# Plotting for HUP 210, 11
# Plotting for HUP 209, 12
# Plotting for HUP 208, 13
# Plotting for HUP 207, 14
# File not found for HUP 206 delta
# File not found for HUP 206 theta
# File not found for HUP 206 alpha
# File not found for HUP 206 beta
# File not found for HUP 206 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_206.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_206.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_206.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_206.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_206.npy
# Plotting for HUP 206, 15
# Skipping HUP 206 due to missing files
# Plotting for HUP 205, 16
# Plotting for HUP 204, 17
# Plotting for HUP 202, 18
# File not found for HUP 201 delta
# File not found for HUP 201 theta
# File not found for HUP 201 alpha
# File not found for HUP 201 beta
# File not found for HUP 201 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_201.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_201.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_201.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_201.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_201.npy
# Plotting for HUP 201, 19
# Skipping HUP 201 due to missing files
# Plotting for HUP 199, 20
# Plotting for HUP 197, 21
# Plotting for HUP 196, 22
# File not found for HUP 195 delta
# File not found for HUP 195 theta
# File not found for HUP 195 alpha
# File not found for HUP 195 beta
# File not found for HUP 195 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_195.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_195.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_195.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_195.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_195.npy
# Plotting for HUP 195, 23
# Skipping HUP 195 due to missing files
# Plotting for HUP 194, 24
# Plotting for HUP 193, 25
# Plotting for HUP 192, 26
# File not found for HUP 191 delta
# File not found for HUP 191 theta
# File not found for HUP 191 alpha
# File not found for HUP 191 beta
# File not found for HUP 191 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_191.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_191.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_191.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_191.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_191.npy
# Plotting for HUP 191, 27
# Skipping HUP 191 due to missing files
# Plotting for HUP 190, 28
# Plotting for HUP 189, 29
# Plotting for HUP 188, 30
# Plotting for HUP 187, 31
# Plotting for HUP 186, 32
# Plotting for HUP 185, 33
# Plotting for HUP 184, 34
# File not found for HUP 182 delta
# File not found for HUP 182 theta
# File not found for HUP 182 alpha
# File not found for HUP 182 beta
# File not found for HUP 182 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_182.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_182.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_182.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_182.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_182.npy
# Plotting for HUP 182, 35
# Skipping HUP 182 due to missing files
# Plotting for HUP 181, 36
# Plotting for HUP 180, 37
# Plotting for HUP 179, 38
# Plotting for HUP 178, 39
# Plotting for HUP 177, 40
# Plotting for HUP 175, 41
# Plotting for HUP 174, 42
# Plotting for HUP 173, 43
# Plotting for HUP 172, 44
# Plotting for HUP 171, 45
# Plotting for HUP 170, 46
# Plotting for HUP 169, 47
# File not found for HUP 168 delta
# File not found for HUP 168 theta
# File not found for HUP 168 alpha
# File not found for HUP 168 beta
# File not found for HUP 168 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_168.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_168.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_168.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_168.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_168.npy
# Plotting for HUP 168, 48
# Skipping HUP 168 due to missing files
# Plotting for HUP 167, 49
# Plotting for HUP 166, 50
# Plotting for HUP 165, 51
# File not found for HUP 164 delta
# File not found for HUP 164 theta
# File not found for HUP 164 alpha
# File not found for HUP 164 beta
# File not found for HUP 164 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_164.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_164.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_164.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_164.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_164.npy
# Plotting for HUP 164, 52
# Skipping HUP 164 due to missing files
# File not found for HUP 163 delta
# File not found for HUP 163 theta
# File not found for HUP 163 alpha
# File not found for HUP 163 beta
# File not found for HUP 163 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_163.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_163.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_163.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_163.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_163.npy
# Plotting for HUP 163, 53
# Skipping HUP 163 due to missing files
# File not found for HUP 162 delta
# File not found for HUP 162 theta
# File not found for HUP 162 alpha
# File not found for HUP 162 beta
# File not found for HUP 162 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_162.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_162.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_162.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_162.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_162.npy
# Plotting for HUP 162, 54
# Skipping HUP 162 due to missing files
# Plotting for HUP 161, 55
# Plotting for HUP 160, 56
# Plotting for HUP 159, 57
# Plotting for HUP 158, 58
# Plotting for HUP 157, 59
# Plotting for HUP 156, 60
# Plotting for HUP 155, 61
# Plotting for HUP 154, 62
# Plotting for HUP 153, 63
# File not found for HUP 152 delta
# File not found for HUP 152 theta
# File not found for HUP 152 alpha
# File not found for HUP 152 beta
# File not found for HUP 152 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_152.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_152.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_152.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_152.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_152.npy
# Plotting for HUP 152, 64
# Skipping HUP 152 due to missing files
# Plotting for HUP 151, 65
# Plotting for HUP 150, 66
# Plotting for HUP 149, 67
# Plotting for HUP 148, 68
# Plotting for HUP 147, 69
# Plotting for HUP 146, 70
# Plotting for HUP 145, 71
# Plotting for HUP 144, 72
# Plotting for HUP 143, 73
# Plotting for HUP 142, 74
# Plotting for HUP 141, 75
# Plotting for HUP 140, 76
# File not found for HUP 139 delta
# File not found for HUP 139 theta
# File not found for HUP 139 alpha
# File not found for HUP 139 beta
# File not found for HUP 139 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_139.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_139.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_139.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_139.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_139.npy
# Plotting for HUP 139, 77
# Skipping HUP 139 due to missing files
# Plotting for HUP 138, 78
# File not found for HUP 137 delta
# File not found for HUP 137 theta
# File not found for HUP 137 alpha
# File not found for HUP 137 beta
# File not found for HUP 137 gamma
# File not found for ../../Data/plv/kuramoto/delta/HUP_137.npy
# File not found for ../../Data/plv/kuramoto/theta/HUP_137.npy
# File not found for ../../Data/plv/kuramoto/alpha/HUP_137.npy
# File not found for ../../Data/plv/kuramoto/beta/HUP_137.npy
# File not found for ../../Data/plv/kuramoto/gamma/HUP_137.npy
# Plotting for HUP 137, 79
# Skipping HUP 137 due to missing files
