# %%
import os
import numpy as np
import pandas as pd
from ieeg.auth import Session
from matplotlib import pyplot as plt

from get_iEEG_data import *
from spike_detector import *
from iEEG_helper_functions import *

SPIKES_OUTPUT_DIR = "../../Data/spikes/devin_spikes/"

# %%
def create_pwd_file(username, password, fname=None):
    if fname is None:
        fname = "{}_ieeglogin.bin".format(username[:3])
    with open(fname, "wb") as f:
        f.write(password.encode())
    print("-- -- IEEG password file saved -- --")


create_pwd_file("dma", "mycqEv-pevfo4-roqfan")

with open("dma_ieeglogin.bin", "r") as f:
    session = Session("dma", f.read())
# Out:
# -- -- IEEG password file saved -- --

# %%
dataset_name = "HUP210_phaseII"
dataset = session.open_dataset(dataset_name)

# %%
all_channel_labels = np.array(dataset.get_channel_labels())
label_idxs = electrode_selection(all_channel_labels)
labels = all_channel_labels[label_idxs]

# %%
duration_usec = dataset.get_time_series_details(labels[5]).duration
duration_hours = int(duration_usec / 1000000 / 60 / 60)
enlarged_duration_hours = duration_hours + 24

# %%
print(f"Opening {dataset_name} with duration {duration_hours} hours")

# Calculate the total number of 2-minute intervals in the enlarged duration
total_intervals = enlarged_duration_hours * 30  # 60min/hour / 2min = 30

# Loop through each 2-minute interval
for interval in range(2427, total_intervals):
    print(f"Getting iEEG data for interval {interval} out of {total_intervals}")
    duration_usec = 1.2e8  # 2 minutes
    start_time_usec = interval * 2 * 60 * 1e6  # 2 minutes in microseconds
    stop_time_usec = start_time_usec + duration_usec

    try:
        ieeg_data, fs = get_iEEG_data(
            "dma",
            "dma_ieeglogin.bin",
            dataset_name,
            start_time_usec,
            stop_time_usec,
            labels,
        )
    except Exception as e:
        # handle the exception
        print(f"Error: {e}")
        break

    # Drop rows that has any nan
    ieeg_data = ieeg_data.dropna(axis=0, how="any")
    if ieeg_data.empty:
        print("Empty dataframe, skip saving...")
        continue

    fs = int(fs)

    good_channels_res = detect_bad_channels_optimized(ieeg_data.to_numpy(), fs)
    good_channel_indicies = good_channels_res[0]
    good_labels = labels[good_channel_indicies]
    ieeg_data = ieeg_data[good_labels]

    ieeg_data = common_average_montage(ieeg_data)

    # Apply the filters directly on the DataFrame
    ieeg_data = pd.DataFrame(notch_filter(ieeg_data.values, 59, 61, fs))
    ieeg_data = pd.DataFrame(bandpass_filter(ieeg_data.values, 1, 70, fs))

    spike_output = spike_detector(
        data=ieeg_data.to_numpy(),
        fs=fs,
        labels=good_labels,
    )
    if len(spike_output) == 0:
        print("No spikes detected, skip saving...")
        continue
    else:
        print(f"{len(np.unique(spike_output[:, 2]))} spikes detected")

    # Save the spike_output to a npy file
    np.save(
        os.path.join(SPIKES_OUTPUT_DIR, f"{dataset_name}_{interval}.npy"),
        spike_output,
    )
# Out:
# Opening HUP210_phaseII with duration 260 hours
# Getting iEEG data for interval 2427 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.0753 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2428 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1781 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 2429 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.0851 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 2430 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3229 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2431 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1073 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2432 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2398 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2433 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3183 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2434 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1628 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 2435 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4311 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 2436 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1086 seconds to execute.
# 'multi_channel_requirement' took 0.0022 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 2437 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2286 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 2438 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1760 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 2439 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1773 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 2440 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1797 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 2441 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1869 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2442 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2169 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2443 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3118 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 2444 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1805 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 2445 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2131 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2446 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1056 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2447 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4695 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2448 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1778 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2449 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3713 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2450 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1826 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2451 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2115 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2452 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1981 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2453 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3777 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2454 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2158 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2455 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4497 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2456 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2579 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 2457 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2679 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2458 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2330 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2459 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2780 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2460 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2023 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2461 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2032 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2462 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1477 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2463 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2313 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2464 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2327 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2465 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3996 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2466 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2296 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2467 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4435 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2468 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3065 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2469 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2895 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2470 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3165 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 2471 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2903 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2472 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3248 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2473 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2465 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2474 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2523 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 2475 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2378 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2476 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2076 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2477 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2417 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 2478 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4019 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2479 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2598 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2480 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3662 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2481 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3401 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 2482 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3136 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2483 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4824 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2484 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3732 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2485 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2248 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2486 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1734 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2487 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3994 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2488 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2690 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2489 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2029 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2490 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3531 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2491 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3037 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2492 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1989 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2493 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2007 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2494 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2173 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2495 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2617 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2496 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1788 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2497 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2566 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2498 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2812 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2499 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3373 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2500 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2257 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2501 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2227 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2502 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2838 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2503 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2112 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2504 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1902 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2505 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4669 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2506 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2553 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2507 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2364 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2508 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1949 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2509 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3084 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2510 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2561 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2511 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3160 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2512 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1872 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2513 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3245 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2514 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2592 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 2515 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2315 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2516 out of 8520
# Using optimized spike detector...
# 'the big loop' took 0.9603 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2517 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4549 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2518 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2417 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2519 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3756 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2520 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2394 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2521 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1916 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2522 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2210 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2523 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.5013 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2524 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1819 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2525 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1474 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2526 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3752 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2527 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1163 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2528 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3148 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2529 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2084 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2530 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1734 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2531 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1976 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 2532 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1681 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2533 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2138 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 2534 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2440 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2535 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1933 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2536 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2441 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 2537 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1510 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2538 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2694 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2539 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1768 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2540 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3235 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2541 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1345 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 2542 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1667 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 2543 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1476 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2544 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4088 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2545 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2094 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2546 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2065 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2547 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1243 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2548 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2948 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2549 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1572 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2550 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3863 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 2551 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2498 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2552 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3217 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2553 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2370 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2554 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2719 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2555 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1381 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2556 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2384 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2557 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2387 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2558 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3157 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2559 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2515 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2560 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2350 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2561 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2185 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2562 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2070 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2563 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3245 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 2564 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2426 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2565 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3893 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2566 out of 8520
# Using optimized spike detector...
# 'the big loop' took 0.9256 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 2567 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2568 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2569 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2570 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2571 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2572 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2573 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2574 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2575 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2576 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2577 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2578 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2579 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2580 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2581 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2582 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2583 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2584 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2585 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2586 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2587 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2588 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2589 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2590 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2591 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2592 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2593 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2594 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2595 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2596 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2597 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2598 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2599 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2600 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2601 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2602 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2603 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2604 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2605 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2606 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2607 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2608 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2609 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2610 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2611 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2612 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2613 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2614 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2615 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2616 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2617 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2618 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2619 out of 8520
# Empty dataframe, skip saving...
# Getting iEEG data for interval 2620 out of 8520
# Using optimized spike detector...
# 'the big loop' took 0.7232 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2621 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3087 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2622 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1884 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2623 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3222 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2624 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2710 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 2625 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3383 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2626 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2763 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2627 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.5118 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2628 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2143 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2629 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1888 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2630 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1739 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2631 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1326 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2632 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2135 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2633 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1349 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2634 out of 8520
# Using optimized spike detector...
# 'the big loop' took 0.9624 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 2635 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2117 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2636 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1925 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2637 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1713 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2638 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2309 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2639 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2523 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2640 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2545 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2641 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2546 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2642 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2167 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2643 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2487 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2644 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2819 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2645 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2830 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 2646 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4804 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2647 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3240 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2648 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1899 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2649 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2843 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2650 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3916 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2651 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2219 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2652 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3350 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2653 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2567 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2654 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2373 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 2655 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2234 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 2656 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2487 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 2657 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2306 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2658 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2965 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2659 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2217 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2660 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2566 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2661 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4199 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2662 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2320 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2663 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.5897 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2664 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2132 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 2665 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3149 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2666 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2646 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2667 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3769 seconds to execute.
# 'multi_channel_requirement' took 0.0033 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 2668 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2946 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2669 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3273 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2670 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3035 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 2671 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2889 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2672 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3032 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 2673 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2316 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 2674 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2844 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2675 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3154 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 2676 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2136 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2677 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2389 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 2678 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2572 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 2679 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2927 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2680 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2818 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2681 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2477 seconds to execute.
# 'multi_channel_requirement' took 0.0031 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 2682 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2978 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 2683 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2912 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 2684 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2614 seconds to execute.
# 'multi_channel_requirement' took 0.0023 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 2685 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2676 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 2686 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2852 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 2687 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2498 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 2688 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.5358 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 2689 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2819 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 2690 out of 8520
# Using optimized spike detector...
# ...
# 10 spikes detected
# Getting iEEG data for interval 4106 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2763 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4107 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4366 seconds to execute.
# 'multi_channel_requirement' took 0.0033 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 4108 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2624 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4109 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3691 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4110 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2223 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4111 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3021 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4112 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3303 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4113 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2638 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4114 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2225 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4115 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2912 seconds to execute.
# 'multi_channel_requirement' took 0.0000 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4116 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1731 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4117 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2764 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4118 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3315 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4119 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2259 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4120 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2849 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4121 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2562 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4122 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4678 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4123 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3399 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4124 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3815 seconds to execute.
# 'multi_channel_requirement' took 0.0000 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4125 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2805 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4126 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4380 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4127 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.5048 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4128 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4424 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4129 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3084 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4130 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1804 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4131 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3677 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4132 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2545 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4133 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3944 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4134 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2570 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4135 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2075 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4136 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3295 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4137 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2748 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4138 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2404 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 4139 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3304 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4140 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2544 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4141 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2403 seconds to execute.
# 'multi_channel_requirement' took 0.0029 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4142 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2457 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 4143 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1901 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 4144 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2298 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 29 spikes detected
# Getting iEEG data for interval 4145 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2517 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4146 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3550 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 4147 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4150 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 27 spikes detected
# Getting iEEG data for interval 4148 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2224 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 30 spikes detected
# Getting iEEG data for interval 4149 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2117 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 4150 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2841 seconds to execute.
# 'multi_channel_requirement' took 0.0029 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4151 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3048 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 4152 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2662 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4153 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2481 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4154 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1770 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4155 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2137 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 29 spikes detected
# Getting iEEG data for interval 4156 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3640 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4157 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2093 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4158 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2040 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 4159 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3257 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 27 spikes detected
# Getting iEEG data for interval 4160 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2431 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 32 spikes detected
# Getting iEEG data for interval 4161 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3545 seconds to execute.
# 'multi_channel_requirement' took 0.0037 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4162 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2615 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 37 spikes detected
# Getting iEEG data for interval 4163 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2154 seconds to execute.
# 'multi_channel_requirement' took 0.0022 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4164 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2275 seconds to execute.
# 'multi_channel_requirement' took 0.0023 seconds to execute.
# 33 spikes detected
# Getting iEEG data for interval 4165 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2717 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 32 spikes detected
# Getting iEEG data for interval 4166 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1661 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 27 spikes detected
# Getting iEEG data for interval 4167 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1921 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4168 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.1432 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4169 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2087 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4170 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2035 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4171 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2058 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4172 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.5441 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4173 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.4833 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4174 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2629 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4175 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3007 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4176 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2421 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4177 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2840 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 4178 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2996 seconds to execute.
# 'multi_channel_requirement' took 0.0024 seconds to execute.
# 34 spikes detected
# Getting iEEG data for interval 4179 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2625 seconds to execute.
# 'multi_channel_requirement' took 0.0024 seconds to execute.
# 36 spikes detected
# Getting iEEG data for interval 4180 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.2072 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 4181 out of 8520
# Using optimized spike detector...
# 'the big loop' took 1.3455 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 4182 out of 8520
# Using optimized spike detector...
