# %%
import os
import numpy as np
import pandas as pd
from ieeg.auth import Session

from get_iEEG_data import *
from spike_detector import *
from iEEG_helper_functions import *

SPIKES_OUTPUT_DIR = "../../Data/spikes/devin_spikes/"

# %%
def create_pwd_file(username, password, fname=None):
    if fname is None:
        fname = "{}_ieeglogin.bin".format(username[:3])
    with open(fname, "wb") as f:
        f.write(password.encode())
    print("-- -- IEEG password file saved -- --")


create_pwd_file("dma", "mycqEv-pevfo4-roqfan")

with open("dma_ieeglogin.bin", "r") as f:
    session = Session("dma", f.read())
# Out:
# -- -- IEEG password file saved -- --

# %%
dataset_name = "HUP143_phaseII"
dataset = session.open_dataset(dataset_name)

# %%
all_channel_labels = np.array(dataset.get_channel_labels())
label_idxs = electrode_selection(all_channel_labels)
labels = all_channel_labels[label_idxs]

# %%
duration_usec = dataset.get_time_series_details(labels[5]).duration
duration_hours = int(duration_usec / 1000000 / 60 / 60)
enlarged_duration_hours = duration_hours + 24

# %%
print(f"Opening {dataset_name} with duration {duration_hours} hours")

# Calculate the total number of 2-minute intervals in the enlarged duration
total_intervals = enlarged_duration_hours * 30  # 60min/hour / 2min = 30

# Loop through each 2-minute interval
for interval in range(4652, total_intervals):
    print(f"Getting iEEG data for interval {interval} out of {total_intervals}")
    duration_usec = 1.2e8  # 2 minutes
    start_time_usec = interval * 2 * 60 * 1e6  # 2 minutes in microseconds
    stop_time_usec = start_time_usec + duration_usec

    try:
        ieeg_data, fs = get_iEEG_data(
            "dma",
            "dma_ieeglogin.bin",
            dataset_name,
            start_time_usec,
            stop_time_usec,
            labels,
        )
    except Exception as e:
        # handle the exception
        print(f"Error: {e}")
        break

    # Drop rows that has any nan
    ieeg_data = ieeg_data.dropna(axis=0, how="any")
    if ieeg_data.empty:
        print("Empty dataframe, skip saving...")
        continue

    fs = int(fs)

    good_channels_res = detect_bad_channels_optimized(ieeg_data.to_numpy(), fs)
    good_channel_indicies = good_channels_res[0]
    good_labels = labels[good_channel_indicies]
    ieeg_data = ieeg_data[good_labels]

    ieeg_data = common_average_montage(ieeg_data)

    # Apply the filters directly on the DataFrame
    ieeg_data = pd.DataFrame(notch_filter(ieeg_data.values, 59, 61, fs))
    ieeg_data = pd.DataFrame(bandpass_filter(ieeg_data.values, 1, 70, fs))

    spike_output = spike_detector(
        data=ieeg_data.to_numpy(),
        fs=fs,
        labels=good_labels,
    )
    if len(spike_output) == 0:
        print("No spikes detected, skip saving...")
        continue
    else:
        print(f"{len(np.unique(spike_output[:, 2]))} spikes detected")

    # Save the spike_output to a npy file
    np.save(
        os.path.join(SPIKES_OUTPUT_DIR, f"{dataset_name}_{interval}.npy"),
        spike_output,
    )
# Out:
# Opening HUP143_phaseII with duration 239 hours
# Getting iEEG data for interval 4652 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1533 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 4653 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8289 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4654 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8910 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4655 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8606 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4656 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8513 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4657 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8365 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4658 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9077 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4659 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9067 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 34 spikes detected
# Getting iEEG data for interval 4660 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8795 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4661 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8825 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 4662 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0267 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4663 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9105 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4664 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9223 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 29 spikes detected
# Getting iEEG data for interval 4665 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8666 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4666 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8657 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4667 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8356 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4668 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8892 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4669 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9436 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4670 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9684 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4671 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9017 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4672 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0683 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4673 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9327 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4674 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9710 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4675 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1064 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4676 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9746 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 36 spikes detected
# Getting iEEG data for interval 4677 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9161 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4678 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8478 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 4679 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9566 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4680 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9122 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4681 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0759 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4682 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.2872 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4683 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9539 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4684 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8407 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4685 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8878 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4686 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9531 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4687 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8906 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4688 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9594 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4689 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9255 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4690 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9743 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4691 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9356 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4692 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8475 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4693 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9343 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4694 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9734 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4695 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8307 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 4696 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8731 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 29 spikes detected
# Getting iEEG data for interval 4697 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9422 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4698 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8600 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4699 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8753 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4700 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8904 seconds to execute.
# 'multi_channel_requirement' took 0.0032 seconds to execute.
# 30 spikes detected
# Getting iEEG data for interval 4701 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9303 seconds to execute.
# 'multi_channel_requirement' took 0.0024 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4702 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0197 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 38 spikes detected
# Getting iEEG data for interval 4703 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8283 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 43 spikes detected
# Getting iEEG data for interval 4704 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8176 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4705 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0262 seconds to execute.
# 'multi_channel_requirement' took 0.0022 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4706 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7976 seconds to execute.
# 'multi_channel_requirement' took 0.0022 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 4707 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8261 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4708 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9914 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4709 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8452 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4710 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9225 seconds to execute.
# 'multi_channel_requirement' took 0.0024 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4711 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8754 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4712 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8705 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4713 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9074 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4714 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8268 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4715 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9834 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4716 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8981 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4717 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9347 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4718 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9644 seconds to execute.
# 'multi_channel_requirement' took 0.0028 seconds to execute.
# 29 spikes detected
# Getting iEEG data for interval 4719 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0666 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4720 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8664 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 4721 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9294 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4722 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9363 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4723 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9446 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4724 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9334 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4725 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9394 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4726 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9445 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4727 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9040 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 36 spikes detected
# Getting iEEG data for interval 4728 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8771 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 31 spikes detected
# Getting iEEG data for interval 4729 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9271 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4730 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8996 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4731 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8218 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4732 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8179 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4733 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8405 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 4734 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8494 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4735 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7859 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4736 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1351 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4737 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7955 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4738 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1778 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4739 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8793 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4740 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9013 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4741 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8133 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4742 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8213 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 4743 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.2523 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4744 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7316 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4745 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7983 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4746 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8914 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4747 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8853 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 4748 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0828 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4749 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8283 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 4750 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8550 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 4751 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9395 seconds to execute.
# 'multi_channel_requirement' took 0.0027 seconds to execute.
# 31 spikes detected
# Getting iEEG data for interval 4752 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8595 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4753 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8603 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4754 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8817 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 4755 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7828 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4756 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8754 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4757 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0402 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4758 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9049 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4759 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9462 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4760 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8901 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4761 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8653 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4762 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8474 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4763 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8357 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4764 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8773 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4765 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8031 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4766 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8999 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4767 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8009 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4768 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8949 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4769 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9389 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4770 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8430 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4771 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9040 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4772 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8686 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4773 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9419 seconds to execute.
# 'multi_channel_requirement' took 0.0027 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4774 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8290 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4775 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7817 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4776 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7501 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4777 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7803 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 4778 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7612 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4779 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7932 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4780 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9796 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4781 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7709 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4782 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7817 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 4783 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7650 seconds to execute.
# 'multi_channel_requirement' took 0.0026 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 4784 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8028 seconds to execute.
# 'multi_channel_requirement' took 0.0025 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 4785 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7995 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4786 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8051 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4787 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8130 seconds to execute.
# 'multi_channel_requirement' took 0.0030 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 4788 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8239 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4789 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7520 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 4790 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8234 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4791 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9889 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 4792 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7774 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4793 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8729 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4794 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8786 seconds to execute.
# 'multi_channel_requirement' took 0.0000 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4795 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9805 seconds to execute.
# 'multi_channel_requirement' took 0.0000 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4796 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9547 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4797 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8385 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4798 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9198 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4799 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8422 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4800 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9489 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4801 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9242 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4802 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8289 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4803 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8634 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4804 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8657 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4805 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8951 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4806 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9001 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4807 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9430 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4808 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9297 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4809 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8573 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4810 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9060 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4811 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8778 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4812 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8366 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4813 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.2263 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4814 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8260 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4815 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8693 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4816 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8628 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4817 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9507 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4818 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0915 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4819 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9130 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4820 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9477 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4821 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8918 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 4822 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8486 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 4823 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7572 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4824 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8558 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4825 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8512 seconds to execute.
# 'multi_channel_requirement' took 0.0023 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 4826 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8435 seconds to execute.
# 'multi_channel_requirement' took 0.0023 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 4827 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8527 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4828 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8277 seconds to execute.
# 'multi_channel_requirement' took 0.0022 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 4829 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8398 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 4830 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8084 seconds to execute.
# 'multi_channel_requirement' took 0.0023 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 4831 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0007 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4832 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8507 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4833 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8830 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4834 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8327 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4835 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8645 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4836 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8915 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4837 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8141 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4838 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8374 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4839 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9350 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4840 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9028 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4841 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9004 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4842 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8570 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4843 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8571 seconds to execute.
# 'multi_channel_requirement' took 0.0003 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4844 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.2143 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4845 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8186 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4846 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8732 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 4847 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9593 seconds to execute.
# 'multi_channel_requirement' took 0.0026 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 4848 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9074 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4849 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8815 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4850 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8797 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 4851 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9059 seconds to execute.
# 'multi_channel_requirement' took 0.0019 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 4852 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8653 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4853 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8853 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4854 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8676 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4855 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8482 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4856 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8178 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4857 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8422 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4858 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1414 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4859 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8634 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4860 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8122 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4861 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9077 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 3 spikes detected
# Getting iEEG data for interval 4862 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8694 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4863 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9326 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 4864 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8067 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4865 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8342 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4866 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9171 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4867 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0006 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 4868 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8618 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4869 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.2085 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 4870 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9165 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 4871 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9305 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 4872 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9488 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 4873 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8516 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4874 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8496 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 4875 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9033 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4876 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9149 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 15 spikes detected
# Getting iEEG data for interval 4877 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8273 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 4878 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8753 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4879 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0540 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 4880 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9141 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 4881 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8625 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 4882 out of 7890
# ...
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 5326 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8464 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 6 spikes detected
# Getting iEEG data for interval 5327 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8284 seconds to execute.
# 'multi_channel_requirement' took 0.0029 seconds to execute.
# 29 spikes detected
# Getting iEEG data for interval 5328 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8708 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 5329 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9890 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 5330 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8760 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 5 spikes detected
# Getting iEEG data for interval 5331 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9060 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 5332 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8762 seconds to execute.
# 'multi_channel_requirement' took 0.0032 seconds to execute.
# 31 spikes detected
# Getting iEEG data for interval 5333 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1185 seconds to execute.
# 'multi_channel_requirement' took 0.0026 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 5334 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8690 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 5335 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7801 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 5336 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8510 seconds to execute.
# 'multi_channel_requirement' took 0.0024 seconds to execute.
# 21 spikes detected
# Getting iEEG data for interval 5337 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8343 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 5338 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8240 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 5339 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8249 seconds to execute.
# 'multi_channel_requirement' took 0.0015 seconds to execute.
# 32 spikes detected
# Getting iEEG data for interval 5340 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7458 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 5341 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8750 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 24 spikes detected
# Getting iEEG data for interval 5342 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8773 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 5343 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7523 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 14 spikes detected
# Getting iEEG data for interval 5344 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7909 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 5345 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0890 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 5346 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7923 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 5347 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0978 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 5348 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8643 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 17 spikes detected
# Getting iEEG data for interval 5349 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8060 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 5350 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7907 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 12 spikes detected
# Getting iEEG data for interval 5351 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7999 seconds to execute.
# 'multi_channel_requirement' took 0.0021 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 5352 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9363 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 5353 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7438 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 5354 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8803 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 5355 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8247 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 5356 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8702 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 5357 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8279 seconds to execute.
# 'multi_channel_requirement' took 0.0011 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 5358 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9024 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 11 spikes detected
# Getting iEEG data for interval 5359 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9154 seconds to execute.
# 'multi_channel_requirement' took 0.0001 seconds to execute.
# 1 spikes detected
# Getting iEEG data for interval 5360 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9105 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 5361 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8757 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 5362 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9212 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 5363 out of 7890
# Empty dataframe, skip saving...
# Getting iEEG data for interval 5364 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8002 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 8 spikes detected
# Getting iEEG data for interval 5365 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9918 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 5366 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8658 seconds to execute.
# 'multi_channel_requirement' took 0.0012 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 5367 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9211 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 5368 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.1307 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 19 spikes detected
# Getting iEEG data for interval 5369 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8597 seconds to execute.
# No spikes detected, skip saving...
# Getting iEEG data for interval 5370 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9084 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 2 spikes detected
# Getting iEEG data for interval 5371 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0283 seconds to execute.
# 'multi_channel_requirement' took 0.0008 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 5372 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8321 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 31 spikes detected
# Getting iEEG data for interval 5373 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8794 seconds to execute.
# 'multi_channel_requirement' took 0.0013 seconds to execute.
# 27 spikes detected
# Getting iEEG data for interval 5374 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9018 seconds to execute.
# 'multi_channel_requirement' took 0.0025 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 5375 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8621 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 5376 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8674 seconds to execute.
# 'multi_channel_requirement' took 0.0025 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 5377 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8544 seconds to execute.
# 'multi_channel_requirement' took 0.0027 seconds to execute.
# 22 spikes detected
# Getting iEEG data for interval 5378 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8224 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 5379 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0875 seconds to execute.
# 'multi_channel_requirement' took 0.0017 seconds to execute.
# 13 spikes detected
# Getting iEEG data for interval 5380 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7486 seconds to execute.
# 'multi_channel_requirement' took 0.0025 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 5381 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7839 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 26 spikes detected
# Getting iEEG data for interval 5382 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7825 seconds to execute.
# 'multi_channel_requirement' took 0.0028 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 5383 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8166 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 23 spikes detected
# Getting iEEG data for interval 5384 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8097 seconds to execute.
# 'multi_channel_requirement' took 0.0007 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 5385 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9676 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 16 spikes detected
# Getting iEEG data for interval 5386 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9875 seconds to execute.
# 'multi_channel_requirement' took 0.0016 seconds to execute.
# 18 spikes detected
# Getting iEEG data for interval 5387 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9315 seconds to execute.
# 'multi_channel_requirement' took 0.0067 seconds to execute.
# 49 spikes detected
# Getting iEEG data for interval 5388 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.2010 seconds to execute.
# 'multi_channel_requirement' took 0.0083 seconds to execute.
# 72 spikes detected
# Getting iEEG data for interval 5389 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8516 seconds to execute.
# 'multi_channel_requirement' took 0.0051 seconds to execute.
# 58 spikes detected
# Getting iEEG data for interval 5390 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8931 seconds to execute.
# 'multi_channel_requirement' took 0.0030 seconds to execute.
# 57 spikes detected
# Getting iEEG data for interval 5391 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8694 seconds to execute.
# 'multi_channel_requirement' took 0.0049 seconds to execute.
# 50 spikes detected
# Getting iEEG data for interval 5392 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.9200 seconds to execute.
# 'multi_channel_requirement' took 0.0020 seconds to execute.
# 41 spikes detected
# Getting iEEG data for interval 5393 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8622 seconds to execute.
# 'multi_channel_requirement' took 0.0029 seconds to execute.
# 25 spikes detected
# Getting iEEG data for interval 5394 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7984 seconds to execute.
# 'multi_channel_requirement' took 0.0018 seconds to execute.
# 42 spikes detected
# Getting iEEG data for interval 5395 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7539 seconds to execute.
# 'multi_channel_requirement' took 0.0028 seconds to execute.
# 28 spikes detected
# Getting iEEG data for interval 5396 out of 7890
# Using optimized spike detector...
# 'the big loop' took 1.0870 seconds to execute.
# 'multi_channel_requirement' took 0.0014 seconds to execute.
# 31 spikes detected
# Getting iEEG data for interval 5397 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.7805 seconds to execute.
# 'multi_channel_requirement' took 0.0002 seconds to execute.
# 4 spikes detected
# Getting iEEG data for interval 5398 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8389 seconds to execute.
# 'multi_channel_requirement' took 0.0009 seconds to execute.
# 20 spikes detected
# Getting iEEG data for interval 5399 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8329 seconds to execute.
# 'multi_channel_requirement' took 0.0005 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 5400 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8728 seconds to execute.
# 'multi_channel_requirement' took 0.0004 seconds to execute.
# 7 spikes detected
# Getting iEEG data for interval 5401 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8687 seconds to execute.
# 'multi_channel_requirement' took 0.0010 seconds to execute.
# 9 spikes detected
# Getting iEEG data for interval 5402 out of 7890
# Using optimized spike detector...
# 'the big loop' took 0.8351 seconds to execute.
# 'multi_channel_requirement' took 0.0006 seconds to execute.
# 10 spikes detected
# Getting iEEG data for interval 5403 out of 7890
