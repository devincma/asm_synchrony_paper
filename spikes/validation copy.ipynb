# %%
import numpy as np
import pandas as pd

# %%
# import csv file from f"../../Public/spikes/v2/HUP_{patient_hup_id}.csv"
patient_hup_id = 142
df = pd.read_csv(f"../../Public/spikes/v2/HUP_{patient_hup_id}.csv")
# df = pd.read_csv(f"../../Public/spikes/v1_August_29/HUP_{patient_hup_id}.csv")

# %%
# Drop peak_time_seconds column
df = df[df.columns.drop(list(df.filter(regex="peak_time_seconds")))]
# Drop is_soz column
df = df[df.columns.drop(list(df.filter(regex="is_soz")))]
# Drop inter_spike_interval_samples
df = df[df.columns.drop(list(df.filter(regex="inter_spike_interval_samples")))]

# %%
# Convert peak_time_microseconds from microseconds to seconds
df["peak_time_seconds"] = df["peak_time_microseconds"] / 1000000
df
# Out:
#         peak_index_samples  peak_time_microseconds  channel_index  \
# 0                  2277670              4448574218              1
# 1                  2277672              4448578125              2
# 2                  2277677              4448587890              3
# 3                  2277695              4448623046             10
# 4                  2277695              4448623046             12
# ...                    ...                     ...            ...
# 708495           282744507            552235365234              2
# 708496           282744508            552235367187              1
# 708497           282745884            552238054687              0
# 708498           282746027            552238333984              3
# 708499           282746029            552238337890             11
#
#        channel_label channel_label_computed  sequence_index  is_leader  \
# 0               LDA2                  LDA02               0       True
# 1               LDA3                  LDA03               0      False
# 2               LDA4                  LDA04               0      False
# 3               LDB3                  LDB03               0      False
# 4               LDB5                  LDB05               0      False
# ...              ...                    ...             ...        ...
# 708495          LDA3                  LDA03          164875       True
# 708496          LDA2                  LDA02          164875      False
# 708497          LDA1                  LDA01          164876       True
# 708498          LDA4                  LDA04          164877       True
# 708499          LDB4                  LDB04          164877      False
#
#         morphology_slow_max  morphology_rise_amp  morphology_decay_amp  \
# 0                567.578496           678.631176           1085.440587
# 1                303.428144          1229.506769           1531.925675
# 2                289.487718          1223.453626           1522.692725
# 3                332.994208           818.581153           1177.735283
# 4                310.679151           554.292807            702.597551
# ...                     ...                  ...                   ...
# 708495           131.381848           488.344777            531.922300
# 708496           684.785633           575.975519            980.430180
# 708497           183.599873           798.992165            423.936718
# 708498           115.769491           212.348134            430.638096
# 708499           313.698131           588.907032            889.815604
#
#         morphology_slow_width  morphology_slow_amp  morphology_rise_slope  \
# 0                          53           567.578496              18.341383
# 1                          50           303.428144              94.577444
# 2                          87           289.487718              26.596818
# 3                          51           332.994208             -16.371623
# 4                          70           310.679151              29.173306
# ...                       ...                  ...                    ...
# 708495                     58           131.381848             -61.043097
# 708496                    188           684.785633             -57.597552
# 708497                    132           183.599873             -44.388454
# 708498                     60           115.769491               4.246963
# 708499                     55           313.698131             -15.100180
#
#         morphology_decay_slope  morphology_average_amp  morphology_linelen  \
# 0                   -51.687647             1221.351469         2498.162056
# 1                   -66.605464             1995.469606         3274.070374
# 2                   -54.381883             1984.799988         3363.373641
# 3                    43.619825             1407.448794         2797.299766
# 4                   -27.022983              905.591583         1961.916230
# ...                        ...                     ...                 ...
# 708495               11.563528              754.305927         1272.095311
# 708496               11.812412             1066.190610         3205.905918
# 708497               10.093731             1010.960524         1797.964738
# 708498              -30.759864              427.667183          925.482733
# 708499               42.372172             1033.814834         2168.388293
#
#         peak_time_seconds
# 0             4448.574218
# 1             4448.578125
# 2             4448.587890
# 3             4448.623046
# 4             4448.623046
# ...                   ...
# 708495      552235.365234
# 708496      552235.367187
# 708497      552238.054687
# 708498      552238.333984
# 708499      552238.337890
#
# [708500 rows x 17 columns]

# %%
# find the rows where the peak_time_seconds is between 24666,24726
window = df[(df["peak_time_seconds"] >= 3186) & (df["peak_time_seconds"] <= 3246)]

# %%
window = df[(df["peak_time_seconds"] >= 7014) & (df["peak_time_seconds"] <= 7074)]

# %%
# find the rows where the peak_time_seconds is between 24666,24726
window = df[(df["peak_time_seconds"] >= 4701) & (df["peak_time_seconds"] <= 4761)]

# %%
window.shape
# Out:
# (31, 17)

# %%
window
# Out:
#      peak_index_samples  peak_time_microseconds  channel_index channel_label  \
# 312             2406973              4701119140              3          LDA4
# 313             2406988              4701148437             12          LDB5
# 314             2406990              4701152343              2          LDA3
# 315             2406998              4701167968              4          LDA5
# 316             2406999              4701169921             18          LDC3
# 317             2407000              4701171875              5          LDA6
# 318             2407000              4701171875             11          LDB4
# 319             2407000              4701171875             10          LDB3
# 320             2407000              4701171875             13          LDB6
# 321             2407000              4701171875              6          LDA7
# 322             2407010              4701191406             17          LDC2
# 323             2409576              4706203125              2          LDA3
# 324             2409579              4706208984             12          LDB5
# 325             2409579              4706208984              9          LDB2
# 326             2409579              4706208984             10          LDB3
# 327             2409579              4706208984              5          LDA6
# 328             2409580              4706210937             11          LDB4
# 329             2409581              4706212890              4          LDA5
# 330             2409589              4706228515              3          LDA4
# 331             2409789              4706619140              2          LDA3
# 332             2409894              4706824218              1          LDA2
# 333             2409909              4706853515              0          LDA1
# 334             2411637              4710228515             22          LDC8
# 335             2412194              4711316406             30         LDE10
# 336             2412400              4711718750             22          LDC8
# 337             2413254              4713386718             94         LGR57
# 338             2428172              4742523437             78         LGR40
# 339             2429224              4744578125             78         LGR40
# 340             2432156              4750304687             78         LGR40
# 341             2433315              4752568359             78         LGR40
# 342             2436049              4757908203              0          LDA1
#
#     channel_label_computed  sequence_index  is_leader  morphology_slow_max  \
# 312                  LDA04              67       True           564.946070
# 313                  LDB05              67      False           653.068902
# 314                  LDA03              67      False           699.094223
# 315                  LDA05              67      False           114.285497
# 316                  LDC03              67      False           311.626247
# 317                  LDA06              67      False            89.553788
# 318                  LDB04              67      False          1427.538389
# 319                  LDB03              67      False          1147.222278
# 320                  LDB06              67      False           177.687492
# 321                  LDA07              67      False            34.660850
# 322                  LDC02              67      False           119.839417
# 323                  LDA03              68       True           199.795259
# 324                  LDB05              68      False            77.701411
# 325                  LDB02              68      False           297.379587
# 326                  LDB03              68      False           143.486816
# 327                  LDA06              68      False           100.672911
# 328                  LDB04              68      False            91.706901
# 329                  LDA05              68      False            72.615383
# 330                  LDA04              68      False           119.009683
# 331                  LDA03              69       True           224.133810
# 332                  LDA02              70       True           370.124723
# 333                  LDA01              70      False           124.247652
# 334                  LDC08              71       True           137.357217
# 335                  LDE01              72       True            97.984654
# 336                  LDC08              73       True           129.668633
# 337                  LGR45              74       True           126.755138
# 338                  LGR29              75       True           819.796270
# 339                  LGR29              76       True          2511.060594
# 340                  LGR29              77       True           624.607727
# 341                  LGR29              78       True          1313.554797
# 342                  LDA01              79       True           205.293901
#
#      morphology_rise_amp  morphology_decay_amp  morphology_slow_width  \
# 312           349.724700            877.126667                    108
# 313           643.304517           1130.861396                     60
# 314           924.757080            495.020049                    106
# 315           902.825283            583.667068                    129
# 316           389.887834            538.441750                     64
# 317           674.024164            358.826931                    138
# 318          2613.456701           2415.161046                    129
# 319          1633.756352           1445.252077                    291
# 320           670.941661            446.435481                    115
# 321           398.759206            240.757417                     50
