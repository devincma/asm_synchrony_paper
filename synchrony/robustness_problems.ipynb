# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
SYNCHRONY_ROBUSTNESS_DIRECTORY = "../../Data/synchrony/all/robustness"
SYNCHRONY_BROADBAND_DIRECTORY = "../../Data/synchrony/all/broadband"
PATIENT_IDS = [143, 182, 199]

# %% [markdown]
# ## Is it broadband problem?

# %%
for patient_id in PATIENT_IDS:
    file = os.path.join(SYNCHRONY_BROADBAND_DIRECTORY, f"HUP_{patient_id}.npy")
    data = np.load(file)
    plt.plot(data)
    plt.show()
