# %%
import os
import numpy as np
import pandas as pd

# %%
og_tables_dir = "../../cnt-data/giant_new_tables"

patient_ids = []

# Iterate through all csv files in og_tables_dir, print out the file name
for file in os.listdir(og_tables_dir):
    if file.endswith(".csv"):
        # Extract HUP_{patient_id}.csv
        patient_id = int(file.split("_")[1].split(".")[0])
        patient_ids.append(patient_id)

# %%
# Example frequency band names
band_names = ["delta", "theta", "alpha", "beta", "gamma"]

# %%
bandpower_dir = "../../cnt-data/bandpower"
synchrony_dir = "../../cnt-data/synchrony/all/broadband"

# %%
for patient_id in patient_ids:
    # Construct the file path for the bandpower and synchrony files
    bandpower_file = f"{bandpower_dir}/HUP_{patient_id}.npy"
    synchrony_file = f"{synchrony_dir}/HUP_{patient_id}.npy"

    # Check if the bandpower file exists
    if not os.path.exists(bandpower_file):
        print(f"Bandpower file for patient {patient_id} not found. Skipping.")
        continue

    # Load the bandpower npy file
    bandpower = np.load(bandpower_file)
    # Load the synchrony npy file
    synchrony = np.load(synchrony_file)

    # Take the mean across the 3rd axis
    bandpower_avg = np.mean(bandpower, axis=2)

    bandpower_len = bandpower.shape[1]
    synchrony_len = synchrony.shape[0]

    # Print bandpower_len and synchrony_len and synchrony_len/bandpower_len
    print(
        f"Patient {patient_id}: bandpower_len={bandpower_len}, synchrony_len={synchrony_len}, synchrony_len/bandpower_len={synchrony_len/bandpower_len}"
    )

    # Load the original table
    og_table = pd.read_csv(f"{og_tables_dir}/HUP_{patient_id}.csv")

    # From the first column where synchrony_broadband is not null, add the bandpower values
    # to the table in the columns "bandpower_{band}" where band is the band name
# Out:
# Patient 219: bandpower_len=170, synchrony_len=2550, synchrony_len/bandpower_len=15.0
# Patient 225: bandpower_len=384, synchrony_len=5760, synchrony_len/bandpower_len=15.0
# Patient 184: bandpower_len=340, synchrony_len=5100, synchrony_len/bandpower_len=15.0
# Patient 190: bandpower_len=660, synchrony_len=9900, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 147 not found. Skipping.
# Bandpower file for patient 153 not found. Skipping.
# Bandpower file for patient 152 not found. Skipping.
# Patient 146: bandpower_len=776, synchrony_len=11640, synchrony_len/bandpower_len=15.0
# Patient 191: bandpower_len=480, synchrony_len=7200, synchrony_len/bandpower_len=15.0
# Patient 185: bandpower_len=512, synchrony_len=7680, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 193 not found. Skipping.
# Patient 187: bandpower_len=402, synchrony_len=6030, synchrony_len/bandpower_len=15.0
# Patient 178: bandpower_len=418, synchrony_len=6270, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 150 not found. Skipping.
# Patient 144: bandpower_len=374, synchrony_len=5610, synchrony_len/bandpower_len=15.0
# Patient 145: bandpower_len=572, synchrony_len=8580, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 151 not found. Skipping.
# Bandpower file for patient 179 not found. Skipping.
# Patient 186: bandpower_len=480, synchrony_len=7200, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 192 not found. Skipping.
# Patient 223: bandpower_len=318, synchrony_len=4770, synchrony_len/bandpower_len=15.0
# Patient 196: bandpower_len=418, synchrony_len=6270, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 182 not found. Skipping.
# Patient 155: bandpower_len=396, synchrony_len=5940, synchrony_len/bandpower_len=15.0
# Patient 141: bandpower_len=340, synchrony_len=5100, synchrony_len/bandpower_len=15.0
# Patient 169: bandpower_len=470, synchrony_len=7050, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 168 not found. Skipping.
# Bandpower file for patient 140 not found. Skipping.
# Patient 154: bandpower_len=186, synchrony_len=2790, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 181 not found. Skipping.
# Patient 142: bandpower_len=670, synchrony_len=10050, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 156 not found. Skipping.
# Patient 157: bandpower_len=428, synchrony_len=6420, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 143 not found. Skipping.
# Patient 180: bandpower_len=382, synchrony_len=5730, synchrony_len/bandpower_len=15.0
# Patient 221: bandpower_len=324, synchrony_len=4860, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 137 not found. Skipping.
# Patient 139: bandpower_len=566, synchrony_len=8490, synchrony_len/bandpower_len=15.0
# Patient 138: bandpower_len=392, synchrony_len=5880, synchrony_len/bandpower_len=15.0
# Patient 210: bandpower_len=568, synchrony_len=8520, synchrony_len/bandpower_len=15.0
# Patient 204: bandpower_len=292, synchrony_len=4380, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 199 not found. Skipping.
# Patient 166: bandpower_len=374, synchrony_len=5610, synchrony_len/bandpower_len=15.0
# Patient 172: bandpower_len=526, synchrony_len=7890, synchrony_len/bandpower_len=15.0
# Patient 173: bandpower_len=522, synchrony_len=7830, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 167 not found. Skipping.
# Patient 205: bandpower_len=442, synchrony_len=6630, synchrony_len/bandpower_len=15.0
# Patient 207: bandpower_len=706, synchrony_len=10590, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 159 not found. Skipping.
# Patient 171: bandpower_len=620, synchrony_len=9300, synchrony_len/bandpower_len=15.0
# Patient 165: bandpower_len=966, synchrony_len=14490, synchrony_len/bandpower_len=15.0
# Patient 164: bandpower_len=370, synchrony_len=5550, synchrony_len/bandpower_len=15.0
# Patient 170: bandpower_len=330, synchrony_len=4950, synchrony_len/bandpower_len=15.0
# Patient 158: bandpower_len=388, synchrony_len=5820, synchrony_len/bandpower_len=15.0
# Patient 206: bandpower_len=750, synchrony_len=11250, synchrony_len/bandpower_len=15.0
# Patient 202: bandpower_len=428, synchrony_len=6420, synchrony_len/bandpower_len=15.0
# Patient 174: bandpower_len=568, synchrony_len=8520, synchrony_len/bandpower_len=15.0
# Patient 160: bandpower_len=718, synchrony_len=10770, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 148 not found. Skipping.
# Bandpower file for patient 149 not found. Skipping.
# Patient 161: bandpower_len=626, synchrony_len=9390, synchrony_len/bandpower_len=15.0
# Patient 175: bandpower_len=144, synchrony_len=2160, synchrony_len/bandpower_len=15.0
# Patient 217: bandpower_len=844, synchrony_len=12660, synchrony_len/bandpower_len=15.0
# Patient 188: bandpower_len=326, synchrony_len=4890, synchrony_len/bandpower_len=15.0
# Patient 163: bandpower_len=636, synchrony_len=9540, synchrony_len/bandpower_len=15.0
# Patient 177: bandpower_len=432, synchrony_len=6480, synchrony_len/bandpower_len=15.0
# Bandpower file for patient 162 not found. Skipping.
# Patient 189: bandpower_len=200, synchrony_len=3000, synchrony_len/bandpower_len=15.0

# %%
target_dir = "../../cnt-data/giant_new_tables_with_bandpower"
os.makedirs(target_dir, exist_ok=True)

band_names = ["delta", "theta", "alpha", "beta", "gamma"]

for patient_id in patient_ids:
    print(f"Processing patient {patient_id}")
    bandpower_file = f"{bandpower_dir}/HUP_{patient_id}.npy"
    synchrony_file = f"{synchrony_dir}/HUP_{patient_id}.npy"

    if not os.path.exists(bandpower_file):
        # print(f"Bandpower file for patient {patient_id} not found. Skipping.")
        continue

    # Load arrays
    bandpower = np.load(
        bandpower_file
    )  # shape might be (5, n*15, #channels) or similar
    synchrony = np.load(
        synchrony_file
    )  # shape (n,) (where each entry is a 2-min block)

    # Average over third axis if needed
    bandpower_avg = np.mean(bandpower, axis=2)  # now shape (5, n*15), for example

    print(np.count_nonzero(~np.isnan(bandpower_avg[1])))

    # Print the number of non-null values in synchrony
    print(np.count_nonzero(~np.isnan(synchrony)))

    bandpower_len = bandpower_avg.shape[
        1
    ]  # total number of 2-min segments in bandpower
    synchrony_len = synchrony.shape[0]  # total number of 2-min segments in synchrony

    # print(
    #     f"Patient {patient_id}: bandpower_len={bandpower_len}, "
    #     f"synchrony_len={synchrony_len}, "
    #     f"ratio={synchrony_len/bandpower_len:.2f}"
    # )

    # Read original CSV
    og_table_path = f"{og_tables_dir}/HUP_{patient_id}.csv"
    og_table = pd.read_csv(og_table_path)

    # Find the first valid row for synchrony_broadband
    first_non_null_idx = og_table["synchrony_broadband"].first_valid_index()
    if first_non_null_idx is None:
        print(f"No valid synchrony_broadband data for patient {patient_id}. Skipping.")
        continue

    # Add NaN columns for bandpower
    for band_name in band_names:
        og_table[f"bandpower_{band_name}"] = np.nan

    # We assume each 30-minute chunk = 15 two-minute segments
    chunk_len = 15

    # Figure out how many 30-min chunks exist in both bandpower and synchrony
    # If bandpower_len = n * 15, then n = bandpower_len // 15 is the number of 30-min chunks.
    n_chunks_bandpower = bandpower_len // chunk_len
    # If synchrony_len = n, that might also imply n 30-minute chunks,
    # or it might be the total # of 2-min segments.
    # Typically, you'd store 1 synchrony value per 2-min block, so n chunks is actually n/15
    # 30-min blocks. But let's assume your code wants to do it chunk by chunk (≥ 1 chunk).
    # If you truly have 1 synchrony value per 2-min block, then the number of 30-min chunks
    # from synchrony’s perspective is synchrony_len // 15.
    # However, your original code used synchrony_len directly as n_chunks.
    # Let's be safe and consider the 30-min-chunk count from synchrony’s perspective:
    n_chunks_synchrony = synchrony_len // 15

    # The actual number of chunks we can fill is the smaller of the two
    n_chunks = min(n_chunks_bandpower, n_chunks_synchrony)

    # Fill the columns
    for chunk_i in range(n_chunks):
        for band_i, band_name in enumerate(band_names):
            # pick the leftmost column for this chunk
            val = bandpower_avg[band_i, chunk_i * chunk_len]

            start_idx = first_non_null_idx + (chunk_i * chunk_len)
            end_idx = start_idx + chunk_len

            if start_idx >= len(og_table):
                break
            end_idx = min(end_idx, len(og_table))

            og_table.loc[start_idx : end_idx - 1, f"bandpower_{band_name}"] = val

    # Save
    out_path = os.path.join(target_dir, f"HUP_{patient_id}.csv")
    og_table.to_csv(out_path, index=False)
    # print(f"Saved updated table for patient {patient_id} to: {out_path}")
# Out:
# Processing patient 219
# 3
# 1786
# Processing patient 225
# 7
# 2498
# Processing patient 184
# 2
# 4009
# Processing patient 190
# 73
# 9165
# Processing patient 147
# Processing patient 153
# Processing patient 152
# Processing patient 146
# 13
# 10243
# Processing patient 191
# 0
# 6115
# Processing patient 185
# 153
# 6340
# Processing patient 193
# Processing patient 187
# 10
# 5089
# Processing patient 178
# 277
# 5509
# Processing patient 150
# Processing patient 144
# 0
# 4890
# Processing patient 145
# 0
# 7769
# Processing patient 151
# Processing patient 179
# Processing patient 186
# 26
# 5990
# Processing patient 192
# Processing patient 223
# 0
# 4051
# Processing patient 196
# 0
# 4992
# Processing patient 182
# Processing patient 155
# 1
# 5127
# Processing patient 141
# 0
# 4342
# Processing patient 169
# 0
# 5871
# Processing patient 168
# Processing patient 140
# Processing patient 154
# 1
# 2064
# Processing patient 181
# Processing patient 142
# 34
# 9277
# Processing patient 156
# Processing patient 157
# 4
# 5631
# Processing patient 143
# Processing patient 180
# 12
# 4627
# Processing patient 221
# 4
# 3993
# Processing patient 137
# Processing patient 139
# 0
# 7685
# Processing patient 138
# 37
# 5019
# Processing patient 210
# 7
# 7185
# Processing patient 204
# 32
# 3472
# Processing patient 199
# Processing patient 166
# 0
# 4876
# Processing patient 172
# 7
# 6753
# Processing patient 173
# 0
# 7054
# Processing patient 167
# Processing patient 205
# 30
# 5237
# Processing patient 207
# 0
# 9286
# Processing patient 159
# Processing patient 171
# 1
# 7916
# Processing patient 165
# 156
# 12398
# Processing patient 164
# 267
# 4836
# Processing patient 170
# 3
# 4191
# Processing patient 158
# 0
# 5044
# Processing patient 206
# 0
# 9895
# Processing patient 202
# 172
# 4984
# Processing patient 174
# 1
# 7316
# Processing patient 160
# 42
# 10029
# Processing patient 148
# Processing patient 149
# Processing patient 161
# 0
# 8375
# Processing patient 175
# 0
# 1437
# Processing patient 217
# 2
# 11775
# Processing patient 188
# 2
# 4141
# Processing patient 163
# 19
# 8767
# Processing patient 177
# 1
# 5645
# Processing patient 162
# Processing patient 189
# 7
# 2130

# %%
# count the number of non-null values in bandpower_avg[0]
print(np.count_nonzero(~np.isnan(bandpower_avg[0])))
# Out:
# 7

# %%
# Example frequency band names
band_names = ["delta", "theta", "alpha", "beta", "gamma"]

for patient_id in patient_ids:
    bandpower_file = f"{bandpower_dir}/HUP_{patient_id}.npy"
    synchrony_file = f"{synchrony_dir}/HUP_{patient_id}.npy"

    # Check if the bandpower file exists
    if not os.path.exists(bandpower_file):
        # print(f"[Patient {patient_id}] bandpower file not found. Skipping.")
        continue

    # Load bandpower (shape might be (5, n*15, X) depending on your data)
    bandpower = np.load(bandpower_file)
    # If your bandpower has shape (5, n*15, n_channels), for instance,
    # we average across the third axis to get shape (5, n*15):
    bandpower_avg = np.mean(bandpower, axis=2)

    # Print overall shape info
    print(f"[Patient {patient_id}] bandpower_avg shape: {bandpower_avg.shape}")

    # For each band (row in bandpower_avg), count non-null values
    for band_i, band_name in enumerate(band_names):
        # Count how many entries are not NaN
        nonnull_count = np.count_nonzero(~np.isnan(bandpower_avg[band_i]))
        print(f"  - {band_name}: {nonnull_count} non-null values")

    print("-" * 40)  # separator for readability
# Out:
# [Patient 219] bandpower_avg shape: (5, 170)
#   - delta: 3 non-null values
#   - theta: 3 non-null values
#   - alpha: 3 non-null values
#   - beta: 3 non-null values
#   - gamma: 3 non-null values
# ----------------------------------------
# [Patient 225] bandpower_avg shape: (5, 384)
#   - delta: 7 non-null values
#   - theta: 7 non-null values
#   - alpha: 7 non-null values
#   - beta: 7 non-null values
#   - gamma: 7 non-null values
# ----------------------------------------
# [Patient 184] bandpower_avg shape: (5, 340)
#   - delta: 2 non-null values
#   - theta: 2 non-null values
#   - alpha: 2 non-null values
#   - beta: 2 non-null values
#   - gamma: 2 non-null values
# ----------------------------------------
# [Patient 190] bandpower_avg shape: (5, 660)
#   - delta: 73 non-null values
#   - theta: 73 non-null values
#   - alpha: 73 non-null values
#   - beta: 73 non-null values
#   - gamma: 73 non-null values
# ----------------------------------------
# [Patient 146] bandpower_avg shape: (5, 776)
#   - delta: 13 non-null values
#   - theta: 13 non-null values
#   - alpha: 13 non-null values
#   - beta: 13 non-null values
#   - gamma: 13 non-null values
# ----------------------------------------
# [Patient 191] bandpower_avg shape: (5, 480)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 185] bandpower_avg shape: (5, 512)
#   - delta: 153 non-null values
#   - theta: 153 non-null values
#   - alpha: 153 non-null values
#   - beta: 153 non-null values
#   - gamma: 153 non-null values
# ----------------------------------------
# [Patient 187] bandpower_avg shape: (5, 402)
#   - delta: 10 non-null values
#   - theta: 10 non-null values
#   - alpha: 10 non-null values
#   - beta: 10 non-null values
#   - gamma: 10 non-null values
# ----------------------------------------
# [Patient 178] bandpower_avg shape: (5, 418)
#   - delta: 277 non-null values
#   - theta: 277 non-null values
#   - alpha: 277 non-null values
#   - beta: 277 non-null values
#   - gamma: 277 non-null values
# ----------------------------------------
# [Patient 144] bandpower_avg shape: (5, 374)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 145] bandpower_avg shape: (5, 572)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 186] bandpower_avg shape: (5, 480)
#   - delta: 26 non-null values
#   - theta: 26 non-null values
#   - alpha: 26 non-null values
#   - beta: 26 non-null values
#   - gamma: 26 non-null values
# ----------------------------------------
# [Patient 223] bandpower_avg shape: (5, 318)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 196] bandpower_avg shape: (5, 418)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 155] bandpower_avg shape: (5, 396)
#   - delta: 1 non-null values
#   - theta: 1 non-null values
#   - alpha: 1 non-null values
#   - beta: 1 non-null values
#   - gamma: 1 non-null values
# ----------------------------------------
# [Patient 141] bandpower_avg shape: (5, 340)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 169] bandpower_avg shape: (5, 470)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 154] bandpower_avg shape: (5, 186)
#   - delta: 1 non-null values
#   - theta: 1 non-null values
#   - alpha: 1 non-null values
#   - beta: 1 non-null values
#   - gamma: 1 non-null values
# ----------------------------------------
# [Patient 142] bandpower_avg shape: (5, 670)
#   - delta: 34 non-null values
#   - theta: 34 non-null values
#   - alpha: 34 non-null values
#   - beta: 34 non-null values
#   - gamma: 34 non-null values
# ----------------------------------------
# [Patient 157] bandpower_avg shape: (5, 428)
#   - delta: 4 non-null values
#   - theta: 4 non-null values
#   - alpha: 4 non-null values
#   - beta: 4 non-null values
#   - gamma: 4 non-null values
# ----------------------------------------
# [Patient 180] bandpower_avg shape: (5, 382)
#   - delta: 12 non-null values
#   - theta: 12 non-null values
#   - alpha: 12 non-null values
#   - beta: 12 non-null values
#   - gamma: 12 non-null values
# ----------------------------------------
# [Patient 221] bandpower_avg shape: (5, 324)
#   - delta: 4 non-null values
#   - theta: 4 non-null values
#   - alpha: 4 non-null values
#   - beta: 4 non-null values
#   - gamma: 4 non-null values
# ----------------------------------------
# [Patient 139] bandpower_avg shape: (5, 566)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 138] bandpower_avg shape: (5, 392)
#   - delta: 37 non-null values
#   - theta: 37 non-null values
#   - alpha: 37 non-null values
#   - beta: 37 non-null values
#   - gamma: 37 non-null values
# ----------------------------------------
# [Patient 210] bandpower_avg shape: (5, 568)
#   - delta: 7 non-null values
#   - theta: 7 non-null values
#   - alpha: 7 non-null values
#   - beta: 7 non-null values
#   - gamma: 7 non-null values
# ----------------------------------------
# [Patient 204] bandpower_avg shape: (5, 292)
#   - delta: 32 non-null values
#   - theta: 32 non-null values
#   - alpha: 32 non-null values
#   - beta: 32 non-null values
#   - gamma: 32 non-null values
# ----------------------------------------
# [Patient 166] bandpower_avg shape: (5, 374)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 172] bandpower_avg shape: (5, 526)
#   - delta: 7 non-null values
#   - theta: 7 non-null values
#   - alpha: 7 non-null values
#   - beta: 7 non-null values
#   - gamma: 7 non-null values
# ----------------------------------------
# [Patient 173] bandpower_avg shape: (5, 522)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 205] bandpower_avg shape: (5, 442)
#   - delta: 30 non-null values
#   - theta: 30 non-null values
#   - alpha: 30 non-null values
#   - beta: 30 non-null values
#   - gamma: 30 non-null values
# ----------------------------------------
# [Patient 207] bandpower_avg shape: (5, 706)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 171] bandpower_avg shape: (5, 620)
#   - delta: 1 non-null values
#   - theta: 1 non-null values
#   - alpha: 1 non-null values
#   - beta: 1 non-null values
#   - gamma: 1 non-null values
# ----------------------------------------
# [Patient 165] bandpower_avg shape: (5, 966)
#   - delta: 156 non-null values
#   - theta: 156 non-null values
#   - alpha: 156 non-null values
#   - beta: 156 non-null values
#   - gamma: 156 non-null values
# ----------------------------------------
# [Patient 164] bandpower_avg shape: (5, 370)
#   - delta: 267 non-null values
#   - theta: 267 non-null values
#   - alpha: 267 non-null values
#   - beta: 267 non-null values
#   - gamma: 267 non-null values
# ----------------------------------------
# [Patient 170] bandpower_avg shape: (5, 330)
#   - delta: 3 non-null values
#   - theta: 3 non-null values
#   - alpha: 3 non-null values
#   - beta: 3 non-null values
#   - gamma: 3 non-null values
# ----------------------------------------
# [Patient 158] bandpower_avg shape: (5, 388)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 206] bandpower_avg shape: (5, 750)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 202] bandpower_avg shape: (5, 428)
#   - delta: 172 non-null values
#   - theta: 172 non-null values
#   - alpha: 172 non-null values
#   - beta: 172 non-null values
#   - gamma: 172 non-null values
# ----------------------------------------
# [Patient 174] bandpower_avg shape: (5, 568)
#   - delta: 1 non-null values
#   - theta: 1 non-null values
#   - alpha: 1 non-null values
#   - beta: 1 non-null values
#   - gamma: 1 non-null values
# ----------------------------------------
# [Patient 160] bandpower_avg shape: (5, 718)
#   - delta: 42 non-null values
#   - theta: 42 non-null values
#   - alpha: 42 non-null values
#   - beta: 42 non-null values
#   - gamma: 42 non-null values
# ----------------------------------------
# [Patient 161] bandpower_avg shape: (5, 626)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 175] bandpower_avg shape: (5, 144)
#   - delta: 0 non-null values
#   - theta: 0 non-null values
#   - alpha: 0 non-null values
#   - beta: 0 non-null values
#   - gamma: 0 non-null values
# ----------------------------------------
# [Patient 217] bandpower_avg shape: (5, 844)
#   - delta: 2 non-null values
#   - theta: 2 non-null values
#   - alpha: 2 non-null values
#   - beta: 2 non-null values
#   - gamma: 2 non-null values
# ----------------------------------------
# [Patient 188] bandpower_avg shape: (5, 326)
#   - delta: 2 non-null values
#   - theta: 2 non-null values
#   - alpha: 2 non-null values
#   - beta: 2 non-null values
#   - gamma: 2 non-null values
# ----------------------------------------
# [Patient 163] bandpower_avg shape: (5, 636)
#   - delta: 19 non-null values
#   - theta: 19 non-null values
#   - alpha: 19 non-null values
#   - beta: 19 non-null values
#   - gamma: 19 non-null values
# ----------------------------------------
# [Patient 177] bandpower_avg shape: (5, 432)
#   - delta: 1 non-null values
#   - theta: 1 non-null values
#   - alpha: 1 non-null values
#   - beta: 1 non-null values
#   - gamma: 1 non-null values
# ----------------------------------------
# [Patient 189] bandpower_avg shape: (5, 200)
#   - delta: 7 non-null values
#   - theta: 7 non-null values
#   - alpha: 7 non-null values
#   - beta: 7 non-null values
#   - gamma: 7 non-null values
# ----------------------------------------
